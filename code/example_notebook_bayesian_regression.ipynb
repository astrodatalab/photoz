# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
import tensorflow_probability as tfp
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
#import data set
import numpy as np
mnist = tf.keras.datasets.mnist
import random
from tensorboard.plugins.hparams import api as hp
import datetime
from tensorflow import keras
from sklearn.model_selection import train_test_split
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
from sklearn import ensemble
from sklearn import linear_model
import tensorflow as tf
import tensorflow_probability as tfp
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
#import data set
import numpy as np
mnist = tf.keras.datasets.mnist
import random
from sklearn.model_selection import train_test_split
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
tfd = tfp.distributions

gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)



import tensorflow as tf
import tensorflow_probability as tfp
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from tensorboard.plugins.hparams import api as hp
import pandas as pd
#import data set
import numpy as np
mnist = tf.keras.datasets.mnist
import random
import datetime
from tensorflow import keras
from sklearn.model_selection import train_test_split
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

#import photoz data:
tfd = tfp.distributions
#from google.colab import files

from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()

photozdata = pd.read_csv('mnt/data/HSC/HSC_v3/trimmed_forced_forced2_spec_z_matched_online.csv')


filt = (photozdata['specz_redshift'] < 4) & (photozdata['specz_redshift'] > 0) & (photozdata['specz_redshift_err'] >0) \
       & (photozdata['specz_redshift_err'] < 1)
photozdata_subset = photozdata[filt]

photozdata = photozdata_subset
spectro_z = np.asarray(photozdata["specz_redshift"])
col1 = np.asarray(photozdata["g_cmodel_mag"])
col2 = np.asarray(photozdata["r_cmodel_mag"])
col3 = np.asarray(photozdata["i_cmodel_mag"])
col4 =np.asarray(photozdata["z_cmodel_mag"])
col5 = np.asarray(photozdata["y_cmodel_mag"])


photodata = {'col1':col1,
             'col2':col2,
             'col3':col3,
             'col4':col4,
             'col5':col5,
             'specz':spectro_z
}


df = pd.DataFrame(photodata)
photodata = df

photodata.replace(-99., np.nan, inplace=True)
photodata.replace(-99.9, np.nan, inplace=True)
photodata.replace(np.inf, np.nan, inplace=True)
photodata= photodata.dropna(how='any')
spectro_z = photodata['specz']
photodata = photodata.drop("specz", axis=1)



#normalize
photodata = min_max_scaler.fit_transform(photodata)
# Out:
# Num GPUs Available:  1
# 1 Physical GPUs, 1 Logical GPUs

# %%
#bin the redshift:

#bin_size = 0.05


x_train ,x_test,y_train,y_test = train_test_split(photodata,spectro_z,test_size=0.8)

# y_train = np.array(y_train)
# y_train = np.round(y_train/bin_size)
# y_test = np.array(y_test)
# y_test_original = y_test
# y_test = np.round(y_test/bin_size)


x_train = np.array(x_train)

x_test = np.array(x_test)


#bin_size = 0.12
def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean=0., stddev=0.1)
    loc = tf.Variable(
        initial_value=loc_norm(shape=(n,), dtype=dtype)
    )
    scale_norm = tf.random_normal_initializer(mean=-3., stddev=0.1)
    scale = tf.Variable(
        initial_value=scale_norm(shape=(n,), dtype=dtype)
    )
    return tf.concat([loc, scale], 0)
def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype=dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc=t, scale=1),
            reinterpreted_batch_ndims=1)),
    ])

def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype=dtype),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc=t[..., :n],
                       scale= 0.0000001*tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims=1)),
    ])


def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype=dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc=t, scale=1),
            reinterpreted_batch_ndims=1)),
    ])

def negative_loglikelihood(targets, estimated_distribution):
    return -estimated_distribution.log_prob(targets)



#bayesian network
input_ = tf.keras.layers.Input(shape=x_train.shape[1:])
hidden1 = tfp.layers.DenseVariational(200, activation='relu', input_shape=(5,),
                                make_posterior_fn=posterior_mean_field,
                                make_prior_fn=prior_trainable)(input_)
hidden2 = tfp.layers.DenseVariational(200, activation='relu', input_shape=(5,),
                                make_posterior_fn=posterior_mean_field,
                                make_prior_fn=prior_trainable)(hidden1)
hidden3 = tfp.layers.DenseVariational(200, activation='relu', input_shape=(5,),
                                make_posterior_fn=posterior_mean_field,
                                make_prior_fn=prior_trainable)(hidden2)
hidden4 = tfp.layers.DenseVariational(200, activation='relu', input_shape=(5,),
                                make_posterior_fn=posterior_mean_field,
                                make_prior_fn=prior_trainable)(hidden3)
concat = tf.keras.layers.Concatenate()([input_, hidden4])
#output = tf.keras.layers.Dense(1)(concat)
distribution_params = tf.keras.layers.Dense(units=2)(concat)
output = tfp.layers.IndependentNormal(1)(distribution_params)
model = tf.keras.Model(inputs=[input_], outputs=[output])


#non-bayesian network 
# input_ = tf.keras.layers.Input(shape=x_train.shape[1:])
# hidden1 = tf.keras.layers.Dense(500, activation="relu")(input_)
# hidden2 = tf.keras.layers.Dense(500, activation="relu")(hidden1)
# hidden3 = tf.keras.layers.Dense(500, activation="relu")(hidden2)
# hidden4 = tf.keras.layers.Dense(500, activation="relu")(hidden3)
# concat = tf.keras.layers.Concatenate()([input_, hidden4])
# output = tf.keras.layers.Dense(1)(concat)
# model = tf.keras.Model(inputs=[input_], outputs=[output])



#use this line for bayesian network
#model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

#use this line for non-bayesian network
#model.compile(optimizer='adam', loss='mean_absolute_error',metrics=[tf.keras.metrics.MeanAbsoluteError()])

model.compile(optimizer='adam', loss=negative_loglikelihood,metrics=[keras.metrics.RootMeanSquaredError()])

model.summary()

#history = model.fit(x_train,y_train,batch_size = 100, epochs=500,shuffle = True,verbose=1,validation_data=(x_test,y_test))
history = model.fit(x_train,y_train,batch_size=5000,epochs=200,shuffle = True,verbose=1,validation_data=(x_test,y_test))


predictions = model.predict(x_test)
#np.argmax(predictions[0])
photoz = []
for i in range(0,len(y_test)):
    #photoz.append(predictions[i]*bin_size)
    photoz.append(predictions[i])

# plt.scatter(y_test_original,photoz)
# #plt.title('Photo-z determination')
# plt.ylabel('spectro-z')
# plt.xlabel('photo-z')
# plt.show()



num_correct = 0
outliers = []
outlier_index = []
cat_outlier_index = []
#y_test = y_test * bin_size
for i in range(0,len(y_test)):

    #if abs(photoz[i] - (y_test[i])*bin_size) < 0.0001:
  
    outliers.append(abs(photoz[i] - y_test_original[i])/(1+y_test_original[i]))

    if outliers[i] > 0.15:
            outlier_index.append(i)


    if outliers[i] > 1:
            cat_outlier_index.append(i)



print("number of outliers: ", len(outlier_index), " out of ", len(y_test))
print("% of outliers: ", 100.0*len(outlier_index)/len(y_test))
print("number of catastrophic outliers: ", len(cat_outlier_index), " out of ", len(y_test))
print("% of catastrophic outliers: ", len(cat_outlier_index)/len(y_test))




plt.scatter(y_test_original,photoz, marker='+',color = 'black')
#plt.title('Photo-z determination')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([.18,1.6*2.4],[0,1.2*2.4], color='black')
plt.plot([0, 1.6 * 2.4], [.15, 2 * 2.4],color = 'black')
plt.show()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_variational_16 (DenseVari (None, 200)          3600        input_5[0][0]
# __________________________________________________________________________________________________
# dense_variational_17 (DenseVari (None, 200)          120600      dense_variational_16[0][0]
# __________________________________________________________________________________________________
# dense_variational_18 (DenseVari (None, 200)          120600      dense_variational_17[0][0]
# __________________________________________________________________________________________________
# dense_variational_19 (DenseVari (None, 200)          120600      dense_variational_18[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 205)          0           input_5[0][0]
#                                                                  dense_variational_19[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 2)            412         concatenate_4[0][0]
# __________________________________________________________________________________________________
# independent_normal_4 (Independe multiple             0           dense_4[0][0]
# ==================================================================================================
# Total params: 365,812
# Trainable params: 365,812
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/200
# 6/6 [==============================] - 2s 71ms/step - loss: 1902000.1250 - root_mean_squared_error: 1.1477 - val_loss: 1901863.1250 - val_root_mean_squared_error: 1.1365
# Epoch 2/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1901675.6250 - root_mean_squared_error: 1.1266 - val_loss: 1901354.5000 - val_root_mean_squared_error: 1.1166
# Epoch 3/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1901306.2500 - root_mean_squared_error: 1.1064 - val_loss: 1900907.2500 - val_root_mean_squared_error: 1.0965
# Epoch 4/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1900648.8750 - root_mean_squared_error: 1.0807 - val_loss: 1900578.6250 - val_root_mean_squared_error: 1.0784
# Epoch 5/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1900382.5000 - root_mean_squared_error: 1.0709 - val_loss: 1899897.2500 - val_root_mean_squared_error: 1.0568
# Epoch 6/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1899953.8750 - root_mean_squared_error: 1.0407 - val_loss: 1899573.2500 - val_root_mean_squared_error: 1.0381
# Epoch 7/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1899296.2500 - root_mean_squared_error: 1.0297 - val_loss: 1899070.3750 - val_root_mean_squared_error: 1.0186
# Epoch 8/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1898835.8750 - root_mean_squared_error: 0.9993 - val_loss: 1898673.1250 - val_root_mean_squared_error: 0.9991
# Epoch 9/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1898498.1250 - root_mean_squared_error: 0.9885 - val_loss: 1898189.1250 - val_root_mean_squared_error: 0.9749
# Epoch 10/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1897700.1250 - root_mean_squared_error: 0.9634 - val_loss: 1897727.2500 - val_root_mean_squared_error: 0.9497
# Epoch 11/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1897644.3750 - root_mean_squared_error: 0.9371 - val_loss: 1897219.5000 - val_root_mean_squared_error: 0.9260
# Epoch 12/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1897296.2500 - root_mean_squared_error: 0.9090 - val_loss: 1896766.6250 - val_root_mean_squared_error: 0.8949
# Epoch 13/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1896853.6250 - root_mean_squared_error: 0.8836 - val_loss: 1896443.3750 - val_root_mean_squared_error: 0.8726
# Epoch 14/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1896238.6250 - root_mean_squared_error: 0.8627 - val_loss: 1895915.1250 - val_root_mean_squared_error: 0.8497
# Epoch 15/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1895919.1250 - root_mean_squared_error: 0.8377 - val_loss: 1895448.5000 - val_root_mean_squared_error: 0.8290
# Epoch 16/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1895300.8750 - root_mean_squared_error: 0.8206 - val_loss: 1895018.1250 - val_root_mean_squared_error: 0.8153
# Epoch 17/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1894828.5000 - root_mean_squared_error: 0.7997 - val_loss: 1894618.1250 - val_root_mean_squared_error: 0.7977
# Epoch 18/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1894350.1250 - root_mean_squared_error: 0.7908 - val_loss: 1894106.2500 - val_root_mean_squared_error: 0.7858
# Epoch 19/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1893918.5000 - root_mean_squared_error: 0.7814 - val_loss: 1893662.7500 - val_root_mean_squared_error: 0.7781
# Epoch 20/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1893588.0000 - root_mean_squared_error: 0.7694 - val_loss: 1893257.3750 - val_root_mean_squared_error: 0.7707
# Epoch 21/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1893088.3750 - root_mean_squared_error: 0.7707 - val_loss: 1892838.0000 - val_root_mean_squared_error: 0.7649
# Epoch 22/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1892566.3750 - root_mean_squared_error: 0.7643 - val_loss: 1892366.0000 - val_root_mean_squared_error: 0.7649
# Epoch 23/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1892204.8750 - root_mean_squared_error: 0.7646 - val_loss: 1891860.7500 - val_root_mean_squared_error: 0.7638
# Epoch 24/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1891673.0000 - root_mean_squared_error: 0.7617 - val_loss: 1891501.7500 - val_root_mean_squared_error: 0.7634
# Epoch 25/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1891416.5000 - root_mean_squared_error: 0.7541 - val_loss: 1891017.1250 - val_root_mean_squared_error: 0.7638
# Epoch 26/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1890939.2500 - root_mean_squared_error: 0.7648 - val_loss: 1890684.0000 - val_root_mean_squared_error: 0.7630
# Epoch 27/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1890677.7500 - root_mean_squared_error: 0.7602 - val_loss: 1890134.5000 - val_root_mean_squared_error: 0.7663
# Epoch 28/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1890090.1250 - root_mean_squared_error: 0.7616 - val_loss: 1889687.3750 - val_root_mean_squared_error: 0.7624
# Epoch 29/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1889568.7500 - root_mean_squared_error: 0.7585 - val_loss: 1889223.2500 - val_root_mean_squared_error: 0.7638
# Epoch 30/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1889212.0000 - root_mean_squared_error: 0.7628 - val_loss: 1888874.6250 - val_root_mean_squared_error: 0.7628
# Epoch 31/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1888816.0000 - root_mean_squared_error: 0.7588 - val_loss: 1888401.0000 - val_root_mean_squared_error: 0.7624
# Epoch 32/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1888370.1250 - root_mean_squared_error: 0.7587 - val_loss: 1887947.3750 - val_root_mean_squared_error: 0.7622
# Epoch 33/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1887850.8750 - root_mean_squared_error: 0.7580 - val_loss: 1887606.3750 - val_root_mean_squared_error: 0.7611
# Epoch 34/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1887281.7500 - root_mean_squared_error: 0.7599 - val_loss: 1887130.6250 - val_root_mean_squared_error: 0.7607
# Epoch 35/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1887152.8750 - root_mean_squared_error: 0.7555 - val_loss: 1886741.3750 - val_root_mean_squared_error: 0.7616
# Epoch 36/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1886686.3750 - root_mean_squared_error: 0.7571 - val_loss: 1886353.8750 - val_root_mean_squared_error: 0.7579
# Epoch 37/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1885884.6250 - root_mean_squared_error: 0.7505 - val_loss: 1885895.6250 - val_root_mean_squared_error: 0.7595
# Epoch 38/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1885862.5000 - root_mean_squared_error: 0.7574 - val_loss: 1885420.6250 - val_root_mean_squared_error: 0.7617
# Epoch 39/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1885474.3750 - root_mean_squared_error: 0.7571 - val_loss: 1885081.5000 - val_root_mean_squared_error: 0.7602
# Epoch 40/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1884765.5000 - root_mean_squared_error: 0.7570 - val_loss: 1884697.1250 - val_root_mean_squared_error: 0.7642
# Epoch 41/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1884382.3750 - root_mean_squared_error: 0.7535 - val_loss: 1884264.8750 - val_root_mean_squared_error: 0.7637
# Epoch 42/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1883941.5000 - root_mean_squared_error: 0.7602 - val_loss: 1883817.6250 - val_root_mean_squared_error: 0.7616
# Epoch 43/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1883572.6250 - root_mean_squared_error: 0.7566 - val_loss: 1883326.5000 - val_root_mean_squared_error: 0.7621
# Epoch 44/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1883219.2500 - root_mean_squared_error: 0.7551 - val_loss: 1882908.2500 - val_root_mean_squared_error: 0.7611
# Epoch 45/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1882691.7500 - root_mean_squared_error: 0.7574 - val_loss: 1882591.1250 - val_root_mean_squared_error: 0.7621
# Epoch 46/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1882254.1250 - root_mean_squared_error: 0.7547 - val_loss: 1881982.7500 - val_root_mean_squared_error: 0.7581
# Epoch 47/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1882166.8750 - root_mean_squared_error: 0.7523 - val_loss: 1881571.3750 - val_root_mean_squared_error: 0.7593
# Epoch 48/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1881361.0000 - root_mean_squared_error: 0.7568 - val_loss: 1881385.6250 - val_root_mean_squared_error: 0.7613
# Epoch 49/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1881088.8750 - root_mean_squared_error: 0.7580 - val_loss: 1880767.5000 - val_root_mean_squared_error: 0.7613
# Epoch 50/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1880792.1250 - root_mean_squared_error: 0.7572 - val_loss: 1880459.3750 - val_root_mean_squared_error: 0.7582
# Epoch 51/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1880202.7500 - root_mean_squared_error: 0.7589 - val_loss: 1880034.8750 - val_root_mean_squared_error: 0.7583
# Epoch 52/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1879871.7500 - root_mean_squared_error: 0.7558 - val_loss: 1879719.5000 - val_root_mean_squared_error: 0.7604
# Epoch 53/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1879479.2500 - root_mean_squared_error: 0.7533 - val_loss: 1879219.6250 - val_root_mean_squared_error: 0.7591
# Epoch 54/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1878969.0000 - root_mean_squared_error: 0.7523 - val_loss: 1878865.0000 - val_root_mean_squared_error: 0.7593
# Epoch 55/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1878483.1250 - root_mean_squared_error: 0.7579 - val_loss: 1878445.7500 - val_root_mean_squared_error: 0.7581
# Epoch 56/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1878368.6250 - root_mean_squared_error: 0.7514 - val_loss: 1878022.7500 - val_root_mean_squared_error: 0.7612
# Epoch 57/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1877802.1250 - root_mean_squared_error: 0.7580 - val_loss: 1877674.5000 - val_root_mean_squared_error: 0.7582
# Epoch 58/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1877490.1250 - root_mean_squared_error: 0.7583 - val_loss: 1877178.8750 - val_root_mean_squared_error: 0.7597
# Epoch 59/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1877094.6250 - root_mean_squared_error: 0.7577 - val_loss: 1876769.0000 - val_root_mean_squared_error: 0.7598
# Epoch 60/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1876730.5000 - root_mean_squared_error: 0.7587 - val_loss: 1876362.0000 - val_root_mean_squared_error: 0.7598
# Epoch 61/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1876332.5000 - root_mean_squared_error: 0.7552 - val_loss: 1876005.1250 - val_root_mean_squared_error: 0.7594
# Epoch 62/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1875556.6250 - root_mean_squared_error: 0.7548 - val_loss: 1875697.5000 - val_root_mean_squared_error: 0.7594
# Epoch 63/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1875466.3750 - root_mean_squared_error: 0.7593 - val_loss: 1875236.2500 - val_root_mean_squared_error: 0.7603
# Epoch 64/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1875032.1250 - root_mean_squared_error: 0.7520 - val_loss: 1874820.5000 - val_root_mean_squared_error: 0.7604
# Epoch 65/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1874626.5000 - root_mean_squared_error: 0.7490 - val_loss: 1874386.3750 - val_root_mean_squared_error: 0.7632
# Epoch 66/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1874147.6250 - root_mean_squared_error: 0.7538 - val_loss: 1874008.2500 - val_root_mean_squared_error: 0.7604
# Epoch 67/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1873849.3750 - root_mean_squared_error: 0.7548 - val_loss: 1873542.5000 - val_root_mean_squared_error: 0.7597
# Epoch 68/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1873494.1250 - root_mean_squared_error: 0.7566 - val_loss: 1873147.5000 - val_root_mean_squared_error: 0.7617
# Epoch 69/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1873007.6250 - root_mean_squared_error: 0.7600 - val_loss: 1872816.5000 - val_root_mean_squared_error: 0.7613
# Epoch 70/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1872782.3750 - root_mean_squared_error: 0.7529 - val_loss: 1872467.6250 - val_root_mean_squared_error: 0.7578
# Epoch 71/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1872499.0000 - root_mean_squared_error: 0.7519 - val_loss: 1872026.8750 - val_root_mean_squared_error: 0.7588
# Epoch 72/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1871910.5000 - root_mean_squared_error: 0.7561 - val_loss: 1871608.0000 - val_root_mean_squared_error: 0.7589
# Epoch 73/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1871439.6250 - root_mean_squared_error: 0.7491 - val_loss: 1871186.6250 - val_root_mean_squared_error: 0.7592
# Epoch 74/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1871155.7500 - root_mean_squared_error: 0.7573 - val_loss: 1870909.3750 - val_root_mean_squared_error: 0.7570
# Epoch 75/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1870814.0000 - root_mean_squared_error: 0.7541 - val_loss: 1870533.1250 - val_root_mean_squared_error: 0.7591
# Epoch 76/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1870435.7500 - root_mean_squared_error: 0.7571 - val_loss: 1870002.5000 - val_root_mean_squared_error: 0.7578
# Epoch 77/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1870018.6250 - root_mean_squared_error: 0.7559 - val_loss: 1869673.7500 - val_root_mean_squared_error: 0.7579
# Epoch 78/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1869465.6250 - root_mean_squared_error: 0.7514 - val_loss: 1869278.7500 - val_root_mean_squared_error: 0.7578
# Epoch 79/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1869257.8750 - root_mean_squared_error: 0.7450 - val_loss: 1868955.6250 - val_root_mean_squared_error: 0.7597
# Epoch 80/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1868752.1250 - root_mean_squared_error: 0.7603 - val_loss: 1868519.8750 - val_root_mean_squared_error: 0.7582
# Epoch 81/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1868458.8750 - root_mean_squared_error: 0.7534 - val_loss: 1868148.8750 - val_root_mean_squared_error: 0.7587
# Epoch 82/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1868001.3750 - root_mean_squared_error: 0.7524 - val_loss: 1867852.1250 - val_root_mean_squared_error: 0.7598
# Epoch 83/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1867706.7500 - root_mean_squared_error: 0.7523 - val_loss: 1867435.6250 - val_root_mean_squared_error: 0.7585
# Epoch 84/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1867411.5000 - root_mean_squared_error: 0.7549 - val_loss: 1866993.3750 - val_root_mean_squared_error: 0.7559
# Epoch 85/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1866921.6250 - root_mean_squared_error: 0.7574 - val_loss: 1866574.3750 - val_root_mean_squared_error: 0.7593
# Epoch 86/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1866650.2500 - root_mean_squared_error: 0.7569 - val_loss: 1866278.7500 - val_root_mean_squared_error: 0.7608
# Epoch 87/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1866172.7500 - root_mean_squared_error: 0.7575 - val_loss: 1865952.3750 - val_root_mean_squared_error: 0.7612
# Epoch 88/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1865602.8750 - root_mean_squared_error: 0.7590 - val_loss: 1865522.8750 - val_root_mean_squared_error: 0.7597
# Epoch 89/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1865354.7500 - root_mean_squared_error: 0.7623 - val_loss: 1865243.2500 - val_root_mean_squared_error: 0.7627
# Epoch 90/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1865174.2500 - root_mean_squared_error: 0.7570 - val_loss: 1864763.6250 - val_root_mean_squared_error: 0.7624
# Epoch 91/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1864664.0000 - root_mean_squared_error: 0.7551 - val_loss: 1864297.2500 - val_root_mean_squared_error: 0.7602
# Epoch 92/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1864200.3750 - root_mean_squared_error: 0.7507 - val_loss: 1864043.7500 - val_root_mean_squared_error: 0.7587
# Epoch 93/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1863938.8750 - root_mean_squared_error: 0.7577 - val_loss: 1863665.3750 - val_root_mean_squared_error: 0.7592
# Epoch 94/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1863438.6250 - root_mean_squared_error: 0.7512 - val_loss: 1863291.3750 - val_root_mean_squared_error: 0.7563
# Epoch 95/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1863189.3750 - root_mean_squared_error: 0.7531 - val_loss: 1863011.0000 - val_root_mean_squared_error: 0.7591
# Epoch 96/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1862855.6250 - root_mean_squared_error: 0.7580 - val_loss: 1862598.3750 - val_root_mean_squared_error: 0.7609
# Epoch 97/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1862380.1250 - root_mean_squared_error: 0.7548 - val_loss: 1862242.2500 - val_root_mean_squared_error: 0.7604
# Epoch 98/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1861990.7500 - root_mean_squared_error: 0.7594 - val_loss: 1861760.0000 - val_root_mean_squared_error: 0.7633
# Epoch 99/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1861754.6250 - root_mean_squared_error: 0.7605 - val_loss: 1861399.7500 - val_root_mean_squared_error: 0.7632
# Epoch 100/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1861380.8750 - root_mean_squared_error: 0.7617 - val_loss: 1861119.7500 - val_root_mean_squared_error: 0.7641
# Epoch 101/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1860934.5000 - root_mean_squared_error: 0.7644 - val_loss: 1860827.0000 - val_root_mean_squared_error: 0.7638
# Epoch 102/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1860410.8750 - root_mean_squared_error: 0.7535 - val_loss: 1860400.3750 - val_root_mean_squared_error: 0.7594
# Epoch 103/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1860058.0000 - root_mean_squared_error: 0.7558 - val_loss: 1859949.0000 - val_root_mean_squared_error: 0.7619
# Epoch 104/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1859916.3750 - root_mean_squared_error: 0.7550 - val_loss: 1859598.7500 - val_root_mean_squared_error: 0.7556
# Epoch 105/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1859504.0000 - root_mean_squared_error: 0.7475 - val_loss: 1859236.0000 - val_root_mean_squared_error: 0.7554
# Epoch 106/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1859218.5000 - root_mean_squared_error: 0.7503 - val_loss: 1859008.5000 - val_root_mean_squared_error: 0.7549
# Epoch 107/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1858833.5000 - root_mean_squared_error: 0.7488 - val_loss: 1858535.7500 - val_root_mean_squared_error: 0.7577
# Epoch 108/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1858441.2500 - root_mean_squared_error: 0.7501 - val_loss: 1858095.8750 - val_root_mean_squared_error: 0.7608
# Epoch 109/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1858093.6250 - root_mean_squared_error: 0.7594 - val_loss: 1857851.2500 - val_root_mean_squared_error: 0.7627
# Epoch 110/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1857610.0000 - root_mean_squared_error: 0.7624 - val_loss: 1857561.1250 - val_root_mean_squared_error: 0.7629
# Epoch 111/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1857385.5000 - root_mean_squared_error: 0.7590 - val_loss: 1857081.2500 - val_root_mean_squared_error: 0.7610
# Epoch 112/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1856985.0000 - root_mean_squared_error: 0.7537 - val_loss: 1856817.3750 - val_root_mean_squared_error: 0.7584
# Epoch 113/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1856777.5000 - root_mean_squared_error: 0.7489 - val_loss: 1856445.3750 - val_root_mean_squared_error: 0.7574
# Epoch 114/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1856267.0000 - root_mean_squared_error: 0.7534 - val_loss: 1856108.8750 - val_root_mean_squared_error: 0.7575
# Epoch 115/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1855833.2500 - root_mean_squared_error: 0.7536 - val_loss: 1855712.2500 - val_root_mean_squared_error: 0.7562
# Epoch 116/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1855626.3750 - root_mean_squared_error: 0.7560 - val_loss: 1855314.5000 - val_root_mean_squared_error: 0.7558
# Epoch 117/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1855173.5000 - root_mean_squared_error: 0.7505 - val_loss: 1855026.1250 - val_root_mean_squared_error: 0.7597
# Epoch 118/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1855050.1250 - root_mean_squared_error: 0.7538 - val_loss: 1854686.7500 - val_root_mean_squared_error: 0.7538
# Epoch 119/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1854576.3750 - root_mean_squared_error: 0.7574 - val_loss: 1854276.5000 - val_root_mean_squared_error: 0.7549
# Epoch 120/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1853977.7500 - root_mean_squared_error: 0.7555 - val_loss: 1853985.8750 - val_root_mean_squared_error: 0.7553
# Epoch 121/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1853849.8750 - root_mean_squared_error: 0.7508 - val_loss: 1853597.3750 - val_root_mean_squared_error: 0.7546
# Epoch 122/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1853405.1250 - root_mean_squared_error: 0.7493 - val_loss: 1853234.7500 - val_root_mean_squared_error: 0.7549
# Epoch 123/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1853146.7500 - root_mean_squared_error: 0.7513 - val_loss: 1852943.2500 - val_root_mean_squared_error: 0.7523
# Epoch 124/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1852842.8750 - root_mean_squared_error: 0.7486 - val_loss: 1852549.5000 - val_root_mean_squared_error: 0.7540
# Epoch 125/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1852357.7500 - root_mean_squared_error: 0.7508 - val_loss: 1852216.1250 - val_root_mean_squared_error: 0.7518
# Epoch 126/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1851978.8750 - root_mean_squared_error: 0.7461 - val_loss: 1851852.3750 - val_root_mean_squared_error: 0.7474
# Epoch 127/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1851799.0000 - root_mean_squared_error: 0.7443 - val_loss: 1851496.5000 - val_root_mean_squared_error: 0.7459
# Epoch 128/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1851458.5000 - root_mean_squared_error: 0.7451 - val_loss: 1851256.1250 - val_root_mean_squared_error: 0.7502
# Epoch 129/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1851232.8750 - root_mean_squared_error: 0.7417 - val_loss: 1850761.6250 - val_root_mean_squared_error: 0.7529
# Epoch 130/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1850659.8750 - root_mean_squared_error: 0.7417 - val_loss: 1850473.1250 - val_root_mean_squared_error: 0.7534
# Epoch 131/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1850370.7500 - root_mean_squared_error: 0.7481 - val_loss: 1850177.3750 - val_root_mean_squared_error: 0.7523
# Epoch 132/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1850193.8750 - root_mean_squared_error: 0.7513 - val_loss: 1849802.3750 - val_root_mean_squared_error: 0.7526
# Epoch 133/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1849566.2500 - root_mean_squared_error: 0.7489 - val_loss: 1849473.2500 - val_root_mean_squared_error: 0.7561
# Epoch 134/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1849472.7500 - root_mean_squared_error: 0.7575 - val_loss: 1849124.5000 - val_root_mean_squared_error: 0.7576
# Epoch 135/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1848986.3750 - root_mean_squared_error: 0.7505 - val_loss: 1848822.2500 - val_root_mean_squared_error: 0.7576
# Epoch 136/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1848657.6250 - root_mean_squared_error: 0.7536 - val_loss: 1848436.6250 - val_root_mean_squared_error: 0.7554
# Epoch 137/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1848512.0000 - root_mean_squared_error: 0.7523 - val_loss: 1848041.7500 - val_root_mean_squared_error: 0.7522
# Epoch 138/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1847927.8750 - root_mean_squared_error: 0.7555 - val_loss: 1847810.5000 - val_root_mean_squared_error: 0.7597
# Epoch 139/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1847619.8750 - root_mean_squared_error: 0.7544 - val_loss: 1847396.7500 - val_root_mean_squared_error: 0.7588
# Epoch 140/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1847502.1250 - root_mean_squared_error: 0.7522 - val_loss: 1847136.8750 - val_root_mean_squared_error: 0.7595
# Epoch 141/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1847123.8750 - root_mean_squared_error: 0.7569 - val_loss: 1846777.8750 - val_root_mean_squared_error: 0.7562
# Epoch 142/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1846668.6250 - root_mean_squared_error: 0.7513 - val_loss: 1846538.3750 - val_root_mean_squared_error: 0.7523
# Epoch 143/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1846271.0000 - root_mean_squared_error: 0.7454 - val_loss: 1846111.7500 - val_root_mean_squared_error: 0.7509
# Epoch 144/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1846161.8750 - root_mean_squared_error: 0.7458 - val_loss: 1845694.1250 - val_root_mean_squared_error: 0.7503
# Epoch 145/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1845606.8750 - root_mean_squared_error: 0.7476 - val_loss: 1845419.0000 - val_root_mean_squared_error: 0.7482
# Epoch 146/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1845403.1250 - root_mean_squared_error: 0.7460 - val_loss: 1845107.2500 - val_root_mean_squared_error: 0.7527
# Epoch 147/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1844938.7500 - root_mean_squared_error: 0.7492 - val_loss: 1844822.3750 - val_root_mean_squared_error: 0.7514
# Epoch 148/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1844756.6250 - root_mean_squared_error: 0.7518 - val_loss: 1844554.2500 - val_root_mean_squared_error: 0.7553
# Epoch 149/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1844484.6250 - root_mean_squared_error: 0.7499 - val_loss: 1844237.5000 - val_root_mean_squared_error: 0.7544
# Epoch 150/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1843991.3750 - root_mean_squared_error: 0.7529 - val_loss: 1843818.8750 - val_root_mean_squared_error: 0.7558
# Epoch 151/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1843550.0000 - root_mean_squared_error: 0.7542 - val_loss: 1843493.6250 - val_root_mean_squared_error: 0.7572
# Epoch 152/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1843566.3750 - root_mean_squared_error: 0.7547 - val_loss: 1843188.0000 - val_root_mean_squared_error: 0.7561
# Epoch 153/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1842899.1250 - root_mean_squared_error: 0.7539 - val_loss: 1842879.0000 - val_root_mean_squared_error: 0.7569
# Epoch 154/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1842650.1250 - root_mean_squared_error: 0.7517 - val_loss: 1842579.8750 - val_root_mean_squared_error: 0.7542
# Epoch 155/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1842273.5000 - root_mean_squared_error: 0.7500 - val_loss: 1842099.8750 - val_root_mean_squared_error: 0.7534
# Epoch 156/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1842152.7500 - root_mean_squared_error: 0.7521 - val_loss: 1841853.5000 - val_root_mean_squared_error: 0.7521
# Epoch 157/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1841857.0000 - root_mean_squared_error: 0.7439 - val_loss: 1841537.7500 - val_root_mean_squared_error: 0.7462
# Epoch 158/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1841453.3750 - root_mean_squared_error: 0.7424 - val_loss: 1841306.5000 - val_root_mean_squared_error: 0.7489
# Epoch 159/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1841189.3750 - root_mean_squared_error: 0.7435 - val_loss: 1840821.8750 - val_root_mean_squared_error: 0.7484
# Epoch 160/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1840827.3750 - root_mean_squared_error: 0.7498 - val_loss: 1840555.6250 - val_root_mean_squared_error: 0.7543
# Epoch 161/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1840566.6250 - root_mean_squared_error: 0.7510 - val_loss: 1840255.5000 - val_root_mean_squared_error: 0.7586
# Epoch 162/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1840299.7500 - root_mean_squared_error: 0.7517 - val_loss: 1840019.5000 - val_root_mean_squared_error: 0.7569
# Epoch 163/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1839899.6250 - root_mean_squared_error: 0.7494 - val_loss: 1839654.3750 - val_root_mean_squared_error: 0.7574
# Epoch 164/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1839454.0000 - root_mean_squared_error: 0.7560 - val_loss: 1839300.3750 - val_root_mean_squared_error: 0.7556
# Epoch 165/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1839266.7500 - root_mean_squared_error: 0.7519 - val_loss: 1839060.5000 - val_root_mean_squared_error: 0.7560
# Epoch 166/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1838812.7500 - root_mean_squared_error: 0.7518 - val_loss: 1838751.0000 - val_root_mean_squared_error: 0.7530
# Epoch 167/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1838558.7500 - root_mean_squared_error: 0.7518 - val_loss: 1838367.7500 - val_root_mean_squared_error: 0.7490
# Epoch 168/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1838232.2500 - root_mean_squared_error: 0.7441 - val_loss: 1838050.6250 - val_root_mean_squared_error: 0.7530
# Epoch 169/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1838108.5000 - root_mean_squared_error: 0.7520 - val_loss: 1837826.3750 - val_root_mean_squared_error: 0.7473
# Epoch 170/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1837756.7500 - root_mean_squared_error: 0.7457 - val_loss: 1837433.2500 - val_root_mean_squared_error: 0.7487
# Epoch 171/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1837293.0000 - root_mean_squared_error: 0.7411 - val_loss: 1837218.2500 - val_root_mean_squared_error: 0.7482
# Epoch 172/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1836767.0000 - root_mean_squared_error: 0.7412 - val_loss: 1836803.1250 - val_root_mean_squared_error: 0.7512
# Epoch 173/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1836781.0000 - root_mean_squared_error: 0.7493 - val_loss: 1836406.0000 - val_root_mean_squared_error: 0.7517
# Epoch 174/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1836501.3750 - root_mean_squared_error: 0.7453 - val_loss: 1836199.8750 - val_root_mean_squared_error: 0.7506
# Epoch 175/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1836204.3750 - root_mean_squared_error: 0.7400 - val_loss: 1835904.1250 - val_root_mean_squared_error: 0.7529
# Epoch 176/200
# 6/6 [==============================] - 0s 10ms/step - loss: 1835677.1250 - root_mean_squared_error: 0.7426 - val_loss: 1835596.5000 - val_root_mean_squared_error: 0.7496
# Epoch 177/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1835499.6250 - root_mean_squared_error: 0.7454 - val_loss: 1835246.3750 - val_root_mean_squared_error: 0.7528
# Epoch 178/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1834975.7500 - root_mean_squared_error: 0.7464 - val_loss: 1834840.5000 - val_root_mean_squared_error: 0.7507
# Epoch 179/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1834967.7500 - root_mean_squared_error: 0.7484 - val_loss: 1834750.0000 - val_root_mean_squared_error: 0.7510
# Epoch 180/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1834629.7500 - root_mean_squared_error: 0.7498 - val_loss: 1834340.7500 - val_root_mean_squared_error: 0.7471
# Epoch 181/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1834112.8750 - root_mean_squared_error: 0.7456 - val_loss: 1834111.8750 - val_root_mean_squared_error: 0.7463
# Epoch 182/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1834067.1250 - root_mean_squared_error: 0.7495 - val_loss: 1833777.6250 - val_root_mean_squared_error: 0.7475
# Epoch 183/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1833575.6250 - root_mean_squared_error: 0.7447 - val_loss: 1833525.5000 - val_root_mean_squared_error: 0.7460
# Epoch 184/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1833229.7500 - root_mean_squared_error: 0.7507 - val_loss: 1833118.5000 - val_root_mean_squared_error: 0.7503
# Epoch 185/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1832948.0000 - root_mean_squared_error: 0.7453 - val_loss: 1832852.0000 - val_root_mean_squared_error: 0.7458
# Epoch 186/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1832705.3750 - root_mean_squared_error: 0.7487 - val_loss: 1832568.2500 - val_root_mean_squared_error: 0.7454
# Epoch 187/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1832578.5000 - root_mean_squared_error: 0.7417 - val_loss: 1832192.0000 - val_root_mean_squared_error: 0.7450
# Epoch 188/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1832139.3750 - root_mean_squared_error: 0.7435 - val_loss: 1832003.7500 - val_root_mean_squared_error: 0.7453
# Epoch 189/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1831843.3750 - root_mean_squared_error: 0.7402 - val_loss: 1831622.3750 - val_root_mean_squared_error: 0.7477
# Epoch 190/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1831481.5000 - root_mean_squared_error: 0.7407 - val_loss: 1831370.2500 - val_root_mean_squared_error: 0.7481
# Epoch 191/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1831044.1250 - root_mean_squared_error: 0.7435 - val_loss: 1830994.1250 - val_root_mean_squared_error: 0.7468
# Epoch 192/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1830702.1250 - root_mean_squared_error: 0.7425 - val_loss: 1830697.0000 - val_root_mean_squared_error: 0.7472
# Epoch 193/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1830740.3750 - root_mean_squared_error: 0.7453 - val_loss: 1830515.2500 - val_root_mean_squared_error: 0.7456
# Epoch 194/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1830326.6250 - root_mean_squared_error: 0.7416 - val_loss: 1830200.3750 - val_root_mean_squared_error: 0.7483
# Epoch 195/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1829968.0000 - root_mean_squared_error: 0.7432 - val_loss: 1829839.3750 - val_root_mean_squared_error: 0.7445
# Epoch 196/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1829828.0000 - root_mean_squared_error: 0.7442 - val_loss: 1829553.3750 - val_root_mean_squared_error: 0.7498
# Epoch 197/200
# 6/6 [==============================] - 0s 13ms/step - loss: 1829360.5000 - root_mean_squared_error: 0.7403 - val_loss: 1829315.2500 - val_root_mean_squared_error: 0.7493
# Epoch 198/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1829003.7500 - root_mean_squared_error: 0.7454 - val_loss: 1828952.5000 - val_root_mean_squared_error: 0.7477
# Epoch 199/200
# 6/6 [==============================] - 0s 12ms/step - loss: 1828859.8750 - root_mean_squared_error: 0.7420 - val_loss: 1828681.1250 - val_root_mean_squared_error: 0.7462
# Epoch 200/200
# 6/6 [==============================] - 0s 11ms/step - loss: 1828630.0000 - root_mean_squared_error: 0.7424 - val_loss: 1828358.0000 - val_root_mean_squared_error: 0.7429
# number of outliers:  71216  out of  102041
# % of outliers:  69.79155437520213
# number of catastrophic outliers:  3107  out of  102041
# % of catastrophic outliers:  0.030448545192618654

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
import matplotlib.cm as cm

# Generate fake data
x = np.array(y_test_original)
y = np.concatenate(photoz, axis = 0)

# Calculate the point density
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

fig, ax = plt.subplots()
ax_ = ax.scatter(x, y, c=z, cmap=cm.Blues, s=5, edgecolor=None, norm=matplotlib.colors.LogNorm())
plt.colorbar(ax_)

# %%
fig, ax = plt.subplots()
ax_ = ax.scatter(x, y, c=z, cmap=cm.Blues, s=2, edgecolor=None, norm=matplotlib.colors.LogNorm())
plt.colorbar(ax_)
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([.18,1.6*2.4],[0,1.2*2.4], color='black')
plt.plot([0, 1.6 * 2.4], [.15, 2 * 2.4],color = 'black')

# %%
import matplotlib
fig, ax = plt.subplots()
ax_ = ax.scatter(x, y, c=z,s = 1,edgecolor=None, norm=matplotlib.colors.LogNorm())
plt.colorbar(ax_)
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([.18,1.6*2.4],[0,1.2*2.4], color='black')
plt.plot([0, 1.6 * 2.4], [.15, 2 * 2.4],color = 'black')

# %%
photoz
# Out:
# [array([0.52814037], dtype=float32),
#  array([0.6955489], dtype=float32),
#  array([0.9124295], dtype=float32),
#  array([0.8047925], dtype=float32),
#  array([0.99726886], dtype=float32),
#  array([0.73195636], dtype=float32),
#  array([0.77351314], dtype=float32),
#  array([1.1156919], dtype=float32),
#  array([1.0604053], dtype=float32),
#  array([0.606275], dtype=float32),
#  array([0.698863], dtype=float32),
#  array([1.3632116], dtype=float32),
#  array([0.790971], dtype=float32),
#  array([0.95021194], dtype=float32),
#  array([0.4216319], dtype=float32),
#  array([0.7285748], dtype=float32),
#  array([0.8684315], dtype=float32),
#  array([0.9382946], dtype=float32),
#  array([0.88369924], dtype=float32),
#  array([-0.00169575], dtype=float32),
#  array([0.43468696], dtype=float32),
#  array([0.85278416], dtype=float32),
#  array([0.50582594], dtype=float32),
#  array([1.0592707], dtype=float32),
#  array([0.37215146], dtype=float32),
#  array([0.02325676], dtype=float32),
#  array([0.28530803], dtype=float32),
#  array([0.7096879], dtype=float32),
#  array([0.48168334], dtype=float32),
#  array([0.6015834], dtype=float32),
#  array([0.26700845], dtype=float32),
#  array([0.54214096], dtype=float32),
#  array([0.81166565], dtype=float32),
#  array([0.49622193], dtype=float32),
#  array([0.82303184], dtype=float32),
#  array([0.58484143], dtype=float32),
#  array([0.99572575], dtype=float32),
#  array([0.22010866], dtype=float32),
#  array([0.47643653], dtype=float32),
#  array([0.13826673], dtype=float32),
#  array([0.9670068], dtype=float32),
#  array([0.48665357], dtype=float32),
#  array([1.0748881], dtype=float32),
#  array([1.4757714], dtype=float32),
#  array([1.7607855], dtype=float32),
#  array([0.92186517], dtype=float32),
#  array([0.8035116], dtype=float32),
#  array([1.0381585], dtype=float32),
#  array([0.81519717], dtype=float32),
#  array([1.2629015], dtype=float32),
#  array([0.59165263], dtype=float32),
#  array([0.95544577], dtype=float32),
#  array([0.5988843], dtype=float32),
#  array([0.08571348], dtype=float32),
#  array([0.3881826], dtype=float32),
#  array([0.70121616], dtype=float32),
#  array([0.5986277], dtype=float32),
#  array([0.6667889], dtype=float32),
#  array([0.8784544], dtype=float32),
#  array([0.64373], dtype=float32),
#  array([0.5037891], dtype=float32),
#  array([0.9594254], dtype=float32),
#  array([0.6480372], dtype=float32),
#  array([1.1445078], dtype=float32),
#  array([0.8728965], dtype=float32),
#  array([0.11284476], dtype=float32),
#  array([0.50154674], dtype=float32),
#  array([1.4312826], dtype=float32),
#  array([0.77858764], dtype=float32),
#  array([2.5006337], dtype=float32),
#  array([0.10451664], dtype=float32),
#  array([1.0866213], dtype=float32),
#  array([2.2684045], dtype=float32),
#  array([1.0051291], dtype=float32),
#  array([0.8817512], dtype=float32),
#  array([0.8570552], dtype=float32),
#  array([1.4493533], dtype=float32),
#  array([0.588665], dtype=float32),
#  array([0.57315415], dtype=float32),
#  array([0.82672614], dtype=float32),
#  array([2.6860034], dtype=float32),
#  array([0.6096222], dtype=float32),
#  array([0.6417912], dtype=float32),
#  array([0.5995371], dtype=float32),
#  array([0.49914327], dtype=float32),
#  array([0.6096547], dtype=float32),
#  array([0.50479895], dtype=float32),
#  array([0.77696764], dtype=float32),
#  array([0.94875795], dtype=float32),
#  array([1.0387838], dtype=float32),
#  array([0.72698075], dtype=float32),
#  array([0.4988637], dtype=float32),
#  array([0.38542032], dtype=float32),
#  array([0.23937586], dtype=float32),
#  array([0.33551538], dtype=float32),
#  array([0.51536167], dtype=float32),
#  array([0.96750385], dtype=float32),
#  array([0.5966235], dtype=float32),
#  array([0.8777752], dtype=float32),
#  array([0.82119316], dtype=float32),
#  array([0.93477345], dtype=float32),
#  array([0.9564118], dtype=float32),
#  array([0.69820726], dtype=float32),
#  array([0.59504086], dtype=float32),
#  array([1.0955938], dtype=float32),
#  array([2.1378033], dtype=float32),
#  array([1.0072125], dtype=float32),
#  array([1.5531095], dtype=float32),
#  array([0.812729], dtype=float32),
#  array([0.59873986], dtype=float32),
#  array([0.8077796], dtype=float32),
#  array([0.8352562], dtype=float32),
#  array([0.50549215], dtype=float32),
#  array([0.962696], dtype=float32),
#  array([0.7077386], dtype=float32),
#  array([1.0440843], dtype=float32),
#  array([0.6987011], dtype=float32),
#  array([0.01005083], dtype=float32),
#  array([0.59906477], dtype=float32),
#  array([0.8124863], dtype=float32),
#  array([0.49239096], dtype=float32),
#  array([0.6386918], dtype=float32),
#  array([0.5949396], dtype=float32),
#  array([0.8588807], dtype=float32),
#  array([0.0004523], dtype=float32),
#  array([0.7604029], dtype=float32),
#  array([0.49685165], dtype=float32),
#  array([0.5011411], dtype=float32),
#  array([0.5898692], dtype=float32),
#  array([0.6677081], dtype=float32),
#  array([0.7967267], dtype=float32),
#  array([0.49436626], dtype=float32),
#  array([0.3765326], dtype=float32),
#  array([0.4765955], dtype=float32),
#  array([0.5110468], dtype=float32),
#  array([0.70277864], dtype=float32),
#  array([1.4279097], dtype=float32),
#  array([0.8068021], dtype=float32),
#  array([0.288982], dtype=float32),
#  array([0.9627492], dtype=float32),
#  array([0.17569381], dtype=float32),
#  array([0.7711925], dtype=float32),
#  array([0.10200009], dtype=float32),
#  array([1.1742237], dtype=float32),
#  array([0.8956539], dtype=float32),
#  array([0.6092349], dtype=float32),
#  array([0.50191844], dtype=float32),
#  array([0.1854189], dtype=float32),
#  array([1.2029707], dtype=float32),
#  array([0.5146329], dtype=float32),
#  array([0.69875765], dtype=float32),
#  array([0.29825112], dtype=float32),
#  array([1.0418755], dtype=float32),
#  array([0.7841237], dtype=float32),
#  array([0.93709993], dtype=float32),
#  array([0.80304116], dtype=float32),
#  array([0.03646735], dtype=float32),
#  array([0.58885354], dtype=float32),
#  array([2.2558076], dtype=float32),
#  array([0.41072127], dtype=float32),
#  array([0.92433566], dtype=float32),
#  array([0.30257073], dtype=float32),
#  array([1.0103549], dtype=float32),
#  array([0.02280699], dtype=float32),
#  array([0.73917645], dtype=float32),
#  array([0.59625494], dtype=float32),
#  array([0.7021468], dtype=float32),
#  array([0.7192163], dtype=float32),
#  array([0.80883616], dtype=float32),
#  array([0.7121994], dtype=float32),
#  array([0.8726884], dtype=float32),
#  array([0.5857858], dtype=float32),
#  array([1.0257424], dtype=float32),
#  array([0.3385149], dtype=float32),
#  array([0.43168074], dtype=float32),
#  array([0.523948], dtype=float32),
#  array([0.6982765], dtype=float32),
#  array([0.58892024], dtype=float32),
#  array([0.20503342], dtype=float32),
#  array([0.90375847], dtype=float32),
#  array([1.0166284], dtype=float32),
#  array([1.0876442], dtype=float32),
#  array([0.50621146], dtype=float32),
#  array([1.570826], dtype=float32),
#  array([0.72889847], dtype=float32),
#  array([0.5291911], dtype=float32),
#  array([0.7747907], dtype=float32),
#  array([0.67812645], dtype=float32),
#  array([0.42697287], dtype=float32),
#  array([0.5787013], dtype=float32),
#  array([0.16716222], dtype=float32),
#  array([0.09980207], dtype=float32),
#  array([0.70224845], dtype=float32),
#  array([0.85869306], dtype=float32),
#  array([0.9965275], dtype=float32),
#  array([0.4239354], dtype=float32),
#  array([0.9635196], dtype=float32),
#  array([0.45581985], dtype=float32),
#  array([0.959753], dtype=float32),
#  array([1.0597554], dtype=float32),
#  array([1.1276346], dtype=float32),
#  array([0.18315345], dtype=float32),
#  array([0.49180314], dtype=float32),
#  array([0.5996463], dtype=float32),
#  array([0.52621204], dtype=float32),
#  array([-0.00899535], dtype=float32),
#  array([0.9774596], dtype=float32),
#  array([0.49070653], dtype=float32),
#  array([0.3058668], dtype=float32),
#  array([0.29931146], dtype=float32),
#  array([0.5446788], dtype=float32),
#  array([0.9528319], dtype=float32),
#  array([0.7060387], dtype=float32),
#  array([0.6429923], dtype=float32),
#  array([0.7309816], dtype=float32),
#  array([-0.07672801], dtype=float32),
#  array([0.8322385], dtype=float32),
#  array([0.49590227], dtype=float32),
#  array([0.7655305], dtype=float32),
#  array([0.59082717], dtype=float32),
#  array([0.6985563], dtype=float32),
#  array([0.84757227], dtype=float32),
#  array([0.8201677], dtype=float32),
#  array([0.46490246], dtype=float32),
#  array([0.7087918], dtype=float32),
#  array([1.2482074], dtype=float32),
#  array([0.86135656], dtype=float32),
#  array([0.20765102], dtype=float32),
#  array([0.4859739], dtype=float32),
#  array([0.5317842], dtype=float32),
#  array([0.10223684], dtype=float32),
#  array([0.9095425], dtype=float32),
#  array([0.5929159], dtype=float32),
#  array([0.8672759], dtype=float32),
#  array([0.70700663], dtype=float32),
#  array([0.03251026], dtype=float32),
#  array([-0.00511593], dtype=float32),
#  array([0.9636392], dtype=float32),
#  array([0.59706324], dtype=float32),
#  array([0.49131203], dtype=float32),
#  array([0.5948699], dtype=float32),
#  array([0.5989367], dtype=float32),
#  array([0.49823043], dtype=float32),
#  array([1.4041885], dtype=float32),
#  array([1.0633254], dtype=float32),
#  array([0.90960723], dtype=float32),
#  array([0.8766307], dtype=float32),
#  array([0.4997379], dtype=float32),
#  array([1.0098681], dtype=float32),
#  array([0.59824604], dtype=float32),
#  array([0.49100086], dtype=float32),
#  array([0.70355535], dtype=float32),
#  array([0.9729171], dtype=float32),
#  array([0.98989505], dtype=float32),
#  array([2.1965895], dtype=float32),
#  array([1.3793368], dtype=float32),
#  array([0.6558462], dtype=float32),
#  array([0.33530995], dtype=float32),
#  array([0.888011], dtype=float32),
#  array([1.9956325], dtype=float32),
#  array([0.7783442], dtype=float32),
#  array([0.9144214], dtype=float32),
#  array([0.77240807], dtype=float32),
#  array([1.0144233], dtype=float32),
#  array([0.8409681], dtype=float32),
#  array([0.60042536], dtype=float32),
#  array([0.45161015], dtype=float32),
#  array([0.8630167], dtype=float32),
#  array([0.50108814], dtype=float32),
#  array([0.5972848], dtype=float32),
#  array([0.6206366], dtype=float32),
#  array([0.6030302], dtype=float32),
#  array([0.67102903], dtype=float32),
#  array([0.5962763], dtype=float32),
#  array([0.49560156], dtype=float32),
#  array([0.69816834], dtype=float32),
#  array([0.9105655], dtype=float32),
#  array([0.92345697], dtype=float32),
#  array([0.6212838], dtype=float32),
#  array([0.92711097], dtype=float32),
#  array([0.70362586], dtype=float32),
#  array([1.0094007], dtype=float32),
#  array([0.7894289], dtype=float32),
#  array([0.9077474], dtype=float32),
#  array([0.7118663], dtype=float32),
#  array([0.5729235], dtype=float32),
#  array([0.7300474], dtype=float32),
#  array([1.0102905], dtype=float32),
#  array([0.5897741], dtype=float32),
#  array([0.14984408], dtype=float32),
#  array([1.1658809], dtype=float32),
#  array([0.84976476], dtype=float32),
#  array([1.1122245], dtype=float32),
#  array([0.30949098], dtype=float32),
#  array([0.8472083], dtype=float32),
#  array([0.00415186], dtype=float32),
#  array([0.38375485], dtype=float32),
#  array([0.9756881], dtype=float32),
#  array([1.0796942], dtype=float32),
#  array([0.7895259], dtype=float32),
#  array([0.71696067], dtype=float32),
#  array([0.7837352], dtype=float32),
#  array([0.68641245], dtype=float32),
#  array([0.8106225], dtype=float32),
#  array([0.59599656], dtype=float32),
#  array([0.4829928], dtype=float32),
#  array([0.45441794], dtype=float32),
#  array([0.03371343], dtype=float32),
#  array([1.0172324], dtype=float32),
#  array([0.48463735], dtype=float32),
#  array([0.5598155], dtype=float32),
#  array([0.38033262], dtype=float32),
#  array([0.60328835], dtype=float32),
#  array([0.5988039], dtype=float32),
#  array([0.70587754], dtype=float32),
#  array([1.4454654], dtype=float32),
#  array([0.6948511], dtype=float32),
#  array([0.8016553], dtype=float32),
#  array([0.55243456], dtype=float32),
#  array([0.9496576], dtype=float32),
#  array([0.8185816], dtype=float32),
#  array([1.1265434], dtype=float32),
#  array([1.0642343], dtype=float32),
#  array([0.70673394], dtype=float32),
#  array([0.4923916], dtype=float32),
#  array([0.56516117], dtype=float32),
#  array([0.11593475], dtype=float32),
#  array([0.5030317], dtype=float32),
#  array([0.45504054], dtype=float32),
#  array([0.85524714], dtype=float32),
#  array([0.3383479], dtype=float32),
#  array([0.44261023], dtype=float32),
#  array([0.82333565], dtype=float32),
#  array([0.6033226], dtype=float32),
#  array([0.80029744], dtype=float32),
#  array([0.6059855], dtype=float32),
#  array([0.66385144], dtype=float32),
#  array([0.4067467], dtype=float32),
#  array([0.7974515], dtype=float32),
#  array([0.6999487], dtype=float32),
#  array([0.7027726], dtype=float32),
#  array([0.7115126], dtype=float32),
#  array([0.5975424], dtype=float32),
#  array([0.49362832], dtype=float32),
#  array([0.48162112], dtype=float32),
#  array([0.9277501], dtype=float32),
#  array([0.27322888], dtype=float32),
#  array([0.70856684], dtype=float32),
#  array([1.1713737], dtype=float32),
#  array([0.4357081], dtype=float32),
#  array([0.95126075], dtype=float32),
#  array([0.69517887], dtype=float32),
#  array([0.5050173], dtype=float32),
#  array([0.38676214], dtype=float32),
#  array([2.3388689], dtype=float32),
#  array([0.47044635], dtype=float32),
#  array([0.6900239], dtype=float32),
#  array([0.10100254], dtype=float32),
#  array([0.8299344], dtype=float32),
#  array([0.27847114], dtype=float32),
#  array([1.1211313], dtype=float32),
#  array([0.4757293], dtype=float32),
#  array([0.1509149], dtype=float32),
#  array([-0.01560114], dtype=float32),
#  array([0.8043211], dtype=float32),
#  array([1.0755805], dtype=float32),
#  array([0.5996394], dtype=float32),
#  array([1.0987874], dtype=float32),
#  array([0.47324377], dtype=float32),
#  array([0.4178513], dtype=float32),
#  array([0.733212], dtype=float32),
#  array([0.6076077], dtype=float32),
#  array([1.0006789], dtype=float32),
#  array([0.8105871], dtype=float32),
#  array([0.59772223], dtype=float32),
#  array([0.4967434], dtype=float32),
#  array([0.6990903], dtype=float32),
#  array([0.52724713], dtype=float32),
#  array([1.3132259], dtype=float32),
#  array([0.30402339], dtype=float32),
#  array([0.59938395], dtype=float32),
#  array([1.1037606], dtype=float32),
#  array([0.7179629], dtype=float32),
#  array([0.7020232], dtype=float32),
#  array([0.86436504], dtype=float32),
#  array([0.79096067], dtype=float32),
#  array([0.2074641], dtype=float32),
#  array([0.80707073], dtype=float32),
#  array([0.7561868], dtype=float32),
#  array([0.64148337], dtype=float32),
#  array([1.1035931], dtype=float32),
#  array([0.83127576], dtype=float32),
#  array([0.32757506], dtype=float32),
#  array([0.60064316], dtype=float32),
#  array([0.42043257], dtype=float32),
#  array([1.0937521], dtype=float32),
#  array([0.86673737], dtype=float32),
#  array([0.4560328], dtype=float32),
#  array([0.5996978], dtype=float32),
#  array([1.0082902], dtype=float32),
#  array([0.1307559], dtype=float32),
#  array([0.9050607], dtype=float32),
#  array([1.0022392], dtype=float32),
#  array([1.0923369], dtype=float32),
#  array([0.68609554], dtype=float32),
#  array([0.49964175], dtype=float32),
#  array([0.7569452], dtype=float32),
#  array([0.9093694], dtype=float32),
#  array([0.63654345], dtype=float32),
#  array([0.88840294], dtype=float32),
#  array([0.13608277], dtype=float32),
#  array([0.53573835], dtype=float32),
#  array([0.543843], dtype=float32),
#  array([2.0120761], dtype=float32),
#  array([0.56070375], dtype=float32),
#  array([0.6037565], dtype=float32),
#  array([1.3229271], dtype=float32),
#  array([0.60618496], dtype=float32),
#  array([0.69003403], dtype=float32),
#  array([0.70265025], dtype=float32),
#  array([0.6037718], dtype=float32),
#  array([0.8491246], dtype=float32),
#  array([0.42733747], dtype=float32),
#  array([0.500699], dtype=float32),
#  array([1.2577378], dtype=float32),
#  array([0.81971306], dtype=float32),
#  array([0.5790149], dtype=float32),
#  array([-0.01851066], dtype=float32),
#  array([1.0239512], dtype=float32),
#  array([1.054687], dtype=float32),
#  array([0.59987164], dtype=float32),
#  array([0.9394728], dtype=float32),
#  array([0.9835977], dtype=float32),
#  array([0.815601], dtype=float32),
#  array([0.22029881], dtype=float32),
#  array([0.7942586], dtype=float32),
#  array([1.0080194], dtype=float32),
#  array([0.8117797], dtype=float32),
#  array([0.6688747], dtype=float32),
#  array([0.8586422], dtype=float32),
#  array([0.7069522], dtype=float32),
#  array([0.67694587], dtype=float32),
#  array([0.2120707], dtype=float32),
#  array([0.69910246], dtype=float32),
#  array([0.51044667], dtype=float32),
#  array([1.0852691], dtype=float32),
#  array([0.07567093], dtype=float32),
#  array([0.11724365], dtype=float32),
#  array([0.7031954], dtype=float32),
#  array([0.6059915], dtype=float32),
#  array([0.40545842], dtype=float32),
#  array([0.99309856], dtype=float32),
#  array([1.0942649], dtype=float32),
#  array([0.0987618], dtype=float32),
#  array([0.5081281], dtype=float32),
#  array([0.823554], dtype=float32),
#  array([0.8435318], dtype=float32),
#  array([0.12085872], dtype=float32),
#  array([1.0218866], dtype=float32),
#  array([0.4835113], dtype=float32),
#  array([0.79991513], dtype=float32),
#  array([0.59260327], dtype=float32),
#  array([0.8834527], dtype=float32),
#  array([0.6986212], dtype=float32),
#  array([1.0290991], dtype=float32),
#  array([0.6020686], dtype=float32),
#  array([0.3956781], dtype=float32),
#  array([0.49983644], dtype=float32),
#  array([0.76425815], dtype=float32),
#  array([2.2855172], dtype=float32),
#  array([1.3498391], dtype=float32),
#  array([0.48522353], dtype=float32),
#  array([0.11227411], dtype=float32),
#  array([0.71081406], dtype=float32),
#  array([0.8036327], dtype=float32),
#  array([0.49428588], dtype=float32),
#  array([0.42962256], dtype=float32),
#  array([0.6676771], dtype=float32),
#  array([0.39576566], dtype=float32),
#  array([0.845813], dtype=float32),
#  array([0.8904878], dtype=float32),
#  array([0.71564084], dtype=float32),
#  array([0.50053686], dtype=float32),
#  array([0.87738544], dtype=float32),
#  array([0.7034033], dtype=float32),
#  array([0.57999694], dtype=float32),
#  array([0.8819578], dtype=float32),
#  array([1.6261189], dtype=float32),
#  array([0.9536788], dtype=float32),
#  array([0.8072435], dtype=float32),
#  array([0.47153345], dtype=float32),
#  array([0.49063188], dtype=float32),
#  array([0.82020277], dtype=float32),
#  array([2.5122163], dtype=float32),
#  array([0.49732858], dtype=float32),
#  array([0.8286357], dtype=float32),
#  array([1.6226578], dtype=float32),
#  array([0.80782187], dtype=float32),
#  array([0.7819685], dtype=float32),
#  array([0.07242339], dtype=float32),
#  array([0.89787275], dtype=float32),
#  array([0.7075235], dtype=float32),
#  array([0.60159534], dtype=float32),
#  array([0.49065977], dtype=float32),
#  array([0.7544327], dtype=float32),
#  array([0.5835857], dtype=float32),
#  array([0.44075108], dtype=float32),
#  array([0.60103863], dtype=float32),
#  array([1.6326983], dtype=float32),
#  array([0.61960894], dtype=float32),
#  array([0.5413582], dtype=float32),
#  array([-0.13974284], dtype=float32),
#  array([1.1650258], dtype=float32),
#  array([0.40906116], dtype=float32),
#  array([0.5955746], dtype=float32),
#  array([0.48638964], dtype=float32),
#  array([1.1405083], dtype=float32),
#  array([0.60494787], dtype=float32),
#  array([0.78767866], dtype=float32),
#  array([1.3676564], dtype=float32),
#  array([1.0242454], dtype=float32),
#  array([0.50850356], dtype=float32),
#  array([0.12095868], dtype=float32),
#  array([0.97360146], dtype=float32),
#  array([0.5226918], dtype=float32),
#  array([0.59050757], dtype=float32),
#  array([0.100956], dtype=float32),
#  array([0.6020511], dtype=float32),
#  array([0.7971812], dtype=float32),
#  array([1.7413911], dtype=float32),
#  array([0.02674207], dtype=float32),
#  array([0.5074921], dtype=float32),
#  array([0.6048663], dtype=float32),
#  array([0.5939891], dtype=float32),
#  array([0.43120995], dtype=float32),
#  array([0.60199064], dtype=float32),
#  array([1.0742139], dtype=float32),
#  array([0.8591501], dtype=float32),
#  array([0.85517436], dtype=float32),
#  array([0.5396267], dtype=float32),
#  array([0.35001042], dtype=float32),
#  array([0.50258505], dtype=float32),
#  array([1.2295725], dtype=float32),
#  array([0.6005561], dtype=float32),
#  array([1.0381194], dtype=float32),
#  array([0.7105538], dtype=float32),
#  array([0.8795625], dtype=float32),
#  array([0.32284924], dtype=float32),
#  array([0.6112003], dtype=float32),
#  array([0.66795665], dtype=float32),
#  array([0.48818913], dtype=float32),
#  array([0.5755771], dtype=float32),
#  array([0.7137462], dtype=float32),
#  array([0.9275481], dtype=float32),
#  array([0.83835375], dtype=float32),
#  array([1.7224997], dtype=float32),
#  array([0.49691248], dtype=float32),
#  array([0.80407], dtype=float32),
#  array([0.59154236], dtype=float32),
#  array([0.91588813], dtype=float32),
#  array([0.8831579], dtype=float32),
#  array([0.60627383], dtype=float32),
#  array([1.0367113], dtype=float32),
#  array([0.9192261], dtype=float32),
#  array([0.490719], dtype=float32),
#  array([0.93494886], dtype=float32),
#  array([1.8518372], dtype=float32),
#  array([0.5311429], dtype=float32),
#  array([0.82190317], dtype=float32),
#  array([0.8344719], dtype=float32),
#  array([0.49958608], dtype=float32),
#  array([0.63895315], dtype=float32),
#  array([0.7570455], dtype=float32),
#  array([0.4226883], dtype=float32),
#  array([0.83276427], dtype=float32),
#  array([0.8028595], dtype=float32),
#  array([1.7361478], dtype=float32),
#  array([0.95483655], dtype=float32),
#  array([1.0643231], dtype=float32),
#  array([0.50851905], dtype=float32),
#  array([0.46188736], dtype=float32),
#  array([0.59790844], dtype=float32),
#  array([0.45225373], dtype=float32),
#  array([0.72896963], dtype=float32),
#  array([1.8759377], dtype=float32),
#  array([0.70865536], dtype=float32),
#  array([1.4189166], dtype=float32),
#  array([0.7872066], dtype=float32),
#  array([0.47711477], dtype=float32),
#  array([0.2978676], dtype=float32),
#  array([1.069894], dtype=float32),
#  array([0.7020064], dtype=float32),
#  array([0.65233576], dtype=float32),
#  array([0.8615962], dtype=float32),
#  array([0.659439], dtype=float32),
#  array([0.4568079], dtype=float32),
#  array([1.6427736], dtype=float32),
#  array([0.92880297], dtype=float32),
#  array([0.8189335], dtype=float32),
#  array([0.78949106], dtype=float32),
#  array([0.8799535], dtype=float32),
#  array([0.819609], dtype=float32),
#  array([0.5135768], dtype=float32),
#  array([0.77896035], dtype=float32),
#  array([0.01441969], dtype=float32),
#  array([0.8565343], dtype=float32),
#  array([0.7909063], dtype=float32),
#  array([0.23920445], dtype=float32),
#  array([0.7129703], dtype=float32),
#  array([0.8835222], dtype=float32),
#  array([0.6514816], dtype=float32),
#  array([1.3568586], dtype=float32),
#  array([0.02786301], dtype=float32),
#  array([0.9246041], dtype=float32),
#  array([0.52806693], dtype=float32),
#  array([0.6211684], dtype=float32),
#  array([1.0892199], dtype=float32),
#  array([1.0140772], dtype=float32),
#  array([0.6976892], dtype=float32),
#  array([0.9234686], dtype=float32),
#  array([0.5633588], dtype=float32),
#  array([0.9445756], dtype=float32),
#  array([0.78078216], dtype=float32),
#  array([0.6065206], dtype=float32),
#  array([1.4235091], dtype=float32),
#  array([0.9788198], dtype=float32),
#  array([1.1158026], dtype=float32),
#  array([0.83796006], dtype=float32),
#  array([-0.00080351], dtype=float32),
#  array([0.60344577], dtype=float32),
#  array([0.6210045], dtype=float32),
#  array([0.49193153], dtype=float32),
#  array([0.6451096], dtype=float32),
#  array([0.8934765], dtype=float32),
#  array([0.6388708], dtype=float32),
#  array([1.1884917], dtype=float32),
#  array([1.26797], dtype=float32),
#  array([1.0962536], dtype=float32),
#  array([0.7044899], dtype=float32),
#  array([0.13713002], dtype=float32),
#  array([0.7089949], dtype=float32),
#  array([0.6017535], dtype=float32),
#  array([0.85825014], dtype=float32),
#  array([0.61937106], dtype=float32),
#  array([0.6070457], dtype=float32),
#  array([0.87000704], dtype=float32),
#  array([0.80685234], dtype=float32),
#  array([0.9361966], dtype=float32),
#  array([1.677026], dtype=float32),
#  array([0.9930272], dtype=float32),
#  array([0.50446177], dtype=float32),
#  array([0.6523911], dtype=float32),
#  array([0.31681916], dtype=float32),
#  array([0.59756815], dtype=float32),
#  array([0.9343503], dtype=float32),
#  array([0.8971478], dtype=float32),
#  array([0.70667106], dtype=float32),
#  array([0.57418835], dtype=float32),
#  array([0.8226115], dtype=float32),
#  array([0.36420998], dtype=float32),
#  array([0.6405102], dtype=float32),
#  array([0.49392882], dtype=float32),
#  array([0.49365035], dtype=float32),
#  array([0.9485734], dtype=float32),
#  array([0.49175197], dtype=float32),
#  array([0.6991664], dtype=float32),
#  array([0.50609416], dtype=float32),
#  array([0.8866375], dtype=float32),
#  array([2.3166223], dtype=float32),
#  array([0.7386748], dtype=float32),
#  array([0.7047629], dtype=float32),
#  array([0.5098758], dtype=float32),
#  array([0.9873981], dtype=float32),
#  array([1.0873296], dtype=float32),
#  array([0.50239164], dtype=float32),
#  array([0.58899385], dtype=float32),
#  array([0.6941295], dtype=float32),
#  array([0.77587473], dtype=float32),
#  array([0.4820118], dtype=float32),
#  array([0.86365664], dtype=float32),
#  array([0.56800634], dtype=float32),
#  array([0.58609813], dtype=float32),
#  array([1.1011254], dtype=float32),
#  array([0.60117054], dtype=float32),
#  array([0.31364366], dtype=float32),
#  array([1.4037551], dtype=float32),
#  array([0.6122733], dtype=float32),
#  array([0.859466], dtype=float32),
#  array([1.4425354], dtype=float32),
#  array([0.8735987], dtype=float32),
#  array([0.62452424], dtype=float32),
#  array([0.58619416], dtype=float32),
#  array([0.4920791], dtype=float32),
#  array([0.69940704], dtype=float32),
#  array([0.5896165], dtype=float32),
#  array([0.5640103], dtype=float32),
#  array([0.60333437], dtype=float32),
#  array([0.59021837], dtype=float32),
#  array([0.8913458], dtype=float32),
#  array([1.2376193], dtype=float32),
#  array([1.0096004], dtype=float32),
#  array([0.49305558], dtype=float32),
#  array([0.01780932], dtype=float32),
#  array([0.50613046], dtype=float32),
#  array([0.42419472], dtype=float32),
#  array([0.7128772], dtype=float32),
#  array([0.61203337], dtype=float32),
#  array([0.9332656], dtype=float32),
#  array([0.10401835], dtype=float32),
#  array([0.17407005], dtype=float32),
#  array([0.59900564], dtype=float32),
#  array([0.58135], dtype=float32),
#  array([1.1148356], dtype=float32),
#  array([0.7259158], dtype=float32),
#  array([0.5917927], dtype=float32),
#  array([0.55081636], dtype=float32),
#  array([0.5926464], dtype=float32),
#  array([0.9051528], dtype=float32),
#  array([1.26611], dtype=float32),
#  array([0.01839041], dtype=float32),
#  array([0.69560885], dtype=float32),
#  array([0.49773774], dtype=float32),
#  array([0.611209], dtype=float32),
#  array([0.49699345], dtype=float32),
#  array([1.4909164], dtype=float32),
#  array([0.7765035], dtype=float32),
#  array([0.8488707], dtype=float32),
#  array([0.7084923], dtype=float32),
#  array([0.48980305], dtype=float32),
#  array([0.70327884], dtype=float32),
#  array([0.789771], dtype=float32),
#  array([1.0715476], dtype=float32),
#  array([0.65412104], dtype=float32),
#  array([0.59619147], dtype=float32),
#  array([0.12254769], dtype=float32),
#  array([0.9165411], dtype=float32),
#  array([1.2261201], dtype=float32),
#  array([1.0341549], dtype=float32),
#  array([0.9721517], dtype=float32),
#  array([0.6074771], dtype=float32),
#  array([0.95395994], dtype=float32),
#  array([0.21358596], dtype=float32),
#  array([0.49066582], dtype=float32),
#  array([0.525508], dtype=float32),
#  array([-0.01560334], dtype=float32),
#  array([0.46586204], dtype=float32),
#  array([0.6971398], dtype=float32),
#  array([0.5982685], dtype=float32),
#  array([0.6970197], dtype=float32),
#  array([0.9896926], dtype=float32),
#  array([0.4916651], dtype=float32),
#  array([1.6767384], dtype=float32),
#  array([0.9778989], dtype=float32),
#  array([0.8777699], dtype=float32),
#  array([0.48902568], dtype=float32),
#  array([0.7766406], dtype=float32),
#  array([0.94811183], dtype=float32),
#  array([1.0921582], dtype=float32),
#  array([0.80590165], dtype=float32),
#  array([1.1143825], dtype=float32),
#  array([0.5024548], dtype=float32),
#  array([1.4318541], dtype=float32),
#  array([0.2873722], dtype=float32),
#  array([1.3072252], dtype=float32),
#  array([0.2210031], dtype=float32),
#  array([0.95233506], dtype=float32),
#  array([0.84028846], dtype=float32),
#  array([0.8591798], dtype=float32),
#  array([0.48653078], dtype=float32),
#  array([1.8534081], dtype=float32),
#  array([0.6741943], dtype=float32),
#  array([0.83866376], dtype=float32),
#  array([0.6053814], dtype=float32),
#  array([0.82830447], dtype=float32),
#  array([1.6417153], dtype=float32),
#  array([0.6495033], dtype=float32),
#  array([0.01153794], dtype=float32),
#  array([0.48439184], dtype=float32),
#  array([0.70421976], dtype=float32),
#  array([0.8263585], dtype=float32),
#  array([0.8075943], dtype=float32),
#  array([0.7727423], dtype=float32),
#  array([0.9391929], dtype=float32),
#  array([0.8984419], dtype=float32),
#  array([1.5025285], dtype=float32),
#  array([0.57345444], dtype=float32),
#  array([0.92099696], dtype=float32),
#  array([0.49222037], dtype=float32),
#  array([0.6197276], dtype=float32),
#  array([0.8223777], dtype=float32),
#  array([0.5412316], dtype=float32),
#  array([0.70530754], dtype=float32),
#  array([1.0039899], dtype=float32),
#  array([0.4917327], dtype=float32),
#  array([1.2823074], dtype=float32),
#  array([1.047768], dtype=float32),
#  array([1.0298847], dtype=float32),
#  array([1.0401384], dtype=float32),
#  array([0.8728768], dtype=float32),
#  array([0.59361124], dtype=float32),
#  array([1.0576934], dtype=float32),
#  array([0.95866996], dtype=float32),
#  array([0.79158705], dtype=float32),
#  array([0.8759975], dtype=float32),
#  array([0.83617145], dtype=float32),
#  array([1.0017434], dtype=float32),
#  array([0.5737453], dtype=float32),
#  array([0.70477], dtype=float32),
#  array([0.48867208], dtype=float32),
#  array([0.49541688], dtype=float32),
#  array([0.5929373], dtype=float32),
#  array([0.82737], dtype=float32),
#  array([0.8606321], dtype=float32),
#  array([0.53068286], dtype=float32),
#  array([0.46707296], dtype=float32),
#  array([1.166748], dtype=float32),
#  array([0.39873242], dtype=float32),
#  array([0.9523944], dtype=float32),
#  array([0.80592006], dtype=float32),
#  array([0.18311952], dtype=float32),
#  array([0.41726157], dtype=float32),
#  array([1.1085395], dtype=float32),
#  array([0.68312114], dtype=float32),
#  array([0.824169], dtype=float32),
#  array([0.5583737], dtype=float32),
#  array([0.8885471], dtype=float32),
#  array([0.96507627], dtype=float32),
#  array([0.7554198], dtype=float32),
#  array([0.7202829], dtype=float32),
#  array([0.6245861], dtype=float32),
#  array([0.90768397], dtype=float32),
#  array([0.75903875], dtype=float32),
#  array([0.81369174], dtype=float32),
#  array([0.6026938], dtype=float32),
#  array([0.34751725], dtype=float32),
#  array([0.597716], dtype=float32),
#  array([0.21989416], dtype=float32),
#  array([0.5370762], dtype=float32),
#  array([0.44049627], dtype=float32),
#  array([1.0761281], dtype=float32),
#  array([0.6421749], dtype=float32),
#  array([0.8777189], dtype=float32),
#  array([0.4991293], dtype=float32),
#  array([0.51051307], dtype=float32),
#  array([1.9891735], dtype=float32),
#  array([0.9223674], dtype=float32),
#  array([0.7267436], dtype=float32),
#  array([0.71442586], dtype=float32),
#  array([0.6203198], dtype=float32),
#  array([1.6950654], dtype=float32),
#  array([0.444082], dtype=float32),
#  array([0.530707], dtype=float32),
#  array([0.09375646], dtype=float32),
#  array([0.60314626], dtype=float32),
#  array([0.8147594], dtype=float32),
#  array([0.51048535], dtype=float32),
#  array([0.520377], dtype=float32),
#  array([0.10255074], dtype=float32),
#  array([0.6572173], dtype=float32),
#  array([0.89346725], dtype=float32),
#  array([0.6002895], dtype=float32),
#  array([0.4378522], dtype=float32),
#  array([0.09335594], dtype=float32),
#  array([1.0225037], dtype=float32),
#  array([0.5820404], dtype=float32),
#  array([0.796246], dtype=float32),
#  array([0.72682726], dtype=float32),
#  array([0.5313124], dtype=float32),
#  array([0.28910428], dtype=float32),
#  array([0.82688683], dtype=float32),
#  array([0.23480968], dtype=float32),
#  array([0.67811745], dtype=float32),
#  array([2.556353], dtype=float32),
#  array([0.60047436], dtype=float32),
#  array([0.52622163], dtype=float32),
#  array([0.80728084], dtype=float32),
#  array([0.61205685], dtype=float32),
#  array([0.00372129], dtype=float32),
#  array([0.8887167], dtype=float32),
#  array([0.57530445], dtype=float32),
#  array([1.27471], dtype=float32),
#  array([0.9299741], dtype=float32),
#  array([1.5613016], dtype=float32),
#  array([0.4938488], dtype=float32),
#  array([0.49323693], dtype=float32),
#  array([0.98957247], dtype=float32),
#  array([0.7132314], dtype=float32),
#  array([1.726373], dtype=float32),
#  array([0.47090837], dtype=float32),
#  array([0.6214186], dtype=float32),
#  array([1.0861925], dtype=float32),
#  array([0.5982157], dtype=float32),
#  array([0.71416026], dtype=float32),
#  array([0.6960141], dtype=float32),
#  array([0.98865575], dtype=float32),
#  array([0.7916115], dtype=float32),
#  array([0.9226207], dtype=float32),
#  array([0.7028474], dtype=float32),
#  array([0.59608907], dtype=float32),
#  array([0.50714713], dtype=float32),
#  array([0.56243974], dtype=float32),
#  array([0.6957383], dtype=float32),
#  array([1.180416], dtype=float32),
#  array([0.85299605], dtype=float32),
#  array([0.83401155], dtype=float32),
#  array([0.7157654], dtype=float32),
#  array([0.80207175], dtype=float32),
#  array([0.6024186], dtype=float32),
#  array([0.50424784], dtype=float32),
#  array([0.8439006], dtype=float32),
#  array([0.5952143], dtype=float32),
#  array([0.6038855], dtype=float32),
#  array([0.5690169], dtype=float32),
#  array([0.6793229], dtype=float32),
#  array([0.69557965], dtype=float32),
#  array([1.2166258], dtype=float32),
#  array([1.1624774], dtype=float32),
#  array([0.8140008], dtype=float32),
#  array([1.8700104], dtype=float32),
#  array([0.29073498], dtype=float32),
#  array([1.3661896], dtype=float32),
#  array([1.1765479], dtype=float32),
#  array([0.91504127], dtype=float32),
#  array([0.6106985], dtype=float32),
#  array([0.5037615], dtype=float32),
#  array([0.70488137], dtype=float32),
#  array([0.6962702], dtype=float32),
#  array([1.1217455], dtype=float32),
#  array([0.7332047], dtype=float32),
#  array([0.8892355], dtype=float32),
#  array([1.0570519], dtype=float32),
#  array([0.49760005], dtype=float32),
#  array([0.5956492], dtype=float32),
#  array([0.8514741], dtype=float32),
#  array([0.6296553], dtype=float32),
#  array([1.0201811], dtype=float32),
#  array([0.49445567], dtype=float32),
#  array([1.9258766], dtype=float32),
#  array([0.6038058], dtype=float32),
#  array([0.4864478], dtype=float32),
#  array([0.535155], dtype=float32),
#  array([1.5806266], dtype=float32),
#  array([0.00988853], dtype=float32),
#  array([0.30746612], dtype=float32),
#  array([0.4999902], dtype=float32),
#  array([1.4793628], dtype=float32),
#  array([0.58767885], dtype=float32),
#  array([0.5990624], dtype=float32),
#  array([0.4873364], dtype=float32),
#  array([0.5008754], dtype=float32),
#  array([1.3744998], dtype=float32),
#  array([0.86707795], dtype=float32),
#  array([1.9620364], dtype=float32),
#  array([0.69979715], dtype=float32),
#  array([0.664783], dtype=float32),
#  array([0.31022102], dtype=float32),
#  array([0.80673915], dtype=float32),
#  array([0.5931209], dtype=float32),
#  array([0.8396716], dtype=float32),
#  array([0.5917236], dtype=float32),
#  array([1.2519182], dtype=float32),
#  array([0.02464276], dtype=float32),
#  array([1.722613], dtype=float32),
#  array([1.0512747], dtype=float32),
#  array([3.8444765], dtype=float32),
#  array([0.73335296], dtype=float32),
#  array([0.9807997], dtype=float32),
#  array([1.2003909], dtype=float32),
#  array([0.6513881], dtype=float32),
#  array([0.6392823], dtype=float32),
#  array([0.96443856], dtype=float32),
#  array([0.29079932], dtype=float32),
#  array([0.5027238], dtype=float32),
#  array([1.0629706], dtype=float32),
#  array([0.10247982], dtype=float32),
#  array([0.71340704], dtype=float32),
#  array([0.7021733], dtype=float32),
#  array([0.74253535], dtype=float32),
#  array([0.5961653], dtype=float32),
#  array([0.47019663], dtype=float32),
#  array([0.8006053], dtype=float32),
#  array([0.9824298], dtype=float32),
#  array([0.47093853], dtype=float32),
#  array([0.9171659], dtype=float32),
#  array([0.2806295], dtype=float32),
#  array([0.49854526], dtype=float32),
#  array([0.9726782], dtype=float32),
#  array([1.0627998], dtype=float32),
#  array([0.85182506], dtype=float32),
#  array([0.9885339], dtype=float32),
#  array([0.5507297], dtype=float32),
#  array([0.8987889], dtype=float32),
#  array([0.81684965], dtype=float32),
#  array([-0.00107657], dtype=float32),
#  array([0.54805845], dtype=float32),
#  array([0.66815555], dtype=float32),
#  array([0.70752704], dtype=float32),
#  array([0.28809813], dtype=float32),
#  array([1.0227522], dtype=float32),
#  array([1.175735], dtype=float32),
#  ...]
