# %% [markdown]
# # Cross-matching HSC spec-z with Mizuki photo-z
#
# Zooey Nguyen
#
# 2021-07-09
#
# Cross-match on HSC v3 data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from scipy.stats import gaussian_kde

# %%
matched_df = pd.read_csv('/data/HSC/crossmatched_mizuki.csv')
matched_df['specz_redshift'] = matched_df['user.specz_redshift']
matched_df = matched_df[(matched_df['specz_redshift'] < 6)]
matched_df
# Out:
#        # object_id_1          ra        dec  \
# 0       3.640705e+16   29.056840  -6.577962
# 1       3.641145e+16   30.558539  -6.526887
# 2       3.641145e+16   30.543371  -6.386090
# 3       3.641157e+16   30.505943  -7.082107
# 4       3.641157e+16   30.505965  -7.082103
# ...              ...         ...        ...
# 84347   7.464917e+16  213.643409  53.133842
# 84348   7.464917e+16  213.931658  53.150962
# 84349   7.464917e+16  213.641172  53.181188
# 84350   7.464917e+16  213.936543  53.223860
# 84351   7.464917e+16  213.876171  53.242133
#
#                                                    coord  skymap_id  \
# 0        (179117.015625, 99518.6015625, -23628.67578125)   82780005
# 1        (176465.515625, 104189.1328125, -23446.0078125)   82790005
# 2        (176542.1875, 104171.3828125, -22942.353515625)   82790006
# 3      (176357.046875, 103906.8828125, -25430.712890625)   82790102
# 4        (176357.015625, 103906.953125, -25430.69921875)   82790102
# ...

# %%
fig, axes = plt.subplots(2,2, figsize=(15,15))
sns.histplot(x=matched_df['specz_redshift'], y=matched_df['photoz_mean'], ax=axes[0,0])
sns.histplot(x=matched_df['specz_redshift'], y=matched_df['photoz_median'], ax=axes[0,1])
sns.histplot(x=matched_df['specz_redshift'], y=matched_df['photoz_mode'], ax=axes[1,0])
sns.histplot(x=matched_df['specz_redshift'], y=matched_df['photoz_best'], ax=axes[1,1])
# Out:
# <AxesSubplot:xlabel='specz_redshift', ylabel='photoz_best'>

# %%
sns.set(rc={'figure.figsize':(10, 10)})
sns.histplot(x=matched_df['specz_redshift'], y=matched_df['photoz_best'])
sns.kdeplot(x=matched_df['specz_redshift'], y=matched_df['photoz_best'])
sns.lineplot(x=[0,4],y=[0,4])
# Out:
# <AxesSubplot:xlabel='specz_redshift', ylabel='photoz_best'>

# %%
from photoz_metrics import *
z_photo = matched_df['photoz_best']
z_spec = matched_df['specz_redshift']

# %%
bias = calculate_bias(z_photo, z_spec)
scatter = calculate_scatter(z_photo, z_spec)
outlier_rate_conv = calculate_outlier_rate(z_photo, z_spec, conventional=True)
outlier_rate_bw = calculate_outlier_rate(z_photo, z_spec, conventional=False)
loss_function = calculate_loss(z_photo, z_spec)

# %%
print(f"Bias: {bias}")
print(f"Scatter: {scatter}")
print(f"Conventional outlier rate: {outlier_rate_conv}")
print(f"Biweight outlier rate: {outlier_rate_bw}")
# Out:
# Bias: 0.18683867491752199
# Scatter: 0.6130142136911716
# Conventional outlier rate: 0.7222000899569492
# Biweight outlier rate: 0.09684508128252907

# %%
sns.histplot(loss_function)
# Out:
# <AxesSubplot:ylabel='Count'>
