# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
import neptune.new as neptune
from neptune.new.integrations.tensorflow_keras import NeptuneCallback

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 20000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %% [markdown]
# hf = h5py.File('/data/HSC/HSC_v6/step3/127x127_out.hdf5', 'r')
# y_array = np.asarray(hf['specz_redshift'][0:])[..., None]
# hf.close()
# plt.hist(y_array, bins = 100, color = 'red', alpha = 0.5)
# hf = h5py.File('/data/HSC/HSC_v6/step3/127x127_in.hdf5', 'r')
# y_array = np.asarray(hf['specz_redshift'][0:])[..., None]
# hf.close()
# plt.hist(y_array, bins = 100, color = 'blue', alpha = 0.5)
# plt.show()

# %% [markdown]
# hf = h5py.File('/data/HSC/HSC_v6/step3/127x127_out.hdf5', 'r')
# y_array = np.asarray(hf['specz_redshift'][0:])[..., None]
# hf.close()
# plt.hist(y_array, bins = 100, color = 'red', alpha = 0.5)
# plt.show()
# hf = h5py.File('/data/HSC/HSC_v6/step3/127x127_in.hdf5', 'r')
# y_array = np.asarray(hf['specz_redshift'][0:])[..., None]
# hf.close()
# plt.hist(y_array, bins = 100, color = 'blue', alpha = 0.5)
# plt.show()

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step3/127x127_mae_in_training_small.hdf5', 'r')
hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_mae_in_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step3/127x127_mae_in_validation_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:], (0, 2, 3, 1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:], (0, 2, 3, 1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:], (0, 2, 3, 1)))
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
object_id_train = np.asarray(hf_train['object_id'][0:])
object_id = np.asarray(hf_test['object_id'][0:])
object_id_validation = np.asarray(hf_validation['object_id'][0:])
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
hf_train_2 = h5py.File('/data/HSC/HSC_v6/step3/127x127_mae_out_training_small.hdf5', 'r')
hf_test_2 = h5py.File('/data/HSC/HSC_v6/step3/127x127_mae_out_testing_small.hdf5', 'r')
hf_validation_2 = h5py.File('/data/HSC/HSC_v6/step3/127x127_mae_out_validation_small.hdf5', 'r')
x_train_2 = np.asarray(np.transpose(hf_train_2['image'][0:], (0, 2 ,3 ,1)))
x_test_2 = np.asarray(np.transpose(hf_test_2['image'][0:], (0, 2, 3, 1)))
x_validation_2 = np.asarray(np.transpose(hf_validation_2['image'][0:], (0, 2, 3, 1)))
x_train_2 = np.true_divide(x_train_2, max_value)
x_test_2 = np.true_divide(x_test_2, max_value)
x_validation_2 = np.true_divide(x_validation_2, max_value)
y_train_2 = np.asarray(hf_train_2['specz_redshift'][0:])[..., None]
y_test_2 = np.asarray(hf_test_2['specz_redshift'][0:])[..., None]
y_validation_2 = np.asarray(hf_validation_2['specz_redshift'][0:])[..., None]
object_id_train_2 = np.asarray(hf_train_2['object_id'][0:])
object_id_2 = np.asarray(hf_test_2['object_id'][0:])
object_id_validation_2 = np.asarray(hf_validation_2['object_id'][0:])
hf_train_2.close()
hf_test_2.close()
hf_validation_2.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.callbacks import ReduceLROnPlateau

# %%
model_1 = Sequential([
    InputLayer(input_shape = (127, 127, 5)),
    Conv2D(32, kernel_size = (3, 3), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_1.build((10000, 127, 127, 5))

model_1.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper (ModuleWrappe (10000, 127, 127, 5)      0
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (10000, 125, 125, 32)     1472
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (10000, 62, 62, 32)       0
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (10000, 61, 61, 32)       4128
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (10000, 30, 30, 32)       0
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (10000, 28, 28, 32)       9248
# _________________________________________________________________
# module_wrapper_6 (ModuleWrap (10000, 27, 27, 32)       4128
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (10000, 23328)            0
# _________________________________________________________________
# dense_variational (DenseVari (10000, 64)               4479168
# _________________________________________________________________
# dense_variational_1 (DenseVa (10000, 64)               12480
# _________________________________________________________________
# module_wrapper_8 (ModuleWrap (10000, 2)                130
# _________________________________________________________________
# independent_normal (Independ multiple                  0
# =================================================================
# Total params: 4,510,754
# Trainable params: 4,510,754
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2 = Sequential([
    InputLayer(input_shape = (127, 127, 5)),
    Conv2D(32, kernel_size = (3, 3), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_2.build((10000, 127, 127, 5))

model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_9 (ModuleWrap (10000, 127, 127, 5)      0
# _________________________________________________________________
# module_wrapper_10 (ModuleWra (10000, 125, 125, 32)     1472
# _________________________________________________________________
# module_wrapper_11 (ModuleWra (10000, 62, 62, 32)       0
# _________________________________________________________________
# module_wrapper_12 (ModuleWra (10000, 61, 61, 32)       4128
# _________________________________________________________________
# module_wrapper_13 (ModuleWra (10000, 30, 30, 32)       0
# _________________________________________________________________
# module_wrapper_14 (ModuleWra (10000, 28, 28, 32)       9248
# _________________________________________________________________
# module_wrapper_15 (ModuleWra (10000, 27, 27, 32)       4128
# _________________________________________________________________
# module_wrapper_16 (ModuleWra (10000, 23328)            0
# _________________________________________________________________
# dense_variational_2 (DenseVa (10000, 64)               4479168
# _________________________________________________________________
# dense_variational_3 (DenseVa (10000, 64)               12480
# _________________________________________________________________
# module_wrapper_17 (ModuleWra (10000, 2)                130
# _________________________________________________________________
# independent_normal_1 (Indepe multiple                  0
# =================================================================
# Total params: 4,510,754
# Trainable params: 4,510,754
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return - estimated_distribution.log_prob(targets)

model_1.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])
model_2.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
run = neptune.init(
    name = "Filtered Data Test",
    project = "astro-data-lab/VAE",
    api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxOGFlZGMxOC04MWU5LTQ2NDctYjlhZS05NGE2NGQ0NmIzMmEifQ==",
)  # your credentials
# Out:
# https://app.neptune.ai/astro-data-lab/VAE/e/VAE-61
# Remember to stop your run once you’ve finished logging your metadata (https://docs.neptune.ai/api-reference/run#.stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %%
# import tensorboard

# model_name = 'HSC_v6_BCNN_v5'

# checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

# weights_path = os.path.join('/models/', model_name) + '/weights'

# log_dir = os.path.join('/logs/', model_name)

# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

lr_callback = ReduceLROnPlateau()

neptune_callback = NeptuneCallback(run = run)

# %%
model_1.fit(x = x_train, y = y_train, epochs = 600, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [neptune_callback, lr_callback])
model_2.fit(x = x_train_2, y = y_train_2, epochs = 600, shuffle = True, verbose = 1, validation_data = (x_validation_2, y_validation_2), callbacks = [neptune_callback, lr_callback])
# Out:
# Epoch 1/600
# 313/313 [==============================] - 411s 12ms/step - loss: 4080.6260 - root_mean_squared_error: 0.9679 - val_loss: 3391.0200 - val_root_mean_squared_error: 0.8456
# Epoch 2/600
# 313/313 [==============================] - 3s 10ms/step - loss: 2917.3191 - root_mean_squared_error: 0.7881 - val_loss: 2501.2629 - val_root_mean_squared_error: 0.7432
# Epoch 3/600
# 313/313 [==============================] - 3s 10ms/step - loss: 2182.9138 - root_mean_squared_error: 0.7167 - val_loss: 1898.8781 - val_root_mean_squared_error: 0.6972
# Epoch 4/600
# 313/313 [==============================] - 3s 10ms/step - loss: 1674.0912 - root_mean_squared_error: 0.6812 - val_loss: 1470.8942 - val_root_mean_squared_error: 0.6668
# Epoch 5/600
# 313/313 [==============================] - 3s 10ms/step - loss: 1306.9629 - root_mean_squared_error: 0.6522 - val_loss: 1157.0157 - val_root_mean_squared_error: 0.6425
# Epoch 6/600
# 313/313 [==============================] - 3s 10ms/step - loss: 1034.1033 - root_mean_squared_error: 0.6351 - val_loss: 920.8883 - val_root_mean_squared_error: 0.6278
# Epoch 7/600
# 313/313 [==============================] - 3s 10ms/step - loss: 826.0504 - root_mean_squared_error: 0.6206 - val_loss: 738.3934 - val_root_mean_squared_error: 0.6127
# Epoch 8/600
# 313/313 [==============================] - 3s 10ms/step - loss: 664.6683 - root_mean_squared_error: 0.6073 - val_loss: 596.4230 - val_root_mean_squared_error: 0.6057
# Epoch 9/600
# 313/313 [==============================] - 3s 10ms/step - loss: 537.4614 - root_mean_squared_error: 0.6057 - val_loss: 482.9237 - val_root_mean_squared_error: 0.6119
# Epoch 10/600
# 313/313 [==============================] - 3s 10ms/step - loss: 435.7115 - root_mean_squared_error: 0.6150 - val_loss: 392.0844 - val_root_mean_squared_error: 0.6101
# Epoch 11/600
# 313/313 [==============================] - 3s 10ms/step - loss: 353.9420 - root_mean_squared_error: 0.6045 - val_loss: 318.4651 - val_root_mean_squared_error: 0.6000
# Epoch 12/600
# 313/313 [==============================] - 3s 10ms/step - loss: 287.5183 - root_mean_squared_error: 0.5948 - val_loss: 258.8528 - val_root_mean_squared_error: 0.5900
# Epoch 13/600
# 313/313 [==============================] - 3s 10ms/step - loss: 233.3733 - root_mean_squared_error: 0.5853 - val_loss: 210.2797 - val_root_mean_squared_error: 0.5806
# Epoch 14/600
# 313/313 [==============================] - 3s 10ms/step - loss: 189.1526 - root_mean_squared_error: 0.5760 - val_loss: 170.1321 - val_root_mean_squared_error: 0.5728
# Epoch 15/600
# 313/313 [==============================] - 3s 10ms/step - loss: 152.8911 - root_mean_squared_error: 0.5707 - val_loss: 137.4411 - val_root_mean_squared_error: 0.5668
# Epoch 16/600
# 313/313 [==============================] - 3s 10ms/step - loss: 123.1109 - root_mean_squared_error: 0.5630 - val_loss: 110.5157 - val_root_mean_squared_error: 0.5598
# Epoch 17/600
# 313/313 [==============================] - 3s 10ms/step - loss: 98.9324 - root_mean_squared_error: 0.5629 - val_loss: 89.2528 - val_root_mean_squared_error: 0.5684
# Epoch 18/600
# 313/313 [==============================] - 3s 10ms/step - loss: 78.9719 - root_mean_squared_error: 0.5662 - val_loss: 70.9397 - val_root_mean_squared_error: 0.5627
# Epoch 19/600
# 313/313 [==============================] - 3s 10ms/step - loss: 62.8463 - root_mean_squared_error: 0.5593 - val_loss: 56.2736 - val_root_mean_squared_error: 0.5562
# Epoch 20/600
# 313/313 [==============================] - 3s 10ms/step - loss: 49.8219 - root_mean_squared_error: 0.5538 - val_loss: 44.4985 - val_root_mean_squared_error: 0.5511
# Epoch 21/600
# 313/313 [==============================] - 3s 10ms/step - loss: 39.2915 - root_mean_squared_error: 0.5487 - val_loss: 35.4662 - val_root_mean_squared_error: 0.5459
# Epoch 22/600
# 313/313 [==============================] - 3s 10ms/step - loss: 30.9467 - root_mean_squared_error: 0.5431 - val_loss: 28.1923 - val_root_mean_squared_error: 0.5405
# Epoch 23/600
# 313/313 [==============================] - 3s 10ms/step - loss: 24.4696 - root_mean_squared_error: 0.5382 - val_loss: 22.5921 - val_root_mean_squared_error: 0.5360
# Epoch 24/600
# 313/313 [==============================] - 3s 10ms/step - loss: 19.3493 - root_mean_squared_error: 0.5340 - val_loss: 18.3573 - val_root_mean_squared_error: 0.5316
# Epoch 25/600
# 313/313 [==============================] - 3s 10ms/step - loss: 15.4193 - root_mean_squared_error: 0.5295 - val_loss: 15.4815 - val_root_mean_squared_error: 0.5275
# Epoch 26/600
# 313/313 [==============================] - 3s 10ms/step - loss: 12.5037 - root_mean_squared_error: 0.5257 - val_loss: 12.1900 - val_root_mean_squared_error: 0.5240
# Epoch 27/600
# 313/313 [==============================] - 3s 10ms/step - loss: 10.3334 - root_mean_squared_error: 0.5223 - val_loss: 10.5568 - val_root_mean_squared_error: 0.5210
# Epoch 28/600
# 313/313 [==============================] - 3s 10ms/step - loss: 8.7341 - root_mean_squared_error: 0.5188 - val_loss: 10.2540 - val_root_mean_squared_error: 0.5175
# Epoch 29/600
# 313/313 [==============================] - 3s 10ms/step - loss: 7.6405 - root_mean_squared_error: 0.5168 - val_loss: 9.4687 - val_root_mean_squared_error: 0.5151
# Epoch 30/600
# 313/313 [==============================] - 3s 10ms/step - loss: 6.8841 - root_mean_squared_error: 0.5135 - val_loss: 9.3752 - val_root_mean_squared_error: 0.5122
# Epoch 31/600
# 313/313 [==============================] - 3s 10ms/step - loss: 6.3611 - root_mean_squared_error: 0.5106 - val_loss: 7.9341 - val_root_mean_squared_error: 0.5087
# Epoch 32/600
# 313/313 [==============================] - 3s 10ms/step - loss: 6.0325 - root_mean_squared_error: 0.5071 - val_loss: 9.5316 - val_root_mean_squared_error: 0.5054
# Epoch 33/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.8206 - root_mean_squared_error: 0.5040 - val_loss: 7.6093 - val_root_mean_squared_error: 0.5023
# Epoch 34/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.7211 - root_mean_squared_error: 0.5012 - val_loss: 10.3284 - val_root_mean_squared_error: 0.4997
# Epoch 35/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6684 - root_mean_squared_error: 0.4993 - val_loss: 12.0487 - val_root_mean_squared_error: 0.4981
# Epoch 36/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6192 - root_mean_squared_error: 0.4969 - val_loss: 9.8154 - val_root_mean_squared_error: 0.4957
# Epoch 37/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6279 - root_mean_squared_error: 0.4944 - val_loss: 11.5934 - val_root_mean_squared_error: 0.4936
# Epoch 38/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6340 - root_mean_squared_error: 0.4928 - val_loss: 11.9766 - val_root_mean_squared_error: 0.4919
# Epoch 39/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.5685 - root_mean_squared_error: 0.4906 - val_loss: 12.3880 - val_root_mean_squared_error: 0.4893
# Epoch 40/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6432 - root_mean_squared_error: 0.4882 - val_loss: 11.4955 - val_root_mean_squared_error: 0.4875
# Epoch 41/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6205 - root_mean_squared_error: 0.4867 - val_loss: 10.7157 - val_root_mean_squared_error: 0.4857
# Epoch 42/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.6301 - root_mean_squared_error: 0.4847 - val_loss: 13.0395 - val_root_mean_squared_error: 0.4837
# Epoch 43/600
# 313/313 [==============================] - 3s 10ms/step - loss: 5.5982 - root_mean_squared_error: 0.4829 - val_loss: 11.0950 - val_root_mean_squared_error: 0.4819
# Epoch 44/600
# 313/313 [==============================] - 3s 10ms/step - loss: -0.4541 - root_mean_squared_error: 0.4805 - val_loss: 12.2971 - val_root_mean_squared_error: 0.4790
# Epoch 45/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.1980 - root_mean_squared_error: 0.4777 - val_loss: 14.2560 - val_root_mean_squared_error: 0.4765
# Epoch 46/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.2602 - root_mean_squared_error: 0.4751 - val_loss: 22.5580 - val_root_mean_squared_error: 0.4742
# Epoch 47/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.3035 - root_mean_squared_error: 0.4733 - val_loss: 23.1395 - val_root_mean_squared_error: 0.4723
# Epoch 48/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.3336 - root_mean_squared_error: 0.4713 - val_loss: 21.7863 - val_root_mean_squared_error: 0.4702
# Epoch 49/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.3747 - root_mean_squared_error: 0.4691 - val_loss: 24.8842 - val_root_mean_squared_error: 0.4681
# Epoch 50/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.3893 - root_mean_squared_error: 0.4672 - val_loss: 27.6354 - val_root_mean_squared_error: 0.4663
# Epoch 51/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.4162 - root_mean_squared_error: 0.4654 - val_loss: 31.0259 - val_root_mean_squared_error: 0.4645
# Epoch 52/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.4361 - root_mean_squared_error: 0.4635 - val_loss: 36.5954 - val_root_mean_squared_error: 0.4627
# Epoch 53/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.4457 - root_mean_squared_error: 0.4616 - val_loss: 35.2501 - val_root_mean_squared_error: 0.4607
# Epoch 54/600
# 313/313 [==============================] - 3s 10ms/step - loss: -1.7953 - root_mean_squared_error: 0.4597 - val_loss: 51.1433 - val_root_mean_squared_error: 0.4588
# Epoch 55/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.1159 - root_mean_squared_error: 0.4579 - val_loss: 48.8590 - val_root_mean_squared_error: 0.4570
# Epoch 56/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.1960 - root_mean_squared_error: 0.4561 - val_loss: 44.9420 - val_root_mean_squared_error: 0.4551
# Epoch 57/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2412 - root_mean_squared_error: 0.4543 - val_loss: 55.6985 - val_root_mean_squared_error: 0.4535
# Epoch 58/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2350 - root_mean_squared_error: 0.4528 - val_loss: 43.8309 - val_root_mean_squared_error: 0.4521
# Epoch 59/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2422 - root_mean_squared_error: 0.4513 - val_loss: 49.5623 - val_root_mean_squared_error: 0.4506
# Epoch 60/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2617 - root_mean_squared_error: 0.4497 - val_loss: 53.1972 - val_root_mean_squared_error: 0.4490
# Epoch 61/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2482 - root_mean_squared_error: 0.4483 - val_loss: 58.5708 - val_root_mean_squared_error: 0.4476
# Epoch 62/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2485 - root_mean_squared_error: 0.4469 - val_loss: 86.1614 - val_root_mean_squared_error: 0.4463
# Epoch 63/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2650 - root_mean_squared_error: 0.4456 - val_loss: 53.4671 - val_root_mean_squared_error: 0.4451
# Epoch 64/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2901 - root_mean_squared_error: 0.4445 - val_loss: 62.3615 - val_root_mean_squared_error: 0.4439
# Epoch 65/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2937 - root_mean_squared_error: 0.4433 - val_loss: 59.1375 - val_root_mean_squared_error: 0.4427
# Epoch 66/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3051 - root_mean_squared_error: 0.4420 - val_loss: 75.8038 - val_root_mean_squared_error: 0.4413
# Epoch 67/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.2905 - root_mean_squared_error: 0.4406 - val_loss: 66.0604 - val_root_mean_squared_error: 0.4400
# Epoch 68/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3163 - root_mean_squared_error: 0.4394 - val_loss: 49.6573 - val_root_mean_squared_error: 0.4387
# Epoch 69/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3153 - root_mean_squared_error: 0.4382 - val_loss: 79.5012 - val_root_mean_squared_error: 0.4376
# Epoch 70/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3089 - root_mean_squared_error: 0.4370 - val_loss: 76.9057 - val_root_mean_squared_error: 0.4366
# Epoch 71/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3257 - root_mean_squared_error: 0.4360 - val_loss: 48.5065 - val_root_mean_squared_error: 0.4354
# Epoch 72/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3260 - root_mean_squared_error: 0.4351 - val_loss: 46.9775 - val_root_mean_squared_error: 0.4347
# Epoch 73/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3373 - root_mean_squared_error: 0.4342 - val_loss: 97.4870 - val_root_mean_squared_error: 0.4337
# Epoch 74/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3362 - root_mean_squared_error: 0.4332 - val_loss: 71.7262 - val_root_mean_squared_error: 0.4327
# Epoch 75/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3422 - root_mean_squared_error: 0.4323 - val_loss: 61.5421 - val_root_mean_squared_error: 0.4319
# Epoch 76/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3298 - root_mean_squared_error: 0.4314 - val_loss: 76.4083 - val_root_mean_squared_error: 0.4310
# Epoch 77/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3340 - root_mean_squared_error: 0.4304 - val_loss: 51.6775 - val_root_mean_squared_error: 0.4300
# Epoch 78/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3300 - root_mean_squared_error: 0.4297 - val_loss: 49.5795 - val_root_mean_squared_error: 0.4292
# Epoch 79/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3326 - root_mean_squared_error: 0.4288 - val_loss: 90.6959 - val_root_mean_squared_error: 0.4285
# Epoch 80/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3295 - root_mean_squared_error: 0.4280 - val_loss: 63.0967 - val_root_mean_squared_error: 0.4276
# Epoch 81/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3441 - root_mean_squared_error: 0.4273 - val_loss: 68.1591 - val_root_mean_squared_error: 0.4271
# Epoch 82/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3429 - root_mean_squared_error: 0.4268 - val_loss: 59.8179 - val_root_mean_squared_error: 0.4265
# Epoch 83/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3569 - root_mean_squared_error: 0.4261 - val_loss: 68.7612 - val_root_mean_squared_error: 0.4257
# Epoch 84/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3418 - root_mean_squared_error: 0.4252 - val_loss: 47.8123 - val_root_mean_squared_error: 0.4248
# Epoch 85/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3469 - root_mean_squared_error: 0.4244 - val_loss: 83.7779 - val_root_mean_squared_error: 0.4241
# Epoch 86/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3428 - root_mean_squared_error: 0.4237 - val_loss: 44.4657 - val_root_mean_squared_error: 0.4233
# Epoch 87/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3376 - root_mean_squared_error: 0.4229 - val_loss: 104.1469 - val_root_mean_squared_error: 0.4226
# Epoch 88/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3302 - root_mean_squared_error: 0.4223 - val_loss: 68.4413 - val_root_mean_squared_error: 0.4219
# Epoch 89/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3355 - root_mean_squared_error: 0.4216 - val_loss: 86.2105 - val_root_mean_squared_error: 0.4212
# Epoch 90/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3417 - root_mean_squared_error: 0.4208 - val_loss: 81.7135 - val_root_mean_squared_error: 0.4205
# Epoch 91/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3378 - root_mean_squared_error: 0.4203 - val_loss: 55.1147 - val_root_mean_squared_error: 0.4199
# Epoch 92/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3391 - root_mean_squared_error: 0.4195 - val_loss: 74.7708 - val_root_mean_squared_error: 0.4193
# Epoch 93/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3273 - root_mean_squared_error: 0.4190 - val_loss: 79.4584 - val_root_mean_squared_error: 0.4186
# Epoch 94/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3410 - root_mean_squared_error: 0.4182 - val_loss: 66.8132 - val_root_mean_squared_error: 0.4179
# Epoch 95/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3422 - root_mean_squared_error: 0.4176 - val_loss: 67.4571 - val_root_mean_squared_error: 0.4173
# Epoch 96/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3382 - root_mean_squared_error: 0.4170 - val_loss: 60.9429 - val_root_mean_squared_error: 0.4168
# Epoch 97/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3359 - root_mean_squared_error: 0.4166 - val_loss: 79.9743 - val_root_mean_squared_error: 0.4164
# Epoch 98/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3452 - root_mean_squared_error: 0.4160 - val_loss: 68.3470 - val_root_mean_squared_error: 0.4157
# Epoch 99/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3326 - root_mean_squared_error: 0.4155 - val_loss: 89.7902 - val_root_mean_squared_error: 0.4152
# Epoch 100/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3347 - root_mean_squared_error: 0.4149 - val_loss: 79.8968 - val_root_mean_squared_error: 0.4146
# Epoch 101/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3352 - root_mean_squared_error: 0.4144 - val_loss: 62.0866 - val_root_mean_squared_error: 0.4142
# Epoch 102/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3419 - root_mean_squared_error: 0.4139 - val_loss: 99.9671 - val_root_mean_squared_error: 0.4137
# Epoch 103/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3469 - root_mean_squared_error: 0.4133 - val_loss: 69.9286 - val_root_mean_squared_error: 0.4131
# Epoch 104/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3362 - root_mean_squared_error: 0.4130 - val_loss: 43.6174 - val_root_mean_squared_error: 0.4128
# Epoch 105/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3376 - root_mean_squared_error: 0.4125 - val_loss: 53.5461 - val_root_mean_squared_error: 0.4123
# Epoch 106/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3402 - root_mean_squared_error: 0.4121 - val_loss: 76.1810 - val_root_mean_squared_error: 0.4118
# Epoch 107/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3369 - root_mean_squared_error: 0.4116 - val_loss: 67.0233 - val_root_mean_squared_error: 0.4113
# Epoch 108/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3308 - root_mean_squared_error: 0.4111 - val_loss: 64.9711 - val_root_mean_squared_error: 0.4108
# Epoch 109/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3351 - root_mean_squared_error: 0.4106 - val_loss: 72.4390 - val_root_mean_squared_error: 0.4104
# Epoch 110/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3415 - root_mean_squared_error: 0.4101 - val_loss: 62.5316 - val_root_mean_squared_error: 0.4100
# Epoch 111/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3393 - root_mean_squared_error: 0.4098 - val_loss: 62.8699 - val_root_mean_squared_error: 0.4097
# Epoch 112/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3381 - root_mean_squared_error: 0.4094 - val_loss: 67.5893 - val_root_mean_squared_error: 0.4091
# Epoch 113/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3227 - root_mean_squared_error: 0.4088 - val_loss: 78.6447 - val_root_mean_squared_error: 0.4086
# Epoch 114/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3363 - root_mean_squared_error: 0.4083 - val_loss: 45.9966 - val_root_mean_squared_error: 0.4082
# Epoch 115/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3361 - root_mean_squared_error: 0.4079 - val_loss: 58.8547 - val_root_mean_squared_error: 0.4076
# Epoch 116/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3383 - root_mean_squared_error: 0.4073 - val_loss: 62.2977 - val_root_mean_squared_error: 0.4070
# Epoch 117/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3352 - root_mean_squared_error: 0.4068 - val_loss: 61.5654 - val_root_mean_squared_error: 0.4066
# Epoch 118/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3357 - root_mean_squared_error: 0.4064 - val_loss: 57.9681 - val_root_mean_squared_error: 0.4062
# Epoch 119/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3447 - root_mean_squared_error: 0.4061 - val_loss: 59.7130 - val_root_mean_squared_error: 0.4060
# Epoch 120/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3289 - root_mean_squared_error: 0.4060 - val_loss: 70.4891 - val_root_mean_squared_error: 0.4058
# Epoch 121/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3311 - root_mean_squared_error: 0.4056 - val_loss: 64.2730 - val_root_mean_squared_error: 0.4054
# Epoch 122/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3470 - root_mean_squared_error: 0.4053 - val_loss: 70.7866 - val_root_mean_squared_error: 0.4052
# Epoch 123/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3370 - root_mean_squared_error: 0.4051 - val_loss: 71.1276 - val_root_mean_squared_error: 0.4050
# Epoch 124/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3314 - root_mean_squared_error: 0.4047 - val_loss: 85.9154 - val_root_mean_squared_error: 0.4045
# Epoch 125/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3343 - root_mean_squared_error: 0.4043 - val_loss: 68.3186 - val_root_mean_squared_error: 0.4042
# Epoch 126/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3220 - root_mean_squared_error: 0.4039 - val_loss: 68.7978 - val_root_mean_squared_error: 0.4037
# Epoch 127/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3254 - root_mean_squared_error: 0.4034 - val_loss: 53.3046 - val_root_mean_squared_error: 0.4032
# Epoch 128/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3264 - root_mean_squared_error: 0.4030 - val_loss: 58.7076 - val_root_mean_squared_error: 0.4027
# Epoch 129/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3315 - root_mean_squared_error: 0.4025 - val_loss: 55.0684 - val_root_mean_squared_error: 0.4023
# Epoch 130/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3297 - root_mean_squared_error: 0.4023 - val_loss: 43.0271 - val_root_mean_squared_error: 0.4022
# Epoch 131/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3204 - root_mean_squared_error: 0.4020 - val_loss: 51.1967 - val_root_mean_squared_error: 0.4019
# Epoch 132/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3285 - root_mean_squared_error: 0.4018 - val_loss: 63.9706 - val_root_mean_squared_error: 0.4016
# Epoch 133/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3299 - root_mean_squared_error: 0.4014 - val_loss: 87.5628 - val_root_mean_squared_error: 0.4013
# Epoch 134/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3353 - root_mean_squared_error: 0.4011 - val_loss: 57.4700 - val_root_mean_squared_error: 0.4009
# Epoch 135/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3450 - root_mean_squared_error: 0.4007 - val_loss: 71.0091 - val_root_mean_squared_error: 0.4006
# Epoch 136/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3431 - root_mean_squared_error: 0.4004 - val_loss: 50.6763 - val_root_mean_squared_error: 0.4003
# Epoch 137/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3334 - root_mean_squared_error: 0.4001 - val_loss: 63.4532 - val_root_mean_squared_error: 0.4000
# Epoch 138/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3392 - root_mean_squared_error: 0.3998 - val_loss: 78.8695 - val_root_mean_squared_error: 0.3997
# Epoch 139/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3439 - root_mean_squared_error: 0.3996 - val_loss: 87.1880 - val_root_mean_squared_error: 0.3994
# Epoch 140/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3379 - root_mean_squared_error: 0.3991 - val_loss: 85.4323 - val_root_mean_squared_error: 0.3989
# Epoch 141/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3383 - root_mean_squared_error: 0.3988 - val_loss: 63.6508 - val_root_mean_squared_error: 0.3986
# Epoch 142/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3383 - root_mean_squared_error: 0.3985 - val_loss: 54.9042 - val_root_mean_squared_error: 0.3983
# Epoch 143/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3371 - root_mean_squared_error: 0.3981 - val_loss: 82.7918 - val_root_mean_squared_error: 0.3980
# Epoch 144/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3433 - root_mean_squared_error: 0.3979 - val_loss: 65.1157 - val_root_mean_squared_error: 0.3978
# Epoch 145/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3293 - root_mean_squared_error: 0.3977 - val_loss: 90.9988 - val_root_mean_squared_error: 0.3975
# Epoch 146/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3402 - root_mean_squared_error: 0.3974 - val_loss: 89.0891 - val_root_mean_squared_error: 0.3974
# Epoch 147/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3440 - root_mean_squared_error: 0.3973 - val_loss: 69.3832 - val_root_mean_squared_error: 0.3971
# Epoch 148/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3347 - root_mean_squared_error: 0.3969 - val_loss: 62.5262 - val_root_mean_squared_error: 0.3968
# Epoch 149/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3428 - root_mean_squared_error: 0.3967 - val_loss: 50.7387 - val_root_mean_squared_error: 0.3967
# Epoch 150/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3303 - root_mean_squared_error: 0.3965 - val_loss: 72.2917 - val_root_mean_squared_error: 0.3963
# Epoch 151/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3409 - root_mean_squared_error: 0.3962 - val_loss: 48.6468 - val_root_mean_squared_error: 0.3962
# Epoch 152/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3263 - root_mean_squared_error: 0.3961 - val_loss: 79.2218 - val_root_mean_squared_error: 0.3959
# Epoch 153/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3341 - root_mean_squared_error: 0.3958 - val_loss: 71.4296 - val_root_mean_squared_error: 0.3956
# Epoch 154/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3267 - root_mean_squared_error: 0.3956 - val_loss: 73.4641 - val_root_mean_squared_error: 0.3955
# Epoch 155/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3320 - root_mean_squared_error: 0.3954 - val_loss: 67.6270 - val_root_mean_squared_error: 0.3953
# Epoch 156/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3329 - root_mean_squared_error: 0.3951 - val_loss: 103.6104 - val_root_mean_squared_error: 0.3950
# Epoch 157/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3424 - root_mean_squared_error: 0.3949 - val_loss: 56.4500 - val_root_mean_squared_error: 0.3947
# Epoch 158/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3384 - root_mean_squared_error: 0.3946 - val_loss: 53.0148 - val_root_mean_squared_error: 0.3944
# Epoch 159/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3288 - root_mean_squared_error: 0.3943 - val_loss: 54.5899 - val_root_mean_squared_error: 0.3942
# Epoch 160/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3394 - root_mean_squared_error: 0.3941 - val_loss: 57.7995 - val_root_mean_squared_error: 0.3940
# Epoch 161/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3295 - root_mean_squared_error: 0.3939 - val_loss: 48.0106 - val_root_mean_squared_error: 0.3938
# Epoch 162/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3401 - root_mean_squared_error: 0.3937 - val_loss: 83.3659 - val_root_mean_squared_error: 0.3937
# Epoch 163/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3346 - root_mean_squared_error: 0.3935 - val_loss: 75.5538 - val_root_mean_squared_error: 0.3934
# Epoch 164/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3258 - root_mean_squared_error: 0.3933 - val_loss: 68.8560 - val_root_mean_squared_error: 0.3932
# Epoch 165/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3373 - root_mean_squared_error: 0.3931 - val_loss: 59.7050 - val_root_mean_squared_error: 0.3930
# Epoch 166/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3500 - root_mean_squared_error: 0.3929 - val_loss: 55.9905 - val_root_mean_squared_error: 0.3929
# Epoch 167/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3287 - root_mean_squared_error: 0.3929 - val_loss: 42.9820 - val_root_mean_squared_error: 0.3927
# Epoch 168/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3385 - root_mean_squared_error: 0.3927 - val_loss: 63.2120 - val_root_mean_squared_error: 0.3925
# Epoch 169/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3357 - root_mean_squared_error: 0.3924 - val_loss: 63.1789 - val_root_mean_squared_error: 0.3923
# Epoch 170/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3326 - root_mean_squared_error: 0.3922 - val_loss: 67.1505 - val_root_mean_squared_error: 0.3922
# Epoch 171/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3418 - root_mean_squared_error: 0.3920 - val_loss: 61.2547 - val_root_mean_squared_error: 0.3918
# Epoch 172/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3394 - root_mean_squared_error: 0.3917 - val_loss: 54.4246 - val_root_mean_squared_error: 0.3916
# Epoch 173/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3307 - root_mean_squared_error: 0.3915 - val_loss: 61.6524 - val_root_mean_squared_error: 0.3914
# Epoch 174/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3394 - root_mean_squared_error: 0.3913 - val_loss: 55.3432 - val_root_mean_squared_error: 0.3912
# Epoch 175/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3359 - root_mean_squared_error: 0.3911 - val_loss: 75.9526 - val_root_mean_squared_error: 0.3909
# Epoch 176/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3331 - root_mean_squared_error: 0.3909 - val_loss: 69.6248 - val_root_mean_squared_error: 0.3908
# Epoch 177/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3299 - root_mean_squared_error: 0.3907 - val_loss: 81.2965 - val_root_mean_squared_error: 0.3907
# Epoch 178/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3433 - root_mean_squared_error: 0.3905 - val_loss: 54.4837 - val_root_mean_squared_error: 0.3904
# Epoch 179/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3331 - root_mean_squared_error: 0.3903 - val_loss: 66.7273 - val_root_mean_squared_error: 0.3902
# Epoch 180/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3380 - root_mean_squared_error: 0.3902 - val_loss: 75.3234 - val_root_mean_squared_error: 0.3901
# Epoch 181/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3254 - root_mean_squared_error: 0.3900 - val_loss: 93.9322 - val_root_mean_squared_error: 0.3899
# Epoch 182/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3465 - root_mean_squared_error: 0.3898 - val_loss: 71.3148 - val_root_mean_squared_error: 0.3897
# Epoch 183/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3357 - root_mean_squared_error: 0.3896 - val_loss: 91.0128 - val_root_mean_squared_error: 0.3895
# Epoch 184/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3366 - root_mean_squared_error: 0.3895 - val_loss: 75.4524 - val_root_mean_squared_error: 0.3894
# Epoch 185/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3331 - root_mean_squared_error: 0.3892 - val_loss: 96.1981 - val_root_mean_squared_error: 0.3891
# Epoch 186/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3465 - root_mean_squared_error: 0.3891 - val_loss: 49.7688 - val_root_mean_squared_error: 0.3890
# Epoch 187/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3398 - root_mean_squared_error: 0.3889 - val_loss: 61.0129 - val_root_mean_squared_error: 0.3888
# Epoch 188/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3292 - root_mean_squared_error: 0.3887 - val_loss: 76.1430 - val_root_mean_squared_error: 0.3885
# Epoch 189/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3252 - root_mean_squared_error: 0.3885 - val_loss: 86.3740 - val_root_mean_squared_error: 0.3884
# Epoch 190/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3432 - root_mean_squared_error: 0.3883 - val_loss: 65.3750 - val_root_mean_squared_error: 0.3882
# Epoch 191/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3333 - root_mean_squared_error: 0.3881 - val_loss: 63.9113 - val_root_mean_squared_error: 0.3880
# Epoch 192/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3478 - root_mean_squared_error: 0.3880 - val_loss: 53.9601 - val_root_mean_squared_error: 0.3879
# Epoch 193/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3302 - root_mean_squared_error: 0.3878 - val_loss: 64.4703 - val_root_mean_squared_error: 0.3878
# Epoch 194/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3384 - root_mean_squared_error: 0.3878 - val_loss: 58.1479 - val_root_mean_squared_error: 0.3878
# Epoch 195/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3427 - root_mean_squared_error: 0.3877 - val_loss: 56.8929 - val_root_mean_squared_error: 0.3876
# Epoch 196/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3356 - root_mean_squared_error: 0.3876 - val_loss: 39.2724 - val_root_mean_squared_error: 0.3875
# Epoch 197/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3322 - root_mean_squared_error: 0.3875 - val_loss: 97.0390 - val_root_mean_squared_error: 0.3873
# Epoch 198/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3325 - root_mean_squared_error: 0.3872 - val_loss: 70.6546 - val_root_mean_squared_error: 0.3872
# Epoch 199/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3243 - root_mean_squared_error: 0.3871 - val_loss: 70.9963 - val_root_mean_squared_error: 0.3871
# Epoch 200/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3375 - root_mean_squared_error: 0.3871 - val_loss: 76.5534 - val_root_mean_squared_error: 0.3870
# Epoch 201/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3414 - root_mean_squared_error: 0.3869 - val_loss: 73.1003 - val_root_mean_squared_error: 0.3869
# Epoch 202/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3471 - root_mean_squared_error: 0.3868 - val_loss: 83.5790 - val_root_mean_squared_error: 0.3868
# Epoch 203/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3331 - root_mean_squared_error: 0.3868 - val_loss: 62.8306 - val_root_mean_squared_error: 0.3867
# Epoch 204/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3419 - root_mean_squared_error: 0.3866 - val_loss: 55.6435 - val_root_mean_squared_error: 0.3866
# Epoch 205/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3316 - root_mean_squared_error: 0.3865 - val_loss: 78.4929 - val_root_mean_squared_error: 0.3864
# Epoch 206/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3363 - root_mean_squared_error: 0.3863 - val_loss: 68.3784 - val_root_mean_squared_error: 0.3863
# Epoch 207/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3405 - root_mean_squared_error: 0.3862 - val_loss: 73.8142 - val_root_mean_squared_error: 0.3862
# Epoch 208/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3379 - root_mean_squared_error: 0.3861 - val_loss: 68.1044 - val_root_mean_squared_error: 0.3860
# Epoch 209/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3389 - root_mean_squared_error: 0.3859 - val_loss: 62.2128 - val_root_mean_squared_error: 0.3859
# Epoch 210/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3483 - root_mean_squared_error: 0.3859 - val_loss: 63.3087 - val_root_mean_squared_error: 0.3858
# Epoch 211/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3308 - root_mean_squared_error: 0.3857 - val_loss: 61.4788 - val_root_mean_squared_error: 0.3857
# Epoch 212/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3338 - root_mean_squared_error: 0.3856 - val_loss: 83.4844 - val_root_mean_squared_error: 0.3855
# Epoch 213/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3267 - root_mean_squared_error: 0.3855 - val_loss: 61.3996 - val_root_mean_squared_error: 0.3854
# Epoch 214/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3408 - root_mean_squared_error: 0.3854 - val_loss: 55.0199 - val_root_mean_squared_error: 0.3853
# Epoch 215/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3278 - root_mean_squared_error: 0.3853 - val_loss: 68.2054 - val_root_mean_squared_error: 0.3853
# Epoch 216/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3279 - root_mean_squared_error: 0.3852 - val_loss: 55.3943 - val_root_mean_squared_error: 0.3851
# Epoch 217/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3417 - root_mean_squared_error: 0.3850 - val_loss: 61.4286 - val_root_mean_squared_error: 0.3850
# Epoch 218/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3355 - root_mean_squared_error: 0.3849 - val_loss: 47.4803 - val_root_mean_squared_error: 0.3848
# Epoch 219/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3499 - root_mean_squared_error: 0.3847 - val_loss: 87.8459 - val_root_mean_squared_error: 0.3846
# Epoch 220/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3284 - root_mean_squared_error: 0.3846 - val_loss: 64.2695 - val_root_mean_squared_error: 0.3845
# Epoch 221/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3388 - root_mean_squared_error: 0.3845 - val_loss: 67.8654 - val_root_mean_squared_error: 0.3844
# Epoch 222/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3315 - root_mean_squared_error: 0.3843 - val_loss: 57.1364 - val_root_mean_squared_error: 0.3842
# Epoch 223/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3416 - root_mean_squared_error: 0.3842 - val_loss: 65.6337 - val_root_mean_squared_error: 0.3841
# Epoch 224/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3431 - root_mean_squared_error: 0.3840 - val_loss: 77.0720 - val_root_mean_squared_error: 0.3840
# Epoch 225/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3346 - root_mean_squared_error: 0.3839 - val_loss: 75.5339 - val_root_mean_squared_error: 0.3839
# Epoch 226/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3388 - root_mean_squared_error: 0.3838 - val_loss: 61.8710 - val_root_mean_squared_error: 0.3838
# Epoch 227/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3391 - root_mean_squared_error: 0.3837 - val_loss: 89.9547 - val_root_mean_squared_error: 0.3836
# Epoch 228/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3447 - root_mean_squared_error: 0.3836 - val_loss: 62.8880 - val_root_mean_squared_error: 0.3835
# Epoch 229/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3313 - root_mean_squared_error: 0.3834 - val_loss: 51.4790 - val_root_mean_squared_error: 0.3834
# Epoch 230/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3299 - root_mean_squared_error: 0.3833 - val_loss: 54.2527 - val_root_mean_squared_error: 0.3833
# Epoch 231/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3351 - root_mean_squared_error: 0.3832 - val_loss: 54.7837 - val_root_mean_squared_error: 0.3832
# Epoch 232/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3245 - root_mean_squared_error: 0.3831 - val_loss: 59.5064 - val_root_mean_squared_error: 0.3831
# Epoch 233/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3325 - root_mean_squared_error: 0.3830 - val_loss: 90.3913 - val_root_mean_squared_error: 0.3829
# Epoch 234/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3487 - root_mean_squared_error: 0.3828 - val_loss: 56.8682 - val_root_mean_squared_error: 0.3827
# Epoch 235/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3271 - root_mean_squared_error: 0.3827 - val_loss: 60.1350 - val_root_mean_squared_error: 0.3826
# Epoch 236/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3326 - root_mean_squared_error: 0.3826 - val_loss: 71.8827 - val_root_mean_squared_error: 0.3825
# Epoch 237/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3419 - root_mean_squared_error: 0.3825 - val_loss: 70.9239 - val_root_mean_squared_error: 0.3825
# Epoch 238/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3370 - root_mean_squared_error: 0.3824 - val_loss: 62.7246 - val_root_mean_squared_error: 0.3823
# Epoch 239/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3298 - root_mean_squared_error: 0.3823 - val_loss: 76.2480 - val_root_mean_squared_error: 0.3822
# Epoch 240/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3383 - root_mean_squared_error: 0.3822 - val_loss: 60.4628 - val_root_mean_squared_error: 0.3821
# Epoch 241/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3295 - root_mean_squared_error: 0.3821 - val_loss: 54.9196 - val_root_mean_squared_error: 0.3820
# Epoch 242/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3268 - root_mean_squared_error: 0.3820 - val_loss: 71.6419 - val_root_mean_squared_error: 0.3819
# Epoch 243/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3313 - root_mean_squared_error: 0.3819 - val_loss: 76.2375 - val_root_mean_squared_error: 0.3818
# Epoch 244/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3335 - root_mean_squared_error: 0.3819 - val_loss: 47.7939 - val_root_mean_squared_error: 0.3818
# Epoch 245/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3430 - root_mean_squared_error: 0.3818 - val_loss: 53.4163 - val_root_mean_squared_error: 0.3818
# Epoch 246/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3370 - root_mean_squared_error: 0.3818 - val_loss: 79.9753 - val_root_mean_squared_error: 0.3817
# Epoch 247/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3367 - root_mean_squared_error: 0.3817 - val_loss: 74.9649 - val_root_mean_squared_error: 0.3816
# Epoch 248/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3388 - root_mean_squared_error: 0.3816 - val_loss: 65.4384 - val_root_mean_squared_error: 0.3816
# Epoch 249/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3355 - root_mean_squared_error: 0.3815 - val_loss: 64.0281 - val_root_mean_squared_error: 0.3815
# Epoch 250/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3379 - root_mean_squared_error: 0.3814 - val_loss: 52.4115 - val_root_mean_squared_error: 0.3814
# Epoch 251/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3347 - root_mean_squared_error: 0.3813 - val_loss: 70.2305 - val_root_mean_squared_error: 0.3812
# Epoch 252/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3378 - root_mean_squared_error: 0.3812 - val_loss: 78.0805 - val_root_mean_squared_error: 0.3811
# Epoch 253/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3388 - root_mean_squared_error: 0.3811 - val_loss: 60.9292 - val_root_mean_squared_error: 0.3810
# Epoch 254/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3471 - root_mean_squared_error: 0.3810 - val_loss: 85.4859 - val_root_mean_squared_error: 0.3809
# Epoch 255/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3337 - root_mean_squared_error: 0.3808 - val_loss: 60.1803 - val_root_mean_squared_error: 0.3808
# Epoch 256/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3280 - root_mean_squared_error: 0.3807 - val_loss: 69.5055 - val_root_mean_squared_error: 0.3807
# Epoch 257/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3434 - root_mean_squared_error: 0.3806 - val_loss: 68.3938 - val_root_mean_squared_error: 0.3805
# Epoch 258/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3354 - root_mean_squared_error: 0.3805 - val_loss: 58.7224 - val_root_mean_squared_error: 0.3804
# Epoch 259/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3326 - root_mean_squared_error: 0.3803 - val_loss: 70.9918 - val_root_mean_squared_error: 0.3803
# Epoch 260/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3396 - root_mean_squared_error: 0.3802 - val_loss: 69.7197 - val_root_mean_squared_error: 0.3801
# Epoch 261/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3424 - root_mean_squared_error: 0.3802 - val_loss: 81.0860 - val_root_mean_squared_error: 0.3802
# Epoch 262/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3238 - root_mean_squared_error: 0.3801 - val_loss: 52.0148 - val_root_mean_squared_error: 0.3801
# Epoch 263/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3351 - root_mean_squared_error: 0.3800 - val_loss: 76.4349 - val_root_mean_squared_error: 0.3800
# Epoch 264/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3424 - root_mean_squared_error: 0.3800 - val_loss: 60.1684 - val_root_mean_squared_error: 0.3799
# Epoch 265/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3396 - root_mean_squared_error: 0.3798 - val_loss: 73.3023 - val_root_mean_squared_error: 0.3798
# Epoch 266/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3280 - root_mean_squared_error: 0.3797 - val_loss: 77.6652 - val_root_mean_squared_error: 0.3797
# Epoch 267/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3312 - root_mean_squared_error: 0.3796 - val_loss: 69.3883 - val_root_mean_squared_error: 0.3796
# Epoch 268/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3302 - root_mean_squared_error: 0.3795 - val_loss: 43.2839 - val_root_mean_squared_error: 0.3794
# Epoch 269/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3362 - root_mean_squared_error: 0.3794 - val_loss: 54.8464 - val_root_mean_squared_error: 0.3793
# Epoch 270/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3394 - root_mean_squared_error: 0.3793 - val_loss: 70.6924 - val_root_mean_squared_error: 0.3793
# Epoch 271/600
# ...
# Epoch 511/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3047 - root_mean_squared_error: 0.3540 - val_loss: 6.0552 - val_root_mean_squared_error: 0.3540
# Epoch 512/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3109 - root_mean_squared_error: 0.3540 - val_loss: 5.5904 - val_root_mean_squared_error: 0.3540
# Epoch 513/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3058 - root_mean_squared_error: 0.3540 - val_loss: 6.1514 - val_root_mean_squared_error: 0.3539
# Epoch 514/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3010 - root_mean_squared_error: 0.3539 - val_loss: 5.4476 - val_root_mean_squared_error: 0.3539
# Epoch 515/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3063 - root_mean_squared_error: 0.3539 - val_loss: 5.8544 - val_root_mean_squared_error: 0.3538
# Epoch 516/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3076 - root_mean_squared_error: 0.3538 - val_loss: 6.2527 - val_root_mean_squared_error: 0.3537
# Epoch 517/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3093 - root_mean_squared_error: 0.3537 - val_loss: 5.7481 - val_root_mean_squared_error: 0.3537
# Epoch 518/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3085 - root_mean_squared_error: 0.3537 - val_loss: 5.9096 - val_root_mean_squared_error: 0.3536
# Epoch 519/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3125 - root_mean_squared_error: 0.3536 - val_loss: 5.1825 - val_root_mean_squared_error: 0.3536
# Epoch 520/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3185 - root_mean_squared_error: 0.3535 - val_loss: 6.0176 - val_root_mean_squared_error: 0.3535
# Epoch 521/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3149 - root_mean_squared_error: 0.3535 - val_loss: 6.6449 - val_root_mean_squared_error: 0.3535
# Epoch 522/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3109 - root_mean_squared_error: 0.3534 - val_loss: 5.1086 - val_root_mean_squared_error: 0.3534
# Epoch 523/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3023 - root_mean_squared_error: 0.3534 - val_loss: 6.0900 - val_root_mean_squared_error: 0.3533
# Epoch 524/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3114 - root_mean_squared_error: 0.3533 - val_loss: 5.4650 - val_root_mean_squared_error: 0.3533
# Epoch 525/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3120 - root_mean_squared_error: 0.3533 - val_loss: 6.5301 - val_root_mean_squared_error: 0.3533
# Epoch 526/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3078 - root_mean_squared_error: 0.3533 - val_loss: 6.1692 - val_root_mean_squared_error: 0.3532
# Epoch 527/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3054 - root_mean_squared_error: 0.3532 - val_loss: 5.6191 - val_root_mean_squared_error: 0.3532
# Epoch 528/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3075 - root_mean_squared_error: 0.3532 - val_loss: 6.1884 - val_root_mean_squared_error: 0.3531
# Epoch 529/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3033 - root_mean_squared_error: 0.3531 - val_loss: 5.1319 - val_root_mean_squared_error: 0.3531
# Epoch 530/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3101 - root_mean_squared_error: 0.3531 - val_loss: 6.0365 - val_root_mean_squared_error: 0.3531
# Epoch 531/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3091 - root_mean_squared_error: 0.3530 - val_loss: 5.8868 - val_root_mean_squared_error: 0.3530
# Epoch 532/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3116 - root_mean_squared_error: 0.3530 - val_loss: 5.6001 - val_root_mean_squared_error: 0.3530
# Epoch 533/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3028 - root_mean_squared_error: 0.3529 - val_loss: 5.7909 - val_root_mean_squared_error: 0.3529
# Epoch 534/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3098 - root_mean_squared_error: 0.3529 - val_loss: 5.5489 - val_root_mean_squared_error: 0.3529
# Epoch 535/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3082 - root_mean_squared_error: 0.3528 - val_loss: 5.2201 - val_root_mean_squared_error: 0.3528
# Epoch 536/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3044 - root_mean_squared_error: 0.3528 - val_loss: 5.3374 - val_root_mean_squared_error: 0.3528
# Epoch 537/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3076 - root_mean_squared_error: 0.3527 - val_loss: 6.1682 - val_root_mean_squared_error: 0.3527
# Epoch 538/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3064 - root_mean_squared_error: 0.3527 - val_loss: 5.7794 - val_root_mean_squared_error: 0.3527
# Epoch 539/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3156 - root_mean_squared_error: 0.3527 - val_loss: 5.7412 - val_root_mean_squared_error: 0.3526
# Epoch 540/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3124 - root_mean_squared_error: 0.3526 - val_loss: 5.8233 - val_root_mean_squared_error: 0.3526
# Epoch 541/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3136 - root_mean_squared_error: 0.3526 - val_loss: 6.2251 - val_root_mean_squared_error: 0.3526
# Epoch 542/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3063 - root_mean_squared_error: 0.3525 - val_loss: 6.0673 - val_root_mean_squared_error: 0.3525
# Epoch 543/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3079 - root_mean_squared_error: 0.3525 - val_loss: 5.5880 - val_root_mean_squared_error: 0.3525
# Epoch 544/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3076 - root_mean_squared_error: 0.3525 - val_loss: 5.1369 - val_root_mean_squared_error: 0.3524
# Epoch 545/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3110 - root_mean_squared_error: 0.3524 - val_loss: 6.2615 - val_root_mean_squared_error: 0.3524
# Epoch 546/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3160 - root_mean_squared_error: 0.3524 - val_loss: 5.8570 - val_root_mean_squared_error: 0.3523
# Epoch 547/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3122 - root_mean_squared_error: 0.3523 - val_loss: 5.7165 - val_root_mean_squared_error: 0.3523
# Epoch 548/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3077 - root_mean_squared_error: 0.3522 - val_loss: 6.2004 - val_root_mean_squared_error: 0.3522
# Epoch 549/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3066 - root_mean_squared_error: 0.3522 - val_loss: 5.5079 - val_root_mean_squared_error: 0.3522
# Epoch 550/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3126 - root_mean_squared_error: 0.3522 - val_loss: 5.7711 - val_root_mean_squared_error: 0.3521
# Epoch 551/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3119 - root_mean_squared_error: 0.3521 - val_loss: 5.3833 - val_root_mean_squared_error: 0.3521
# Epoch 552/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3092 - root_mean_squared_error: 0.3521 - val_loss: 5.6073 - val_root_mean_squared_error: 0.3521
# Epoch 553/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3109 - root_mean_squared_error: 0.3520 - val_loss: 6.1985 - val_root_mean_squared_error: 0.3520
# Epoch 554/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3124 - root_mean_squared_error: 0.3520 - val_loss: 6.1540 - val_root_mean_squared_error: 0.3520
# Epoch 555/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3148 - root_mean_squared_error: 0.3519 - val_loss: 5.2692 - val_root_mean_squared_error: 0.3519
# Epoch 556/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3140 - root_mean_squared_error: 0.3519 - val_loss: 5.3165 - val_root_mean_squared_error: 0.3519
# Epoch 557/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3158 - root_mean_squared_error: 0.3519 - val_loss: 6.3458 - val_root_mean_squared_error: 0.3519
# Epoch 558/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3140 - root_mean_squared_error: 0.3518 - val_loss: 5.3124 - val_root_mean_squared_error: 0.3518
# Epoch 559/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3094 - root_mean_squared_error: 0.3518 - val_loss: 6.1563 - val_root_mean_squared_error: 0.3518
# Epoch 560/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3123 - root_mean_squared_error: 0.3518 - val_loss: 6.1963 - val_root_mean_squared_error: 0.3518
# Epoch 561/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3020 - root_mean_squared_error: 0.3518 - val_loss: 5.9381 - val_root_mean_squared_error: 0.3518
# Epoch 562/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3047 - root_mean_squared_error: 0.3517 - val_loss: 5.3994 - val_root_mean_squared_error: 0.3517
# Epoch 563/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3030 - root_mean_squared_error: 0.3517 - val_loss: 5.5394 - val_root_mean_squared_error: 0.3517
# Epoch 564/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3162 - root_mean_squared_error: 0.3517 - val_loss: 5.8254 - val_root_mean_squared_error: 0.3517
# Epoch 565/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3066 - root_mean_squared_error: 0.3517 - val_loss: 5.5417 - val_root_mean_squared_error: 0.3516
# Epoch 566/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3048 - root_mean_squared_error: 0.3516 - val_loss: 5.5736 - val_root_mean_squared_error: 0.3516
# Epoch 567/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3141 - root_mean_squared_error: 0.3516 - val_loss: 5.3053 - val_root_mean_squared_error: 0.3515
# Epoch 568/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3092 - root_mean_squared_error: 0.3515 - val_loss: 5.7578 - val_root_mean_squared_error: 0.3515
# Epoch 569/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3051 - root_mean_squared_error: 0.3515 - val_loss: 5.2563 - val_root_mean_squared_error: 0.3515
# Epoch 570/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3145 - root_mean_squared_error: 0.3514 - val_loss: 6.1155 - val_root_mean_squared_error: 0.3514
# Epoch 571/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3042 - root_mean_squared_error: 0.3514 - val_loss: 5.8972 - val_root_mean_squared_error: 0.3514
# Epoch 572/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3114 - root_mean_squared_error: 0.3513 - val_loss: 5.1392 - val_root_mean_squared_error: 0.3513
# Epoch 573/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3112 - root_mean_squared_error: 0.3513 - val_loss: 6.3172 - val_root_mean_squared_error: 0.3513
# Epoch 574/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3036 - root_mean_squared_error: 0.3513 - val_loss: 5.7568 - val_root_mean_squared_error: 0.3512
# Epoch 575/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3104 - root_mean_squared_error: 0.3512 - val_loss: 5.5406 - val_root_mean_squared_error: 0.3512
# Epoch 576/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3088 - root_mean_squared_error: 0.3512 - val_loss: 5.4896 - val_root_mean_squared_error: 0.3512
# Epoch 577/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3197 - root_mean_squared_error: 0.3512 - val_loss: 5.2045 - val_root_mean_squared_error: 0.3511
# Epoch 578/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3164 - root_mean_squared_error: 0.3511 - val_loss: 5.7368 - val_root_mean_squared_error: 0.3511
# Epoch 579/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3120 - root_mean_squared_error: 0.3511 - val_loss: 5.5548 - val_root_mean_squared_error: 0.3510
# Epoch 580/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3159 - root_mean_squared_error: 0.3510 - val_loss: 5.7199 - val_root_mean_squared_error: 0.3510
# Epoch 581/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3145 - root_mean_squared_error: 0.3510 - val_loss: 6.8063 - val_root_mean_squared_error: 0.3509
# Epoch 582/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3117 - root_mean_squared_error: 0.3509 - val_loss: 6.0660 - val_root_mean_squared_error: 0.3509
# Epoch 583/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3065 - root_mean_squared_error: 0.3509 - val_loss: 5.7189 - val_root_mean_squared_error: 0.3509
# Epoch 584/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3055 - root_mean_squared_error: 0.3508 - val_loss: 5.8375 - val_root_mean_squared_error: 0.3508
# Epoch 585/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3111 - root_mean_squared_error: 0.3508 - val_loss: 5.5749 - val_root_mean_squared_error: 0.3508
# Epoch 586/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3062 - root_mean_squared_error: 0.3508 - val_loss: 5.8511 - val_root_mean_squared_error: 0.3507
# Epoch 587/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3081 - root_mean_squared_error: 0.3507 - val_loss: 5.8215 - val_root_mean_squared_error: 0.3507
# Epoch 588/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3050 - root_mean_squared_error: 0.3507 - val_loss: 6.0923 - val_root_mean_squared_error: 0.3506
# Epoch 589/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3145 - root_mean_squared_error: 0.3506 - val_loss: 5.4657 - val_root_mean_squared_error: 0.3506
# Epoch 590/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3081 - root_mean_squared_error: 0.3506 - val_loss: 5.5118 - val_root_mean_squared_error: 0.3506
# Epoch 591/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3082 - root_mean_squared_error: 0.3505 - val_loss: 6.9774 - val_root_mean_squared_error: 0.3505
# Epoch 592/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3122 - root_mean_squared_error: 0.3505 - val_loss: 6.2376 - val_root_mean_squared_error: 0.3505
# Epoch 593/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3139 - root_mean_squared_error: 0.3504 - val_loss: 5.6457 - val_root_mean_squared_error: 0.3504
# Epoch 594/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3095 - root_mean_squared_error: 0.3504 - val_loss: 6.2557 - val_root_mean_squared_error: 0.3504
# Epoch 595/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3031 - root_mean_squared_error: 0.3504 - val_loss: 5.3369 - val_root_mean_squared_error: 0.3504
# Epoch 596/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3003 - root_mean_squared_error: 0.3504 - val_loss: 6.2979 - val_root_mean_squared_error: 0.3504
# Epoch 597/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3107 - root_mean_squared_error: 0.3503 - val_loss: 6.0340 - val_root_mean_squared_error: 0.3503
# Epoch 598/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3087 - root_mean_squared_error: 0.3503 - val_loss: 5.4575 - val_root_mean_squared_error: 0.3503
# Epoch 599/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3217 - root_mean_squared_error: 0.3503 - val_loss: 6.0849 - val_root_mean_squared_error: 0.3503
# Epoch 600/600
# 313/313 [==============================] - 3s 10ms/step - loss: -2.3097 - root_mean_squared_error: 0.3502 - val_loss: 6.0618 - val_root_mean_squared_error: 0.3502

# %%
# model_2.save_weights(weights_path.format(epoch = 900))

# %%
# model_2.load_weights(weights_path)

# %%
photoz = []

for i in range(t):
    photoz.append(model_1(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
photoz_2 = []

for i in range(t):
    photoz_2.append(model_2(np.array([x_test_2[i]])).mean()[0][0])

photoz_2 = np.asarray(photoz_2).astype('float32')

# %% [markdown]
# photoz_train = []
#
# for i in range(n):
#     photoz_train.append(model_2(np.array([x_train[i]])).mean()[0][0])
#
# photoz_train = np.asarray(photoz_train).astype('float32')

# %% [markdown]
# photoz_validation = []
#
# for i in range(v):
#     photoz_validation.append(model_2(np.array([x_validation[i]])).mean()[0][0])
#
# photoz_validation = np.asarray(photoz_validation).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]
specz_2 = np.asarray(y_test_2)[:,0]
# specz_train = np.asarray(y_train)[:,0]
# specz_validation = np.asarray(y_validation)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_1(np.array([x_test[i]])).stddev()[0][0])

# %%
photoz_err_2 = []

for i in range(t):
    photoz_err_2.append(model_2(np.array([x_test_2[i]])).stddev()[0][0])

# %% [markdown]
# photoz_err_train = []
#
# for i in range(n):
#     photoz_err_train.append(model_2(np.array([x_train[i]])).stddev()[0][0])

# %% [markdown]
# photoz_err_validation = []
#
# for i in range(v):
#     photoz_err_validation.append(model_2(np.array([x_validation[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)
xy_2 = np.asarray(np.vstack([specz_2, photoz_2])).astype('float32')
z_2 = gaussian_kde(xy_2)(xy_2)

# %%
import seaborn as sns
z_max = 4
sns.set(rc = {'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz_2, photoz_2, c = z_2, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap = 0
overlap_array = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap += 1
        overlap_array.append(1)
    else:
        overlap_array.append(0)

# %%
overlap_2 = 0
overlap_array_2 = []
for i in range(0,t):
    if np.abs(specz_2[i]-photoz_2[i])<=photoz_err[i]:
        overlap_2 += 1
        overlap_array_2.append(1)
    else:
        overlap_array_2.append(0)

# %%
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction with error, Bayesian')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_2/t))
# Out:
# Coverage: 0.3915

# %%
combined_array = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array))) 
combined_array_2 = np.transpose(np.vstack((specz_2, photoz_2, photoz_err_2, overlap_array_2)))

# %%
sorted_combined_array = sorted(combined_array, key=lambda x: x[0])
sorted_combined_array_2 = sorted(combined_array_2, key=lambda x: x[0])

# %%
bins = int(z_max*5)
splitted_sorted_combined_array = np.array_split(sorted_combined_array, bins)
coverage = []
for i in range(0, bins):
    bins_count = 0
    for j in range(0,len(splitted_sorted_combined_array[i])):
        if splitted_sorted_combined_array[i][j][3] == 1:
            bins_count += 1
    coverage.append(bins_count/len(splitted_sorted_combined_array[i])/0.6827)

# %%
bins_2 = int(z_max*5)
splitted_sorted_combined_array_2 = np.array_split(sorted_combined_array_2, bins_2)
coverage_2 = []
for i in range(0, bins_2):
    bins_count_2 = 0
    for j in range(0,len(splitted_sorted_combined_array_2[i])):
        if splitted_sorted_combined_array_2[i][j][3] == 1:
            bins_count_2 += 1
    coverage_2.append(bins_count_2/len(splitted_sorted_combined_array_2[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_2)

# %%
plt.plot(x_array, coverage, c = 'blue')
plt.plot(x_array, coverage_2, c = 'red')
plt.title('Coverage')
plt.xlabel('spectroscopic redshift')
plt.ylabel('coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
print("Filtered Coverage: "+str(overlap/t))
print("Coverage: "+str(overlap_2/t))
# Out:
# Filtered Coverage: 0.2885
# Coverage: 0.3915

# %%
mean_array = []
for i in range(0, bins):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array[i])):
        bias = (splitted_sorted_combined_array[i][j][1]-splitted_sorted_combined_array[i][j][0])/(1 + splitted_sorted_combined_array[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array[i]))
x_array = np.arange(0, z_max, z_max/bins)

# %%
mean_array_2 = []
for i in range(0, bins_2):
    total_2 = 0
    for j in range(0, len(splitted_sorted_combined_array_2[i])):
        bias_2 = (splitted_sorted_combined_array_2[i][j][1]-splitted_sorted_combined_array_2[i][j][0])/(1 + splitted_sorted_combined_array_2[i][j][0])
        total_2 += bias_2/(1 + splitted_sorted_combined_array_2[i][j][0])
    mean_array_2.append(total_2/len(splitted_sorted_combined_array_2[i]))

# %%
error_array = []
for i in range(0,bins):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array[i])):
        error_total += splitted_sorted_combined_array[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array[i]))

# %%
error_array_2 = []
for i in range(0,bins_2):
    error_total_2 = 0
    for j in range(0,len(splitted_sorted_combined_array_2[i])):
        error_total_2 += splitted_sorted_combined_array_2[i][j][2]
    error_array_2.append(error_total_2/len(splitted_sorted_combined_array_2[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.errorbar(x_array, mean_array_2, yerr = error_array_2, fmt = "o", color = 'red', markersize = 4, elinewidth = 2)
plt.title(' ')
plt.xlabel('True Redshift')
plt.ylabel('Bias (Predicted - True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array_2 = np.transpose(np.vstack((specz_2, photoz_2, photoz_err_2)))
sorted_combined_outlier_array_2 = sorted(combined_outlier_array_2, key = lambda x: x[0])
bins_outlier = int(z_max * 20)
splitted_sorted_combined_outlier_array_2 = np.array_split(sorted_combined_outlier_array_2, bins_outlier)
outlier_array_2 = []
outlier_count_total_2 = 0
for i in range(0, bins_outlier):
    outlier_count_2 = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array_2[i])):
        if np.abs(splitted_sorted_combined_outlier_array_2[i][j][1] - splitted_sorted_combined_outlier_array_2[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array_2[i][j][2]:
            outlier_count_2 += 1
            outlier_count_total_2 += 1
    outlier_array_2.append(outlier_count_2 / len(specz) * bins_outlier)

combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key = lambda x: x[0])
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array, bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0, bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count / len(specz) * bins_outlier)

x_array_outlier = np.arange(0, z_max, z_max / bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.plot(x_array_outlier, outlier_array_2, c = 'red')
plt.title('')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0, z_max])
plt.ylim([0, 1 / 2])
plt.show()

print("Outlier Rate Filtered: "+str(outlier_count_total/len(specz)))
print("Outlier Rate: "+str(outlier_count_total_2/len(specz)))
# Out:
# Outlier Rate Filtered: 0.364
# Outlier Rate: 0.2475

# %%
combined_outlier_array = np.transpose(np.vstack((specz, np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key = lambda x: x[0])
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array, bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0, bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] / (splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count / len(specz) * bins_outlier)

combined_outlier_array_2 = np.transpose(np.vstack((specz_2, np.subtract(photoz_2, specz_2))))
sorted_combined_outlier_array_2 = sorted(combined_outlier_array_2, key = lambda x: x[0])
splitted_sorted_combined_outlier_array_2 = np.array_split(sorted_combined_outlier_array_2, bins_outlier)
outlier_array_2 = []
outlier_count_total_2 = 0
for i in range(0, bins_outlier):
    outlier_count_2 = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array_2[i])):
        if np.abs(splitted_sorted_combined_outlier_array_2[i][j][1] / (splitted_sorted_combined_outlier_array_2[i][j][0] + 1)) >= .15:
            outlier_count_2 += 1
            outlier_count_total_2 += 1
    outlier_array_2.append(outlier_count_2 / len(specz_2) * bins_outlier)

plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.plot(x_array_outlier, outlier_array_2, c = 'red')

plt.title('')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

print("Outlier Rate Filtered: "+str(outlier_count_total/len(specz)))
print("Outlier Rate: "+str(outlier_count_total_2/len(specz)))
# Out:
# Outlier Rate Filtered: 0.0955
# Outlier Rate: 0.0665

# %% [markdown]
# uncertains = []
# for i in range(0, len(photoz_err)):
#     if photoz_err[i].numpy() >= 1:
#         uncertains.append(i)
#         print("Object ID: " + str(object_id[i]) + ", Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
plt.imshow(x_train_2[9][:,:,0])

# %% [markdown]
# check = 2
# current = uncertains[check]
# print("Object ID: " + str(object_id[current]) + ", Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
# plt.imshow(x_test[current][:,:,0])
# plt.grid(False)

# %% [markdown]
# biases = []
# for i in range(0, len(photoz)):
#     if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
#         biases.append(i)
#         print("Object ID: " + str(object_id[i]) + ", Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %% [markdown]
# check_bias = 3
# current_bias = biases[check_bias]
# print("Object ID: " + str(object_id[current_bias]) + ", Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
# plt.imshow(x_test[current_bias][:,:,0])
# plt.grid(False)

# %%
# END
