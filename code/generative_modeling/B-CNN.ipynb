# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
# Out:
# 2023-07-21 00:55:47.541422: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-21 00:55:48.189711: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-07-21 00:55:49.569199: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:49.626119: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:49.626296: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:49.628353: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:49.628500: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:49.628633: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:50.312911: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:50.313109: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:50.313242: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-21 00:55:50.313476: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_training_small.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_train.hdf5', 'r')\
hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_7.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_validation_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
t = len(x_test)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model_variational = Sequential([
    InputLayer(input_shape = (127, 127, 5)),
    tfpl.Convolution2DFlipout(32, kernel_size=(3, 3), activation = 'tanh', kernel_divergence_fn = kl_divergence_function),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    Dropout(0.2),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 127, 127, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 125, 125, 32)     2912
#  ut)
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 61, 61, 32)        4128
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 32)        4128
#
#  flatten (Flatten)           (None, 23328)             0
#
#  dropout (Dropout)           (None, 23328)             0
#
#  dense_variational (DenseVar  (None, 64)               4479168
#  iational)
#
#  dense_variational_1 (DenseV  (None, 64)               12480
#  ariational)
#
#  dense (Dense)               (None, 2)                 130
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 4,512,194
# Trainable params: 4,512,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return - estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'HSC_v6_BCNN_v5'

checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

log_dir = os.path.join('/logs/', model_name)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# 2023-07-21 00:56:43.031123: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3225800000 exceeds 10% of free system memory.
# 2023-07-21 00:56:44.615742: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3225800000 exceeds 10% of free system memory.
# Epoch 1/60
# 2023-07-21 00:56:48.234004: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-21 00:56:48.234518: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x287c4260 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-21 00:56:48.234554: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-07-21 00:56:48.265783: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-21 00:56:48.388580: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-21 00:56:48.455298: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-07-21 00:56:48.960992: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-21 00:56:49.077660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 [==============================] - ETA: 0s - loss: 4087.5459 - root_mean_squared_error: 1.0234
# 2023-07-21 00:56:55.498858: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 645160000 exceeds 10% of free system memory.
# 2023-07-21 00:56:55.831120: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 645160000 exceeds 10% of free system memory.
# 313/313 [==============================] - 11s 20ms/step - loss: 4087.5459 - root_mean_squared_error: 1.0234 - val_loss: 3399.0806 - val_root_mean_squared_error: 0.8235 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 4s 12ms/step - loss: 2924.9817 - root_mean_squared_error: 0.8225 - val_loss: 2508.7979 - val_root_mean_squared_error: 0.8138 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 4s 12ms/step - loss: 2190.5752 - root_mean_squared_error: 0.8057 - val_loss: 1906.3142 - val_root_mean_squared_error: 0.6281 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1680.8243 - root_mean_squared_error: 0.6303 - val_loss: 1477.2980 - val_root_mean_squared_error: 0.5919 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1313.0649 - root_mean_squared_error: 0.6254 - val_loss: 1162.9034 - val_root_mean_squared_error: 0.5894 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1039.3058 - root_mean_squared_error: 0.6039 - val_loss: 925.6391 - val_root_mean_squared_error: 0.5755 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 4s 12ms/step - loss: 830.5577 - root_mean_squared_error: 0.5960 - val_loss: 742.5496 - val_root_mean_squared_error: 0.5028 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 4s 12ms/step - loss: 668.5190 - root_mean_squared_error: 0.5919 - val_loss: 599.2159 - val_root_mean_squared_error: 0.5198 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 4s 12ms/step - loss: 540.6951 - root_mean_squared_error: 0.5705 - val_loss: 485.7915 - val_root_mean_squared_error: 0.4575 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 4s 12ms/step - loss: 438.6242 - root_mean_squared_error: 0.5733 - val_loss: 394.2508 - val_root_mean_squared_error: 0.6222 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 4s 12ms/step - loss: 356.5288 - root_mean_squared_error: 0.5611 - val_loss: 320.5582 - val_root_mean_squared_error: 0.6111 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 4s 12ms/step - loss: 289.7213 - root_mean_squared_error: 0.5205 - val_loss: 260.7152 - val_root_mean_squared_error: 0.5542 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 4s 13ms/step - loss: 235.3758 - root_mean_squared_error: 0.5601 - val_loss: 211.5107 - val_root_mean_squared_error: 0.3884 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 4s 12ms/step - loss: 190.8914 - root_mean_squared_error: 0.5247 - val_loss: 171.3851 - val_root_mean_squared_error: 0.5563 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 4s 12ms/step - loss: 154.4350 - root_mean_squared_error: 0.5534 - val_loss: 138.3945 - val_root_mean_squared_error: 0.6162 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 4s 13ms/step - loss: 124.5700 - root_mean_squared_error: 0.5330 - val_loss: 111.3134 - val_root_mean_squared_error: 0.4701 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 4s 12ms/step - loss: 100.1029 - root_mean_squared_error: 0.4817 - val_loss: 89.3875 - val_root_mean_squared_error: 0.4168 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 4s 12ms/step - loss: 80.5985 - root_mean_squared_error: 0.9005 - val_loss: 71.3769 - val_root_mean_squared_error: 0.6113 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 4s 13ms/step - loss: 63.9788 - root_mean_squared_error: 0.5633 - val_loss: 56.7789 - val_root_mean_squared_error: 0.5260 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 4s 13ms/step - loss: 50.8707 - root_mean_squared_error: 0.5091 - val_loss: 45.1179 - val_root_mean_squared_error: 0.4011 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 4s 12ms/step - loss: 40.2986 - root_mean_squared_error: 0.4753 - val_loss: 35.6930 - val_root_mean_squared_error: 0.4556 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 4s 12ms/step - loss: 31.9867 - root_mean_squared_error: 0.4677 - val_loss: 28.2507 - val_root_mean_squared_error: 0.4642 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 4s 12ms/step - loss: 25.3508 - root_mean_squared_error: 0.5003 - val_loss: 22.4927 - val_root_mean_squared_error: 0.4490 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 4s 13ms/step - loss: 20.2104 - root_mean_squared_error: 0.5222 - val_loss: 18.1594 - val_root_mean_squared_error: 0.3861 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 4s 12ms/step - loss: 16.2726 - root_mean_squared_error: 0.4856 - val_loss: 14.5284 - val_root_mean_squared_error: 0.4272 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 4s 13ms/step - loss: 13.2956 - root_mean_squared_error: 0.4633 - val_loss: 12.0893 - val_root_mean_squared_error: 0.4623 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 4s 12ms/step - loss: 11.1343 - root_mean_squared_error: 0.4811 - val_loss: 10.3928 - val_root_mean_squared_error: 0.4213 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 4s 12ms/step - loss: 9.5490 - root_mean_squared_error: 0.4550 - val_loss: 8.9172 - val_root_mean_squared_error: 0.3390 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 4s 12ms/step - loss: 8.4502 - root_mean_squared_error: 0.4717 - val_loss: 7.9957 - val_root_mean_squared_error: 0.4322 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 4s 13ms/step - loss: 7.6697 - root_mean_squared_error: 0.4714 - val_loss: 7.4111 - val_root_mean_squared_error: 0.3626 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.2326 - root_mean_squared_error: 0.4723 - val_loss: 7.1594 - val_root_mean_squared_error: 0.5535 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.8693 - root_mean_squared_error: 0.4693 - val_loss: 6.8043 - val_root_mean_squared_error: 0.4527 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.6459 - root_mean_squared_error: 0.4558 - val_loss: 6.6122 - val_root_mean_squared_error: 0.3747 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.5217 - root_mean_squared_error: 0.4359 - val_loss: 6.8133 - val_root_mean_squared_error: 0.4843 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4601 - root_mean_squared_error: 0.4471 - val_loss: 6.5342 - val_root_mean_squared_error: 0.4377 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4511 - root_mean_squared_error: 0.4418 - val_loss: 6.5986 - val_root_mean_squared_error: 0.3139 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4383 - root_mean_squared_error: 0.4780 - val_loss: 6.5424 - val_root_mean_squared_error: 0.3522 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4590 - root_mean_squared_error: 0.4528 - val_loss: 6.6909 - val_root_mean_squared_error: 0.4585 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4464 - root_mean_squared_error: 0.3996 - val_loss: 6.6045 - val_root_mean_squared_error: 0.3670 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4583 - root_mean_squared_error: 0.4416 - val_loss: 6.6384 - val_root_mean_squared_error: 0.3877 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.4635 - root_mean_squared_error: 0.4332 - val_loss: 6.5928 - val_root_mean_squared_error: 0.4339 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4675 - root_mean_squared_error: 0.4583 - val_loss: 6.6069 - val_root_mean_squared_error: 0.3583 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4472 - root_mean_squared_error: 0.4124 - val_loss: 6.6788 - val_root_mean_squared_error: 0.3632 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4510 - root_mean_squared_error: 0.4416 - val_loss: 6.7044 - val_root_mean_squared_error: 0.3806 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4405 - root_mean_squared_error: 0.4286 - val_loss: 6.8037 - val_root_mean_squared_error: 0.3814 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.5550 - root_mean_squared_error: 0.4253 - val_loss: 0.3352 - val_root_mean_squared_error: 0.4102 - lr: 1.0000e-04
# Epoch 47/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1266 - root_mean_squared_error: 0.4006 - val_loss: 0.2933 - val_root_mean_squared_error: 0.3557 - lr: 1.0000e-04
# Epoch 48/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1333 - root_mean_squared_error: 0.3919 - val_loss: 0.3094 - val_root_mean_squared_error: 0.3338 - lr: 1.0000e-04
# Epoch 49/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1480 - root_mean_squared_error: 0.3661 - val_loss: 0.3666 - val_root_mean_squared_error: 0.3338 - lr: 1.0000e-04
# Epoch 50/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1495 - root_mean_squared_error: 0.3955 - val_loss: 0.3475 - val_root_mean_squared_error: 0.3696 - lr: 1.0000e-04
# Epoch 51/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1532 - root_mean_squared_error: 0.3721 - val_loss: 0.3247 - val_root_mean_squared_error: 0.3498 - lr: 1.0000e-04
# Epoch 52/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1591 - root_mean_squared_error: 0.3733 - val_loss: 0.3588 - val_root_mean_squared_error: 0.3761 - lr: 1.0000e-04
# Epoch 53/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1815 - root_mean_squared_error: 0.3798 - val_loss: 0.4211 - val_root_mean_squared_error: 0.3477 - lr: 1.0000e-04
# Epoch 54/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1618 - root_mean_squared_error: 0.3744 - val_loss: 0.3449 - val_root_mean_squared_error: 0.3355 - lr: 1.0000e-04
# Epoch 55/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1868 - root_mean_squared_error: 0.3855 - val_loss: 0.3841 - val_root_mean_squared_error: 0.3160 - lr: 1.0000e-04
# Epoch 56/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1873 - root_mean_squared_error: 0.3695 - val_loss: 0.3419 - val_root_mean_squared_error: 0.3312 - lr: 1.0000e-04
# Epoch 57/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.1946 - root_mean_squared_error: 0.3722 - val_loss: 0.3652 - val_root_mean_squared_error: 0.3499 - lr: 1.0000e-04
# Epoch 58/60
# 313/313 [==============================] - 4s 13ms/step - loss: -0.4806 - root_mean_squared_error: 0.3695 - val_loss: -0.1135 - val_root_mean_squared_error: 0.3432 - lr: 1.0000e-05
# Epoch 59/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.7718 - root_mean_squared_error: 0.3788 - val_loss: -0.1979 - val_root_mean_squared_error: 0.3465 - lr: 1.0000e-05
# Epoch 60/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.8473 - root_mean_squared_error: 0.3684 - val_loss: -0.2781 - val_root_mean_squared_error: 0.3486 - lr: 1.0000e-05

# %% [markdown]
# # hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_max_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
# x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
# t = len(x_test)
# max_value = 1
# x_test = np.true_divide(x_test, max_value)[0:t]
# y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
# hf_test.close()

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
plt.imshow(x_test[100][:,:,4])

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.044577511643379905

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.044577511643379905

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.scatter(x_array, mean_array, marker='o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True)/(1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1])
plt.show()

# print("Outlier Rate: "+str(outlier_count_total/len(specz)))

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check = 2
current = uncertains[check]
print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 check = 2
# ----> 2 current = uncertains[check]
#       3 print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
#       4 plt.imshow(x_test[current][:,:,0])
#
# IndexError: list index out of range

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)

# %%
a = 988
b = 264
c = 1198
d = 112
e = 241
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_test[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_test[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_test[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_test[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_test[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_test[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_test[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_test[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_test[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_test[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
a = 24
b = 15
c = 10
d = 96
e = 1868
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_train[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_train[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_train[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_train[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_train[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_train[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_train[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_train[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_train[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_train[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
for i in range(10000):
    if np.abs(y_train[i][0]-4)<0.1:
        print(i)

# %%
# END
