# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
# Out:
# 2023-06-28 06:08:42.603726: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-28 06:08:43.151683: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-06-28 06:08:44.196883: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.220222: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.220421: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.222155: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.222304: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.222433: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.716048: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.716246: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.716379: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-28 06:08:44.716486: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_training_small.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_train.hdf5', 'r')\
hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_normalized.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_validation_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, max_value)[0:t]
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model_variational = Sequential([
    InputLayer(input_shape = (127, 127, 5)),
    tfpl.Convolution2DFlipout(32, kernel_size=(3, 3), activation = 'tanh', kernel_divergence_fn = kl_divergence_function),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    Dropout(0.2),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 127, 127, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 125, 125, 32)     2912
#  ut)
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 61, 61, 32)        4128
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 32)        4128
#
#  flatten (Flatten)           (None, 23328)             0
#
#  dropout (Dropout)           (None, 23328)             0
#
#  dense_variational (DenseVar  (None, 64)               4479168
#  iational)
#
#  dense_variational_1 (DenseV  (None, 64)               12480
#  ariational)
#
#  dense (Dense)               (None, 2)                 130
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 4,512,194
# Trainable params: 4,512,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return - estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'HSC_v6_BCNN_v5'

checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

log_dir = os.path.join('/logs/', model_name)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# 2023-06-28 06:08:49.224837: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3225800000 exceeds 10% of free system memory.
# 2023-06-28 06:08:50.916553: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3225800000 exceeds 10% of free system memory.
# Epoch 1/60
# 2023-06-28 06:08:54.093250: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-28 06:08:54.593956: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-06-28 06:08:54.650912: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fdbae8bef10 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-28 06:08:54.650932: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-06-28 06:08:54.654461: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-28 06:08:54.693704: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-28 06:08:54.708141: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-06-28 06:08:54.752212: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 [==============================] - 9s 17ms/step - loss: 4113.9072 - root_mean_squared_error: 0.9801 - val_loss: 3430.1709 - val_root_mean_squared_error: 0.8144 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 4s 12ms/step - loss: 2958.5886 - root_mean_squared_error: 0.8011 - val_loss: 2541.6697 - val_root_mean_squared_error: 0.6610 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 4s 12ms/step - loss: 2221.1973 - root_mean_squared_error: 0.6579 - val_loss: 1934.2504 - val_root_mean_squared_error: 0.5895 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1707.5444 - root_mean_squared_error: 0.6025 - val_loss: 1501.4747 - val_root_mean_squared_error: 0.5329 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 4s 13ms/step - loss: 1335.5081 - root_mean_squared_error: 0.5849 - val_loss: 1182.6259 - val_root_mean_squared_error: 0.6109 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1058.3163 - root_mean_squared_error: 0.5874 - val_loss: 942.7433 - val_root_mean_squared_error: 0.5662 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 4s 12ms/step - loss: 846.6278 - root_mean_squared_error: 0.5637 - val_loss: 757.2845 - val_root_mean_squared_error: 0.5735 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 4s 12ms/step - loss: 681.9192 - root_mean_squared_error: 0.5543 - val_loss: 611.6948 - val_root_mean_squared_error: 0.4615 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 4s 12ms/step - loss: 552.1408 - root_mean_squared_error: 0.5505 - val_loss: 496.1052 - val_root_mean_squared_error: 0.5178 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 4s 12ms/step - loss: 448.3297 - root_mean_squared_error: 0.5855 - val_loss: 403.0894 - val_root_mean_squared_error: 0.5350 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 4s 12ms/step - loss: 364.6038 - root_mean_squared_error: 0.5771 - val_loss: 327.8661 - val_root_mean_squared_error: 0.4838 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 4s 12ms/step - loss: 296.5888 - root_mean_squared_error: 0.5211 - val_loss: 266.9770 - val_root_mean_squared_error: 0.5375 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 4s 12ms/step - loss: 241.1758 - root_mean_squared_error: 0.5123 - val_loss: 216.7600 - val_root_mean_squared_error: 0.4294 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 4s 12ms/step - loss: 195.8152 - root_mean_squared_error: 0.5033 - val_loss: 175.9922 - val_root_mean_squared_error: 0.5493 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 4s 12ms/step - loss: 158.5142 - root_mean_squared_error: 0.4731 - val_loss: 142.1447 - val_root_mean_squared_error: 0.4405 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 4s 12ms/step - loss: 127.9986 - root_mean_squared_error: 0.4780 - val_loss: 114.5361 - val_root_mean_squared_error: 0.5151 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 4s 12ms/step - loss: 102.9754 - root_mean_squared_error: 0.5065 - val_loss: 92.0738 - val_root_mean_squared_error: 0.6450 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 4s 12ms/step - loss: 82.5352 - root_mean_squared_error: 0.4793 - val_loss: 73.5771 - val_root_mean_squared_error: 0.4296 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 4s 12ms/step - loss: 65.8734 - root_mean_squared_error: 0.5409 - val_loss: 58.6049 - val_root_mean_squared_error: 0.4789 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 4s 12ms/step - loss: 52.4071 - root_mean_squared_error: 0.4726 - val_loss: 46.5678 - val_root_mean_squared_error: 0.4043 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 4s 12ms/step - loss: 41.5320 - root_mean_squared_error: 0.4475 - val_loss: 36.8958 - val_root_mean_squared_error: 0.4282 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 4s 12ms/step - loss: 32.9214 - root_mean_squared_error: 0.4485 - val_loss: 29.1910 - val_root_mean_squared_error: 0.3743 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 4s 12ms/step - loss: 26.1166 - root_mean_squared_error: 0.4533 - val_loss: 23.2662 - val_root_mean_squared_error: 0.4451 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 4s 12ms/step - loss: 20.7802 - root_mean_squared_error: 0.4660 - val_loss: 18.6719 - val_root_mean_squared_error: 0.4427 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 4s 13ms/step - loss: 16.7404 - root_mean_squared_error: 0.4782 - val_loss: 15.5042 - val_root_mean_squared_error: 0.4002 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 4s 13ms/step - loss: 13.6477 - root_mean_squared_error: 0.4510 - val_loss: 12.4674 - val_root_mean_squared_error: 0.4420 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 4s 12ms/step - loss: 11.3330 - root_mean_squared_error: 0.4162 - val_loss: 10.4683 - val_root_mean_squared_error: 0.4576 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 4s 12ms/step - loss: 9.6738 - root_mean_squared_error: 0.4261 - val_loss: 9.3211 - val_root_mean_squared_error: 0.4103 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 4s 13ms/step - loss: 8.5255 - root_mean_squared_error: 0.4346 - val_loss: 8.1756 - val_root_mean_squared_error: 0.4414 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.6818 - root_mean_squared_error: 0.4258 - val_loss: 7.5000 - val_root_mean_squared_error: 0.3825 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1277 - root_mean_squared_error: 0.4152 - val_loss: 7.1253 - val_root_mean_squared_error: 0.3784 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.8176 - root_mean_squared_error: 0.4299 - val_loss: 6.8436 - val_root_mean_squared_error: 0.3688 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.5705 - root_mean_squared_error: 0.4045 - val_loss: 6.6451 - val_root_mean_squared_error: 0.3519 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4667 - root_mean_squared_error: 0.4990 - val_loss: 6.6637 - val_root_mean_squared_error: 0.3505 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3898 - root_mean_squared_error: 0.4289 - val_loss: 6.6336 - val_root_mean_squared_error: 0.3427 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.3586 - root_mean_squared_error: 0.4051 - val_loss: 6.6355 - val_root_mean_squared_error: 0.4932 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3381 - root_mean_squared_error: 0.4095 - val_loss: 6.5896 - val_root_mean_squared_error: 0.3776 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.3619 - root_mean_squared_error: 0.4155 - val_loss: 6.6127 - val_root_mean_squared_error: 0.3729 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3454 - root_mean_squared_error: 0.4370 - val_loss: 6.6708 - val_root_mean_squared_error: 0.3382 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.4399 - root_mean_squared_error: 0.4415 - val_loss: 6.7221 - val_root_mean_squared_error: 0.3833 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3744 - root_mean_squared_error: 0.4336 - val_loss: 6.6685 - val_root_mean_squared_error: 0.3175 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3645 - root_mean_squared_error: 0.4524 - val_loss: 6.7328 - val_root_mean_squared_error: 0.3759 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3626 - root_mean_squared_error: 0.4155 - val_loss: 6.6929 - val_root_mean_squared_error: 0.4485 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3882 - root_mean_squared_error: 0.4739 - val_loss: 6.7708 - val_root_mean_squared_error: 0.4367 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3411 - root_mean_squared_error: 0.4185 - val_loss: 6.8517 - val_root_mean_squared_error: 0.3602 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.3560 - root_mean_squared_error: 0.4301 - val_loss: 6.9390 - val_root_mean_squared_error: 0.3640 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.3447 - root_mean_squared_error: 0.4083 - val_loss: 6.9634 - val_root_mean_squared_error: 0.3415 - lr: 0.0010
# Epoch 48/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.4329 - root_mean_squared_error: 0.3894 - val_loss: 0.4278 - val_root_mean_squared_error: 0.3373 - lr: 1.0000e-04
# Epoch 49/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.2551 - root_mean_squared_error: 0.3690 - val_loss: 0.5040 - val_root_mean_squared_error: 0.3370 - lr: 1.0000e-04
# Epoch 50/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.2713 - root_mean_squared_error: 0.3688 - val_loss: 0.4871 - val_root_mean_squared_error: 0.3414 - lr: 1.0000e-04
# Epoch 51/60
# 313/313 [==============================] - 4s 13ms/step - loss: -0.2749 - root_mean_squared_error: 0.3736 - val_loss: 0.4737 - val_root_mean_squared_error: 0.3278 - lr: 1.0000e-04
# Epoch 52/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.2820 - root_mean_squared_error: 0.3758 - val_loss: 0.4812 - val_root_mean_squared_error: 0.3422 - lr: 1.0000e-04
# Epoch 53/60
# 313/313 [==============================] - 4s 13ms/step - loss: -0.2936 - root_mean_squared_error: 0.3512 - val_loss: 0.5037 - val_root_mean_squared_error: 0.3291 - lr: 1.0000e-04
# Epoch 54/60
# 313/313 [==============================] - 4s 13ms/step - loss: -0.2984 - root_mean_squared_error: 0.3625 - val_loss: 0.5284 - val_root_mean_squared_error: 0.3485 - lr: 1.0000e-04
# Epoch 55/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.2985 - root_mean_squared_error: 0.3972 - val_loss: 0.4580 - val_root_mean_squared_error: 0.3445 - lr: 1.0000e-04
# Epoch 56/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.3018 - root_mean_squared_error: 0.3700 - val_loss: 0.5774 - val_root_mean_squared_error: 0.3232 - lr: 1.0000e-04
# Epoch 57/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.3273 - root_mean_squared_error: 0.3728 - val_loss: 0.4922 - val_root_mean_squared_error: 0.3747 - lr: 1.0000e-04
# Epoch 58/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.3260 - root_mean_squared_error: 0.3722 - val_loss: 0.5275 - val_root_mean_squared_error: 0.3241 - lr: 1.0000e-04
# Epoch 59/60
# 313/313 [==============================] - 4s 13ms/step - loss: -0.6278 - root_mean_squared_error: 0.3720 - val_loss: 0.0938 - val_root_mean_squared_error: 0.3249 - lr: 1.0000e-05
# Epoch 60/60
# 313/313 [==============================] - 4s 12ms/step - loss: -0.8938 - root_mean_squared_error: 0.3815 - val_loss: -0.0363 - val_root_mean_squared_error: 0.3391 - lr: 1.0000e-05

# %%
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_normalized.hdf5', 'r')\
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_max_1.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
max_value = 1
x_test = np.true_divide(x_test, max_value)[0:t]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
hf_test.close()

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
plt.imshow(x_test[0][:,:,0])

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.0465

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.3225

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.scatter(x_array, mean_array, marker='o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True)/(1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1])
plt.show()

# print("Outlier Rate: "+str(outlier_count_total/len(specz)))

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))
# Out:
# Spectro_z: 0.962495822534478, Photo_z: 1.3180724, Photo_z_err: 1.0051117
# Spectro_z: 2.1018924719752032, Photo_z: 1.1223547, Photo_z_err: 1.0286622
# Spectro_z: 0.4236602063705637, Photo_z: 1.0992188, Photo_z_err: 1.1869007
# Spectro_z: 2.9070219734409792, Photo_z: 1.5016247, Photo_z_err: 1.0967464
# Spectro_z: 3.481057267437464, Photo_z: 1.7753496, Photo_z_err: 1.0207733
# Spectro_z: 1.509039991324638, Photo_z: 1.1902081, Photo_z_err: 1.119761
# Spectro_z: 2.701941818946938, Photo_z: 1.3845253, Photo_z_err: 1.1798307
# Spectro_z: 1.9729921286211227, Photo_z: 1.5859042, Photo_z_err: 1.0025015
# Spectro_z: 0.97224259261472, Photo_z: 1.2388239, Photo_z_err: 1.0395075
# Spectro_z: 2.5702866150823045, Photo_z: 1.45486, Photo_z_err: 1.0560663
# Spectro_z: 1.4166916141719574, Photo_z: 1.1674973, Photo_z_err: 1.1592875
# Spectro_z: 3.385641377879032, Photo_z: 1.2622613, Photo_z_err: 1.0195653
# Spectro_z: 2.093550072963056, Photo_z: 1.539228, Photo_z_err: 1.0366513
# Spectro_z: 2.9838709162056336, Photo_z: 1.2751681, Photo_z_err: 1.0336018
# Spectro_z: 2.261923620972243, Photo_z: 1.2183781, Photo_z_err: 1.1427282
# Spectro_z: 1.4936668747763835, Photo_z: 0.8770441, Photo_z_err: 1.0826979
# Spectro_z: 2.6423069449103633, Photo_z: 1.3820481, Photo_z_err: 1.0342879
# Spectro_z: 2.760529793794342, Photo_z: 0.9619148, Photo_z_err: 1.0082535

# %%
check = 2
current = uncertains[check]
print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)
# Out:
# Spectro_z: 0.4236602063705637, Photo_z: 1.0992188, Photo_z_err: 1.1869007

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))
# Out:
# Spectro_z: 1.8146795467578518, Photo_z: 0.7394258, Photo_z_err: 0.45288742
# Spectro_z: 3.377056204122996, Photo_z: 1.6217501, Photo_z_err: 0.3793757
# Spectro_z: 3.9609214078799715, Photo_z: 1.7160772, Photo_z_err: 0.46218947
# Spectro_z: 3.2764430088037586, Photo_z: 1.4502828, Photo_z_err: 0.4609936
# Spectro_z: 2.374941580264775, Photo_z: 0.56821895, Photo_z_err: 0.3132655
# Spectro_z: 1.8389880910752479, Photo_z: 0.5806137, Photo_z_err: 0.32196292
# Spectro_z: 3.944598539961188, Photo_z: 2.0388036, Photo_z_err: 0.33122444
# Spectro_z: 3.42480845102567, Photo_z: 1.5879307, Photo_z_err: 0.49131772
# Spectro_z: 2.1460076993059203, Photo_z: 0.6952301, Photo_z_err: 0.43730518
# Spectro_z: 3.6790789876574506, Photo_z: 1.7255058, Photo_z_err: 0.41875416
# Spectro_z: 3.2941839963845703, Photo_z: 1.5591958, Photo_z_err: 0.47124618
# Spectro_z: 2.653426172831882, Photo_z: 1.1638223, Photo_z_err: 0.48634672
# Spectro_z: 2.994015995689931, Photo_z: 1.786304, Photo_z_err: 0.48104036
# Spectro_z: 3.7102209702261417, Photo_z: 2.0065706, Photo_z_err: 0.3215737
# Spectro_z: 2.0762006312993115, Photo_z: 0.63998497, Photo_z_err: 0.47255945
# Spectro_z: 2.0080022523090877, Photo_z: 0.970741, Photo_z_err: 0.4398726
# Spectro_z: 2.9958758027600245, Photo_z: 1.7022347, Photo_z_err: 0.4433614
# Spectro_z: 2.9010930460746445, Photo_z: 1.8112035, Photo_z_err: 0.4102253
# Spectro_z: 3.4324004786010716, Photo_z: 1.8391292, Photo_z_err: 0.43616262
# Spectro_z: 3.5774339419797636, Photo_z: 2.1520152, Photo_z_err: 0.3900101
# Spectro_z: 3.303419151269629, Photo_z: 1.784966, Photo_z_err: 0.48809075
# Spectro_z: 3.9952140528697337, Photo_z: 2.0133812, Photo_z_err: 0.4574986
# Spectro_z: 3.2176696526536133, Photo_z: 1.708543, Photo_z_err: 0.4891138
# Spectro_z: 3.6321956352937277, Photo_z: 2.013351, Photo_z_err: 0.41903326
# Spectro_z: 3.1427640662009595, Photo_z: 1.6576701, Photo_z_err: 0.46829122
# Spectro_z: 2.960590197221, Photo_z: 1.8630655, Photo_z_err: 0.45117676
# Spectro_z: 3.742337024054147, Photo_z: 2.0772772, Photo_z_err: 0.49453837
# Spectro_z: 1.7379840162620028, Photo_z: 0.5272027, Photo_z_err: 0.4617293
# Spectro_z: 3.6420763134348793, Photo_z: 2.0539963, Photo_z_err: 0.34185678
# Spectro_z: 3.8300805878344666, Photo_z: 2.0402946, Photo_z_err: 0.30661246
# Spectro_z: 3.9220129339453997, Photo_z: 1.9168003, Photo_z_err: 0.49531597
# Spectro_z: 1.520811073974678, Photo_z: 0.47091085, Photo_z_err: 0.27186188
# Spectro_z: 3.220406165372893, Photo_z: 1.9768095, Photo_z_err: 0.4976976
# Spectro_z: 2.9395926708272344, Photo_z: 1.2150406, Photo_z_err: 0.4365035
# Spectro_z: 3.375581933609649, Photo_z: 1.9435538, Photo_z_err: 0.33826768
# Spectro_z: 3.0114385980080662, Photo_z: 1.8452322, Photo_z_err: 0.46584737
# Spectro_z: 2.626196285152609, Photo_z: 1.346708, Photo_z_err: 0.48882487
# Spectro_z: 3.8802855029754437, Photo_z: 1.7412784, Photo_z_err: 0.45602465
# Spectro_z: 2.761990873982054, Photo_z: 1.3129146, Photo_z_err: 0.41483012
# Spectro_z: 3.675448595967953, Photo_z: 1.3900111, Photo_z_err: 0.4629559
# Spectro_z: 3.4547859474372897, Photo_z: 1.9278584, Photo_z_err: 0.4498407
# Spectro_z: 1.8118500812499256, Photo_z: 0.7730898, Photo_z_err: 0.2219089
# Spectro_z: 1.931066591209138, Photo_z: 0.8488883, Photo_z_err: 0.28986555
# Spectro_z: 3.8069297088961114, Photo_z: 1.9175533, Photo_z_err: 0.49609047
# Spectro_z: 3.9049312574403685, Photo_z: 1.9436476, Photo_z_err: 0.49062294
# Spectro_z: 3.602937187552591, Photo_z: 1.8253624, Photo_z_err: 0.41493383
# Spectro_z: 3.2360972400288586, Photo_z: 1.9121836, Photo_z_err: 0.419708
# Spectro_z: 3.6356365549090106, Photo_z: 2.2209408, Photo_z_err: 0.49406624
# Spectro_z: 3.1769657297385936, Photo_z: 2.0676568, Photo_z_err: 0.49001232
# Spectro_z: 1.916952740351344, Photo_z: 0.6343119, Photo_z_err: 0.47111166
# Spectro_z: 3.9587454135222178, Photo_z: 2.1115832, Photo_z_err: 0.49231064
# Spectro_z: 3.7817115064713733, Photo_z: 1.9510118, Photo_z_err: 0.4301658
# Spectro_z: 3.9223427506511688, Photo_z: 1.8580742, Photo_z_err: 0.37982863
# Spectro_z: 3.785196912581109, Photo_z: 2.0136368, Photo_z_err: 0.42675424
# Spectro_z: 3.408151246780828, Photo_z: 1.9969178, Photo_z_err: 0.4773875
# Spectro_z: 2.710185596272677, Photo_z: 0.8668546, Photo_z_err: 0.33692676
# Spectro_z: 2.8900317502186614, Photo_z: 1.800261, Photo_z_err: 0.4812412
# Spectro_z: 3.217589617218572, Photo_z: 1.483525, Photo_z_err: 0.49773848
# Spectro_z: 2.916406378008799, Photo_z: 1.8244786, Photo_z_err: 0.4306049
# Spectro_z: 3.8274549822212296, Photo_z: 1.9360669, Photo_z_err: 0.33127946
# Spectro_z: 2.2171542115368243, Photo_z: 0.38977098, Photo_z_err: 0.22979221
# Spectro_z: 3.223229324710188, Photo_z: 2.1304507, Photo_z_err: 0.47839046
# Spectro_z: 3.612500309615371, Photo_z: 2.289758, Photo_z_err: 0.43157634
# Spectro_z: 2.6551780885153216, Photo_z: 1.4953252, Photo_z_err: 0.39631215
# Spectro_z: 3.223439697496069, Photo_z: 1.8393936, Photo_z_err: 0.46397758
# Spectro_z: 3.8798503207092616, Photo_z: 1.7729425, Photo_z_err: 0.49524963
# Spectro_z: 3.591022409280421, Photo_z: 1.9269897, Photo_z_err: 0.49976745
# Spectro_z: 2.9721360506601546, Photo_z: 1.6563579, Photo_z_err: 0.47196227
# Spectro_z: 3.5119567913467025, Photo_z: 1.3933481, Photo_z_err: 0.4799579
# Spectro_z: 3.3216138876860306, Photo_z: 1.8189538, Photo_z_err: 0.48425823
# Spectro_z: 1.615520781923932, Photo_z: 0.57939225, Photo_z_err: 0.2723813
# Spectro_z: 3.597252079231117, Photo_z: 1.8521194, Photo_z_err: 0.44600913
# Spectro_z: 3.566867971092506, Photo_z: 2.0866866, Photo_z_err: 0.48578572
# Spectro_z: 3.415183659397294, Photo_z: 1.7827313, Photo_z_err: 0.44809473
# Spectro_z: 3.51221884199413, Photo_z: 1.7863854, Photo_z_err: 0.43693593
# Spectro_z: 3.7857206652666644, Photo_z: 1.8791184, Photo_z_err: 0.4367555
# Spectro_z: 2.535660770762313, Photo_z: 0.7154207, Photo_z_err: 0.4526042
# Spectro_z: 3.3455560798045663, Photo_z: 1.5200555, Photo_z_err: 0.47426057
# Spectro_z: 3.8674548406523073, Photo_z: 1.7477026, Photo_z_err: 0.39342102
# Spectro_z: 3.963920657304679, Photo_z: 1.9775565, Photo_z_err: 0.4600884
# Spectro_z: 3.5858231353745156, Photo_z: 1.8757613, Photo_z_err: 0.47729045
# Spectro_z: 3.4755634525824712, Photo_z: 2.1608796, Photo_z_err: 0.47615683
# Spectro_z: 3.4025304314809954, Photo_z: 1.9919372, Photo_z_err: 0.4583183
# Spectro_z: 1.7799854314636545, Photo_z: 0.5334865, Photo_z_err: 0.32207122
# Spectro_z: 3.7265942392228992, Photo_z: 2.061767, Photo_z_err: 0.47652388
# Spectro_z: 3.4191222998256605, Photo_z: 1.5844369, Photo_z_err: 0.44859213
# Spectro_z: 3.1092880254621096, Photo_z: 1.7725315, Photo_z_err: 0.4916593
# Spectro_z: 1.506010894963889, Photo_z: 0.4527923, Photo_z_err: 0.3595007
# Spectro_z: 3.257299629412812, Photo_z: 1.680373, Photo_z_err: 0.30756444
# Spectro_z: 2.930216115146092, Photo_z: 1.7775143, Photo_z_err: 0.48951763
# Spectro_z: 3.0960681979691893, Photo_z: 1.6717962, Photo_z_err: 0.45161057
# Spectro_z: 2.795910450095656, Photo_z: 1.4681923, Photo_z_err: 0.39102232
# Spectro_z: 3.443554035067855, Photo_z: 1.6990308, Photo_z_err: 0.41677624
# Spectro_z: 3.671456097791615, Photo_z: 1.9647866, Photo_z_err: 0.45941588
# Spectro_z: 3.9770401281699543, Photo_z: 2.102756, Photo_z_err: 0.451137
# Spectro_z: 3.3154297264098664, Photo_z: 1.612719, Photo_z_err: 0.4966641
# Spectro_z: 3.737099062322874, Photo_z: 1.5724928, Photo_z_err: 0.4782379
# Spectro_z: 3.4711770791501366, Photo_z: 2.0125408, Photo_z_err: 0.41287047
# Spectro_z: 2.900697630920785, Photo_z: 1.8728607, Photo_z_err: 0.45015955
# Spectro_z: 3.2961245140436612, Photo_z: 1.4379439, Photo_z_err: 0.49080688
# Spectro_z: 3.9362368551046774, Photo_z: 1.8731146, Photo_z_err: 0.4979337
# Spectro_z: 0.17767814577757068, Photo_z: 1.2650533, Photo_z_err: 0.30369368
# Spectro_z: 2.7612374327656557, Photo_z: 1.6229963, Photo_z_err: 0.38657346
# Spectro_z: 3.1918934712590517, Photo_z: 1.8907626, Photo_z_err: 0.45416614
# Spectro_z: 1.809730235405147, Photo_z: 0.65766764, Photo_z_err: 0.3866212
# Spectro_z: 2.903982945721832, Photo_z: 1.5578768, Photo_z_err: 0.4276045
# Spectro_z: 2.771878625374511, Photo_z: 1.551828, Photo_z_err: 0.44860506
# Spectro_z: 3.6536987860248886, Photo_z: 1.8266256, Photo_z_err: 0.4585014
# Spectro_z: 1.9732428190426372, Photo_z: 0.7648462, Photo_z_err: 0.43013722
# Spectro_z: 3.688649990938191, Photo_z: 2.202333, Photo_z_err: 0.4646133
# Spectro_z: 3.9500765383249345, Photo_z: 2.0931735, Photo_z_err: 0.44768932
# Spectro_z: 3.214394372722567, Photo_z: 1.7781913, Photo_z_err: 0.4447679
# Spectro_z: 2.846031839705083, Photo_z: 1.5567787, Photo_z_err: 0.45700973
# Spectro_z: 3.7523399412035245, Photo_z: 2.0371652, Photo_z_err: 0.3794335
# Spectro_z: 2.9912977421320357, Photo_z: 1.8464559, Photo_z_err: 0.44491687
# Spectro_z: 2.142117031258752, Photo_z: 0.8647063, Photo_z_err: 0.470693
# Spectro_z: 3.3505110343208266, Photo_z: 1.5725341, Photo_z_err: 0.47351807
# Spectro_z: 3.694015709183208, Photo_z: 1.9910388, Photo_z_err: 0.42741925
# Spectro_z: 3.7640793296843347, Photo_z: 1.8687541, Photo_z_err: 0.44276085
# Spectro_z: 2.838032946975721, Photo_z: 1.757524, Photo_z_err: 0.40978
# Spectro_z: 3.316936356299015, Photo_z: 2.0273762, Photo_z_err: 0.47984943
# Spectro_z: 3.7017273657023804, Photo_z: 1.8697599, Photo_z_err: 0.45929205
# Spectro_z: 3.519525633295377, Photo_z: 1.9903414, Photo_z_err: 0.46740848
# Spectro_z: 1.9425223847054345, Photo_z: 0.8753155, Photo_z_err: 0.47279084
# Spectro_z: 2.9368524033636376, Photo_z: 1.5688481, Photo_z_err: 0.47606617
# Spectro_z: 3.2294259119006203, Photo_z: 1.5065914, Photo_z_err: 0.4391522
# Spectro_z: 3.024562004022199, Photo_z: 1.9979308, Photo_z_err: 0.4546033
# Spectro_z: 1.8800857974794054, Photo_z: 0.87742186, Photo_z_err: 0.48184
# Spectro_z: 3.2285617236413495, Photo_z: 1.6336234, Photo_z_err: 0.40683866
# Spectro_z: 3.829566739988555, Photo_z: 2.0277328, Photo_z_err: 0.35939288
# Spectro_z: 3.7515366034146633, Photo_z: 1.8575765, Photo_z_err: 0.46956664
# Spectro_z: 3.1505877856682005, Photo_z: 1.8350792, Photo_z_err: 0.35315454
# Spectro_z: 3.7261334823301095, Photo_z: 1.7858894, Photo_z_err: 0.33778214
# Spectro_z: 3.7230861879258943, Photo_z: 2.0031097, Photo_z_err: 0.45268008
# Spectro_z: 3.8388596985675614, Photo_z: 2.13335, Photo_z_err: 0.3531785
# Spectro_z: 3.3938042557670443, Photo_z: 1.8708403, Photo_z_err: 0.48859978
# Spectro_z: 2.750575298148892, Photo_z: 1.6702954, Photo_z_err: 0.48327404
# Spectro_z: 3.9126897126847964, Photo_z: 1.6264198, Photo_z_err: 0.49138325
# Spectro_z: 3.318320146067658, Photo_z: 1.879755, Photo_z_err: 0.48240033
# Spectro_z: 3.6304480485704165, Photo_z: 1.8154993, Photo_z_err: 0.43560287
# Spectro_z: 3.3803317490174014, Photo_z: 1.7488635, Photo_z_err: 0.38897946
# Spectro_z: 3.9265781037159275, Photo_z: 2.010707, Photo_z_err: 0.3846715
# Spectro_z: 3.362924950902854, Photo_z: 1.9479558, Photo_z_err: 0.46011025
# Spectro_z: 1.8825198491946393, Photo_z: 0.4759264, Photo_z_err: 0.22789739
# Spectro_z: 2.7623564968246757, Photo_z: 1.6094232, Photo_z_err: 0.4175241
# Spectro_z: 3.491102001636229, Photo_z: 1.6193187, Photo_z_err: 0.44450474
# Spectro_z: 3.5275531636873017, Photo_z: 2.0017176, Photo_z_err: 0.46879488
# Spectro_z: 1.6250489983635434, Photo_z: 0.5490767, Photo_z_err: 0.4156022
# Spectro_z: 1.8519979493798675, Photo_z: 0.5623862, Photo_z_err: 0.2789708
# Spectro_z: 3.4066986553680074, Photo_z: 2.045167, Photo_z_err: 0.45853835

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)
# Out:
# Spectro_z: 3.2764430088037586, Photo_z: 1.4502828, Photo_z_err: 0.4609936

# %%
a = 988
b = 264
c = 1198
d = 112
e = 241
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_test[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_test[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_test[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_test[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_test[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_test[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_test[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_test[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_test[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_test[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
a = 24
b = 15
c = 10
d = 96
e = 1868
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_train[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_train[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_train[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_train[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_train[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_train[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_train[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_train[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_train[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_train[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
for i in range(10000):
    if np.abs(y_train[i][0]-4)<0.1:
        print(i)
# Out:
# 1868
# 1967

# %%
# END
