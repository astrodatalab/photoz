# %%
import sys, os
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp

from tensorflow import keras
from tensorflow_probability import layers as tfpl
from tensorflow_probability import distributions as tfd
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import InputLayer, MaxPooling2D, Conv2D, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow_probability.python.distributions import kl_divergence
# Out:
# 2023-09-05 10:50:05.066669: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-09-05 10:50:05.752289: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-09-05 10:50:06.961858: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.029811: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.029993: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.032411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.032546: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.032665: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.615119: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.615293: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.615414: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-09-05 10:50:07.615518: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/temp/5x64x64_training.hdf5', 'r')
hf_test = h5py.File('/data/HSC/HSC_v6/temp/5x127x127_training.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_train.hdf5', 'r')\
# hf_test = h5py.File('/data3/Billy/64x64_cvae_generated_11.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/temp/5x64x64_validation_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
t = len(x_test)
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, 4.16)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
plt.imshow(x_train[0][:,:,0])

# %%
plt.imshow(x_test[0][:,:,0])

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
model_variational = Sequential([
    InputLayer(input_shape=(64, 64, 5)),
    
    # First Conv block
    tfpl.Convolution2DFlipout(16, kernel_size = (3, 3), activation = None, kernel_divergence_fn = kl_divergence_function),
    BatchNormalization(),
    Activation('relu'),
    tfpl.Convolution2DFlipout(32, kernel_size = (3, 3), activation = None, kernel_divergence_fn = kl_divergence_function),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(2, 2),
    
    # Second Conv block
    Conv2D(64, kernel_size = (3, 3), activation = None),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, kernel_size = (3, 3), activation = None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(2, 2),
    
    Flatten(),
    Dropout(0.3),
    
    # Dense Variational layer
    tfpl.DenseVariational(64, 
                          make_posterior_fn = posterior_mean_field,
                          make_prior_fn = prior_trainable,
                          kl_weight = 1 / n),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.2),
    
    # Output layer
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 64, 64, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 62, 62, 16)       1456
#  ut)
#
#  batch_normalization (BatchN  (None, 62, 62, 16)       64
#  ormalization)
#
#  activation (Activation)     (None, 62, 62, 16)        0
#
#  conv2d_flipout_1 (Conv2DFli  (None, 60, 60, 32)       9248
#  pout)
#
#  batch_normalization_1 (Batc  (None, 60, 60, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 26, 26, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dropout (Dropout)           (None, 21632)             0
#
#  dense_variational (DenseVar  (None, 64)               4153536
#  iational)
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 4,257,938
# Trainable params: 4,257,330
# Non-trainable params: 608
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return -estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'bayesian_cnn_rockfish_example'

# checkpoint_filepath = os.path.join('/data/tuando/models/', model_name) + '/' + model_name

weights_path = os.path.join('/data/tuando/models/', model_name) + '/weights'

# log_dir = os.path.join('/data/tuando/logs/', model_name)

# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# Epoch 1/60
# 2023-09-05 10:50:18.667565: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-09-05 10:50:19.362575: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-09-05 10:50:19.521043: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f8c60512c50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-09-05 10:50:19.521067: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-09-05 10:50:19.535045: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-09-05 10:50:19.643190: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-09-05 10:50:19.697703: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-09-05 10:50:19.751583: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 [==============================] - 10s 13ms/step - loss: 4543.5610 - root_mean_squared_error: 1.6791 - val_loss: 3971.6624 - val_root_mean_squared_error: 1.5251 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 3s 9ms/step - loss: 3833.2151 - root_mean_squared_error: 1.6420 - val_loss: 3694.1694 - val_root_mean_squared_error: 2.0877 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 3s 10ms/step - loss: 3567.6277 - root_mean_squared_error: 1.7548 - val_loss: 3445.0974 - val_root_mean_squared_error: 1.7802 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 3s 9ms/step - loss: 3334.0923 - root_mean_squared_error: 1.7075 - val_loss: 3225.3904 - val_root_mean_squared_error: 1.6062 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 3s 10ms/step - loss: 3124.0610 - root_mean_squared_error: 1.7205 - val_loss: 3024.3972 - val_root_mean_squared_error: 1.5841 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2933.3079 - root_mean_squared_error: 1.8260 - val_loss: 2842.4729 - val_root_mean_squared_error: 1.5909 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2757.5847 - root_mean_squared_error: 1.8296 - val_loss: 2673.9072 - val_root_mean_squared_error: 1.6095 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2595.7490 - root_mean_squared_error: 1.7967 - val_loss: 2518.3696 - val_root_mean_squared_error: 1.7427 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2444.3152 - root_mean_squared_error: 1.7722 - val_loss: 2370.7708 - val_root_mean_squared_error: 1.7162 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 3s 9ms/step - loss: 2301.5847 - root_mean_squared_error: 1.7706 - val_loss: 2232.2375 - val_root_mean_squared_error: 1.6277 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2166.5630 - root_mean_squared_error: 1.8927 - val_loss: 2100.9241 - val_root_mean_squared_error: 1.7006 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2038.6031 - root_mean_squared_error: 1.7556 - val_loss: 1976.2473 - val_root_mean_squared_error: 1.6090 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1917.0812 - root_mean_squared_error: 1.8358 - val_loss: 1857.7571 - val_root_mean_squared_error: 1.8011 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1800.7396 - root_mean_squared_error: 1.7601 - val_loss: 1743.6304 - val_root_mean_squared_error: 1.5319 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1690.0796 - root_mean_squared_error: 1.7344 - val_loss: 1635.6320 - val_root_mean_squared_error: 1.6768 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1584.1647 - root_mean_squared_error: 1.6466 - val_loss: 1532.2079 - val_root_mean_squared_error: 1.5306 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1483.0172 - root_mean_squared_error: 1.6948 - val_loss: 1433.4501 - val_root_mean_squared_error: 1.6358 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1386.4320 - root_mean_squared_error: 1.6189 - val_loss: 1339.4424 - val_root_mean_squared_error: 1.6582 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1294.4778 - root_mean_squared_error: 1.6687 - val_loss: 1248.9271 - val_root_mean_squared_error: 1.3826 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 3s 9ms/step - loss: 1206.5981 - root_mean_squared_error: 1.6293 - val_loss: 1163.9038 - val_root_mean_squared_error: 1.5473 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1123.2524 - root_mean_squared_error: 1.5736 - val_loss: 1082.1550 - val_root_mean_squared_error: 1.5246 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1043.3228 - root_mean_squared_error: 1.5241 - val_loss: 1004.6971 - val_root_mean_squared_error: 1.6506 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 3s 10ms/step - loss: 968.2776 - root_mean_squared_error: 1.5119 - val_loss: 931.9194 - val_root_mean_squared_error: 1.4644 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 3s 10ms/step - loss: 896.7683 - root_mean_squared_error: 1.4671 - val_loss: 862.4898 - val_root_mean_squared_error: 1.3811 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 3s 10ms/step - loss: 829.2491 - root_mean_squared_error: 1.4406 - val_loss: 796.7496 - val_root_mean_squared_error: 1.4213 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 3s 10ms/step - loss: 765.7708 - root_mean_squared_error: 1.3999 - val_loss: 734.7161 - val_root_mean_squared_error: 1.2139 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 3s 9ms/step - loss: 705.8518 - root_mean_squared_error: 1.3123 - val_loss: 676.7849 - val_root_mean_squared_error: 1.3367 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 3s 10ms/step - loss: 649.6550 - root_mean_squared_error: 1.3152 - val_loss: 622.4842 - val_root_mean_squared_error: 1.1264 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 3s 10ms/step - loss: 596.8456 - root_mean_squared_error: 1.2922 - val_loss: 571.3442 - val_root_mean_squared_error: 1.3273 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 3s 9ms/step - loss: 547.4482 - root_mean_squared_error: 1.3422 - val_loss: 523.4569 - val_root_mean_squared_error: 1.1483 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 3s 10ms/step - loss: 501.4450 - root_mean_squared_error: 1.2498 - val_loss: 479.4535 - val_root_mean_squared_error: 1.3374 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 3s 10ms/step - loss: 458.3335 - root_mean_squared_error: 1.3650 - val_loss: 437.3822 - val_root_mean_squared_error: 1.3988 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 3s 10ms/step - loss: 418.2973 - root_mean_squared_error: 1.3542 - val_loss: 399.0000 - val_root_mean_squared_error: 1.3549 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 3s 10ms/step - loss: 381.1559 - root_mean_squared_error: 1.1993 - val_loss: 363.2840 - val_root_mean_squared_error: 1.3578 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 3s 9ms/step - loss: 346.8635 - root_mean_squared_error: 1.2018 - val_loss: 330.3080 - val_root_mean_squared_error: 1.2402 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 3s 10ms/step - loss: 315.0315 - root_mean_squared_error: 1.1719 - val_loss: 299.4905 - val_root_mean_squared_error: 1.1726 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 3s 10ms/step - loss: 285.6237 - root_mean_squared_error: 1.1622 - val_loss: 271.1366 - val_root_mean_squared_error: 1.0581 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 3s 10ms/step - loss: 258.5572 - root_mean_squared_error: 1.1094 - val_loss: 245.2404 - val_root_mean_squared_error: 1.0660 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 3s 10ms/step - loss: 233.6539 - root_mean_squared_error: 1.1923 - val_loss: 221.6006 - val_root_mean_squared_error: 1.0243 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 3s 10ms/step - loss: 210.8513 - root_mean_squared_error: 1.1754 - val_loss: 199.8559 - val_root_mean_squared_error: 1.1703 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 3s 10ms/step - loss: 189.9970 - root_mean_squared_error: 1.1526 - val_loss: 180.3492 - val_root_mean_squared_error: 1.4869 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 3s 10ms/step - loss: 170.8942 - root_mean_squared_error: 1.1522 - val_loss: 161.4097 - val_root_mean_squared_error: 1.1571 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 3s 9ms/step - loss: 153.3479 - root_mean_squared_error: 1.0555 - val_loss: 144.8800 - val_root_mean_squared_error: 0.8615 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 3s 10ms/step - loss: 137.5417 - root_mean_squared_error: 1.1068 - val_loss: 130.2697 - val_root_mean_squared_error: 1.2429 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 3s 10ms/step - loss: 123.0764 - root_mean_squared_error: 1.1263 - val_loss: 115.9288 - val_root_mean_squared_error: 1.0978 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 3s 10ms/step - loss: 110.0579 - root_mean_squared_error: 0.9454 - val_loss: 103.6724 - val_root_mean_squared_error: 0.9977 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 3s 9ms/step - loss: 98.2294 - root_mean_squared_error: 0.8878 - val_loss: 92.5728 - val_root_mean_squared_error: 1.1702 - lr: 0.0010
# Epoch 48/60
# 313/313 [==============================] - 3s 9ms/step - loss: 87.5238 - root_mean_squared_error: 0.9308 - val_loss: 82.2947 - val_root_mean_squared_error: 0.8881 - lr: 0.0010
# Epoch 49/60
# 313/313 [==============================] - 3s 10ms/step - loss: 77.9116 - root_mean_squared_error: 0.8250 - val_loss: 73.4907 - val_root_mean_squared_error: 0.8858 - lr: 0.0010
# Epoch 50/60
# 313/313 [==============================] - 3s 10ms/step - loss: 69.3157 - root_mean_squared_error: 0.8362 - val_loss: 65.0336 - val_root_mean_squared_error: 0.8807 - lr: 0.0010
# Epoch 51/60
# 313/313 [==============================] - 3s 9ms/step - loss: 61.8418 - root_mean_squared_error: 1.0741 - val_loss: 57.8438 - val_root_mean_squared_error: 0.7565 - lr: 0.0010
# Epoch 52/60
# 313/313 [==============================] - 3s 9ms/step - loss: 54.7550 - root_mean_squared_error: 0.8941 - val_loss: 51.3652 - val_root_mean_squared_error: 1.1190 - lr: 0.0010
# Epoch 53/60
# 313/313 [==============================] - 3s 10ms/step - loss: 48.5729 - root_mean_squared_error: 0.8722 - val_loss: 45.5482 - val_root_mean_squared_error: 0.9601 - lr: 0.0010
# Epoch 54/60
# 313/313 [==============================] - 3s 10ms/step - loss: 43.1723 - root_mean_squared_error: 0.8797 - val_loss: 40.4139 - val_root_mean_squared_error: 0.8441 - lr: 0.0010
# Epoch 55/60
# 313/313 [==============================] - 3s 10ms/step - loss: 38.3138 - root_mean_squared_error: 0.8682 - val_loss: 35.9471 - val_root_mean_squared_error: 0.7268 - lr: 0.0010
# Epoch 56/60
# 313/313 [==============================] - 3s 10ms/step - loss: 34.0621 - root_mean_squared_error: 0.7415 - val_loss: 32.0016 - val_root_mean_squared_error: 0.6893 - lr: 0.0010
# Epoch 57/60
# 313/313 [==============================] - 3s 10ms/step - loss: 30.3254 - root_mean_squared_error: 0.7773 - val_loss: 28.4193 - val_root_mean_squared_error: 0.6882 - lr: 0.0010
# Epoch 58/60
# 313/313 [==============================] - 3s 10ms/step - loss: 27.0246 - root_mean_squared_error: 0.7311 - val_loss: 25.4243 - val_root_mean_squared_error: 0.5189 - lr: 0.0010
# Epoch 59/60
# 313/313 [==============================] - 3s 10ms/step - loss: 24.1743 - root_mean_squared_error: 0.6389 - val_loss: 22.6193 - val_root_mean_squared_error: 0.5259 - lr: 0.0010
# Epoch 60/60
# 313/313 [==============================] - 3s 10ms/step - loss: 21.6333 - root_mean_squared_error: 0.5928 - val_loss: 20.2872 - val_root_mean_squared_error: 0.4969 - lr: 0.0010

# %% [markdown]
# # hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_max_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
# x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
# t = len(x_test)
# max_value = 1
# x_test = np.true_divide(x_test, max_value)[0:t]
# y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
# hf_test.close()

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
plt.imshow(x_test[98][:,:,4])

# %%
y_test[98]
# Out:
# array([0.2316716])

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.8205

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.8205

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.scatter(x_array, mean_array, marker='o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True)/(1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1])
plt.show()

# print("Outlier Rate: "+str(outlier_count_total/len(specz)))

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))
# Out:
# Spectro_z: 1.18259001, Photo_z: 1.4530026, Photo_z_err: 1.0543871
# Spectro_z: 2.42777991, Photo_z: 1.4804052, Photo_z_err: 1.1753082
# Spectro_z: 1.28392994, Photo_z: 1.5949731, Photo_z_err: 1.1919172
# Spectro_z: 2.75950503, Photo_z: 1.7387371, Photo_z_err: 1.1635232
# Spectro_z: 1.41940999, Photo_z: 1.6429771, Photo_z_err: 1.1430151
# Spectro_z: 1.08195806, Photo_z: 1.4870467, Photo_z_err: 2.042021
# Spectro_z: 2.21507001, Photo_z: 1.6914937, Photo_z_err: 1.1560491
# Spectro_z: 1.35273004, Photo_z: 1.8029277, Photo_z_err: 1.1178923
# Spectro_z: 1.28115404, Photo_z: 1.5646083, Photo_z_err: 1.1415588
# Spectro_z: 1.69402003, Photo_z: 1.1768457, Photo_z_err: 1.0257481
# Spectro_z: 1.26039004, Photo_z: 1.633168, Photo_z_err: 1.1549683
# Spectro_z: 1.68195903, Photo_z: 1.4982662, Photo_z_err: 1.1014277
# Spectro_z: 2.21758008, Photo_z: 1.6157346, Photo_z_err: 1.141026
# Spectro_z: 1.21512997, Photo_z: 1.6460733, Photo_z_err: 1.0848937
# Spectro_z: 1.66568005, Photo_z: 1.5062964, Photo_z_err: 1.2435857
# Spectro_z: 1.12054503, Photo_z: 1.8212901, Photo_z_err: 1.096623
# Spectro_z: 2.39241004, Photo_z: 1.5627875, Photo_z_err: 1.1494343
# Spectro_z: 2.32091999, Photo_z: 1.7728854, Photo_z_err: 1.3251086
# Spectro_z: 1.17987001, Photo_z: 1.6324425, Photo_z_err: 1.1053288
# Spectro_z: 2.00746012, Photo_z: 1.230507, Photo_z_err: 1.1957589
# Spectro_z: 1.97101295, Photo_z: 1.5454103, Photo_z_err: 1.1792943
# Spectro_z: 1.95455003, Photo_z: 1.4963487, Photo_z_err: 1.1142603
# Spectro_z: 0.777740002, Photo_z: 1.588868, Photo_z_err: 1.1471193
# Spectro_z: 1.83831406, Photo_z: 1.2544494, Photo_z_err: 1.0476949
# Spectro_z: 2.30589008, Photo_z: 1.8598557, Photo_z_err: 1.221788
# Spectro_z: 2.52589989, Photo_z: 1.7228093, Photo_z_err: 1.2441093
# Spectro_z: 2.01372004, Photo_z: 1.4106047, Photo_z_err: 1.0669188
# Spectro_z: 0.634880006, Photo_z: 1.5602338, Photo_z_err: 1.0542403
# Spectro_z: 3.19560003, Photo_z: 1.5709536, Photo_z_err: 1.0760107
# Spectro_z: 2.27212, Photo_z: 1.58444, Photo_z_err: 1.2952744
# Spectro_z: 2.63613009, Photo_z: 1.7205098, Photo_z_err: 1.1352956
# Spectro_z: 2.25905991, Photo_z: 1.6186364, Photo_z_err: 1.1483744
# Spectro_z: 1.14906001, Photo_z: 1.6289475, Photo_z_err: 1.1649266
# Spectro_z: 0.87865001, Photo_z: 1.483401, Photo_z_err: 1.0609763
# Spectro_z: 1.82590997, Photo_z: 1.2961445, Photo_z_err: 1.1468141
# Spectro_z: 1.06232703, Photo_z: 1.5658276, Photo_z_err: 1.0661299
# Spectro_z: 2.98144698, Photo_z: 1.2904503, Photo_z_err: 1.0670197
# Spectro_z: 2.4907701, Photo_z: 1.4395964, Photo_z_err: 1.1279571
# Spectro_z: 1.58900404, Photo_z: 1.6338415, Photo_z_err: 1.0482215
# Spectro_z: 1.53464997, Photo_z: 1.6203127, Photo_z_err: 1.1056579
# Spectro_z: 1.84053802, Photo_z: 1.6360751, Photo_z_err: 1.1291356
# Spectro_z: 1.68387997, Photo_z: 1.7232001, Photo_z_err: 1.0638062
# Spectro_z: 1.72407997, Photo_z: 1.176307, Photo_z_err: 1.0260131
# Spectro_z: 2.25361991, Photo_z: 1.4181161, Photo_z_err: 1.185914
# Spectro_z: 2.24763989, Photo_z: 1.5276709, Photo_z_err: 1.1286594
# Spectro_z: 1.42436004, Photo_z: 1.6436849, Photo_z_err: 1.2481953
# Spectro_z: 1.05407, Photo_z: 1.3647135, Photo_z_err: 1.036245
# Spectro_z: 1.18715, Photo_z: 1.6580251, Photo_z_err: 1.2286239
# Spectro_z: 2.29052997, Photo_z: 1.6982712, Photo_z_err: 1.0179105
# Spectro_z: 2.4395299, Photo_z: 1.4050136, Photo_z_err: 1.137166
# Spectro_z: 2.24962997, Photo_z: 1.5512191, Photo_z_err: 1.1020136
# Spectro_z: 2.72887993, Photo_z: 1.7378138, Photo_z_err: 1.1447983
# Spectro_z: 3.21930003, Photo_z: 1.5658448, Photo_z_err: 1.1185331
# Spectro_z: 2.36467004, Photo_z: 1.6229026, Photo_z_err: 1.1292174
# Spectro_z: 1.14443004, Photo_z: 1.7242416, Photo_z_err: 1.1812097
# Spectro_z: 2.95861006, Photo_z: 1.518956, Photo_z_err: 1.3215035
# Spectro_z: 2.26847005, Photo_z: 1.7769105, Photo_z_err: 1.2880695
# Spectro_z: 2.09067011, Photo_z: 1.6090866, Photo_z_err: 1.2413895
# Spectro_z: 0.899945915, Photo_z: 1.4750851, Photo_z_err: 1.0627692
# Spectro_z: 1.05555999, Photo_z: 1.4606804, Photo_z_err: 1.0550102
# Spectro_z: 2.26328993, Photo_z: 1.4138134, Photo_z_err: 1.0623305
# Spectro_z: 1.18550801, Photo_z: 1.6038322, Photo_z_err: 1.3119681
# Spectro_z: 2.5857501, Photo_z: 1.6177078, Photo_z_err: 1.073829
# Spectro_z: 2.13035989, Photo_z: 1.6527084, Photo_z_err: 1.3485382
# Spectro_z: 2.66753006, Photo_z: 1.592678, Photo_z_err: 1.1922691
# Spectro_z: 0.863740027, Photo_z: 2.5916617, Photo_z_err: 1.61442
# Spectro_z: 2.52825999, Photo_z: 1.2652484, Photo_z_err: 1.0906848
# Spectro_z: 2.33450007, Photo_z: 1.7886403, Photo_z_err: 1.2550781
# Spectro_z: 2.04081988, Photo_z: 1.7581728, Photo_z_err: 1.2710164
# Spectro_z: 1.80871296, Photo_z: 1.699642, Photo_z_err: 1.2199311
# Spectro_z: 1.17776501, Photo_z: 1.4416237, Photo_z_err: 1.2014096
# Spectro_z: 3.73107004, Photo_z: 1.049222, Photo_z_err: 1.0967891
# Spectro_z: 2.22394991, Photo_z: 1.6198255, Photo_z_err: 1.2446938
# Spectro_z: 2.64362001, Photo_z: 1.5724822, Photo_z_err: 1.1259223
# Spectro_z: 2.59710002, Photo_z: 1.5555208, Photo_z_err: 1.1521062
# Spectro_z: 3.58112001, Photo_z: 1.2600285, Photo_z_err: 1.096833
# Spectro_z: 0.787540019, Photo_z: 1.3081292, Photo_z_err: 1.351529
# Spectro_z: 2.18368006, Photo_z: 1.754028, Photo_z_err: 1.1773878
# Spectro_z: 1.37774897, Photo_z: 1.2827189, Photo_z_err: 1.17193
# Spectro_z: 2.14608908, Photo_z: 1.6412904, Photo_z_err: 1.123914
# Spectro_z: 3.25243998, Photo_z: 1.594735, Photo_z_err: 1.0783316
# Spectro_z: 2.45251989, Photo_z: 1.6201534, Photo_z_err: 1.184905
# Spectro_z: 1.9964, Photo_z: 1.4058931, Photo_z_err: 1.0015478
# Spectro_z: 2.90592003, Photo_z: 1.6795259, Photo_z_err: 1.1305473
# Spectro_z: 0.393854886, Photo_z: 1.185117, Photo_z_err: 1.1322563
# Spectro_z: 1.70061803, Photo_z: 1.4985392, Photo_z_err: 1.0807817
# Spectro_z: 1.70490801, Photo_z: 1.545361, Photo_z_err: 1.0088682
# Spectro_z: 1.71477401, Photo_z: 1.6359816, Photo_z_err: 1.1662692
# Spectro_z: 2.78044009, Photo_z: 1.7008216, Photo_z_err: 1.124787
# Spectro_z: 1.26674998, Photo_z: 0.7347646, Photo_z_err: 1.009123
# Spectro_z: 2.92459989, Photo_z: 1.3269062, Photo_z_err: 1.1629536
# Spectro_z: 2.22421002, Photo_z: 1.6641296, Photo_z_err: 1.2053365
# Spectro_z: 0.776409984, Photo_z: 1.5610137, Photo_z_err: 1.2219031
# Spectro_z: 2.45534992, Photo_z: 1.6229887, Photo_z_err: 1.1140505
# Spectro_z: 0.759869993, Photo_z: 1.402727, Photo_z_err: 1.5146155
# Spectro_z: 2.5650599, Photo_z: 1.6096857, Photo_z_err: 1.1946014
# Spectro_z: 1.70965695, Photo_z: 1.5766547, Photo_z_err: 1.1871115
# Spectro_z: 1.88121998, Photo_z: 1.3208284, Photo_z_err: 1.0167423

# %%
check = 2
current = uncertains[check]
print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)
# Out:
# Spectro_z: 1.28392994, Photo_z: 1.5949731, Photo_z_err: 1.1919172

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))
# Out:
# Spectro_z: 2.91554999, Photo_z: 0.7235451, Photo_z_err: 0.4617712
# Spectro_z: 2.27442002, Photo_z: 0.44712672, Photo_z_err: 0.2653166

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 check_bias = 3
# ----> 2 current_bias = biases[check_bias]
#       3 print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
#       4 plt.imshow(x_test[current_bias][:,:,0])
#
# IndexError: list index out of range

# %%
a = 988
b = 264
c = 1198
d = 112
e = 241
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_test[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_test[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_test[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_test[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_test[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_test[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_test[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_test[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_test[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_test[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
a = 24
b = 15
c = 10
d = 96
e = 1868
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_train[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_train[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_train[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_train[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_train[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_train[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_train[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_train[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_train[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_train[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
for i in range(10000):
    if np.abs(y_train[i][0]-4)<0.1:
        print(i)

# %%
# END
