# %% [markdown]
# To work on:
# Axes labels to the plots
# Small z range
# Implement callbacks, weights saving, predictions saving, ...
# Put more data in training

# %%
import os
import h5py
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from DataMaker import *

# %%
LATENT_DIM = 256
BASE_DEPTH = 8
IMAGE_SHAPE = (5, 127, 127)
EPOCHS = 100
GB_LIMIT = 10
CHECKPOINTS_TO_SAVE = 4
KL_WEIGHT = 1e-6
# Good value: between 1e-6 and 1e-7

# %%
DATASET_NAME = "HSC_v6_small"
MODEL_TYPE = "VAE"
MODEL_VERSION = "v7"

model_id = '_'.join([DATASET_NAME, MODEL_TYPE, MODEL_VERSION])
dir_model = os.path.join('/models', model_id, 'model')
dir_checkpoints = os.path.join('/models', model_id, 'checkpoints')
dir_logs = os.path.join('/logs', model_id)
dir_predictions = os.path.join('/predictions', model_id)
weights_file = dir_model + '/weights.h5'

print(weights_file)
print(dir_model)
print(dir_checkpoints)
print(dir_logs)
print(dir_predictions)

os.makedirs(dir_model, exist_ok=True)
os.makedirs(dir_checkpoints, exist_ok=True)
os.makedirs(dir_logs, exist_ok=True)
os.makedirs(dir_predictions, exist_ok=True)
# Out:
# /models/HSC_v6_small_VAE_v7/model/weights.h5
# /models/HSC_v6_small_VAE_v7/model
# /models/HSC_v6_small_VAE_v7/checkpoints
# /logs/HSC_v6_small_VAE_v7
# /predictions/HSC_v6_small_VAE_v7

# %% [markdown]
# ## Allocate GPU
#
# Make sure to check others' current usage on Aurora in terminal using `watch nvidia-smi`. Set your `GB_LIMIT` accordingly, in gigabytes. Aurora has 50GB of memory.

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=GB_LIMIT* 2000)])
        logical_gpus = tf.config.experimental.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 2022-10-28 17:04:37.903250: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 1 Physical GPUs, 1 Logical GPUs
# 2022-10-28 17:04:37.915266: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:37.916230: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:37.918038: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-28 17:04:37.919403: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:37.920327: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:37.921229: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:38.332750: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:38.333696: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:38.334586: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-28 17:04:38.335461: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %% [markdown]
# ## Data
#
# Create the shuffled and batched data generators.

# %% [markdown]
# from albumentations import Compose
# from albumentations.augmentations.transforms import ToFloat

# %% [markdown]
# my_augmenter = Compose([ToFloat(max_value=4.16)])
# batch_args_gen = {'X_key': 'image', 'y_key': 'image', 'labels_encoding': False, 'scaler': False,
#                   'batch_size': BATCH_SIZE, 'mode': 'train', 'shuffle': True}
# args_gen = {'X_key': 'image', 'y_key': 'image', 'labels_encoding': False, 'scaler': False,
#             'batch_size': 1, 'mode': 'test', 'shuffle': False}
# start_path = "/data/HSC/HSC_v6/step2A/127x127/five_band_image127x127_with_metadata_corrected_"
# TRAIN_PATH = start_path + "training_small.hdf5"
# VAL_PATH = start_path + "validation_small.hdf5"
# TEST_PATH = start_path + "testing_small.hdf5"

# %% [markdown]
# train_gen = HDF5ImageGenerator(src=TRAIN_PATH, **batch_args_gen)
# val_gen = HDF5ImageGenerator(src=VAL_PATH, **batch_args_gen)
# test_gen = HDF5ImageGenerator(src=TEST_PATH, **args_gen)

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step2A/127x127/five_band_image127x127_with_metadata_corrected_training_small.hdf5', 'r')
hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/five_band_image127x127_with_metadata_corrected_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step2A/127x127/five_band_image127x127_with_metadata_corrected_validation_small.hdf5', 'r')
x_train = np.asarray(hf_train['image'][0:])
x_test = np.asarray(hf_test['image'][0:])
x_validation = np.asarray(hf_validation['image'][0:])
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
# object_id_train = np.asarray(hf_train['object_id'][0:])
# object_id = np.asarray(hf_test['object_id'][0:])
# object_id_validation = np.asarray(hf_validation['object_id'][0:])
hf_train.close()
hf_test.close()
hf_validation.close()

# %% [markdown]
# for i in range(0,10000):
#     if y_train[i]>=0.1:
#         np.delete(x_train, i)
#         np.delete(y_train, i)
# for i in range(0,2000):
#     if y_test[i]>=0.1:
#         np.delete(x_test, i)
#         np.delete(y_test, i)
# for i in range(0,2000):
#     if y_validation[i]>=0.1:
#         np.delete(x_validation, i)
#         np.delete(y_validation, i)

# %% [markdown]
# ## Callbacks
#
# What we'd like to save during training.
#
# - Metrics logs per epoch to visualise in TensorBoard.
# - Model weights per epoch.
# - Predictions and corresponding metrics per prediction per epoch.

# %% [markdown]
# An alternative to ReduceLROnPlateau is LearningRateScheduler to decrease step size after a fixed number of epochs, but I think we'd prefer to do it by metric.

# %%
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

logs_callback = TensorBoard(log_dir=dir_logs)
weights_callback = ModelCheckpoint(filepath=os.path.join(dir_checkpoints, 'weights_epoch{epoch}.hdf5'),
                                   save_freq=int(EPOCHS/CHECKPOINTS_TO_SAVE),
                                   save_weights_only=True
                                  )
LR_callback = ReduceLROnPlateau()

# %% [markdown]
# ## VAE Model

# %% [markdown]
# ### Define model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Cropping2D, ZeroPadding2D
from tensorflow.keras.layers import Conv2D, Conv2DTranspose
from tensorflow.keras.layers import Input, Flatten, Dense, Reshape
import tensorflow_probability as tfp
from tensorflow_probability import layers as tfpl
from tensorflow_probability import distributions as tfd
from tensorflow.nn import leaky_relu

prior = tfd.Independent(tfd.Normal(loc=tf.zeros(LATENT_DIM), scale = 0.1), reinterpreted_batch_ndims=1)

class VAE(Model):
    def __init__(self):
        super(VAE, self).__init__()
        
        images = Input(shape=IMAGE_SHAPE)
        x = Conv2D(BASE_DEPTH, 3, strides=1, activation=leaky_relu,
                   padding='same', data_format='channels_first')(images)
        x = Conv2D(BASE_DEPTH, 3, strides=2, activation=leaky_relu,
                   padding='same', data_format='channels_first')(x)
        x = Conv2D(BASE_DEPTH, 3, strides=1, activation=leaky_relu,
                   padding='same', data_format='channels_first')(x)
        x = Conv2D(BASE_DEPTH, 3, strides=2, activation=leaky_relu,
                   padding='same', data_format='channels_first')(x)
        x = Conv2D(BASE_DEPTH, 3, strides=2, activation=leaky_relu,
                   padding='same', data_format='channels_first')(x)
        x = Flatten()(x)
        x = Dense(tfpl.MultivariateNormalTriL.params_size(LATENT_DIM), activation=None)(x)
        z = tfpl.MultivariateNormalTriL(LATENT_DIM,
                  activity_regularizer=tfpl.KLDivergenceRegularizer(prior, weight=KL_WEIGHT))(x)
        self.encoder = Model(images, z, name='encoder')

        latents = Input(shape=LATENT_DIM)
        x = Dense(4*LATENT_DIM*16*16, activation=None)(latents)
        x = Reshape((4*LATENT_DIM,16,16))(x)
        x = Conv2DTranspose(BASE_DEPTH, 3, strides=2, activation=leaky_relu,
                            padding='same', data_format='channels_first')(x)
        x = Conv2DTranspose(BASE_DEPTH, 3, strides=1, activation=leaky_relu,
                            padding='same', data_format='channels_first')(x)
        x = Conv2DTranspose(BASE_DEPTH, 3, strides=2, activation=leaky_relu,
                            padding='same', data_format='channels_first')(x)
        x = Conv2DTranspose(BASE_DEPTH, 3, strides=1, activation=leaky_relu,
                            padding='same', data_format='channels_first')(x)
        x = Conv2DTranspose(BASE_DEPTH, 3, strides=2, activation=leaky_relu,
                            padding='same', data_format='channels_first')(x)
        x = Conv2DTranspose(BASE_DEPTH, 3, strides=1, activation=leaky_relu,
                            padding='same', data_format='channels_first')(x)
        x = Conv2D(IMAGE_SHAPE[0], 3, strides=1, activation=None, 
                   padding='same', data_format='channels_first')(x)
        outputs = Cropping2D(cropping=((0,1),(0,1)), data_format='channels_first')(x)
        self.decoder = Model(latents, outputs, name='decoder')

    def call(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
    
    def summary(self):
        print(self.encoder.summary())
        print(self.decoder.summary())

# %%
model = VAE()

# %%
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "encoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 5, 127, 127)]     0
#
#  conv2d (Conv2D)             (None, 8, 127, 127)       368
#
#  conv2d_1 (Conv2D)           (None, 8, 64, 64)         584
#
#  conv2d_2 (Conv2D)           (None, 8, 64, 64)         584
#
#  conv2d_3 (Conv2D)           (None, 8, 32, 32)         584
#
#  conv2d_4 (Conv2D)           (None, 8, 16, 16)         584
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 33152)             67928448
#
#  multivariate_normal_tri_l (  ((None, 256),            0
#  MultivariateNormalTriL)      (None, 256))
#
# =================================================================
# Total params: 67,931,152
# Trainable params: 67,931,152
# Non-trainable params: 0
# _________________________________________________________________
# None
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256)]             0
#
#  dense_1 (Dense)             (None, 262144)            67371008
#
#  reshape (Reshape)           (None, 1024, 16, 16)      0
#
#  conv2d_transpose (Conv2DTra  (None, 8, 32, 32)        73736
#  nspose)
#
#  conv2d_transpose_1 (Conv2DT  (None, 8, 32, 32)        584
#  ranspose)
#
#  conv2d_transpose_2 (Conv2DT  (None, 8, 64, 64)        584
#  ranspose)
#
#  conv2d_transpose_3 (Conv2DT  (None, 8, 64, 64)        584
#  ranspose)
#
#  conv2d_transpose_4 (Conv2DT  (None, 8, 128, 128)      584
#  ranspose)
#
#  conv2d_transpose_5 (Conv2DT  (None, 8, 128, 128)      584
#  ranspose)
#
#  conv2d_5 (Conv2D)           (None, 5, 128, 128)       365
#
#  cropping2d (Cropping2D)     (None, 5, 127, 127)       0
#
# =================================================================
# Total params: 67,448,029
# Trainable params: 67,448,029
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### Train model

# %%
history = model.fit(
    x = x_train,
    y = x_train,
    epochs = 200,
    # callbacks=[logs_callback, weights_callback],
    validation_data = (x_validation, x_validation),
    verbose=2)
# Out:
# 2022-10-28 17:04:42.269659: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3225800000 exceeds 10% of free system memory.
# 2022-10-28 17:04:43.357257: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3225800000 exceeds 10% of free system memory.
# 2022-10-28 17:04:44.446771: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3225800000 exceeds 10% of free system memory.
# 2022-10-28 17:04:45.297350: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 3225800000 exceeds 10% of free system memory.
# Epoch 1/200
# 2022-10-28 17:06:55.846926: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8201
# 2022-10-28 17:09:52.166393: I tensorflow/core/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2022-10-28 17:09:52.904035: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 - 444s - loss: 0.1863 - val_loss: 0.1506 - 444s/epoch - 1s/step
# Epoch 2/200
# 313/313 - 9s - loss: 0.1480 - val_loss: 0.1464 - 9s/epoch - 29ms/step
# Epoch 3/200
# 313/313 - 9s - loss: 0.1426 - val_loss: 0.1426 - 9s/epoch - 29ms/step
# Epoch 4/200
# 313/313 - 9s - loss: 0.1413 - val_loss: 0.1405 - 9s/epoch - 29ms/step
# Epoch 5/200
# 313/313 - 9s - loss: 0.1370 - val_loss: 0.1365 - 9s/epoch - 28ms/step
# Epoch 6/200
# 313/313 - 9s - loss: 0.1385 - val_loss: 0.1363 - 9s/epoch - 29ms/step
# Epoch 7/200
# 313/313 - 9s - loss: 0.1331 - val_loss: 0.1345 - 9s/epoch - 30ms/step
# Epoch 8/200
# 313/313 - 9s - loss: 0.1329 - val_loss: 0.1338 - 9s/epoch - 29ms/step
# Epoch 9/200
# 313/313 - 9s - loss: 0.1317 - val_loss: 0.1312 - 9s/epoch - 29ms/step
# Epoch 10/200
# 313/313 - 9s - loss: 0.1280 - val_loss: 0.1323 - 9s/epoch - 29ms/step
# Epoch 11/200
# 313/313 - 9s - loss: 0.1295 - val_loss: 0.1324 - 9s/epoch - 29ms/step
# Epoch 12/200
# 313/313 - 9s - loss: 0.1295 - val_loss: 0.1442 - 9s/epoch - 29ms/step
# Epoch 13/200
# 313/313 - 9s - loss: 0.1284 - val_loss: 0.1294 - 9s/epoch - 29ms/step
# Epoch 14/200
# 313/313 - 9s - loss: 0.1253 - val_loss: 0.1310 - 9s/epoch - 29ms/step
# Epoch 15/200
# 313/313 - 9s - loss: 0.1266 - val_loss: 0.1305 - 9s/epoch - 29ms/step
# Epoch 16/200
# 313/313 - 9s - loss: 0.1255 - val_loss: 0.1282 - 9s/epoch - 29ms/step
# Epoch 17/200
# 313/313 - 9s - loss: 0.1279 - val_loss: 0.1351 - 9s/epoch - 29ms/step
# Epoch 18/200
# 313/313 - 9s - loss: 0.1228 - val_loss: 0.1294 - 9s/epoch - 29ms/step
# Epoch 19/200
# 313/313 - 9s - loss: 0.1207 - val_loss: 0.1272 - 9s/epoch - 29ms/step
# Epoch 20/200
# 313/313 - 9s - loss: 0.1223 - val_loss: 0.1291 - 9s/epoch - 29ms/step
# Epoch 21/200
# 313/313 - 9s - loss: 0.1237 - val_loss: 0.1269 - 9s/epoch - 29ms/step
# Epoch 22/200
# 313/313 - 9s - loss: 0.1189 - val_loss: 0.1281 - 9s/epoch - 30ms/step
# Epoch 23/200
# 313/313 - 9s - loss: 0.1210 - val_loss: 0.1281 - 9s/epoch - 29ms/step
# Epoch 24/200
# 313/313 - 9s - loss: 0.1183 - val_loss: 0.1268 - 9s/epoch - 30ms/step
# Epoch 25/200
# 313/313 - 9s - loss: 0.1287 - val_loss: 0.1335 - 9s/epoch - 30ms/step
# Epoch 26/200
# 313/313 - 9s - loss: 0.1261 - val_loss: 0.1306 - 9s/epoch - 29ms/step
# Epoch 27/200
# 313/313 - 9s - loss: 0.1180 - val_loss: 0.1255 - 9s/epoch - 29ms/step
# Epoch 28/200
# 313/313 - 9s - loss: 0.1159 - val_loss: 0.1265 - 9s/epoch - 29ms/step
# Epoch 29/200
# 313/313 - 9s - loss: 0.1241 - val_loss: 0.1272 - 9s/epoch - 29ms/step
# Epoch 30/200
# 313/313 - 9s - loss: 0.1187 - val_loss: 0.1282 - 9s/epoch - 29ms/step
# Epoch 31/200
# 313/313 - 9s - loss: 0.1166 - val_loss: 0.1229 - 9s/epoch - 29ms/step
# Epoch 32/200
# 313/313 - 9s - loss: 0.1158 - val_loss: 0.1266 - 9s/epoch - 29ms/step
# Epoch 33/200
# 313/313 - 9s - loss: 0.1191 - val_loss: 0.1289 - 9s/epoch - 29ms/step
# Epoch 34/200
# 313/313 - 9s - loss: 0.1117 - val_loss: 0.1264 - 9s/epoch - 30ms/step
# Epoch 35/200
# 313/313 - 9s - loss: 0.1150 - val_loss: 0.1317 - 9s/epoch - 29ms/step
# Epoch 36/200
# 313/313 - 9s - loss: 0.1139 - val_loss: 0.1254 - 9s/epoch - 29ms/step
# Epoch 37/200
# 313/313 - 9s - loss: 0.1119 - val_loss: 0.1229 - 9s/epoch - 29ms/step
# Epoch 38/200
# 313/313 - 9s - loss: 0.1126 - val_loss: 0.1229 - 9s/epoch - 29ms/step
# Epoch 39/200
# 313/313 - 9s - loss: 0.1122 - val_loss: 0.1271 - 9s/epoch - 29ms/step
# Epoch 40/200
# 313/313 - 9s - loss: 0.1180 - val_loss: 0.1242 - 9s/epoch - 29ms/step
# Epoch 41/200
# 313/313 - 9s - loss: 0.1087 - val_loss: 0.1253 - 9s/epoch - 29ms/step
# Epoch 42/200
# 313/313 - 9s - loss: 0.1164 - val_loss: 0.1277 - 9s/epoch - 30ms/step
# Epoch 43/200
# 313/313 - 9s - loss: 0.1129 - val_loss: 0.1232 - 9s/epoch - 29ms/step
# Epoch 44/200
# 313/313 - 9s - loss: 0.1092 - val_loss: 0.1281 - 9s/epoch - 29ms/step
# Epoch 45/200
# 313/313 - 9s - loss: 0.1087 - val_loss: 0.1215 - 9s/epoch - 29ms/step
# Epoch 46/200
# 313/313 - 9s - loss: 0.1247 - val_loss: 0.1220 - 9s/epoch - 29ms/step
# Epoch 47/200
# 313/313 - 9s - loss: 0.1117 - val_loss: 0.1231 - 9s/epoch - 28ms/step
# Epoch 48/200
# 313/313 - 9s - loss: 0.1119 - val_loss: 0.1217 - 9s/epoch - 29ms/step
# Epoch 49/200
# 313/313 - 9s - loss: 0.1211 - val_loss: 0.1222 - 9s/epoch - 29ms/step
# Epoch 50/200
# 313/313 - 9s - loss: 0.1107 - val_loss: 0.1221 - 9s/epoch - 29ms/step
# Epoch 51/200
# 313/313 - 9s - loss: 0.1065 - val_loss: 0.1264 - 9s/epoch - 29ms/step
# Epoch 52/200
# 313/313 - 9s - loss: 0.1129 - val_loss: 0.1195 - 9s/epoch - 29ms/step
# Epoch 53/200
# 313/313 - 9s - loss: 0.1073 - val_loss: 0.1199 - 9s/epoch - 29ms/step
# Epoch 54/200
# 313/313 - 9s - loss: 0.1090 - val_loss: 0.1283 - 9s/epoch - 29ms/step
# Epoch 55/200
# 313/313 - 9s - loss: 0.1064 - val_loss: 0.1202 - 9s/epoch - 29ms/step
# Epoch 56/200
# 313/313 - 9s - loss: 0.1009 - val_loss: 0.1217 - 9s/epoch - 29ms/step
# Epoch 57/200
# 313/313 - 9s - loss: 0.1114 - val_loss: 0.1190 - 9s/epoch - 29ms/step
# Epoch 58/200
# 313/313 - 9s - loss: 0.1090 - val_loss: 0.1185 - 9s/epoch - 29ms/step
# Epoch 59/200
# 313/313 - 9s - loss: 0.1051 - val_loss: 0.1191 - 9s/epoch - 29ms/step
# Epoch 60/200
# 313/313 - 9s - loss: 0.1010 - val_loss: 0.1194 - 9s/epoch - 29ms/step
# Epoch 61/200
# 313/313 - 9s - loss: 0.1002 - val_loss: 0.1219 - 9s/epoch - 29ms/step
# Epoch 62/200
# 313/313 - 9s - loss: 0.0991 - val_loss: 0.1158 - 9s/epoch - 29ms/step
# Epoch 63/200
# 313/313 - 9s - loss: 0.1032 - val_loss: 0.1224 - 9s/epoch - 29ms/step
# Epoch 64/200
# 313/313 - 9s - loss: 0.1017 - val_loss: 0.1199 - 9s/epoch - 29ms/step
# Epoch 65/200
# 313/313 - 9s - loss: 0.1020 - val_loss: 0.1155 - 9s/epoch - 29ms/step
# Epoch 66/200
# 313/313 - 9s - loss: 0.1085 - val_loss: 0.1188 - 9s/epoch - 30ms/step
# Epoch 67/200
# 313/313 - 9s - loss: 0.1022 - val_loss: 0.1189 - 9s/epoch - 30ms/step
# Epoch 68/200
# 313/313 - 9s - loss: 0.1024 - val_loss: 0.1210 - 9s/epoch - 29ms/step
# Epoch 69/200
# 313/313 - 9s - loss: 0.0999 - val_loss: 0.1167 - 9s/epoch - 30ms/step
# Epoch 70/200
# 313/313 - 9s - loss: 0.1035 - val_loss: 0.1198 - 9s/epoch - 30ms/step
# Epoch 71/200
# 313/313 - 9s - loss: 0.1003 - val_loss: 0.1223 - 9s/epoch - 30ms/step
# Epoch 72/200
# 313/313 - 9s - loss: 0.0971 - val_loss: 0.1229 - 9s/epoch - 29ms/step
# Epoch 73/200
# 313/313 - 9s - loss: 0.0930 - val_loss: 0.1179 - 9s/epoch - 30ms/step
# Epoch 74/200
# 313/313 - 9s - loss: 0.0960 - val_loss: 0.1142 - 9s/epoch - 29ms/step
# Epoch 75/200
# 313/313 - 9s - loss: 0.0931 - val_loss: 0.1158 - 9s/epoch - 29ms/step
# Epoch 76/200
# 313/313 - 9s - loss: 0.0941 - val_loss: 0.1190 - 9s/epoch - 30ms/step
# Epoch 77/200
# 313/313 - 9s - loss: 0.0954 - val_loss: 0.1196 - 9s/epoch - 30ms/step
# Epoch 78/200
# 313/313 - 9s - loss: 0.0981 - val_loss: 0.1156 - 9s/epoch - 30ms/step
# Epoch 79/200
# 313/313 - 9s - loss: 0.0941 - val_loss: 0.1202 - 9s/epoch - 29ms/step
# Epoch 80/200
# 313/313 - 9s - loss: 0.0913 - val_loss: 0.1165 - 9s/epoch - 29ms/step
# Epoch 81/200
# 313/313 - 9s - loss: 0.0934 - val_loss: 0.1189 - 9s/epoch - 29ms/step
# Epoch 82/200
# 313/313 - 9s - loss: 0.0920 - val_loss: 0.1179 - 9s/epoch - 29ms/step
# Epoch 83/200
# 313/313 - 9s - loss: 0.0919 - val_loss: 0.1160 - 9s/epoch - 29ms/step
# Epoch 84/200
# 313/313 - 9s - loss: 0.0953 - val_loss: 0.1152 - 9s/epoch - 30ms/step
# Epoch 85/200
# 313/313 - 9s - loss: 0.0927 - val_loss: 0.1132 - 9s/epoch - 30ms/step
# Epoch 86/200
# 313/313 - 9s - loss: 0.0947 - val_loss: 0.1151 - 9s/epoch - 29ms/step
# Epoch 87/200
# 313/313 - 9s - loss: 0.0877 - val_loss: 0.1106 - 9s/epoch - 30ms/step
# Epoch 88/200
# 313/313 - 9s - loss: 0.0955 - val_loss: 0.1191 - 9s/epoch - 30ms/step
# Epoch 89/200
# 313/313 - 9s - loss: 0.0913 - val_loss: 0.1138 - 9s/epoch - 29ms/step
# Epoch 90/200
# 313/313 - 9s - loss: 0.0921 - val_loss: 0.1167 - 9s/epoch - 30ms/step
# Epoch 91/200
# 313/313 - 9s - loss: 0.0899 - val_loss: 0.1105 - 9s/epoch - 30ms/step
# Epoch 92/200
# 313/313 - 9s - loss: 0.0865 - val_loss: 0.1145 - 9s/epoch - 29ms/step
# Epoch 93/200
# 313/313 - 9s - loss: 0.0852 - val_loss: 0.1127 - 9s/epoch - 29ms/step
# Epoch 94/200
# 313/313 - 9s - loss: 0.0874 - val_loss: 0.1138 - 9s/epoch - 29ms/step
# Epoch 95/200
# 313/313 - 9s - loss: 0.0920 - val_loss: 0.1125 - 9s/epoch - 29ms/step
# Epoch 96/200
# 313/313 - 9s - loss: 0.0873 - val_loss: 0.1187 - 9s/epoch - 29ms/step
# Epoch 97/200
# 313/313 - 9s - loss: 0.0852 - val_loss: 0.1144 - 9s/epoch - 29ms/step
# Epoch 98/200
# 313/313 - 9s - loss: 0.0893 - val_loss: 0.1077 - 9s/epoch - 29ms/step
# Epoch 99/200
# 313/313 - 9s - loss: 0.0849 - val_loss: 0.1094 - 9s/epoch - 29ms/step
# Epoch 100/200
# 313/313 - 9s - loss: 0.0826 - val_loss: 0.1064 - 9s/epoch - 29ms/step
# Epoch 101/200
# 313/313 - 9s - loss: 0.0813 - val_loss: 0.1154 - 9s/epoch - 29ms/step
# Epoch 102/200
# 313/313 - 9s - loss: 0.0803 - val_loss: 0.1120 - 9s/epoch - 29ms/step
# Epoch 103/200
# 313/313 - 9s - loss: 0.1016 - val_loss: 0.1154 - 9s/epoch - 29ms/step
# Epoch 104/200
# 313/313 - 9s - loss: 0.0855 - val_loss: 0.1139 - 9s/epoch - 29ms/step
# Epoch 105/200
# 313/313 - 9s - loss: 0.0849 - val_loss: 0.1085 - 9s/epoch - 29ms/step
# Epoch 106/200
# 313/313 - 9s - loss: 0.0809 - val_loss: 0.1072 - 9s/epoch - 29ms/step
# Epoch 107/200
# 313/313 - 9s - loss: 0.0796 - val_loss: 0.1084 - 9s/epoch - 28ms/step
# Epoch 108/200
# 313/313 - 9s - loss: 0.0786 - val_loss: 0.1101 - 9s/epoch - 29ms/step
# Epoch 109/200
# 313/313 - 9s - loss: 0.0840 - val_loss: 0.1076 - 9s/epoch - 29ms/step
# Epoch 110/200
# 313/313 - 9s - loss: 0.0774 - val_loss: 0.1057 - 9s/epoch - 29ms/step
# Epoch 111/200
# 313/313 - 9s - loss: 0.0781 - val_loss: 0.1057 - 9s/epoch - 29ms/step
# Epoch 112/200
# 313/313 - 9s - loss: 0.0797 - val_loss: 0.1068 - 9s/epoch - 30ms/step
# Epoch 113/200
# 313/313 - 9s - loss: 0.0784 - val_loss: 0.1230 - 9s/epoch - 29ms/step
# Epoch 114/200
# 313/313 - 9s - loss: 0.0802 - val_loss: 0.1062 - 9s/epoch - 29ms/step
# Epoch 115/200
# 313/313 - 9s - loss: 0.0772 - val_loss: 0.1084 - 9s/epoch - 30ms/step
# Epoch 116/200
# 313/313 - 9s - loss: 0.0772 - val_loss: 0.1090 - 9s/epoch - 29ms/step
# Epoch 117/200
# 313/313 - 9s - loss: 0.0754 - val_loss: 0.1072 - 9s/epoch - 29ms/step
# Epoch 118/200
# 313/313 - 9s - loss: 0.0739 - val_loss: 0.1086 - 9s/epoch - 29ms/step
# Epoch 119/200
# 313/313 - 9s - loss: 0.0803 - val_loss: 0.1054 - 9s/epoch - 29ms/step
# Epoch 120/200
# 313/313 - 9s - loss: 0.0757 - val_loss: 0.1123 - 9s/epoch - 29ms/step
# Epoch 121/200
# 313/313 - 9s - loss: 0.0778 - val_loss: 0.1033 - 9s/epoch - 29ms/step
# Epoch 122/200
# 313/313 - 9s - loss: 0.0756 - val_loss: 0.1041 - 9s/epoch - 29ms/step
# Epoch 123/200
# 313/313 - 9s - loss: 0.0726 - val_loss: 0.1072 - 9s/epoch - 30ms/step
# Epoch 124/200
# 313/313 - 9s - loss: 0.0739 - val_loss: 0.1099 - 9s/epoch - 29ms/step
# Epoch 125/200
# 313/313 - 9s - loss: 0.0767 - val_loss: 0.1026 - 9s/epoch - 29ms/step
# Epoch 126/200
# 313/313 - 9s - loss: 0.0700 - val_loss: 0.1059 - 9s/epoch - 29ms/step
# Epoch 127/200
# 313/313 - 9s - loss: 0.0761 - val_loss: 0.1052 - 9s/epoch - 30ms/step
# Epoch 128/200
# 313/313 - 9s - loss: 0.0714 - val_loss: 0.1059 - 9s/epoch - 29ms/step
# Epoch 129/200
# 313/313 - 9s - loss: 0.0732 - val_loss: 0.1010 - 9s/epoch - 29ms/step
# Epoch 130/200
# 313/313 - 9s - loss: 0.0682 - val_loss: 0.1043 - 9s/epoch - 29ms/step
# Epoch 131/200
# 313/313 - 9s - loss: 0.0694 - val_loss: 0.1007 - 9s/epoch - 29ms/step
# Epoch 132/200
# 313/313 - 9s - loss: 0.0705 - val_loss: 0.0983 - 9s/epoch - 29ms/step
# Epoch 133/200
# 313/313 - 9s - loss: 0.0693 - val_loss: 0.0999 - 9s/epoch - 29ms/step
# Epoch 134/200
# 313/313 - 9s - loss: 0.0683 - val_loss: 0.1053 - 9s/epoch - 29ms/step
# Epoch 135/200
# 313/313 - 9s - loss: 0.0687 - val_loss: 0.1003 - 9s/epoch - 29ms/step
# Epoch 136/200
# 313/313 - 9s - loss: 0.0747 - val_loss: 0.1013 - 9s/epoch - 29ms/step
# Epoch 137/200
# 313/313 - 9s - loss: 0.0681 - val_loss: 0.1048 - 9s/epoch - 29ms/step
# Epoch 138/200
# 313/313 - 9s - loss: 0.0658 - val_loss: 0.0991 - 9s/epoch - 29ms/step
# Epoch 139/200
# 313/313 - 9s - loss: 0.0686 - val_loss: 0.1045 - 9s/epoch - 29ms/step
# Epoch 140/200
# 313/313 - 9s - loss: 0.0653 - val_loss: 0.1075 - 9s/epoch - 30ms/step
# Epoch 141/200
# 313/313 - 9s - loss: 0.0648 - val_loss: 0.1043 - 9s/epoch - 30ms/step
# Epoch 142/200
# 313/313 - 9s - loss: 0.0640 - val_loss: 0.1005 - 9s/epoch - 29ms/step
# Epoch 143/200
# 313/313 - 9s - loss: 0.0702 - val_loss: 0.1017 - 9s/epoch - 29ms/step
# Epoch 144/200
# 313/313 - 9s - loss: 0.0682 - val_loss: 0.0983 - 9s/epoch - 30ms/step
# Epoch 145/200
# 313/313 - 9s - loss: 0.0660 - val_loss: 0.0976 - 9s/epoch - 30ms/step
# Epoch 146/200
# 313/313 - 9s - loss: 0.0628 - val_loss: 0.0974 - 9s/epoch - 29ms/step
# Epoch 147/200
# 313/313 - 9s - loss: 0.0639 - val_loss: 0.1009 - 9s/epoch - 30ms/step
# Epoch 148/200
# 313/313 - 9s - loss: 0.0648 - val_loss: 0.1010 - 9s/epoch - 30ms/step
# Epoch 149/200
# 313/313 - 9s - loss: 0.0630 - val_loss: 0.0983 - 9s/epoch - 28ms/step
# Epoch 150/200
# 313/313 - 9s - loss: 0.0633 - val_loss: 0.1002 - 9s/epoch - 29ms/step
# Epoch 151/200
# 313/313 - 9s - loss: 0.0636 - val_loss: 0.0936 - 9s/epoch - 29ms/step
# Epoch 152/200
# 313/313 - 9s - loss: 0.0605 - val_loss: 0.0977 - 9s/epoch - 29ms/step
# Epoch 153/200
# 313/313 - 9s - loss: 0.0610 - val_loss: 0.1000 - 9s/epoch - 29ms/step
# Epoch 154/200
# 313/313 - 9s - loss: 0.0607 - val_loss: 0.0980 - 9s/epoch - 29ms/step
# Epoch 155/200
# 313/313 - 9s - loss: 0.0627 - val_loss: 0.0993 - 9s/epoch - 29ms/step
# Epoch 156/200
# 313/313 - 9s - loss: 0.0600 - val_loss: 0.0977 - 9s/epoch - 29ms/step
# Epoch 157/200
# 313/313 - 9s - loss: 0.0597 - val_loss: 0.0996 - 9s/epoch - 30ms/step
# Epoch 158/200
# 313/313 - 9s - loss: 0.0590 - val_loss: 0.0990 - 9s/epoch - 30ms/step
# Epoch 159/200
# 313/313 - 9s - loss: 0.0590 - val_loss: 0.1019 - 9s/epoch - 30ms/step
# Epoch 160/200
# 313/313 - 9s - loss: 0.0602 - val_loss: 0.0960 - 9s/epoch - 29ms/step
# Epoch 161/200
# 313/313 - 9s - loss: 0.0596 - val_loss: 0.0979 - 9s/epoch - 29ms/step
# Epoch 162/200
# 313/313 - 9s - loss: 0.0610 - val_loss: 0.0943 - 9s/epoch - 29ms/step
# Epoch 163/200
# 313/313 - 9s - loss: 0.0580 - val_loss: 0.0992 - 9s/epoch - 29ms/step
# Epoch 164/200
# 313/313 - 9s - loss: 0.0582 - val_loss: 0.0953 - 9s/epoch - 29ms/step
# Epoch 165/200
# 313/313 - 9s - loss: 0.0561 - val_loss: 0.0992 - 9s/epoch - 30ms/step
# Epoch 166/200
# 313/313 - 9s - loss: 0.0575 - val_loss: 0.0971 - 9s/epoch - 30ms/step
# Epoch 167/200
# 313/313 - 9s - loss: 0.0589 - val_loss: 0.0995 - 9s/epoch - 29ms/step
# Epoch 168/200
# 313/313 - 9s - loss: 0.0577 - val_loss: 0.1005 - 9s/epoch - 30ms/step
# Epoch 169/200
# 313/313 - 9s - loss: 0.0564 - val_loss: 0.0984 - 9s/epoch - 30ms/step
# Epoch 170/200
# 313/313 - 9s - loss: 0.0560 - val_loss: 0.0918 - 9s/epoch - 29ms/step
# Epoch 171/200
# 313/313 - 9s - loss: 0.0546 - val_loss: 0.0970 - 9s/epoch - 30ms/step
# Epoch 172/200
# 313/313 - 9s - loss: 0.0574 - val_loss: 0.0996 - 9s/epoch - 29ms/step
# Epoch 173/200
# 313/313 - 9s - loss: 0.0555 - val_loss: 0.0961 - 9s/epoch - 29ms/step
# Epoch 174/200
# 313/313 - 9s - loss: 0.0602 - val_loss: 0.1018 - 9s/epoch - 29ms/step
# Epoch 175/200
# 313/313 - 9s - loss: 0.0554 - val_loss: 0.0998 - 9s/epoch - 29ms/step
# Epoch 176/200
# 313/313 - 9s - loss: 0.0548 - val_loss: 0.1015 - 9s/epoch - 29ms/step
# Epoch 177/200
# 313/313 - 9s - loss: 0.0541 - val_loss: 0.0956 - 9s/epoch - 29ms/step
# Epoch 178/200
# 313/313 - 9s - loss: 0.0583 - val_loss: 0.0964 - 9s/epoch - 29ms/step
# Epoch 179/200
# 313/313 - 9s - loss: 0.0537 - val_loss: 0.0918 - 9s/epoch - 29ms/step
# Epoch 180/200
# 313/313 - 9s - loss: 0.0534 - val_loss: 0.1015 - 9s/epoch - 30ms/step
# Epoch 181/200
# 313/313 - 9s - loss: 0.0536 - val_loss: 0.0972 - 9s/epoch - 29ms/step
# Epoch 182/200
# 313/313 - 9s - loss: 0.0524 - val_loss: 0.0913 - 9s/epoch - 29ms/step
# Epoch 183/200
# 313/313 - 9s - loss: 0.0520 - val_loss: 0.0880 - 9s/epoch - 30ms/step
# Epoch 184/200
# 313/313 - 9s - loss: 0.0527 - val_loss: 0.0937 - 9s/epoch - 29ms/step
# Epoch 185/200
# 313/313 - 9s - loss: 0.0514 - val_loss: 0.0963 - 9s/epoch - 29ms/step
# Epoch 186/200
# 313/313 - 9s - loss: 0.0504 - val_loss: 0.0970 - 9s/epoch - 30ms/step
# Epoch 187/200
# 313/313 - 9s - loss: 0.0545 - val_loss: 0.0891 - 9s/epoch - 29ms/step
# Epoch 188/200
# 313/313 - 9s - loss: 0.0512 - val_loss: 0.0949 - 9s/epoch - 29ms/step
# Epoch 189/200
# 313/313 - 9s - loss: 0.0482 - val_loss: 0.0962 - 9s/epoch - 30ms/step
# Epoch 190/200
# 313/313 - 9s - loss: 0.0519 - val_loss: 0.0955 - 9s/epoch - 29ms/step
# Epoch 191/200
# 313/313 - 9s - loss: 0.0500 - val_loss: 0.0966 - 9s/epoch - 29ms/step
# Epoch 192/200
# 313/313 - 9s - loss: 0.0501 - val_loss: 0.0911 - 9s/epoch - 29ms/step
# Epoch 193/200
# 313/313 - 9s - loss: 0.0502 - val_loss: 0.0926 - 9s/epoch - 29ms/step
# Epoch 194/200
# 313/313 - 9s - loss: 0.0484 - val_loss: 0.0897 - 9s/epoch - 29ms/step
# Epoch 195/200
# 313/313 - 9s - loss: 0.0487 - val_loss: 0.0928 - 9s/epoch - 30ms/step
# Epoch 196/200
# 313/313 - 9s - loss: 0.0520 - val_loss: 0.0930 - 9s/epoch - 30ms/step
# Epoch 197/200
# 313/313 - 9s - loss: 0.0493 - val_loss: 0.0918 - 9s/epoch - 29ms/step
# Epoch 198/200
# 313/313 - 9s - loss: 0.0490 - val_loss: 0.0928 - 9s/epoch - 29ms/step
# Epoch 199/200
# 313/313 - 9s - loss: 0.0496 - val_loss: 0.0949 - 9s/epoch - 29ms/step
# Epoch 200/200
# 313/313 - 9s - loss: 0.0488 - val_loss: 0.0903 - 9s/epoch - 29ms/step

# %% [markdown]
# ### Save final model

# %%
# model.save_weights(weights_file)

# %% [markdown]
# ## Save final predictions

# %%
from sys import stdout
from time import sleep

# %%
def save_preds(dataset='train', num_to_save=None):
    if dataset == 'train':
        datagen = HDF5ImageGenerator(src=TRAIN_PATH, **args_gen)
    elif dataset == 'val':
        datagen = HDF5ImageGenerator(src=VAL_PATH, **args_gen)
    else:
        dataset = 'test'
        datagen = test_gen
    preds_path = os.path.join(dir_predictions, dataset + "_preds.hdf5")
    print("Saving predictions for", dataset, "dataset in", preds_path)
    
    if num_to_save is None:
        size = len(datagen._indices)
    else:
        size = num_to_save

    with h5py.File(preds_path, 'w') as f:
        f.create_dataset('true', (size, ) + IMAGE_SHAPE)
        f.create_dataset('pred', (size, ) + IMAGE_SHAPE)
        f.create_dataset('loss', size)
        it = iter(datagen)
        for i in range(size):
            x = next(it)
            f['true'][i] = x
            f['pred'][i] = model.predict(x, verbose=0)
            f['loss'][i] = model.evaluate(x, x, verbose=0)
            stdout.write("\rSaved %d samples of " % i + str(size))
            stdout.flush()
            i += 1

# %%
# save_preds('train')

# %%
# save_preds('val')

# %%
# save_preds('test')

# %% [markdown]
# def display_preds(dataset='train', num_to_show=10):
#     preds_path = os.path.join(dir_predictions, dataset + "_preds.hdf5")
#     with h5py.File(preds_path, 'r') as f:
#         fig, axes = plt.subplots(nrows=num_to_show, ncols=2, figsize=(10,5*num_to_show))
#         for i in range(num_to_show):
#             axes[i][0].imshow(np.array([x_test[i]])[0][1])
#             axes[i][0].set_title('True')
#             axes[i][1].imshow(model(np.array([x_test[i]]))[0][1])
#             axes[i][1].set_title("Pred, loss %.2f" % f['loss'][i])

# %%
def scatter_bands(num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = 2, ncols = 5, figsize = (20, 10))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_array = np.append(true_array, np.amax(np.array([x_test[i]])[0][j]))
            pred_array = np.append(pred_array, np.amax(model(np.array([x_test[i]]))[0][j]))
        axes[int((i - index)/5)][int((i - index)%5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index)/5)][int((i - index)%5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index)/5)][int((i - index)%5)].set_xlabel("Bands")
        axes[int((i - index)/5)][int((i - index)%5)].set_ylabel("Maximum normalized pixel value")
        axes[int((i - index)/5)][int((i - index)%5)].legend()

# %%
scatter_bands()

# %%
def scatter_bands_percentile(percentile = 90, num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = 2, ncols = 5, figsize = (20, 10))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_90 = np.percentile(np.array([x_test[i]])[0][j].flatten(), percentile)
            pred_90 = np.percentile(np.asarray(model(np.array([x_test[i]]))[0][j]).flatten(), percentile)
            true_array = np.append(true_array, true_90)
            pred_array = np.append(pred_array, pred_90)
        axes[int((i - index)/5)][int((i - index)%5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index)/5)][int((i - index)%5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index)/5)][int((i - index)%5)].set_xlabel('Bands')
        axes[int((i - index)/5)][int((i - index)%5)].set_ylabel(f'{percentile}th percentile normalized pixel value')
        axes[int((i - index)/5)][int((i - index)%5)].legend()

# %%
def scatter_bands_mean(num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = 2, ncols = 5, figsize = (20, 10))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_mean = np.mean(np.array([x_test[i]])[0][j].flatten())
            pred_mean = np.mean(np.asarray(model(np.array([x_test[i]]))[0][j]).flatten())
            true_array = np.append(true_array, true_mean)
            pred_array = np.append(pred_array, pred_mean)
        axes[int((i - index)/5)][int((i - index)%5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index)/5)][int((i - index)%5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index)/5)][int((i - index)%5)].set_xlabel('Bands')
        axes[int((i - index)/5)][int((i - index)%5)].set_ylabel('Mean normalized pixel value')
        axes[int((i - index)/5)][int((i - index)%5)].legend()

# %%
scatter_bands_mean(10, 0)

# %% [markdown]
# scatter_bands_percentile(50, 10, 0)

# %%
def display_histograms(num_to_show = 2, index = 0):
    fig, axes = plt.subplots(nrows = num_to_show, ncols = 5, figsize = (20, 10))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        for j in range(0, 5):
            true_arr = sorted(np.array([x_test[i]])[0][j].flatten())
            pred_arr = sorted(np.asarray(model(np.array([x_test[i]]))[0][j]).flatten())
            true_arr = true_arr[0:int(len(true_arr)*.99)]
            pred_arr = pred_arr[0:int(len(pred_arr)*.99)]
            axes[i][j].hist(true_arr, 100, color = 'blue', label = 'True', alpha=0.5)
            axes[i][j].hist(pred_arr, 100, color = 'red', label = 'Predicted', alpha=0.5)
            axes[i][j].set_xlabel("Pixel Values")
            axes[i][j].set_ylabel("Count")
            axes[i][j].legend()
    fig.suptitle('Histograms of Predicted vs. True Image, Horizontal are Bands')

# %%
display_histograms()

# %%
def display_5_bands(index):
    fig, axes = plt.subplots(nrows = 2, ncols = 5, figsize = (20, 10))
    for i in range(0, 5):
        axes[0][i].imshow(np.array([x_test[index]])[0][i])
        max_pixel_true = round(np.amax(np.array([x_test[index]])[0][i]), 2)
        axes[0][i].set_title(f'True band {i} max = ' + str(max_pixel_true))
        pred = model(np.array([x_test[index]]))[0][i]
        axes[1][i].imshow(pred)
        max_pixel_pred = round(np.amax(pred), 2)
        axes[1][i].set_title(f'Pred band {i} max = ' + str(max_pixel_pred))

# %%
display_5_bands(4)

# %% [markdown]
# display_preds('val', num_to_show=10)

# %% [markdown]
# ### Example generations

# %%
from matplotlib import gridspec
import math

# %% [markdown]
# def generate_example_galaxies(num_to_generate=10):
#     z = prior.sample(num_to_generate)
#     xhat = model.decoder(z)
#     cols = 3
#     rows = int(math.ceil(num_to_generate / cols))
#     gs = gridspec.GridSpec(rows, cols)
#     fig = plt.figure(figsize=(15, 5*rows))
#     for i in range(num_to_generate):
#         ax = fig.add_subplot(gs[i])
#         ax.imshow(xhat[i][0])
#         ax.set_title(f'Generated image {i}')

# %%
def generate_example_galaxies(num_to_generate = 10):
    z = prior.sample(num_to_generate)
    xhat = model.decoder(z)
    fig, axes = plt.subplots(nrows = num_to_generate, ncols = 5, figsize = (4 * 5, 4 * num_to_generate))
    for i in range(num_to_generate):
        for j in range(0,5):
            axes[i][j].imshow(xhat[i][j])
            axes[i][j].set_title(f'Generated image {i} band {j}')

# %%
generate_example_galaxies(10)
