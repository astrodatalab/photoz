# %%
import sys, os
import numpy as np
import h5py
import random
import glob
import neptune
import matplotlib.pyplot as plt
from astropy.io import fits
import tqdm
import tensorflow as tf
import tensorflow_probability as tfp

from tqdm import tqdm
from tensorflow import keras
from tensorflow_probability import layers as tfpl
from tensorflow_probability import distributions as tfd
from tensorflow.keras import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import Concatenate, Input, MaxPooling2D, Conv2D, Conv2DTranspose, Flatten, Dropout, Dense, BatchNormalization, Activation, Reshape, LeakyReLU
from tensorflow.keras.optimizers import Adam
from tensorflow_probability.python.distributions import kl_divergence
from neptune.integrations.tensorflow_keras import NeptuneCallback
from DataMakerCVAE import *

# %%
LATENT_DIM = 64
IMAGE_SHAPE = (5, 64, 64)
BATCH_SIZE = 512
EPOCHS = 250
CHECKPOINTS_TO_SAVE = 4
KL_WEIGHT = 1e-3

# %%
gpus = tf.config.list_physical_devices('GPU');
if gpus:
    try:
        tf.config.experimental.set_virtual_device_configuration(
            gpus[0],
            [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 20000)]);
        logical_gpus = tf.config.experimental.list_logical_devices('GPU');
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2024-01-16 00:32:04.614703: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.694834: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.695089: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.698961: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.699163: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.699344: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.783802: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.784035: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.784221: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-01-16 00:32:04.784366: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 20000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
args_gen = {'X_key' : 'image',
    'y_key' : 'specz_redshift',
    'scaler' : False,
    'labels_encoding' : False,
    'batch_size': BATCH_SIZE,
    'mode' : 'train',
    'shuffle' : False}

train_gen = HDF5ImageGenerator(src = '/data/HSC/HSC_v6/step2A/64x64/5x64x64_training.hdf5', **args_gen)
test_gen = HDF5ImageGenerator(src = '/data/HSC/HSC_v6/step2A/64x64/5x64x64_testing.hdf5', **args_gen)
val_gen = HDF5ImageGenerator(src = '/data/HSC/HSC_v6/step2A/64x64/5x64x64_validation.hdf5', **args_gen)

# %%
# Prior
prior = tfd.Independent(tfd.Normal(loc = tf.zeros(LATENT_DIM), scale = 1.0), reinterpreted_batch_ndims = 1)

# Encoder
images = Input(shape = IMAGE_SHAPE)
redshifts = Input(shape = (1,))
conv1 = Conv2D(32, 3, strides = 2, activation = "relu", padding = 'same', data_format = 'channels_first')(images)
conv2 = Conv2D(64, 3, strides = 2, activation = "relu", padding = 'same', data_format = 'channels_first')(conv1)
conv3 = Conv2D(128, 2, strides = 1, activation = "relu", padding = 'same', data_format = 'channels_first')(conv2)
flatten1 = Flatten()(conv1)
flatten2 = Flatten()(conv2)
flatten3 = Flatten()(conv3)
x = tf.keras.layers.Concatenate()([flatten1, flatten2, flatten3, redshifts])
x = Dense(256, activation = "relu")(x)
x = Dense(128, activation = "relu")(x)
x = Dense(tfpl.MultivariateNormalTriL.params_size(LATENT_DIM), activation = None)(x)
z = tfpl.MultivariateNormalTriL(LATENT_DIM, activity_regularizer = tfpl.KLDivergenceRegularizer(prior, weight=KL_WEIGHT))(x)

encoder = Model([images, redshifts], z)
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.

# %%
zc = Input(shape = (LATENT_DIM + 1,))
x = Dense(128, activation = "relu")(zc)
x = Dense(256, activation = "relu")(x)
x = Dense(128 * 16 * 16 + 64 * 16 * 16 + 32 * 32 * 32, activation = "relu")(x)
dense1, dense2, dense3 = tf.split(x, [128 * 16 * 16, 64 * 16 * 16, 32 * 32 * 32], axis = 1)
reshape1 = Reshape((128, 16, 16))(dense1)
reshape2 = Reshape((64, 16, 16))(dense2)
reshape3 = Reshape((32, 32, 32))(dense3)
deconv1 = Conv2DTranspose(64, 2, strides = 1, activation = "relu", padding = 'same', data_format = 'channels_first')(reshape1)
deconv2 = Conv2DTranspose(32, 3, strides = 2, activation = "relu", padding = 'same', data_format = 'channels_first')(reshape2 + deconv1)
deconv3 = Conv2DTranspose(5, 3, strides = 2, activation = "relu", padding = 'same', data_format = 'channels_first')(reshape3 + deconv2)
outputs = Reshape(IMAGE_SHAPE)(deconv3)

decoder = Model(zc, outputs)

# %%
z = encoder([images, redshifts])
zc = tf.keras.layers.Concatenate()([z, redshifts])  # Assuming you want to concat the output of encoder and redshifts
decoder_output = decoder(zc)

model = Model(inputs = [images, redshifts], outputs = decoder_output)

# %%
encoder.summary()
decoder.summary()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 64, 64)]  0           []
#
#  conv2d (Conv2D)                (None, 32, 32, 32)   1472        ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 64, 16, 16)   18496       ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 128, 16, 16)  32896       ['conv2d_1[0][0]']
#
#  flatten (Flatten)              (None, 32768)        0           ['conv2d[0][0]']
#
#  flatten_1 (Flatten)            (None, 16384)        0           ['conv2d_1[0][0]']
#
#  flatten_2 (Flatten)            (None, 32768)        0           ['conv2d_2[0][0]']
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  concatenate (Concatenate)      (None, 81921)        0           ['flatten[0][0]',
#                                                                   'flatten_1[0][0]',
#                                                                   'flatten_2[0][0]',
#                                                                   'input_2[0][0]']
#
#  dense (Dense)                  (None, 256)          20972032    ['concatenate[0][0]']
#
#  dense_1 (Dense)                (None, 128)          32896       ['dense[0][0]']
#
#  dense_2 (Dense)                (None, 2144)         276576      ['dense_1[0][0]']
#
#  multivariate_normal_tri_l (Mul  ((None, 64),        0           ['dense_2[0][0]']
#  tivariateNormalTriL)            (None, 64))
#
# ==================================================================================================
# Total params: 21,334,368
# Trainable params: 21,334,368
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 65)]         0           []
#
#  dense_3 (Dense)                (None, 128)          8448        ['input_3[0][0]']
#
#  dense_4 (Dense)                (None, 256)          33024       ['dense_3[0][0]']
#
#  dense_5 (Dense)                (None, 81920)        21053440    ['dense_4[0][0]']
#
#  tf.split (TFOpLambda)          [(None, 32768),      0           ['dense_5[0][0]']
#                                  (None, 16384),
#                                  (None, 32768)]
#
#  reshape (Reshape)              (None, 128, 16, 16)  0           ['tf.split[0][0]']
#
#  reshape_1 (Reshape)            (None, 64, 16, 16)   0           ['tf.split[0][1]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 16, 16)  32832       ['reshape[0][0]']
#  ose)
#
#  tf.__operators__.add (TFOpLamb  (None, 64, 16, 16)  0           ['reshape_1[0][0]',
#  da)                                                              'conv2d_transpose[0][0]']
#
#  reshape_2 (Reshape)            (None, 32, 32, 32)   0           ['tf.split[0][2]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 32)  18464       ['tf.__operators__.add[0][0]']
#  spose)
#
#  tf.__operators__.add_1 (TFOpLa  (None, 32, 32, 32)  0           ['reshape_2[0][0]',
#  mbda)                                                            'conv2d_transpose_1[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 5, 64, 64)   1445        ['tf.__operators__.add_1[0][0]']
#  spose)
#
#  reshape_3 (Reshape)            (None, 5, 64, 64)    0           ['conv2d_transpose_2[0][0]']
#
# ==================================================================================================
# Total params: 21,147,653
# Trainable params: 21,147,653
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 64, 64)]  0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  model (Functional)             (None, 64)           21334368    ['input_1[0][0]',
#                                                                   'input_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 65)           0           ['model[0][0]',
#                                                                   'input_2[0][0]']
#
#  model_1 (Functional)           (None, 5, 64, 64)    21147653    ['concatenate_1[0][0]']
#
# ==================================================================================================
# Total params: 42,482,021
# Trainable params: 42,482,021
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
optimizer = Adam(learning_rate = 0.001)
model.compile(optimizer = optimizer, loss = 'mse')

# %%
run = neptune.init_run(
    name = "CVAE",
    project = "astro-data-lab/VAE",
    api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiIxOGFlZGMxOC04MWU5LTQ2NDctYjlhZS05NGE2NGQ0NmIzMmEifQ==",
)  # your credentials

model_name = 'cvae'

weights_path = os.path.join('/data3/Billy/models/', model_name) + '/weights'

neptune_callback = NeptuneCallback(run = run)

LR_callback = ReduceLROnPlateau()
# Out:
# /tmp/ipykernel_3353448/3186989927.py:1: NeptuneWarning: To avoid unintended consumption of logging hours during interactive sessions, the following monitoring options are disabled unless set to 'True' when initializing the run: 'capture_stdout', 'capture_stderr', and 'capture_hardware_metrics'.
#   run = neptune.init_run(
# https://app.neptune.ai/astro-data-lab/VAE/e/VAE-258

# %%
history = model.fit(train_gen, epochs = 100, callbacks = [neptune_callback, LR_callback], validation_data = val_gen, verbose = 1)
# Out:
# Epoch 1/100
# 2024-01-16 00:32:09.769958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2024-01-16 00:32:12.134436: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2024-01-16 00:32:12.295685: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-16 00:32:12.575988: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2024-01-16 00:32:13.085167: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f7879683980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-01-16 00:32:13.085194: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2024-01-16 00:32:13.102609: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-01-16 00:32:13.232908: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2024-01-16 00:32:13.296117: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 400/400 [==============================] - ETA: 0s - loss: 2.7570
# 2024-01-16 00:37:25.952508: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 400/400 [==============================] - 381s 940ms/step - loss: 2.7570 - val_loss: 1.5798 - lr: 0.0010
# Epoch 2/100
# 400/400 [==============================] - 229s 571ms/step - loss: 2.0275 - val_loss: 1.5052 - lr: 0.0010
# Epoch 3/100
# 400/400 [==============================] - 270s 672ms/step - loss: 1.8815 - val_loss: 1.5046 - lr: 0.0010
# Epoch 4/100
# 400/400 [==============================] - 405s 1s/step - loss: 1.9914 - val_loss: 1.4920 - lr: 0.0010
# Epoch 5/100
# 400/400 [==============================] - 449s 1s/step - loss: 1.8549 - val_loss: 1.4644 - lr: 0.0010
# Epoch 6/100
# 400/400 [==============================] - 406s 1s/step - loss: 1.8417 - val_loss: 1.4832 - lr: 0.0010
# Epoch 7/100
# 400/400 [==============================] - 398s 997ms/step - loss: 1.8018 - val_loss: 1.4405 - lr: 0.0010
# Epoch 8/100
# 400/400 [==============================] - 404s 1s/step - loss: 1.7160 - val_loss: 1.3586 - lr: 0.0010
# Epoch 9/100
# 400/400 [==============================] - 374s 934ms/step - loss: 1.6944 - val_loss: 1.3565 - lr: 0.0010
# Epoch 10/100
# 400/400 [==============================] - 382s 957ms/step - loss: 1.6945 - val_loss: 1.3402 - lr: 0.0010
# Epoch 11/100
# 400/400 [==============================] - 403s 1s/step - loss: 1.6609 - val_loss: 1.2771 - lr: 0.0010
# Epoch 12/100
# 400/400 [==============================] - 387s 969ms/step - loss: 1.6268 - val_loss: 1.2506 - lr: 0.0010
# Epoch 13/100
# 400/400 [==============================] - 380s 950ms/step - loss: 1.5556 - val_loss: 1.4558 - lr: 0.0010
# Epoch 14/100
# 400/400 [==============================] - 372s 931ms/step - loss: 1.5308 - val_loss: 1.1674 - lr: 0.0010
# Epoch 15/100
# 400/400 [==============================] - 383s 958ms/step - loss: 1.4871 - val_loss: 1.1828 - lr: 0.0010
# Epoch 16/100
# 400/400 [==============================] - 382s 956ms/step - loss: 1.4689 - val_loss: 1.1751 - lr: 0.0010
# Epoch 17/100
# 400/400 [==============================] - 366s 917ms/step - loss: 1.4449 - val_loss: 1.1419 - lr: 0.0010
# Epoch 18/100
# 400/400 [==============================] - 346s 865ms/step - loss: 1.4470 - val_loss: 1.1442 - lr: 0.0010
# Epoch 19/100
# 400/400 [==============================] - 381s 952ms/step - loss: 1.4083 - val_loss: 1.1300 - lr: 0.0010
# Epoch 20/100
# 400/400 [==============================] - 365s 913ms/step - loss: 1.3728 - val_loss: 1.0788 - lr: 0.0010
# Epoch 21/100
# 400/400 [==============================] - 392s 982ms/step - loss: 1.5209 - val_loss: 1.1963 - lr: 0.0010
# Epoch 22/100
# 400/400 [==============================] - 388s 971ms/step - loss: 1.3524 - val_loss: 1.1597 - lr: 0.0010
# Epoch 23/100
# 400/400 [==============================] - 382s 957ms/step - loss: 1.3122 - val_loss: 1.0319 - lr: 0.0010
# Epoch 24/100
# 400/400 [==============================] - 370s 924ms/step - loss: 1.2901 - val_loss: 1.0447 - lr: 0.0010
# Epoch 25/100
# 400/400 [==============================] - 383s 959ms/step - loss: 1.3294 - val_loss: 1.0444 - lr: 0.0010
# Epoch 26/100
# 400/400 [==============================] - 376s 940ms/step - loss: 1.3789 - val_loss: 1.0326 - lr: 0.0010
# Epoch 27/100
# 400/400 [==============================] - 367s 916ms/step - loss: 1.2966 - val_loss: 1.0181 - lr: 0.0010
# Epoch 28/100
# 400/400 [==============================] - 376s 940ms/step - loss: 1.2265 - val_loss: 1.0040 - lr: 0.0010
# Epoch 29/100
# 400/400 [==============================] - 379s 947ms/step - loss: 1.2613 - val_loss: 1.2468 - lr: 0.0010
# Epoch 30/100
# 400/400 [==============================] - 370s 925ms/step - loss: 1.1944 - val_loss: 1.1781 - lr: 0.0010
# Epoch 31/100
# 400/400 [==============================] - 377s 942ms/step - loss: 1.1861 - val_loss: 0.9383 - lr: 0.0010
# Epoch 32/100
# 400/400 [==============================] - 378s 945ms/step - loss: 1.1630 - val_loss: 0.9441 - lr: 0.0010
# Epoch 33/100
# 400/400 [==============================] - 360s 900ms/step - loss: 1.1472 - val_loss: 0.9220 - lr: 0.0010
# Epoch 82/100
# 400/400 [==============================] - 340s 848ms/step - loss: 0.8351 - val_loss: 0.7448 - lr: 0.0010
# Epoch 83/100
# 400/400 [==============================] - 333s 835ms/step - loss: 0.9350 - val_loss: 0.7380 - lr: 0.0010
# Epoch 84/100
# 400/400 [==============================] - 337s 845ms/step - loss: 0.7634 - val_loss: 0.6956 - lr: 1.0000e-04
# Epoch 85/100
# 400/400 [==============================] - 352s 879ms/step - loss: 0.7335 - val_loss: 0.6871 - lr: 1.0000e-04
# Epoch 86/100
# 400/400 [==============================] - 318s 793ms/step - loss: 0.7204 - val_loss: 0.6842 - lr: 1.0000e-04
# Epoch 87/100
# 400/400 [==============================] - 336s 841ms/step - loss: 0.7119 - val_loss: 0.6739 - lr: 1.0000e-04
# Epoch 88/100
# 400/400 [==============================] - 326s 815ms/step - loss: 0.7045 - val_loss: 0.6712 - lr: 1.0000e-04
# Epoch 89/100
# 400/400 [==============================] - 321s 802ms/step - loss: 0.6998 - val_loss: 0.6688 - lr: 1.0000e-04
# Epoch 90/100
# 400/400 [==============================] - 348s 871ms/step - loss: 0.6954 - val_loss: 0.6662 - lr: 1.0000e-04
# Epoch 91/100
# 400/400 [==============================] - 310s 777ms/step - loss: 0.6914 - val_loss: 0.6639 - lr: 1.0000e-04
# Epoch 92/100
# 400/400 [==============================] - 320s 802ms/step - loss: 0.6882 - val_loss: 0.6613 - lr: 1.0000e-04
# Epoch 93/100
# 400/400 [==============================] - 329s 823ms/step - loss: 0.6848 - val_loss: 0.6661 - lr: 1.0000e-04
# Epoch 94/100
# 400/400 [==============================] - 318s 795ms/step - loss: 0.6811 - val_loss: 0.6598 - lr: 1.0000e-04
# Epoch 95/100
# 400/400 [==============================] - 333s 833ms/step - loss: 0.6793 - val_loss: 0.6564 - lr: 1.0000e-04
# Epoch 96/100
# 400/400 [==============================] - 324s 809ms/step - loss: 0.6767 - val_loss: 0.6560 - lr: 1.0000e-04
# Epoch 97/100
# 400/400 [==============================] - 333s 835ms/step - loss: 0.6737 - val_loss: 0.6542 - lr: 1.0000e-04
# Epoch 98/100
# 400/400 [==============================] - 349s 872ms/step - loss: 0.6723 - val_loss: 0.6551 - lr: 1.0000e-04
# Epoch 99/100
# 400/400 [==============================] - 318s 795ms/step - loss: 0.6696 - val_loss: 0.6537 - lr: 1.0000e-04
# Epoch 100/100
# 400/400 [==============================] - 359s 897ms/step - loss: 0.6673 - val_loss: 0.6524 - lr: 1.0000e-04

# %%
model.save_weights(weights_path)

# %%
model.load_weights(weights_path)

# %%
lib = 3
index = 466
z = test_gen[lib][0][1][index]
z_shifted = 2
band = 0
print(f'z = {z}')
str = np.asarray(encoder([np.array([test_gen[lib][0][0][index]]), np.array([test_gen[lib][0][1][index]])])[0])
str = np.concatenate((str, np.array([z])))
str = str.reshape(1, LATENT_DIM + 1)
str_shifted = np.asarray(encoder([np.array([test_gen[lib][0][0][index]]), np.array([test_gen[lib][0][1][index]])])[0])
str_shifted = np.concatenate((str_shifted, np.array([z_shifted])))
str_shifted = str_shifted.reshape(1, LATENT_DIM + 1)
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (10, 5))
axes[0].imshow(test_gen[lib][0][0][index][band], cmap = 'afmhot')
axes[1].imshow(decoder([str])[0][band], cmap = 'afmhot')
axes[2].imshow(decoder([str_shifted])[0][band], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[0].set_title("Original")
axes[1].set_title("Regenerated")
axes[2].set_title("Regenerated Far")
plt.show()
# Out:
# z = 0.0843899995

# %%
lib = 5
index = 273
z = test_gen[lib][0][1][index]
z_shifted = 0.1
band = 0
print(f'z = {z}')
str = np.asarray(encoder([np.array([test_gen[lib][0][0][index]]), np.array([test_gen[lib][0][1][index]])])[0])
str = np.concatenate((str, np.array([z])))
str = str.reshape(1, LATENT_DIM + 1)
str_shifted = np.asarray(encoder([np.array([test_gen[lib][0][0][index]]), np.array([test_gen[lib][0][1][index]])])[0])
str_shifted = np.concatenate((str_shifted, np.array([z_shifted])))
str_shifted = str_shifted.reshape(1, LATENT_DIM + 1)
fig, axes = plt.subplots(nrows = 1, ncols = 3, figsize = (10, 5))
axes[0].imshow(test_gen[lib][0][0][index][band], cmap = 'afmhot')
axes[1].imshow(decoder([str])[0][band], cmap = 'afmhot')
axes[2].imshow(decoder([str_shifted])[0][band], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[0].set_title("Original")
axes[1].set_title("Regenerated")
axes[2].set_title("Regenerated Close")
plt.show()
# Out:
# z = 0.840770006

# %%
band = 0
str = prior.sample(1)[0]
strlo = np.concatenate((str, np.array([0.1])))
strlo = strlo.reshape(1, LATENT_DIM + 1)
strhi = np.concatenate((str, np.array([2])))
strhi = strhi.reshape(1, LATENT_DIM + 1)
fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
axes[0].imshow(decoder([strlo])[0][band], cmap = 'afmhot')
axes[1].imshow(decoder([strhi])[0][band], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[0].set_title("Low z")
axes[1].set_title("High z")
plt.show()

# %% [markdown]
# fig, axes = plt.subplots(nrows = 1, ncols = 2, figsize = (10, 5))
# x_array = np.arange(5)
# lo_array = np.array([])
# hi_array = np.array([])
# for j in range(0, 5):
#     lo_array = np.append(lo_array, decoder([strlo])[0][j][63][63])
#     hi_array = np.append(hi_array, decoder([strhi])[0][j][63][63])
# axes[0].scatter(x_array, lo_array, c = 'blue', label = 'Low')
# axes[1].scatter(x_array, hi_array, c = 'red', label = 'High')
# axes[0].set_xlabel("Bands")
# axes[0].set_ylabel("Central Pixel Value")
# axes[0].legend()
# axes[1].legend()

# %%
fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (5, 5))
x_array = np.arange(5)
lo_array = np.array([])
hi_array = np.array([])
for j in range(0, 5):
    lo_array = np.append(lo_array, np.amax(np.transpose(np.asarray(decoder([strlo])[0][j][60:67]))[60:67].flatten()))
    hi_array = np.append(hi_array, np.amax(np.transpose(np.asarray(decoder([strhi])[0][j][60:67]))[60:67].flatten()))
axes.scatter(x_array, lo_array, c = 'blue', label = 'Low')
axes.scatter(x_array, hi_array, c = 'red', label = 'High')
axes.set_xlabel("Bands")
axes.set_ylabel("Max Pixel Value Near Center")
axes.legend()
axes.legend()

# %% [markdown]
# for j in range(3, 80):
#     for i in range(0, 512):
#         if test_gen[j][0][1][i] <= 0.1:
#             print(j)
#             print(i)

# %%
for j in range(3, 80):
    for i in range(0, 512):
        if test_gen[j][0][1][i] >= 3.5:
            print(j)
            print(i)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 3
#       1 for j in range(3, 80):
#       2     for i in range(0, 512):
# ----> 3         if test_gen[j][0][1][i] >= 3.5:
#       4             print(j)
#       5             print(i)
#
# IndexError: index 487 is out of bounds for axis 0 with size 487

# %%
for i in range(0, 84):
    l = 512
    if i == 83:
        l = 464
    for j in range(0, l):
        index = i * BATCH_SIZE + j + 1
        stdout.write("\rChecking %d samples of " % (index) + "42960")
        z = test_gen[i][0][1][j]
        str = np.asarray(encoder([np.array([test_gen[i][0][0][j]]), np.array([test_gen[i][0][1][j]])])[0])
        str = np.concatenate((str, np.array([z])))
        str = str.reshape(1, LATENT_DIM + 1)
        hdul = fits.PrimaryHDU(data = test_gen[i][0][0][j])
        string = f"/data/CVAE Generated/Full/Original Galaxy #{index}.fits"
        hdul.writeto(string, overwrite = True)
        hdul = fits.PrimaryHDU(data = decoder([str])[0])
        string = f"/data/CVAE Generated/Full/Reconstructed Galaxy #{index}.fits"
        hdul.writeto(string, overwrite = True)

# %%
def scatter_bands_max_near_center(num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = int(num_to_show / 5), ncols = 5, figsize = (20, int(num_to_show)))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_array = np.append(true_array, np.amax(np.array([test_gen[0][0][0][i][j]])))
            pred_array = np.append(pred_array, np.amax(np.transpose(np.asarray(model([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])])[0][j][60:67]))[60:67].flatten()))
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_xlabel("Bands")
        axes[int((i - index) / 5)][int((i - index) % 5)].set_ylabel(f"Maximum normalized pixel value z = {np.array([test_gen[0][0][1][i]])[0]}")
        axes[int((i - index) / 5)][int((i - index) % 5)].legend()

def scatter_bands_max(num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = int(num_to_show / 5), ncols = 5, figsize = (20, int(num_to_show)))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_array = np.append(true_array, np.amax(np.array([test_gen[0][0][0][i][j]])))
            pred_array = np.append(pred_array, np.amax(np.array([model([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])])[0][j]])))
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_xlabel("Bands")
        axes[int((i - index) / 5)][int((i - index) % 5)].set_ylabel("Maximum normalized pixel value")
        axes[int((i - index) / 5)][int((i - index) % 5)].legend()
        
def scatter_bands_center(num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = int(num_to_show / 5), ncols = 5, figsize = (20, int(num_to_show)))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_array = np.append(true_array, np.array([test_gen[0][0][0][i][j]])[0][63][63])
            pred_array = np.append(pred_array, model([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])])[0][j][63][63])
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_xlabel("Bands")
        axes[int((i - index) / 5)][int((i - index) % 5)].set_ylabel(f"Central pixel value z = {np.array([test_gen[0][0][1][i]])}")
        axes[int((i - index) / 5)][int((i - index) % 5)].legend()
        
def scatter_bands_center_shift(lib = 3, i = 37, z = 1):
    print(z)
    fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (5, 5))
    x_array = np.arange(5)
    true_array = np.array([])
    pred_array = np.array([])
    for j in range(0, 5):
        true_array = np.append(true_array, np.array([test_gen[lib][0][0][i][j]])[0][63][63])
        pred_array = np.append(pred_array, model([np.array([test_gen[lib][0][0][i]]), np.array([z])])[0][j][63][63])
    axes.scatter(x_array, true_array, c = 'blue', label = 'True')
    axes.scatter(x_array, pred_array, c = 'red', label = 'Predicted')
    axes.set_xlabel("Bands")
    axes.set_ylabel("Central pixel value")
    axes.legend()
    
def scatter_bands_max_shift(lib = 3, i = 37, z = 1):
    print(z)
    fig, axes = plt.subplots(nrows = 1, ncols = 1, figsize = (5, 5))
    x_array = np.arange(5)
    true_array = np.array([])
    pred_array = np.array([])
    for j in range(0, 5):
        true_array = np.append(true_array, np.amax(np.array([test_gen[lib][0][0][i][j]])))
        pred_array = np.append(pred_array, np.amax(np.array([model([np.array([test_gen[lib][0][0][i]]), np.array([z])])[0][j]])))
    axes.scatter(x_array, true_array, c = 'blue', label = 'True')
    axes.scatter(x_array, pred_array, c = 'red', label = 'Predicted')
    axes.set_xlabel("Bands")
    axes.set_ylabel("Central pixel value")
    axes.legend()

def scatter_bands_percentile(percentile = 90, num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = int(num_to_show /  5), ncols = 5, figsize = (20, int(num_to_show)))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_90 = np.percentile(np.array([test_gen[0][0][0][i][j]]).flatten(), percentile)
            pred_90 = np.percentile(np.asarray(model([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])])[0][j]).flatten(), percentile)
            true_array = np.append(true_array, true_90)
            pred_array = np.append(pred_array, pred_90)
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_xlabel('Bands')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_ylabel(f'{percentile}th percentile normalized pixel value')
        axes[int((i - index) / 5)][int((i - index) % 5)].legend()

def scatter_bands_mean(num_to_show = 10, index = 0):
    fig, axes = plt.subplots(nrows = int(num_to_show / 5), ncols = 5, figsize = (20, int(num_to_show)))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        true_array = np.array([])
        pred_array = np.array([])
        for j in range(0, 5):
            true_mean = np.mean(np.array([test_gen[0][0][0][i][j]]).flatten())
            pred_mean = np.mean(np.asarray(model([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])])[0][j]).flatten())
            true_array = np.append(true_array, true_mean)
            pred_array = np.append(pred_array, pred_mean)
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, true_array, c = 'blue', label = 'True')
        axes[int((i - index) / 5)][int((i - index) % 5)].scatter(x_array, pred_array, c = 'red', label = 'Predicted')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_xlabel('Bands')
        axes[int((i - index) / 5)][int((i - index) % 5)].set_ylabel('Mean normalized pixel value')
        axes[int((i - index) / 5)][int((i - index) % 5)].legend()

def display_histograms(num_to_show = 2, index = 0):
    fig, axes = plt.subplots(nrows = num_to_show, ncols = 5, figsize = (20, int(num_to_show)))
    for i in range(index, index + num_to_show):
        x_array = np.arange(5)
        for j in range(0, 5):
            true_arr = sorted(np.array([test_gen[0][0][0][i][j]]).flatten())
            pred_arr = sorted(np.asarray(model([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])])[0][j]).flatten())
            true_arr = true_arr[0 : int(len(true_arr) * .99)]
            pred_arr = pred_arr[0 : int(len(pred_arr) * .99)]
            axes[i][j].hist(true_arr, 100, color = 'blue', label = 'True', alpha = 0.5)
            axes[i][j].hist(pred_arr, 100, color = 'red', label = 'Predicted', alpha = 0.5)
            axes[i][j].set_xlabel("Pixel Values")
            axes[i][j].set_ylabel("Count")
            axes[i][j].legend()
    fig.suptitle('Histograms of Predicted vs. True Image, Horizontal are Bands')
    
def display_5_bands(index):
    fig, axes = plt.subplots(nrows = 2, ncols = 5, figsize = (20, 10))
    loss = round(model.evaluate([np.array([test_gen[0][0][0][index]]), np.array([test_gen[0][0][1][index]])], np.array([test_gen[0][0][0][index]]), verbose = 0), 2)
    for i in range(0, 5):
        axes[0][i].imshow(np.array([test_gen[0][0][0][index]])[0][i], cmap = 'afmhot')
        max_pixel_true = round(np.amax(np.array([test_gen[0][0][0][index]])[0][i]), 2)
        # axes[0][i].set_title(f'True band {i} max = {max_pixel_true}')
        pred = model([np.array([test_gen[0][0][0][index]]), np.array([test_gen[0][0][1][index]])])[0][i]
        axes[1][i].imshow(pred, cmap = 'afmhot')
        max_pixel_pred = round(np.amax(pred), 2)
        axes[1][i].set_title(f'\n loss = {loss}') # f'Pred band {i} max = {max_pixel_pred}' + 
        
def display_high_loss(num_to_show, min_loss):
    fig, axes = plt.subplots(nrows = num_to_show, ncols = 5, figsize = (20, 5 * num_to_show))
    r = 0
    for i in range(BATCH_SIZE):
        loss = round(model.evaluate([np.array([test_gen[0][0][0][i]]), np.array([test_gen[0][0][1][i]])], np.array([test_gen[0][0][0][i]]), verbose = 0), 2)
        if loss >= min_loss:
            print(i)
            for j in range(0, 5):
                axes[r][j].imshow(np.array([test_gen[0][0][0][i]])[0][j], cmap = 'afmhot')
                axes[r][j].set_title(f'Loss = {loss}')
            r += 1
        if r >= num_to_show:
            break

# %%
scatter_bands_max_near_center(num_to_show = 10, index = 10)

# %%
x_array = np.array([])
y_array = np.array([])
l = len(test_gen[0][0][0])
print(l)
for i in range(0, l):
    x_array = np.append(x_array, np.amax(np.array([test_gen[0][0][0][i][4]])))
    y_array = np.append(y_array, np.array([test_gen[0][0][1][i]])[0])
    print(i)
plt.scatter(y_array, x_array)

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([y_array, x_array])).astype('float32')
z = gaussian_kde(xy)(xy)
plt.scatter(y_array, x_array, s = 5, c = z)
plt.xlim(0,4)
plt.ylim(0, 80)
plt.xlabel("z")
plt.ylabel("Maximum Pixel Value near the Center")
plt.show()

# %%
scatter_bands_center_shift(lib = 3, i = 267, z = 40)

# %%
scatter_bands_max_shift(lib = 3, i = 37, z = test_gen[3][0][1][37])

# %%
scatter_bands_max_shift(lib = 3, i = 37, z = 0.1)

# %%
scatter_bands_max()

# %%
scatter_bands_center()

# %%
scatter_bands_mean(10, 0)

# %%
scatter_bands_percentile()

# %%
# display_histograms()

# %%
display_5_bands(38)

# %%
display_high_loss(10, 1)

# %%
from tqdm import tqdm

# %% [markdown]
# random_keys = np.asarray(prior.sample(2000))
# np.save('/data/HSC_generated/HSC_generated_v1/random_keys_cvae.npy', random_keys)

# %%
random_keys = np.load('/data/HSC_generated/HSC_generated_v1/random_keys_cvae.npy')
random_redshift = np.load('/data/HSC_generated/HSC_generated_v1/random_redshift.npy')

# %%
hf = h5py.File('/data3/Billy/5x64x64_cvae.hdf5', 'a')
str = prior.sample(1)[0]
str = np.concatenate((str, np.array([0.1])))
str = str.reshape(1, LATENT_DIM + 1)
image_g = decoder([str])[0][0]
image_r = decoder([str])[0][1]
image_i = decoder([str])[0][2]
image_z = decoder([str])[0][3]
image_y = decoder([str])[0][4]
five_band_image = []
five_band_image.append(image_g)
five_band_image.append(image_r)
five_band_image.append(image_i)
five_band_image.append(image_z)
five_band_image.append(image_y)
five_band_image_reshape = np.reshape(np.array(five_band_image), [1, 5, 64, 64])
hf.create_dataset('image', data = five_band_image_reshape, chunks = True, maxshape = (None, 5, 64, 64))
hf.create_dataset('specz_redshift', data = [0.1], chunks = True, maxshape = (None, ))
for i in tqdm(range(1999)):
    z = random.uniform(0, 2)
    str = prior.sample(1)[0]
    str = np.concatenate((str, np.array([z])))
    str = str.reshape(1, LATENT_DIM + 1)
    image_g = decoder([str])[0][0]
    image_r = decoder([str])[0][1]
    image_i = decoder([str])[0][2]
    image_z = decoder([str])[0][3]
    image_y = decoder([str])[0][4]
    five_band_image = []
    five_band_image.append(image_g)
    five_band_image.append(image_r)
    five_band_image.append(image_i)
    five_band_image.append(image_z)
    five_band_image.append(image_y)
    five_band_image_reshape = np.reshape(np.array(five_band_image), [1, 5, 64, 64])
    hf['specz_redshift'].resize((hf['specz_redshift'].shape[0] + 1), axis = 0)
    hf['specz_redshift'][hf['specz_redshift'].shape[0] - 1] = [z]
    hf['image'].resize((hf['image'].shape[0] + 1), axis = 0)
    hf['image'][hf['image'].shape[0] - 1, :, :, :] = five_band_image
hf.close()
# Out:
# 100%|██████████| 1999/1999 [01:08<00:00, 29.24it/s]

# %%
total = 2000

hf = h5py.File('/data/HSC_generated/HSC_generated_v1/cvae/64x64/5x64x64_testing.hdf5', 'a')

fits_dir = "/data/HSC_generated/HSC_generated_v1/cvae/"
if not os.path.exists(fits_dir):
    os.mkdir(fits_dir)

# Load the latest saved weights, if any
latest_generated = sorted(glob.glob(f"{fits_dir}/y_band_cvae/cvae_y_band_*.fits"))

if latest_generated:
    
    latest_gen = int(latest_generated[-1].split('_')[-1].split('.')[0]) - 1
    print(f"Resuming to generate image {latest_gen + 1}, overwriting current image {latest_gen + 1} (to prevent fits corruption).")
    
else:
    
    latest_gen = 0  # Start from epoch 0
    print("Generating image 1")

for number_generated in tqdm(range(latest_gen, total)):
    z = random_redshift[number_generated]
    seed = random_keys[number_generated]
    x = np.concatenate((seed, np.array([z])))
    x = x.reshape(1, LATENT_DIM + 1)
    x = decoder([x])[0]
    g_band = x[0]
    r_band = x[1]
    i_band = x[2]
    z_band = x[3]
    y_band = x[4]
    
    hdul = fits.PrimaryHDU(data = g_band)
    string = f"{fits_dir}g_band_cvae/cvae_g_band_{number_generated + 1}.fits"
    hdul.writeto(string, overwrite = True)
    
    hdul = fits.PrimaryHDU(data = r_band)
    string = f"{fits_dir}r_band_cvae/cvae_r_band_{number_generated + 1}.fits"
    hdul.writeto(string, overwrite = True)
    
    hdul = fits.PrimaryHDU(data = i_band)
    string = f"{fits_dir}i_band_cvae/cvae_i_band_{number_generated + 1}.fits"
    hdul.writeto(string, overwrite = True)
    
    hdul = fits.PrimaryHDU(data = z_band)
    string = f"{fits_dir}z_band_cvae/cvae_z_band_{number_generated + 1}.fits"
    hdul.writeto(string, overwrite = True)
    
    hdul = fits.PrimaryHDU(data = y_band)
    string = f"{fits_dir}y_band_cvae/cvae_y_band_{number_generated + 1}.fits"
    hdul.writeto(string, overwrite = True)
    
    five_band_image = []
    five_band_image.append(g_band)
    five_band_image.append(r_band)
    five_band_image.append(i_band)
    five_band_image.append(z_band)
    five_band_image.append(y_band)
    
    five_band_image_reshape = np.reshape(np.array(five_band_image), [1, 5, 64, 64])
    
    if number_generated > 0:
        
        hf['specz_redshift'].resize((hf['specz_redshift'].shape[0] + 1), axis = 0)
        hf['specz_redshift'][hf['specz_redshift'].shape[0] - 1] = [z]
        hf['image'].resize((hf['image'].shape[0] + 1), axis = 0)
        hf['image'][hf['image'].shape[0] - 1, :, :, :] = five_band_image
    
    else:
        
        hf.create_dataset('image', data = five_band_image_reshape, chunks = True, maxshape = (None, 5, 64, 64))
        hf.create_dataset('specz_redshift', data = [z], chunks = True, maxshape = (None, ))
    
    # print(f"Saved fits number {number_generated + 1} to {fits_dir}")
    
hf.close()
# Out:
# Generating image 1
# Saved fits number 1 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 2 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 3 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 4 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 5 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 6 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 7 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 8 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 9 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 10 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 11 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 12 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 13 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 14 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 15 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 16 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 17 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 18 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 19 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 20 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 21 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 22 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 23 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 24 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 25 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 26 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 27 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 28 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 29 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 30 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 31 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 32 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 33 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 34 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 35 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 36 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 37 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 38 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 39 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 40 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 41 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 42 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 43 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 44 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 45 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 46 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 47 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 48 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 49 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 50 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 51 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 52 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 53 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 54 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 55 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 56 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 57 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 58 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 59 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 60 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 61 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 62 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 63 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 64 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 65 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 66 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 67 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 68 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 69 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 70 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 71 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 72 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 73 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 74 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 75 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 76 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 77 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 78 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 79 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 80 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 81 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 82 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 83 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 84 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 85 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 86 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 87 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 88 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 89 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 90 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 91 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 92 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 93 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 94 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 95 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 96 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 97 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 98 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 99 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 100 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 101 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 102 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 103 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 104 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 105 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 106 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 107 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 108 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 109 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 110 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 111 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 112 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 113 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 114 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 115 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 116 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 117 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 118 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 119 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 120 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 121 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 122 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 123 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 124 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 125 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 126 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 127 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 128 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 129 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 130 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 131 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 132 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 133 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 134 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 135 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 136 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 137 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 138 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 139 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 140 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 141 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 142 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 143 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 144 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 145 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 146 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 147 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 148 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 149 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 150 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 151 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 152 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 153 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 154 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 155 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 156 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 157 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 158 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 159 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 160 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 161 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 162 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 163 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 164 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 165 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 166 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 167 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 168 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 169 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 170 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 171 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 172 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 173 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 174 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 175 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 176 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 177 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 178 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 179 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 180 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 181 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 182 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 183 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 184 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 185 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 186 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 187 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 188 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 189 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 190 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 191 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 192 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 193 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 194 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 195 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 196 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 197 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 198 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 199 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 200 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 201 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 202 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 203 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 204 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 205 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 206 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 207 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 208 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 209 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number 210 to /data/HSC_generated/HSC_generated_v1/cvae/
# Saved fits number