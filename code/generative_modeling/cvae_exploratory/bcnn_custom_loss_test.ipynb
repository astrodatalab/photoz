# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
# Out:
# 2023-07-10 09:53:38.091198: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-10 09:53:38.625791: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-07-10 09:53:39.628544: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:39.648326: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:39.648525: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:39.650418: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:39.650564: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:39.650692: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:40.150715: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:40.150910: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:40.151042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-10 09:53:40.151148: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_training_small.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_train.hdf5', 'r')\
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_2.hdf5', 'r')
hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_validation_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
t = len(x_test)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model_variational = Sequential([
    InputLayer(input_shape = (127, 127, 5)),
    tfpl.Convolution2DFlipout(32, kernel_size=(3, 3), activation = 'tanh', kernel_divergence_fn = kl_divergence_function),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    Dropout(0.2),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 127, 127, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 125, 125, 32)     2912
#  ut)
#
#  max_pooling2d (MaxPooling2D  (None, 62, 62, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 61, 61, 32)        4128
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 28, 28, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 27, 27, 32)        4128
#
#  flatten (Flatten)           (None, 23328)             0
#
#  dropout (Dropout)           (None, 23328)             0
#
#  dense_variational (DenseVar  (None, 64)               4479168
#  iational)
#
#  dense_variational_1 (DenseV  (None, 64)               12480
#  ariational)
#
#  dense (Dense)               (None, 2)                 130
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 4,512,194
# Trainable params: 4,512,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
import warnings

# Mute runtime warnings
warnings.filterwarnings("ignore")

distribution = np.loadtxt('hsc_distribution_400.csv', delimiter = ',')
weight = 1 / distribution
weight[np.isinf(weight)] = 0

def find_weight(z):
    return tf.gather(weight, tf.cast(z * 100, tf.int32))

# %%
def loss_function(targets, estimated_distribution):
    return -estimated_distribution.log_prob(targets) * tf.cast(find_weight(targets), dtype = estimated_distribution.dtype)

model_variational.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'HSC_v6_BCNN_v5'

checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

log_dir = os.path.join('/logs/', model_name)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# 2023-07-10 09:53:43.852713: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3225800000 exceeds 10% of free system memory.
# 2023-07-10 09:53:45.478193: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 3225800000 exceeds 10% of free system memory.
# Epoch 1/60
# 2023-07-10 09:53:48.655168: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-10 09:53:49.149074: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-10 09:53:49.251748: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x21d89e70 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-10 09:53:49.251766: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-07-10 09:53:49.255090: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-10 09:53:49.308066: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-10 09:53:49.352040: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-07-10 09:53:49.476792: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 [==============================] - 10s 17ms/step - loss: 4098.0776 - root_mean_squared_error: 1.2771 - val_loss: 3413.0938 - val_root_mean_squared_error: 1.1475 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 4s 13ms/step - loss: 2938.7461 - root_mean_squared_error: 1.1169 - val_loss: 2522.6550 - val_root_mean_squared_error: 1.0835 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 4s 13ms/step - loss: 2202.4817 - root_mean_squared_error: 1.0921 - val_loss: 1916.4375 - val_root_mean_squared_error: 1.0512 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1690.9404 - root_mean_squared_error: 1.0785 - val_loss: 1485.9017 - val_root_mean_squared_error: 1.0748 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1321.2461 - root_mean_squared_error: 1.0714 - val_loss: 1170.2930 - val_root_mean_squared_error: 1.0547 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1045.8885 - root_mean_squared_error: 1.0626 - val_loss: 931.3206 - val_root_mean_squared_error: 1.0281 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 4s 12ms/step - loss: 836.2940 - root_mean_squared_error: 1.0348 - val_loss: 747.5429 - val_root_mean_squared_error: 1.0315 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 4s 12ms/step - loss: 673.2949 - root_mean_squared_error: 1.0563 - val_loss: 603.6392 - val_root_mean_squared_error: 0.9762 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 4s 13ms/step - loss: 544.6850 - root_mean_squared_error: 0.9978 - val_loss: 489.3213 - val_root_mean_squared_error: 0.9525 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 4s 12ms/step - loss: 442.1234 - root_mean_squared_error: 0.9556 - val_loss: 397.7615 - val_root_mean_squared_error: 0.9769 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 4s 12ms/step - loss: 359.3365 - root_mean_squared_error: 0.9371 - val_loss: 323.3039 - val_root_mean_squared_error: 0.9524 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 4s 13ms/step - loss: 292.2667 - root_mean_squared_error: 0.9147 - val_loss: 263.0388 - val_root_mean_squared_error: 0.8759 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 4s 12ms/step - loss: 237.6173 - root_mean_squared_error: 0.8775 - val_loss: 213.6342 - val_root_mean_squared_error: 0.8815 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 4s 12ms/step - loss: 192.8434 - root_mean_squared_error: 0.8438 - val_loss: 173.0789 - val_root_mean_squared_error: 0.8221 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 4s 12ms/step - loss: 156.1382 - root_mean_squared_error: 0.8051 - val_loss: 140.1295 - val_root_mean_squared_error: 0.7655 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 4s 12ms/step - loss: 126.0999 - root_mean_squared_error: 0.7852 - val_loss: 112.8755 - val_root_mean_squared_error: 0.7596 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 4s 12ms/step - loss: 101.4895 - root_mean_squared_error: 0.7596 - val_loss: 90.6624 - val_root_mean_squared_error: 0.7555 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 4s 12ms/step - loss: 81.3613 - root_mean_squared_error: 0.7265 - val_loss: 72.6224 - val_root_mean_squared_error: 0.6980 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 4s 12ms/step - loss: 65.0306 - root_mean_squared_error: 0.7020 - val_loss: 57.9149 - val_root_mean_squared_error: 0.6430 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 4s 13ms/step - loss: 51.8170 - root_mean_squared_error: 0.6913 - val_loss: 46.0842 - val_root_mean_squared_error: 0.6680 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 4s 12ms/step - loss: 41.1943 - root_mean_squared_error: 0.6745 - val_loss: 36.6225 - val_root_mean_squared_error: 0.6278 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 4s 12ms/step - loss: 32.7387 - root_mean_squared_error: 0.6543 - val_loss: 29.1374 - val_root_mean_squared_error: 0.6155 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 4s 12ms/step - loss: 26.0915 - root_mean_squared_error: 0.6445 - val_loss: 23.2762 - val_root_mean_squared_error: 0.6249 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 4s 12ms/step - loss: 20.9247 - root_mean_squared_error: 0.6501 - val_loss: 18.7544 - val_root_mean_squared_error: 0.6303 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 4s 12ms/step - loss: 16.9685 - root_mean_squared_error: 0.6516 - val_loss: 15.3035 - val_root_mean_squared_error: 0.6332 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 4s 12ms/step - loss: 13.9786 - root_mean_squared_error: 0.6700 - val_loss: 12.7445 - val_root_mean_squared_error: 0.6434 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 4s 12ms/step - loss: 11.7775 - root_mean_squared_error: 0.6438 - val_loss: 10.8836 - val_root_mean_squared_error: 0.6082 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 4s 12ms/step - loss: 10.1829 - root_mean_squared_error: 0.6371 - val_loss: 9.5471 - val_root_mean_squared_error: 0.6232 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 4s 12ms/step - loss: 9.0661 - root_mean_squared_error: 0.6463 - val_loss: 8.6301 - val_root_mean_squared_error: 0.6059 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 4s 12ms/step - loss: 8.2981 - root_mean_squared_error: 0.6680 - val_loss: 8.0094 - val_root_mean_squared_error: 0.6097 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.7929 - root_mean_squared_error: 0.6473 - val_loss: 7.5992 - val_root_mean_squared_error: 0.5954 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.4770 - root_mean_squared_error: 0.6718 - val_loss: 7.3569 - val_root_mean_squared_error: 0.6592 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.2892 - root_mean_squared_error: 0.6530 - val_loss: 7.2229 - val_root_mean_squared_error: 0.6021 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1833 - root_mean_squared_error: 0.6451 - val_loss: 7.1594 - val_root_mean_squared_error: 0.6201 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1332 - root_mean_squared_error: 0.7005 - val_loss: 7.1279 - val_root_mean_squared_error: 0.6404 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1177 - root_mean_squared_error: 0.6624 - val_loss: 7.1193 - val_root_mean_squared_error: 0.6628 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1196 - root_mean_squared_error: 0.6571 - val_loss: 7.1288 - val_root_mean_squared_error: 0.6785 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1363 - root_mean_squared_error: 0.6586 - val_loss: 7.1334 - val_root_mean_squared_error: 0.6210 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1518 - root_mean_squared_error: 0.6815 - val_loss: 7.1456 - val_root_mean_squared_error: 0.6407 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1653 - root_mean_squared_error: 0.6708 - val_loss: 7.1937 - val_root_mean_squared_error: 0.7648 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1872 - root_mean_squared_error: 0.6646 - val_loss: 7.1930 - val_root_mean_squared_error: 0.6154 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.1912 - root_mean_squared_error: 0.6572 - val_loss: 7.2132 - val_root_mean_squared_error: 0.6475 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.2067 - root_mean_squared_error: 0.6538 - val_loss: 7.2099 - val_root_mean_squared_error: 0.7106 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.2141 - root_mean_squared_error: 0.6842 - val_loss: 7.2056 - val_root_mean_squared_error: 0.6774 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.2228 - root_mean_squared_error: 0.7372 - val_loss: 7.2442 - val_root_mean_squared_error: 0.6670 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 4s 12ms/step - loss: 7.2270 - root_mean_squared_error: 0.6587 - val_loss: 7.2235 - val_root_mean_squared_error: 0.7028 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 4s 12ms/step - loss: 1.4235 - root_mean_squared_error: 0.7026 - val_loss: 0.7750 - val_root_mean_squared_error: 0.6861 - lr: 1.0000e-04
# Epoch 48/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7750 - root_mean_squared_error: 0.6522 - val_loss: 0.7775 - val_root_mean_squared_error: 0.6422 - lr: 1.0000e-04
# Epoch 49/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7779 - root_mean_squared_error: 0.6438 - val_loss: 0.7752 - val_root_mean_squared_error: 0.6374 - lr: 1.0000e-04
# Epoch 50/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7788 - root_mean_squared_error: 0.6383 - val_loss: 0.7755 - val_root_mean_squared_error: 0.6054 - lr: 1.0000e-04
# Epoch 51/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7786 - root_mean_squared_error: 0.6531 - val_loss: 0.7760 - val_root_mean_squared_error: 0.5934 - lr: 1.0000e-04
# Epoch 52/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7781 - root_mean_squared_error: 0.6461 - val_loss: 0.7785 - val_root_mean_squared_error: 0.6627 - lr: 1.0000e-04
# Epoch 53/60
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7770 - root_mean_squared_error: 0.6560 - val_loss: 0.7757 - val_root_mean_squared_error: 0.6384 - lr: 1.0000e-04
# Epoch 54/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7763 - root_mean_squared_error: 0.6453 - val_loss: 0.7747 - val_root_mean_squared_error: 0.6343 - lr: 1.0000e-04
# Epoch 55/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7737 - root_mean_squared_error: 0.6590 - val_loss: 0.7774 - val_root_mean_squared_error: 0.5772 - lr: 1.0000e-04
# Epoch 56/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7738 - root_mean_squared_error: 0.6416 - val_loss: 0.7728 - val_root_mean_squared_error: 0.6214 - lr: 1.0000e-04
# Epoch 57/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7717 - root_mean_squared_error: 0.6310 - val_loss: 0.7726 - val_root_mean_squared_error: 0.6132 - lr: 1.0000e-04
# Epoch 58/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7704 - root_mean_squared_error: 0.6469 - val_loss: 0.7670 - val_root_mean_squared_error: 0.6036 - lr: 1.0000e-04
# Epoch 59/60
# 313/313 [==============================] - 4s 13ms/step - loss: 0.7686 - root_mean_squared_error: 0.6557 - val_loss: 0.7687 - val_root_mean_squared_error: 0.6629 - lr: 1.0000e-04
# Epoch 60/60
# 313/313 [==============================] - 4s 12ms/step - loss: 0.7677 - root_mean_squared_error: 0.6607 - val_loss: 0.7658 - val_root_mean_squared_error: 0.5960 - lr: 1.0000e-04

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
plt.imshow(x_test[100][:,:,4])

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.7675

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.7675

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.scatter(x_array, mean_array, marker='o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True)/(1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1])
plt.show()

# print("Outlier Rate: "+str(outlier_count_total/len(specz)))

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))
# Out:
# Spectro_z: 1.43838, Photo_z: 0.99876887, Photo_z_err: 1.5274516
# Spectro_z: 0.533190727, Photo_z: 0.9681534, Photo_z_err: 1.1651553
# Spectro_z: 2.05401993, Photo_z: 1.1434911, Photo_z_err: 1.6038108
# Spectro_z: 0.969799995, Photo_z: 0.80353874, Photo_z_err: 1.0021579
# Spectro_z: 2.80553007, Photo_z: 1.3536725, Photo_z_err: 1.2828715
# Spectro_z: 1.43046999, Photo_z: 0.5859683, Photo_z_err: 1.2250793
# Spectro_z: 0.477200001, Photo_z: 1.1430928, Photo_z_err: 1.0671172
# Spectro_z: 1.69831002, Photo_z: 0.938003, Photo_z_err: 1.0014055
# Spectro_z: 2.58675003, Photo_z: 1.1590694, Photo_z_err: 1.1794297
# Spectro_z: 1.02073002, Photo_z: 1.1736252, Photo_z_err: 1.0847737
# Spectro_z: 0.560011387, Photo_z: 0.8340753, Photo_z_err: 1.2857149
# Spectro_z: 1.60283101, Photo_z: 1.6739984, Photo_z_err: 1.3140118
# Spectro_z: 0.412990004, Photo_z: 1.0667217, Photo_z_err: 1.5172302
# Spectro_z: 0.904044986, Photo_z: 0.97561544, Photo_z_err: 1.2413423
# Spectro_z: 1.44349003, Photo_z: 1.061058, Photo_z_err: 1.1366671
# Spectro_z: 2.39291, Photo_z: 1.4331882, Photo_z_err: 1.4723876
# Spectro_z: 2.5417099, Photo_z: 1.573734, Photo_z_err: 2.5443437
# Spectro_z: 1.51027, Photo_z: 1.4658055, Photo_z_err: 1.5468441
# Spectro_z: 1.17549396, Photo_z: 0.8883222, Photo_z_err: 1.2411611
# Spectro_z: 2.41971993, Photo_z: 1.1720643, Photo_z_err: 1.0429868
# Spectro_z: 1.57739997, Photo_z: 1.3176675, Photo_z_err: 1.058773
# Spectro_z: 1.65156996, Photo_z: 0.9540677, Photo_z_err: 1.3464227
# Spectro_z: 1.586725, Photo_z: 1.8471446, Photo_z_err: 1.2407708
# Spectro_z: 2.32499003, Photo_z: 1.460489, Photo_z_err: 1.1626184
# Spectro_z: 2.42681003, Photo_z: 1.7591641, Photo_z_err: 2.1921892
# Spectro_z: 2.83587003, Photo_z: 0.985743, Photo_z_err: 1.2050467
# Spectro_z: 0.472779989, Photo_z: 0.70862246, Photo_z_err: 1.0271982
# Spectro_z: 1.36442006, Photo_z: 0.7814503, Photo_z_err: 1.9601665
# Spectro_z: 1.73482502, Photo_z: 1.1888837, Photo_z_err: 1.3195901
# Spectro_z: 2.46601009, Photo_z: 1.0894754, Photo_z_err: 1.1907914
# Spectro_z: 1.49959004, Photo_z: 1.1170933, Photo_z_err: 1.4158891
# Spectro_z: 1.56279695, Photo_z: 1.1378572, Photo_z_err: 1.622841
# Spectro_z: 1.68648398, Photo_z: 1.3087358, Photo_z_err: 1.4213991
# Spectro_z: 0.794024527, Photo_z: 1.3305938, Photo_z_err: 1.0356185
# Spectro_z: 0.844259977, Photo_z: 0.82037663, Photo_z_err: 1.1486272
# Spectro_z: 2.29820991, Photo_z: 1.3625834, Photo_z_err: 1.1141362
# Spectro_z: 1.60350001, Photo_z: 1.2330384, Photo_z_err: 2.2494838
# Spectro_z: 3.1536901, Photo_z: 1.8531587, Photo_z_err: 1.634642
# Spectro_z: 2.2506001, Photo_z: 1.1098413, Photo_z_err: 1.8699739
# Spectro_z: 2.28549004, Photo_z: 1.4548745, Photo_z_err: 1.5425307
# Spectro_z: 3.54637003, Photo_z: 1.361922, Photo_z_err: 1.9771609
# Spectro_z: 2.97578001, Photo_z: 1.2331339, Photo_z_err: 1.2802721
# Spectro_z: 2.24154997, Photo_z: 0.9385437, Photo_z_err: 1.4779129
# Spectro_z: 2.24628997, Photo_z: 1.0827243, Photo_z_err: 1.1983
# Spectro_z: 2.37159991, Photo_z: 0.9471661, Photo_z_err: 1.567538
# Spectro_z: 0.33750999, Photo_z: 0.75805926, Photo_z_err: 1.1205709
# Spectro_z: 2.56750011, Photo_z: 1.4906714, Photo_z_err: 1.42108
# Spectro_z: 2.97807002, Photo_z: 0.80021113, Photo_z_err: 2.1610222
# Spectro_z: 3.46231008, Photo_z: 0.8301425, Photo_z_err: 1.2706605
# Spectro_z: 1.88620996, Photo_z: 1.2376397, Photo_z_err: 1.56114
# Spectro_z: 2.90335011, Photo_z: 1.1989155, Photo_z_err: 1.8461525
# Spectro_z: 1.04811001, Photo_z: 1.1777897, Photo_z_err: 1.0569521
# Spectro_z: 2.19109988, Photo_z: 1.4226327, Photo_z_err: 1.177798
# Spectro_z: 2.87620997, Photo_z: 1.3964071, Photo_z_err: 1.0709602
# Spectro_z: 1.08318996, Photo_z: 1.4660404, Photo_z_err: 1.1961678
# Spectro_z: 2.49773002, Photo_z: 1.1152306, Photo_z_err: 1.0094216
# Spectro_z: 1.56961, Photo_z: 1.4393451, Photo_z_err: 1.3558581
# Spectro_z: 2.18052912, Photo_z: 1.2305758, Photo_z_err: 1.0818068
# Spectro_z: 2.00169992, Photo_z: 1.2914276, Photo_z_err: 2.4736822
# Spectro_z: 0.653454006, Photo_z: 1.5560932, Photo_z_err: 1.1968461
# Spectro_z: 2.399611, Photo_z: 1.2536888, Photo_z_err: 1.1212933
# Spectro_z: 0.547725677, Photo_z: 1.0006129, Photo_z_err: 1.5528512
# Spectro_z: 2.038378, Photo_z: 1.5523407, Photo_z_err: 1.8734672
# Spectro_z: 1.55851996, Photo_z: 1.2768123, Photo_z_err: 1.0633117
# Spectro_z: 0.871720016, Photo_z: 1.2691033, Photo_z_err: 1.0855865
# Spectro_z: 1.79936004, Photo_z: 1.2867208, Photo_z_err: 1.2388892
# Spectro_z: 2.51462102, Photo_z: 1.2616351, Photo_z_err: 1.3423437
# Spectro_z: 2.27388, Photo_z: 1.5576615, Photo_z_err: 1.259319
# Spectro_z: 2.59594989, Photo_z: 1.5579336, Photo_z_err: 1.6323373
# Spectro_z: 2.82118011, Photo_z: 1.3878279, Photo_z_err: 1.4643077
# Spectro_z: 2.46420002, Photo_z: 1.7360952, Photo_z_err: 1.1977357
# Spectro_z: 2.63646007, Photo_z: 1.6668453, Photo_z_err: 1.4962188
# Spectro_z: 2.21766996, Photo_z: 1.173066, Photo_z_err: 1.1995215
# Spectro_z: 0.506900012, Photo_z: 1.1330949, Photo_z_err: 1.0745931
# Spectro_z: 0.868399978, Photo_z: 1.0742369, Photo_z_err: 1.0028852
# Spectro_z: 2.89982009, Photo_z: 2.0437477, Photo_z_err: 1.7700828
# Spectro_z: 0.818499982, Photo_z: 0.9250173, Photo_z_err: 1.0508229
# Spectro_z: 0.590300024, Photo_z: 1.2307543, Photo_z_err: 1.0479859
# Spectro_z: 1.16152, Photo_z: 1.3862224, Photo_z_err: 1.0786835
# Spectro_z: 0.430400014, Photo_z: 1.1216633, Photo_z_err: 1.4110447
# Spectro_z: 1.62017, Photo_z: 1.8207619, Photo_z_err: 1.6677531
# Spectro_z: 2.71784997, Photo_z: 1.3267117, Photo_z_err: 1.6408327
# Spectro_z: 0.705579996, Photo_z: 0.8080347, Photo_z_err: 1.2119836
# Spectro_z: 0.913940012, Photo_z: 0.95053214, Photo_z_err: 1.4610834
# Spectro_z: 0.221530005, Photo_z: 0.6955074, Photo_z_err: 1.3850703
# Spectro_z: 3.26555991, Photo_z: 1.1258075, Photo_z_err: 2.2280858
# Spectro_z: 3.25749993, Photo_z: 1.307128, Photo_z_err: 1.0561767
# Spectro_z: 1.94422996, Photo_z: 1.3440785, Photo_z_err: 1.7241993
# Spectro_z: 1.95248997, Photo_z: 1.0614955, Photo_z_err: 1.379945
# Spectro_z: 1.10225797, Photo_z: 1.3529277, Photo_z_err: 1.5917348
# Spectro_z: 1.875018, Photo_z: 1.7730868, Photo_z_err: 1.1650484
# Spectro_z: 2.06502008, Photo_z: 0.800566, Photo_z_err: 1.6080649
# Spectro_z: 2.40742993, Photo_z: 0.696779, Photo_z_err: 1.3330247
# Spectro_z: 3.8645401, Photo_z: 1.4025104, Photo_z_err: 1.8975476
# Spectro_z: 2.16662002, Photo_z: 1.460382, Photo_z_err: 1.0951431
# Spectro_z: 2.26780009, Photo_z: 1.2543483, Photo_z_err: 1.0212368
# Spectro_z: 2.00449991, Photo_z: 1.1514132, Photo_z_err: 1.5987825
# Spectro_z: 1.21080005, Photo_z: 0.9032767, Photo_z_err: 1.4831895
# Spectro_z: 2.53684998, Photo_z: 1.3145857, Photo_z_err: 1.6137774
# Spectro_z: 0.551699996, Photo_z: 1.1255879, Photo_z_err: 1.3903818
# Spectro_z: 0.893100023, Photo_z: 0.9785671, Photo_z_err: 1.3289047
# Spectro_z: 2.2906301, Photo_z: 1.5276062, Photo_z_err: 1.7085934
# Spectro_z: 1.25768995, Photo_z: 0.8610948, Photo_z_err: 2.1372752
# Spectro_z: 2.24554992, Photo_z: 1.3128848, Photo_z_err: 1.4408708
# Spectro_z: 2.33625007, Photo_z: 0.8474686, Photo_z_err: 1.8718112
# Spectro_z: 2.01125908, Photo_z: 1.668411, Photo_z_err: 2.075036
# Spectro_z: 2.46494007, Photo_z: 1.5589006, Photo_z_err: 1.1048615
# Spectro_z: 2.70373011, Photo_z: 0.95446086, Photo_z_err: 1.5625206
# Spectro_z: 0.638759971, Photo_z: 0.7216097, Photo_z_err: 1.6723963
# Spectro_z: 1.50618994, Photo_z: 1.1758671, Photo_z_err: 1.6114101
# Spectro_z: 2.86160994, Photo_z: 1.2066078, Photo_z_err: 1.0645878
# Spectro_z: 2.30692005, Photo_z: 1.2931631, Photo_z_err: 1.5774864
# Spectro_z: 1.31491995, Photo_z: 1.1881092, Photo_z_err: 1.003269
# Spectro_z: 2.24908996, Photo_z: 1.2285538, Photo_z_err: 1.0051913
# Spectro_z: 2.78531003, Photo_z: 1.4606512, Photo_z_err: 1.3189569
# Spectro_z: 0.980352223, Photo_z: 0.75462556, Photo_z_err: 1.5290523
# Spectro_z: 1.72841001, Photo_z: 1.4840658, Photo_z_err: 1.5049163
# Spectro_z: 1.46682, Photo_z: 1.1753881, Photo_z_err: 1.426106
# Spectro_z: 3.1082201, Photo_z: 1.6181941, Photo_z_err: 2.0365338
# Spectro_z: 2.33026004, Photo_z: 1.7919331, Photo_z_err: 1.5011655
# Spectro_z: 1.54918504, Photo_z: 1.2251896, Photo_z_err: 1.4551923
# Spectro_z: 0.59096998, Photo_z: 1.2316281, Photo_z_err: 1.7748832
# Spectro_z: 3.19344997, Photo_z: 1.1184183, Photo_z_err: 1.4182575
# Spectro_z: 1.54535997, Photo_z: 1.235513, Photo_z_err: 1.2779182
# Spectro_z: 1.86107004, Photo_z: 0.661314, Photo_z_err: 1.3255601
# Spectro_z: 0.66952002, Photo_z: 1.077648, Photo_z_err: 1.376307
# Spectro_z: 2.16125989, Photo_z: 1.5657897, Photo_z_err: 1.151052
# Spectro_z: 0.678269982, Photo_z: 0.8514387, Photo_z_err: 1.0499235
# Spectro_z: 1.56860006, Photo_z: 1.0955148, Photo_z_err: 1.0059066

# %%
check = 2
current = uncertains[check]
print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)
# Out:
# Spectro_z: 2.05401993, Photo_z: 1.1434911, Photo_z_err: 1.6038108

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))
# Out:
# Spectro_z: 2.29530001, Photo_z: 0.7605633, Photo_z_err: 0.40766096
# Spectro_z: 1.85189998, Photo_z: 0.70648056, Photo_z_err: 0.39753157
# Spectro_z: 1.72249997, Photo_z: 0.7168299, Photo_z_err: 0.37546736
# Spectro_z: 1.76779103, Photo_z: 0.7669679, Photo_z_err: 0.45550066
# Spectro_z: 2.17549992, Photo_z: 0.9098602, Photo_z_err: 0.47172475
# Spectro_z: 2.73541307, Photo_z: 0.5464153, Photo_z_err: 0.3451452
# Spectro_z: 2.83924007, Photo_z: 0.82655853, Photo_z_err: 0.4913515
# Spectro_z: 2.88223004, Photo_z: 0.91420174, Photo_z_err: 0.28801054
# Spectro_z: 2.6556499, Photo_z: 1.5168886, Photo_z_err: 0.3615705
# Spectro_z: 2.67902994, Photo_z: 1.6496713, Photo_z_err: 0.41071218
# Spectro_z: 2.96415997, Photo_z: 0.4859333, Photo_z_err: 0.27346852
# Spectro_z: 2.68711996, Photo_z: 0.83468276, Photo_z_err: 0.45373258
# Spectro_z: 2.65280008, Photo_z: 0.767755, Photo_z_err: 0.4429999
# Spectro_z: 1.9066, Photo_z: 0.6971281, Photo_z_err: 0.4068198
# Spectro_z: 2.19309998, Photo_z: 0.74459624, Photo_z_err: 0.46004435

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)
# Out:
# Spectro_z: 1.76779103, Photo_z: 0.7669679, Photo_z_err: 0.45550066

# %%
a = 988
b = 264
c = 1198
d = 112
e = 241
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_test[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_test[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_test[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_test[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_test[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_test[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_test[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_test[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_test[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_test[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
a = 24
b = 15
c = 10
d = 96
e = 1868
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_train[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_train[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_train[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_train[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_train[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_train[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_train[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_train[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_train[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_train[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
for i in range(10000):
    if np.abs(y_train[i][0]-4)<0.1:
        print(i)
# Out:
# 1868
# 1967

# %%
# END
