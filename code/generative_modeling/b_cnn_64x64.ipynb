# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

import sys,os
import numpy as np
import pandas as pd
import random
import h5py
# Out:
# 2023-08-07 06:21:28.544832: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-07 06:21:29.238024: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-08-07 06:21:30.731022: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:30.789830: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:30.790032: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:30.792333: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:30.792498: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:30.792626: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:31.429733: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:31.429931: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:31.430065: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-07 06:21:31.430172: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step3A/64x64_training_z_less_than_2_small.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_train.hdf5', 'r')\
hf_test = h5py.File('/data3/Billy/64x64_cvae_generated_11.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')

for k in hf_train.keys():
    print(k)

hf_validation = h5py.File('/data/HSC/HSC_v6/step3A/64x64_validation_z_less_than_2_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
t = len(x_test)
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, 4.16)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()
# Out:
# coord
# dec
# g_cmodel_mag
# g_cmodel_magsigma
# i_cmodel_mag
# i_cmodel_magsigma
# image
# object_id
# r_cmodel_mag
# r_cmodel_magsigma
# ra
# skymap_id
# specz_dec
# specz_flag_homogeneous
# specz_mag_i
# specz_name
# specz_ra
# specz_redshift
# specz_redshift_err
# y_cmodel_mag
# y_cmodel_magsigma
# z_cmodel_mag
# z_cmodel_magsigma

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model_variational = Sequential([
    InputLayer(input_shape = (64, 64, 5)),
    tfpl.Convolution2DFlipout(32, kernel_size=(3, 3), activation = 'tanh', kernel_divergence_fn = kl_divergence_function),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    Dropout(0.2),
    tfpl.DenseVariational(128, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(128, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 127, 127, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 62, 62, 32)       2912
#  ut)
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        4128
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 32)        4128
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense_variational (DenseVar  (None, 128)              1769856
#  iational)
#
#  dense_variational_1 (DenseV  (None, 128)              49536
#  ariational)
#
#  dense (Dense)               (None, 2)                 258
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 1,840,066
# Trainable params: 1,840,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return - estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'HSC_v6_BCNN_v5'

checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

log_dir = os.path.join('/logs/', model_name)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# Epoch 1/60
# 2023-08-05 05:36:24.381316: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-08-05 05:36:24.873169: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-08-05 05:36:24.937040: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fa617214fa0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-05 05:36:24.937059: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-08-05 05:36:24.942861: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-05 05:36:24.970120: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-08-05 05:36:25.013142: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-08-05 05:36:25.064280: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 313/313 [==============================] - 7s 10ms/step - loss: 1656.8055 - root_mean_squared_error: 0.7188 - val_loss: 1377.9402 - val_root_mean_squared_error: 0.6000 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1185.2782 - root_mean_squared_error: 0.5029 - val_loss: 1015.9685 - val_root_mean_squared_error: 0.4492 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 2s 7ms/step - loss: 887.1151 - root_mean_squared_error: 0.3982 - val_loss: 771.8348 - val_root_mean_squared_error: 0.4026 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 2s 7ms/step - loss: 680.5069 - root_mean_squared_error: 0.3637 - val_loss: 597.7937 - val_root_mean_squared_error: 0.3842 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 2s 7ms/step - loss: 531.4348 - root_mean_squared_error: 0.3521 - val_loss: 470.6451 - val_root_mean_squared_error: 0.3720 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 2s 7ms/step - loss: 420.4293 - root_mean_squared_error: 0.3452 - val_loss: 374.4437 - val_root_mean_squared_error: 0.3028 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 2s 7ms/step - loss: 335.8737 - root_mean_squared_error: 0.3392 - val_loss: 300.1688 - val_root_mean_squared_error: 0.3307 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 2s 7ms/step - loss: 270.2068 - root_mean_squared_error: 0.3252 - val_loss: 242.1547 - val_root_mean_squared_error: 0.3422 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 2s 7ms/step - loss: 218.4842 - root_mean_squared_error: 0.3228 - val_loss: 196.1667 - val_root_mean_squared_error: 0.2836 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 2s 7ms/step - loss: 177.1743 - root_mean_squared_error: 0.3144 - val_loss: 159.2655 - val_root_mean_squared_error: 0.3445 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 2s 7ms/step - loss: 143.8689 - root_mean_squared_error: 0.3131 - val_loss: 129.3760 - val_root_mean_squared_error: 0.2927 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 2s 7ms/step - loss: 116.8706 - root_mean_squared_error: 0.3120 - val_loss: 105.0290 - val_root_mean_squared_error: 0.2751 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 2s 7ms/step - loss: 94.8553 - root_mean_squared_error: 0.2862 - val_loss: 85.3386 - val_root_mean_squared_error: 0.2583 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 2s 7ms/step - loss: 76.8384 - root_mean_squared_error: 0.2892 - val_loss: 69.0273 - val_root_mean_squared_error: 0.2628 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 2s 7ms/step - loss: 62.1233 - root_mean_squared_error: 0.3191 - val_loss: 55.6896 - val_root_mean_squared_error: 0.2458 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 2s 7ms/step - loss: 49.9956 - root_mean_squared_error: 0.2694 - val_loss: 44.7798 - val_root_mean_squared_error: 0.3898 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 2s 7ms/step - loss: 40.0754 - root_mean_squared_error: 0.2641 - val_loss: 35.8511 - val_root_mean_squared_error: 0.2488 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 2s 7ms/step - loss: 32.0026 - root_mean_squared_error: 0.2675 - val_loss: 28.5513 - val_root_mean_squared_error: 0.3330 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 2s 7ms/step - loss: 25.4431 - root_mean_squared_error: 0.2614 - val_loss: 22.5791 - val_root_mean_squared_error: 0.2293 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 2s 7ms/step - loss: 20.1148 - root_mean_squared_error: 0.2700 - val_loss: 17.8218 - val_root_mean_squared_error: 0.2402 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 2s 7ms/step - loss: 15.8423 - root_mean_squared_error: 0.2603 - val_loss: 13.9802 - val_root_mean_squared_error: 0.2424 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 2s 7ms/step - loss: 12.4184 - root_mean_squared_error: 0.2460 - val_loss: 10.9950 - val_root_mean_squared_error: 0.2368 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 2s 7ms/step - loss: 9.7520 - root_mean_squared_error: 0.2432 - val_loss: 8.6317 - val_root_mean_squared_error: 0.2304 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 2s 7ms/step - loss: 7.6704 - root_mean_squared_error: 0.2375 - val_loss: 6.8785 - val_root_mean_squared_error: 0.2786 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 2s 7ms/step - loss: 6.0685 - root_mean_squared_error: 0.2561 - val_loss: 5.4597 - val_root_mean_squared_error: 0.2337 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 2s 7ms/step - loss: 4.8466 - root_mean_squared_error: 0.2371 - val_loss: 4.4172 - val_root_mean_squared_error: 0.2370 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 2s 7ms/step - loss: 3.9567 - root_mean_squared_error: 0.2333 - val_loss: 3.7326 - val_root_mean_squared_error: 0.2382 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 2s 7ms/step - loss: 3.6518 - root_mean_squared_error: 0.3089 - val_loss: 3.9094 - val_root_mean_squared_error: 0.3345 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 2s 7ms/step - loss: 3.1076 - root_mean_squared_error: 0.3855 - val_loss: 2.7517 - val_root_mean_squared_error: 0.2533 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.6013 - root_mean_squared_error: 0.2512 - val_loss: 2.5124 - val_root_mean_squared_error: 0.2256 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.3775 - root_mean_squared_error: 0.2314 - val_loss: 2.3222 - val_root_mean_squared_error: 0.2379 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.2221 - root_mean_squared_error: 0.2528 - val_loss: 2.1838 - val_root_mean_squared_error: 0.2351 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.1209 - root_mean_squared_error: 0.2305 - val_loss: 2.1940 - val_root_mean_squared_error: 0.1863 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0788 - root_mean_squared_error: 0.2272 - val_loss: 2.1991 - val_root_mean_squared_error: 0.2136 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0395 - root_mean_squared_error: 0.2241 - val_loss: 2.1425 - val_root_mean_squared_error: 0.2309 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0333 - root_mean_squared_error: 0.2350 - val_loss: 2.1438 - val_root_mean_squared_error: 0.2588 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0233 - root_mean_squared_error: 0.2344 - val_loss: 2.1389 - val_root_mean_squared_error: 0.1947 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0248 - root_mean_squared_error: 0.2199 - val_loss: 2.2614 - val_root_mean_squared_error: 0.2106 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0505 - root_mean_squared_error: 0.2642 - val_loss: 2.1553 - val_root_mean_squared_error: 0.2240 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0005 - root_mean_squared_error: 0.2146 - val_loss: 2.1153 - val_root_mean_squared_error: 0.2366 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0155 - root_mean_squared_error: 0.2189 - val_loss: 2.1404 - val_root_mean_squared_error: 0.3454 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0163 - root_mean_squared_error: 0.2333 - val_loss: 2.3938 - val_root_mean_squared_error: 0.1875 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0060 - root_mean_squared_error: 0.2164 - val_loss: 2.1108 - val_root_mean_squared_error: 0.2568 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0056 - root_mean_squared_error: 0.2380 - val_loss: 2.2937 - val_root_mean_squared_error: 0.2901 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9986 - root_mean_squared_error: 0.2029 - val_loss: 2.0961 - val_root_mean_squared_error: 0.2666 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9783 - root_mean_squared_error: 0.2067 - val_loss: 2.1164 - val_root_mean_squared_error: 0.2618 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 2s 6ms/step - loss: 1.9750 - root_mean_squared_error: 0.2217 - val_loss: 2.1401 - val_root_mean_squared_error: 0.3587 - lr: 0.0010
# Epoch 48/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9799 - root_mean_squared_error: 0.2176 - val_loss: 2.1367 - val_root_mean_squared_error: 0.3002 - lr: 0.0010
# Epoch 49/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9469 - root_mean_squared_error: 0.2101 - val_loss: 2.2110 - val_root_mean_squared_error: 0.2550 - lr: 0.0010
# Epoch 50/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9556 - root_mean_squared_error: 0.2031 - val_loss: 2.0770 - val_root_mean_squared_error: 0.1976 - lr: 0.0010
# Epoch 51/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9455 - root_mean_squared_error: 0.2063 - val_loss: 2.2580 - val_root_mean_squared_error: 0.2102 - lr: 0.0010
# Epoch 52/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9620 - root_mean_squared_error: 0.2120 - val_loss: 2.2033 - val_root_mean_squared_error: 0.2145 - lr: 0.0010
# Epoch 53/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9537 - root_mean_squared_error: 0.2290 - val_loss: 2.1301 - val_root_mean_squared_error: 0.2007 - lr: 0.0010
# Epoch 54/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9429 - root_mean_squared_error: 0.2111 - val_loss: 2.0904 - val_root_mean_squared_error: 0.1934 - lr: 0.0010
# Epoch 55/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9492 - root_mean_squared_error: 0.2085 - val_loss: 2.1265 - val_root_mean_squared_error: 0.2217 - lr: 0.0010
# Epoch 56/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9247 - root_mean_squared_error: 0.2141 - val_loss: 2.0610 - val_root_mean_squared_error: 0.2866 - lr: 0.0010
# Epoch 57/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9026 - root_mean_squared_error: 0.2036 - val_loss: 2.0990 - val_root_mean_squared_error: 0.2151 - lr: 0.0010
# Epoch 58/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9023 - root_mean_squared_error: 0.2059 - val_loss: 2.2182 - val_root_mean_squared_error: 0.1809 - lr: 0.0010
# Epoch 59/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9071 - root_mean_squared_error: 0.2003 - val_loss: 2.0833 - val_root_mean_squared_error: 0.2273 - lr: 0.0010
# Epoch 60/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.8889 - root_mean_squared_error: 0.2052 - val_loss: 2.0787 - val_root_mean_squared_error: 0.2579 - lr: 0.0010

# %% [markdown]
# # hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_max_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
# x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
# t = len(x_test)
# max_value = 1
# x_test = np.true_divide(x_test, max_value)[0:t]
# y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
# hf_test.close()

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
plt.imshow(x_test[98][:,:,4])

# %%
y_test[98]
# Out:
# array([1.33088507])

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.5145

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.5145

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.scatter(x_array, mean_array, marker='o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True)/(1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1])
plt.show()

# print("Outlier Rate: "+str(outlier_count_total/len(specz)))

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check = 2
current = uncertains[check]
print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 check = 2
# ----> 2 current = uncertains[check]
#       3 print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
#       4 plt.imshow(x_test[current][:,:,0])
#
# IndexError: list index out of range

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)

# %%
a = 988
b = 264
c = 1198
d = 112
e = 241
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_test[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_test[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_test[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_test[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_test[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_test[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_test[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_test[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_test[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_test[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
a = 24
b = 15
c = 10
d = 96
e = 1868
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_train[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_train[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_train[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_train[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_train[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_train[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_train[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_train[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_train[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_train[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
for i in range(10000):
    if np.abs(y_train[i][0]-4)<0.1:
        print(i)

# %%
# END
