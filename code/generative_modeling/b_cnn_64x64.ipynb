# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau

import sys,os
import numpy as np
import pandas as pd
import random
import h5py
# Out:
# 2023-07-31 23:38:52.815189: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-07-31 23:38:53.361864: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-07-31 23:38:54.394416: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.414391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.414590: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.416372: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.416518: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.416647: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.889978: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.890170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.890302: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-07-31 23:38:54.890407: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step3A/64x64_training_z_less_than_2_small.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_train.hdf5', 'r')\
hf_test = h5py.File('/data3/Billy/64x64_cvae_generated_4.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step3A/64x64_validation_z_less_than_2_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
t = len(x_test)
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, 4.16)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model_variational = Sequential([
    InputLayer(input_shape = (64, 64, 5)),
    tfpl.Convolution2DFlipout(32, kernel_size=(3, 3), activation = 'tanh', kernel_divergence_fn = kl_divergence_function),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    Dropout(0.2),
    tfpl.DenseVariational(128, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(128, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 127, 127, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 62, 62, 32)       2912
#  ut)
#
#  max_pooling2d (MaxPooling2D  (None, 31, 31, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 30, 30, 32)        4128
#
#  max_pooling2d_1 (MaxPooling  (None, 15, 15, 32)       0
#  2D)
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 32)        9248
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 32)        4128
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dropout (Dropout)           (None, 4608)              0
#
#  dense_variational (DenseVar  (None, 128)              1769856
#  iational)
#
#  dense_variational_1 (DenseV  (None, 128)              49536
#  ariational)
#
#  dense (Dense)               (None, 2)                 258
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 1,840,066
# Trainable params: 1,840,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return - estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'HSC_v6_BCNN_v5'

checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

log_dir = os.path.join('/logs/', model_name)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# 2023-07-31 23:46:20.932431: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 819200000 exceeds 10% of free system memory.
# 2023-07-31 23:46:21.341405: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 819200000 exceeds 10% of free system memory.
# Epoch 1/60
# 2023-07-31 23:46:23.588800: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-07-31 23:46:23.588989: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x29fb50e0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-07-31 23:46:23.589015: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-07-31 23:46:23.597558: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-07-31 23:46:23.692656: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-31 23:46:23.739532: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-07-31 23:46:24.064363: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-07-31 23:46:24.176982: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 [==============================] - 7s 10ms/step - loss: 1654.1373 - root_mean_squared_error: 0.6710 - val_loss: 1374.4323 - val_root_mean_squared_error: 0.5752 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1183.0477 - root_mean_squared_error: 0.5328 - val_loss: 1013.8799 - val_root_mean_squared_error: 0.5420 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 2s 7ms/step - loss: 885.2941 - root_mean_squared_error: 0.4689 - val_loss: 769.8276 - val_root_mean_squared_error: 0.3890 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 2s 7ms/step - loss: 678.7587 - root_mean_squared_error: 0.3695 - val_loss: 596.4188 - val_root_mean_squared_error: 0.3474 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 2s 7ms/step - loss: 529.7745 - root_mean_squared_error: 0.3765 - val_loss: 469.0293 - val_root_mean_squared_error: 0.3347 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 2s 7ms/step - loss: 419.1900 - root_mean_squared_error: 0.3608 - val_loss: 373.2191 - val_root_mean_squared_error: 0.2917 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 2s 7ms/step - loss: 334.7257 - root_mean_squared_error: 0.3241 - val_loss: 299.1310 - val_root_mean_squared_error: 0.3405 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 2s 7ms/step - loss: 269.2917 - root_mean_squared_error: 0.3364 - val_loss: 241.3259 - val_root_mean_squared_error: 0.3166 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 2s 7ms/step - loss: 217.6726 - root_mean_squared_error: 0.3121 - val_loss: 195.6303 - val_root_mean_squared_error: 0.6159 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 2s 7ms/step - loss: 176.5107 - root_mean_squared_error: 0.3379 - val_loss: 158.8177 - val_root_mean_squared_error: 0.3121 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 2s 7ms/step - loss: 143.3363 - root_mean_squared_error: 0.3321 - val_loss: 128.9270 - val_root_mean_squared_error: 0.3110 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 2s 7ms/step - loss: 116.4028 - root_mean_squared_error: 0.2887 - val_loss: 104.7549 - val_root_mean_squared_error: 0.4461 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 2s 7ms/step - loss: 94.4605 - root_mean_squared_error: 0.2902 - val_loss: 84.9845 - val_root_mean_squared_error: 0.3144 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 2s 7ms/step - loss: 76.5461 - root_mean_squared_error: 0.2909 - val_loss: 68.6056 - val_root_mean_squared_error: 0.2755 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 2s 7ms/step - loss: 61.7949 - root_mean_squared_error: 0.2663 - val_loss: 55.3987 - val_root_mean_squared_error: 0.2705 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 2s 7ms/step - loss: 49.7929 - root_mean_squared_error: 0.2694 - val_loss: 44.5380 - val_root_mean_squared_error: 0.2275 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 2s 7ms/step - loss: 39.9136 - root_mean_squared_error: 0.2660 - val_loss: 35.6866 - val_root_mean_squared_error: 0.2888 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 2s 7ms/step - loss: 31.8697 - root_mean_squared_error: 0.2966 - val_loss: 28.3829 - val_root_mean_squared_error: 0.2995 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 2s 7ms/step - loss: 25.2966 - root_mean_squared_error: 0.2829 - val_loss: 22.5940 - val_root_mean_squared_error: 0.2248 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 2s 7ms/step - loss: 19.9967 - root_mean_squared_error: 0.2690 - val_loss: 17.7435 - val_root_mean_squared_error: 0.2366 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 2s 8ms/step - loss: 15.7490 - root_mean_squared_error: 0.2690 - val_loss: 13.8813 - val_root_mean_squared_error: 0.2429 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 2s 7ms/step - loss: 12.3543 - root_mean_squared_error: 0.2586 - val_loss: 10.9105 - val_root_mean_squared_error: 0.2293 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 2s 7ms/step - loss: 9.7015 - root_mean_squared_error: 0.2485 - val_loss: 8.6617 - val_root_mean_squared_error: 0.3186 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 2s 8ms/step - loss: 7.6034 - root_mean_squared_error: 0.2329 - val_loss: 6.8271 - val_root_mean_squared_error: 0.3417 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 2s 7ms/step - loss: 6.0167 - root_mean_squared_error: 0.2455 - val_loss: 5.3720 - val_root_mean_squared_error: 0.2566 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 2s 7ms/step - loss: 4.8473 - root_mean_squared_error: 0.2488 - val_loss: 4.3719 - val_root_mean_squared_error: 0.2098 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 2s 7ms/step - loss: 3.9447 - root_mean_squared_error: 0.2418 - val_loss: 3.7479 - val_root_mean_squared_error: 0.3308 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 2s 7ms/step - loss: 3.3329 - root_mean_squared_error: 0.2657 - val_loss: 3.2091 - val_root_mean_squared_error: 0.2061 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.8505 - root_mean_squared_error: 0.2460 - val_loss: 2.7035 - val_root_mean_squared_error: 0.2064 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.5474 - root_mean_squared_error: 0.2266 - val_loss: 2.5735 - val_root_mean_squared_error: 0.2803 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.3136 - root_mean_squared_error: 0.2377 - val_loss: 2.3736 - val_root_mean_squared_error: 0.2350 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.1844 - root_mean_squared_error: 0.2404 - val_loss: 2.1689 - val_root_mean_squared_error: 0.2381 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.1132 - root_mean_squared_error: 0.2369 - val_loss: 2.3397 - val_root_mean_squared_error: 0.2169 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0591 - root_mean_squared_error: 0.2344 - val_loss: 2.1692 - val_root_mean_squared_error: 0.2193 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0314 - root_mean_squared_error: 0.2507 - val_loss: 2.0923 - val_root_mean_squared_error: 0.2937 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9797 - root_mean_squared_error: 0.2228 - val_loss: 2.0565 - val_root_mean_squared_error: 0.2364 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0054 - root_mean_squared_error: 0.2245 - val_loss: 2.1226 - val_root_mean_squared_error: 0.2836 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 2s 7ms/step - loss: 2.0158 - root_mean_squared_error: 0.2370 - val_loss: 2.1917 - val_root_mean_squared_error: 0.2213 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9759 - root_mean_squared_error: 0.2222 - val_loss: 2.0658 - val_root_mean_squared_error: 0.2178 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9730 - root_mean_squared_error: 0.2198 - val_loss: 2.0975 - val_root_mean_squared_error: 0.2124 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9801 - root_mean_squared_error: 0.2170 - val_loss: 2.1103 - val_root_mean_squared_error: 0.2073 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9829 - root_mean_squared_error: 0.2227 - val_loss: 2.0829 - val_root_mean_squared_error: 0.2061 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9629 - root_mean_squared_error: 0.2212 - val_loss: 2.0647 - val_root_mean_squared_error: 0.1987 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9962 - root_mean_squared_error: 0.2402 - val_loss: 2.2806 - val_root_mean_squared_error: 0.2097 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9918 - root_mean_squared_error: 0.2370 - val_loss: 2.1561 - val_root_mean_squared_error: 0.2302 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 2s 7ms/step - loss: 1.9487 - root_mean_squared_error: 0.2113 - val_loss: 2.2189 - val_root_mean_squared_error: 0.1833 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.4871 - root_mean_squared_error: 0.1928 - val_loss: -0.5344 - val_root_mean_squared_error: 0.2048 - lr: 1.0000e-04
# Epoch 48/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.7840 - root_mean_squared_error: 0.1842 - val_loss: -0.5406 - val_root_mean_squared_error: 0.1994 - lr: 1.0000e-04
# Epoch 49/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.7954 - root_mean_squared_error: 0.1780 - val_loss: -0.5452 - val_root_mean_squared_error: 0.1931 - lr: 1.0000e-04
# Epoch 50/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.7982 - root_mean_squared_error: 0.1828 - val_loss: -0.5823 - val_root_mean_squared_error: 0.1962 - lr: 1.0000e-04
# Epoch 51/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.7961 - root_mean_squared_error: 0.1795 - val_loss: -0.5510 - val_root_mean_squared_error: 0.1962 - lr: 1.0000e-04
# Epoch 52/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8021 - root_mean_squared_error: 0.1800 - val_loss: -0.5629 - val_root_mean_squared_error: 0.1923 - lr: 1.0000e-04
# Epoch 53/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8020 - root_mean_squared_error: 0.1901 - val_loss: -0.5801 - val_root_mean_squared_error: 0.1958 - lr: 1.0000e-04
# Epoch 54/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8049 - root_mean_squared_error: 0.1808 - val_loss: -0.5590 - val_root_mean_squared_error: 0.2013 - lr: 1.0000e-04
# Epoch 55/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8134 - root_mean_squared_error: 0.1752 - val_loss: -0.5535 - val_root_mean_squared_error: 0.1952 - lr: 1.0000e-04
# Epoch 56/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8195 - root_mean_squared_error: 0.1834 - val_loss: -0.5292 - val_root_mean_squared_error: 0.1993 - lr: 1.0000e-04
# Epoch 57/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8328 - root_mean_squared_error: 0.1862 - val_loss: -0.5078 - val_root_mean_squared_error: 0.1875 - lr: 1.0000e-04
# Epoch 58/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8137 - root_mean_squared_error: 0.1767 - val_loss: -0.5580 - val_root_mean_squared_error: 0.1770 - lr: 1.0000e-04
# Epoch 59/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8237 - root_mean_squared_error: 0.1805 - val_loss: -0.5561 - val_root_mean_squared_error: 0.2053 - lr: 1.0000e-04
# Epoch 60/60
# 313/313 [==============================] - 2s 7ms/step - loss: -0.8417 - root_mean_squared_error: 0.1843 - val_loss: -0.5716 - val_root_mean_squared_error: 0.1929 - lr: 1.0000e-04

# %% [markdown]
# # hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_regenerated_light.hdf5', 'r')
# hf_test = h5py.File('/data3/Diffusion/127x127_diffusion_generated_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated_max_1.hdf5', 'r')
# # hf_test = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_testing_small.hdf5', 'r')
# x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
# t = len(x_test)
# max_value = 1
# x_test = np.true_divide(x_test, max_value)[0:t]
# y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None][0:t]
# hf_test.close()

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
plt.imshow(x_test[100][:,:,4])

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.13

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational/t))

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.scatter(x_array, mean_array, marker='o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True)/(1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1])
plt.show()

# print("Outlier Rate: "+str(outlier_count_total/len(specz)))

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check = 2
current = uncertains[check]
print("Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)

# %%
a = 988
b = 264
c = 1198
d = 112
e = 241
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_test[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_test[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_test[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_test[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_test[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_test[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_test[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_test[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_test[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_test[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
a = 24
b = 15
c = 10
d = 96
e = 1868
fig, axes = plt.subplots(nrows = 1, ncols = 5, figsize = (10, 5))
axes[0].imshow(x_train[a][:,:,0], cmap = 'afmhot')
axes[1].imshow(x_train[b][:,:,0], cmap = 'afmhot')
axes[2].imshow(x_train[c][:,:,0], cmap = 'afmhot')
axes[3].imshow(x_train[d][:,:,0], cmap = 'afmhot')
axes[4].imshow(x_train[e][:,:,0], cmap = 'afmhot')
axes[0].axis('off')
axes[1].axis('off')
axes[2].axis('off')
axes[3].axis('off')
axes[4].axis('off')
# plt.title("Generated g Band Images")
# axes[0].set_title("Generated g Band Image 1", size = 5)
# axes[1].set_title("Generated g Band Image 2", size = 5)
# axes[2].set_title("Generated g Band Image 3", size = 5)
# axes[3].set_title("Generated g Band Image 4", size = 5)
# axes[4].set_title("Generated g Band Image 5", size = 5)
axes[0].annotate(f"z = {np.round(y_train[a][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[1].annotate(f"z = {np.round(y_train[b][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[2].annotate(f"z = {np.round(y_train[c][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[3].annotate(f"z = {np.round(y_train[d][0], 3)}", xy = (10, 10), color = 'white', size = 10)
axes[4].annotate(f"z = {np.round(y_train[e][0], 3)}", xy = (10, 10), color = 'white', size = 10)
plt.show()

# %%
for i in range(10000):
    if np.abs(y_train[i][0]-4)<0.1:
        print(i)

# %%
# END
