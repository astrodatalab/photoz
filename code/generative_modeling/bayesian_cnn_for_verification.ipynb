# %%
import sys, os
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp

from tensorflow import keras
from tensorflow_probability import layers as tfpl
from tensorflow_probability import distributions as tfd
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import InputLayer, MaxPooling2D, Conv2D, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow_probability.python.distributions import kl_divergence
# Out:
# 2023-08-08 07:58:14.387729: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-08 07:58:14.926813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-08-08 07:58:15.757751: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:15.777212: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:15.777403: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:15.779261: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:15.779402: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:15.779524: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:16.254541: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:16.254728: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:16.254855: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-08-08 07:58:16.254963: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step3A/64x64_training_z_less_than_2_small.hdf5', 'r')
hf_test = h5py.File('/data/HSC/HSC_v6/step3A/64x64_testing_z_less_than_2_small.hdf5', 'r')
# hf_test = h5py.File('/data3/Billy/64x64_cvae_generated_11.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step3A/64x64_validation_z_less_than_2_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0 : ],(0, 2, 3, 1)))
x_test = np.asarray(np.transpose(hf_test['image'][0 : ],(0, 2, 3, 1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0 : ], (0, 2, 3, 1)))
n = 10000
t = 2000
v = 2000
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0 : ])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0 : ])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0 : ])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
model_variational = Sequential([
    InputLayer(input_shape=(64, 64, 5)),
    
    # First Conv block
    tfpl.Convolution2DFlipout(16, kernel_size = (3, 3), activation = None, kernel_divergence_fn = kl_divergence_function),
    BatchNormalization(),
    Activation('relu'),
    tfpl.Convolution2DFlipout(32, kernel_size = (3, 3), activation = None, kernel_divergence_fn = kl_divergence_function),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(2, 2),
    
    # Second Conv block
    Conv2D(64, kernel_size = (3, 3), activation = None),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, kernel_size = (3, 3), activation = None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(2, 2),
    
    Flatten(),
    Dropout(0.3),
    
    # Dense Variational layer
    tfpl.DenseVariational(64, 
                          make_posterior_fn = posterior_mean_field,
                          make_prior_fn = prior_trainable,
                          kl_weight = 1 / n),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.2),
    
    # Output layer
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 64, 64, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 62, 62, 16)       1456
#  ut)
#
#  batch_normalization (BatchN  (None, 62, 62, 16)       64
#  ormalization)
#
#  activation (Activation)     (None, 62, 62, 16)        0
#
#  conv2d_flipout_1 (Conv2DFli  (None, 60, 60, 32)       9248
#  pout)
#
#  batch_normalization_1 (Batc  (None, 60, 60, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 26, 26, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dropout (Dropout)           (None, 21632)             0
#
#  dense_variational (DenseVar  (None, 64)               4153536
#  iational)
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 4,257,938
# Trainable params: 4,257,330
# Non-trainable params: 608
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return -estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'bayesian_cnn_rockfish_example'

# checkpoint_filepath = os.path.join('/data/tuando/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

# log_dir = os.path.join('/data/tuando/logs/', model_name)

# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# Epoch 1/60
# 2023-08-08 07:58:20.776530: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-08-08 07:58:21.260737: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-08-08 07:58:21.406653: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f4b43abc650 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-08-08 07:58:21.406678: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-08-08 07:58:21.410037: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-08-08 07:58:21.469964: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-08-08 07:58:21.517667: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-08-08 07:58:21.566899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 [==============================] - 9s 13ms/step - loss: 3777.7168 - root_mean_squared_error: 2.2036 - val_loss: 3146.4192 - val_root_mean_squared_error: 2.0931 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2716.6499 - root_mean_squared_error: 1.2268 - val_loss: 2338.9683 - val_root_mean_squared_error: 1.5472 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 3s 10ms/step - loss: 2048.0994 - root_mean_squared_error: 0.9932 - val_loss: 1786.9045 - val_root_mean_squared_error: 0.8402 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 3s 10ms/step - loss: 1580.4780 - root_mean_squared_error: 0.7920 - val_loss: 1392.5536 - val_root_mean_squared_error: 0.7041 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 3s 9ms/step - loss: 1240.6716 - root_mean_squared_error: 0.7133 - val_loss: 1101.0504 - val_root_mean_squared_error: 0.6575 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 3s 10ms/step - loss: 986.5085 - root_mean_squared_error: 0.6654 - val_loss: 880.8825 - val_root_mean_squared_error: 0.7515 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 3s 10ms/step - loss: 792.0495 - root_mean_squared_error: 0.6054 - val_loss: 709.6455 - val_root_mean_squared_error: 0.6390 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 3s 10ms/step - loss: 640.2720 - root_mean_squared_error: 0.6395 - val_loss: 575.2130 - val_root_mean_squared_error: 0.5769 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 3s 10ms/step - loss: 520.1662 - root_mean_squared_error: 0.5589 - val_loss: 468.1950 - val_root_mean_squared_error: 0.4827 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 3s 9ms/step - loss: 423.9025 - root_mean_squared_error: 0.5677 - val_loss: 382.0609 - val_root_mean_squared_error: 0.5053 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 3s 10ms/step - loss: 346.5405 - root_mean_squared_error: 0.6276 - val_loss: 312.3808 - val_root_mean_squared_error: 0.9967 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 3s 10ms/step - loss: 282.8701 - root_mean_squared_error: 0.5293 - val_loss: 254.9377 - val_root_mean_squared_error: 0.4402 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 3s 10ms/step - loss: 230.9802 - root_mean_squared_error: 0.4467 - val_loss: 208.0187 - val_root_mean_squared_error: 0.3617 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 3s 10ms/step - loss: 188.5204 - root_mean_squared_error: 0.4249 - val_loss: 169.7255 - val_root_mean_squared_error: 0.4245 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 3s 10ms/step - loss: 153.5090 - root_mean_squared_error: 0.4203 - val_loss: 137.8148 - val_root_mean_squared_error: 0.3528 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 3s 10ms/step - loss: 124.6093 - root_mean_squared_error: 0.3700 - val_loss: 111.7697 - val_root_mean_squared_error: 0.4691 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 3s 9ms/step - loss: 100.9230 - root_mean_squared_error: 0.3639 - val_loss: 90.2743 - val_root_mean_squared_error: 0.3426 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 3s 10ms/step - loss: 81.4429 - root_mean_squared_error: 0.3386 - val_loss: 72.8265 - val_root_mean_squared_error: 0.5169 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 3s 10ms/step - loss: 65.6181 - root_mean_squared_error: 0.3578 - val_loss: 58.6236 - val_root_mean_squared_error: 0.6055 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 3s 10ms/step - loss: 52.6290 - root_mean_squared_error: 0.3418 - val_loss: 46.8302 - val_root_mean_squared_error: 0.3058 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 3s 10ms/step - loss: 42.2317 - root_mean_squared_error: 0.3169 - val_loss: 37.5516 - val_root_mean_squared_error: 0.3457 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 3s 10ms/step - loss: 33.7781 - root_mean_squared_error: 0.3201 - val_loss: 30.0073 - val_root_mean_squared_error: 0.2853 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 3s 10ms/step - loss: 27.1062 - root_mean_squared_error: 0.2970 - val_loss: 24.1247 - val_root_mean_squared_error: 0.2780 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 3s 10ms/step - loss: 21.8540 - root_mean_squared_error: 0.2961 - val_loss: 19.5346 - val_root_mean_squared_error: 0.3070 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 3s 9ms/step - loss: 17.7837 - root_mean_squared_error: 0.2946 - val_loss: 15.9706 - val_root_mean_squared_error: 0.3050 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 3s 10ms/step - loss: 14.7150 - root_mean_squared_error: 0.3050 - val_loss: 13.2261 - val_root_mean_squared_error: 0.2604 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 3s 10ms/step - loss: 12.3175 - root_mean_squared_error: 0.2864 - val_loss: 11.2459 - val_root_mean_squared_error: 0.2846 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 3s 10ms/step - loss: 10.5744 - root_mean_squared_error: 0.2877 - val_loss: 9.7689 - val_root_mean_squared_error: 0.2777 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 3s 10ms/step - loss: 9.3404 - root_mean_squared_error: 0.2945 - val_loss: 8.7567 - val_root_mean_squared_error: 0.2598 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 3s 10ms/step - loss: 8.4003 - root_mean_squared_error: 0.2764 - val_loss: 7.9727 - val_root_mean_squared_error: 0.3203 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 3s 10ms/step - loss: 7.7633 - root_mean_squared_error: 0.2815 - val_loss: 7.3518 - val_root_mean_squared_error: 0.3058 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 3s 10ms/step - loss: 7.3264 - root_mean_squared_error: 0.2746 - val_loss: 7.0332 - val_root_mean_squared_error: 0.2660 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 3s 10ms/step - loss: 7.0091 - root_mean_squared_error: 0.2784 - val_loss: 6.7987 - val_root_mean_squared_error: 0.2847 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.7798 - root_mean_squared_error: 0.2657 - val_loss: 6.6044 - val_root_mean_squared_error: 0.2642 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.6622 - root_mean_squared_error: 0.2701 - val_loss: 6.5286 - val_root_mean_squared_error: 0.2806 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.5561 - root_mean_squared_error: 0.2638 - val_loss: 6.4514 - val_root_mean_squared_error: 0.2670 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.4890 - root_mean_squared_error: 0.2600 - val_loss: 6.4182 - val_root_mean_squared_error: 0.2466 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.4504 - root_mean_squared_error: 0.2666 - val_loss: 6.3140 - val_root_mean_squared_error: 0.2594 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.4205 - root_mean_squared_error: 0.2692 - val_loss: 6.2711 - val_root_mean_squared_error: 0.2564 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.3710 - root_mean_squared_error: 0.2532 - val_loss: 6.2184 - val_root_mean_squared_error: 0.2467 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.3524 - root_mean_squared_error: 0.2634 - val_loss: 6.1252 - val_root_mean_squared_error: 0.3038 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.3370 - root_mean_squared_error: 0.2622 - val_loss: 6.2612 - val_root_mean_squared_error: 0.2694 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.2848 - root_mean_squared_error: 0.2541 - val_loss: 6.1901 - val_root_mean_squared_error: 0.2520 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.2846 - root_mean_squared_error: 0.2723 - val_loss: 6.1655 - val_root_mean_squared_error: 0.2744 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 3s 9ms/step - loss: 6.2255 - root_mean_squared_error: 0.2458 - val_loss: 6.1366 - val_root_mean_squared_error: 0.2329 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.2212 - root_mean_squared_error: 0.2551 - val_loss: 6.0910 - val_root_mean_squared_error: 0.2365 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.2027 - root_mean_squared_error: 0.2403 - val_loss: 6.1036 - val_root_mean_squared_error: 0.2366 - lr: 0.0010
# Epoch 48/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.1874 - root_mean_squared_error: 0.2516 - val_loss: 6.0593 - val_root_mean_squared_error: 0.2553 - lr: 0.0010
# Epoch 49/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.1551 - root_mean_squared_error: 0.2560 - val_loss: 6.0655 - val_root_mean_squared_error: 0.2356 - lr: 0.0010
# Epoch 50/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.1461 - root_mean_squared_error: 0.2579 - val_loss: 5.9641 - val_root_mean_squared_error: 0.2575 - lr: 0.0010
# Epoch 51/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.1290 - root_mean_squared_error: 0.2443 - val_loss: 6.0026 - val_root_mean_squared_error: 0.2535 - lr: 0.0010
# Epoch 52/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.1307 - root_mean_squared_error: 0.2432 - val_loss: 6.0340 - val_root_mean_squared_error: 0.2545 - lr: 0.0010
# Epoch 53/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.1593 - root_mean_squared_error: 0.2538 - val_loss: 5.9195 - val_root_mean_squared_error: 0.2492 - lr: 0.0010
# Epoch 54/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.0801 - root_mean_squared_error: 0.2505 - val_loss: 5.9206 - val_root_mean_squared_error: 0.2553 - lr: 0.0010
# Epoch 55/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.0714 - root_mean_squared_error: 0.2428 - val_loss: 5.9625 - val_root_mean_squared_error: 0.2534 - lr: 0.0010
# Epoch 56/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.0639 - root_mean_squared_error: 0.2474 - val_loss: 5.9445 - val_root_mean_squared_error: 0.2578 - lr: 0.0010
# Epoch 57/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.0452 - root_mean_squared_error: 0.2315 - val_loss: 5.9504 - val_root_mean_squared_error: 0.2390 - lr: 0.0010
# Epoch 58/60
# 313/313 [==============================] - 3s 10ms/step - loss: 5.9995 - root_mean_squared_error: 0.2379 - val_loss: 5.9306 - val_root_mean_squared_error: 0.2566 - lr: 0.0010
# Epoch 59/60
# 313/313 [==============================] - 3s 10ms/step - loss: 6.0174 - root_mean_squared_error: 0.2433 - val_loss: 5.9398 - val_root_mean_squared_error: 0.2545 - lr: 0.0010
# Epoch 60/60
# 313/313 [==============================] - 3s 9ms/step - loss: 6.0037 - root_mean_squared_error: 0.2454 - val_loss: 6.0079 - val_root_mean_squared_error: 0.2403 - lr: 0.0010

# %%
model_variational.save_weights(weights_path)

# %%
model_variational.load_weights(weights_path)

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[ : , 0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 2
sns.set(rc = {'figure.figsize' : (10, 10), 'lines.markersize' : 20})
plt.rcParams.update({'font.size' : 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0, t):
    if np.abs(specz[i]-photoz[i]) <= photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc = {'figure.figsize' : (5, 5), 'lines.markersize' : 40})
plt.rcParams.update({'font.size' : 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[ : display_size], photoz[ : display_size], c = z[ : display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[ : display_size], photoz[ : display_size], yerr = photoz_err[ : display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: " + str(overlap_variational / t))
# Out:
# Coverage: 0.7785

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x : x[0])

# %%
bins_variational = int(z_max * 5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational / len(splitted_sorted_combined_array_variational[i]) / 0.6827)
x_array = np.arange(0, z_max, z_max / bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 2], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational / t))
# Out:
# Coverage: 0.7785

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1] - splitted_sorted_combined_array_variational[i][j][0]) / (1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias / (1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total / len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max / bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total / len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc = {'figure.figsize' : (5, 5), 'lines.markersize' : 40})
plt.rcParams.update({'font.size' : 40})
plt.scatter(x_array, mean_array, marker = 'o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True) / (1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key = lambda x : x[0])
bins_outlier = int(z_max * 20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array, bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0, bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count / len(specz) * bins_outlier)
x_array_outlier = np.arange(0, z_max, z_max / bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0, z_max])
plt.ylim([0, 1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key = lambda x : x[0])
bins_outlier = int(z_max * 10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array, bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0, bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] / (splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count / len(specz) * bins_outlier)
x_array_outlier = np.arange(0, z_max, z_max /bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0, z_max])
plt.ylim([0, 1])
plt.show()

print("Outlier Rate: "+str(outlier_count_total / len(specz)))
# Out:
# Outlier Rate: 0.0565

# %%
# END
