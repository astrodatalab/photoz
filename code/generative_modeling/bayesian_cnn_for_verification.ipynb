# %%
import sys, os
import numpy as np
import h5py
import matplotlib.pyplot as plt
import tensorflow as tf
import tensorflow_probability as tfp

from tensorflow import keras
from tensorflow_probability import layers as tfpl
from tensorflow_probability import distributions as tfd
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.layers import InputLayer, MaxPooling2D, Conv2D, Flatten, Dropout, Dense, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow_probability.python.distributions import kl_divergence
# Out:
# 2023-10-05 10:32:41.945371: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 10:32:42.613596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2023-10-05 10:32:43.745086: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:43.768305: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:43.768493: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:43.770660: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:43.770798: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:43.770917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:44.569714: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:44.569899: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:44.570023: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-05 10:32:44.570134: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 2000
v = 2000

# %%
hf_train = h5py.File('/data/HSC/HSC_v6/step3A/64x64_training_z_less_than_2_small.hdf5', 'r')
# hf_test = h5py.File('/data/HSC/HSC_v6/step3A/64x64_testing_z_less_than_2_small.hdf5', 'r')
hf_test = h5py.File('/data3/Billy/64x64_cvae_generated_12.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step3A/64x64_validation_z_less_than_2_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0 : ],(0, 2, 3, 1)))
x_test = np.asarray(np.transpose(hf_test['image'][0 : ],(0, 2, 3, 1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0 : ], (0, 2, 3, 1)))
n = 10000
t = 2000
v = 2000
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0 : ])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0 : ])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0 : ])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
model_variational = Sequential([
    InputLayer(input_shape=(64, 64, 5)),
    
    # First Conv block
    tfpl.Convolution2DFlipout(16, kernel_size = (3, 3), activation = None, kernel_divergence_fn = kl_divergence_function),
    BatchNormalization(),
    Activation('relu'),
    tfpl.Convolution2DFlipout(32, kernel_size = (3, 3), activation = None, kernel_divergence_fn = kl_divergence_function),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(2, 2),
    
    # Second Conv block
    Conv2D(64, kernel_size = (3, 3), activation = None),
    BatchNormalization(),
    Activation('relu'),
    Conv2D(128, kernel_size = (3, 3), activation = None),
    BatchNormalization(),
    Activation('relu'),
    MaxPooling2D(2, 2),
    
    Flatten(),
    Dropout(0.3),
    
    # Dense Variational layer
    tfpl.DenseVariational(64, 
                          make_posterior_fn = posterior_mean_field,
                          make_prior_fn = prior_trainable,
                          kl_weight = 1 / n),
    BatchNormalization(),
    Activation('relu'),
    Dropout(0.2),
    
    # Output layer
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 64, 64, 5))

model_variational.summary()
# Out:
# WARNING:tensorflow:Please fix your imports. Module tensorflow.python.training.tracking.data_structures has been moved to tensorflow.python.trackable.data_structures. The old module will be deleted in version 2.11.
# 2023-10-05 10:32:56.443042: I tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:736] failed to allocate 9.77GiB (10485760000 bytes) from device: CUDA_ERROR_OUT_OF_MEMORY: out of memory
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:99: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   loc = add_variable_fn(
# /home/billyli/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow_probability/python/layers/util.py:109: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use the `layer.add_weight()` method instead.
#   untransformed_scale = add_variable_fn(
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_flipout (Conv2DFlipo  (None, 62, 62, 16)       1456
#  ut)
#
#  batch_normalization (BatchN  (None, 62, 62, 16)       64
#  ormalization)
#
#  activation (Activation)     (None, 62, 62, 16)        0
#
#  conv2d_flipout_1 (Conv2DFli  (None, 60, 60, 32)       9248
#  pout)
#
#  batch_normalization_1 (Batc  (None, 60, 60, 32)       128
#  hNormalization)
#
#  activation_1 (Activation)   (None, 60, 60, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 30, 30, 32)       0
#  )
#
#  conv2d (Conv2D)             (None, 28, 28, 64)        18496
#
#  batch_normalization_2 (Batc  (None, 28, 28, 64)       256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 28, 28, 64)        0
#
#  conv2d_1 (Conv2D)           (None, 26, 26, 128)       73856
#
#  batch_normalization_3 (Batc  (None, 26, 26, 128)      512
#  hNormalization)
#
#  activation_3 (Activation)   (None, 26, 26, 128)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 13, 13, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 21632)             0
#
#  dropout (Dropout)           (None, 21632)             0
#
#  dense_variational (DenseVar  (None, 64)               4153536
#  iational)
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  activation_4 (Activation)   (None, 64)                0
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense (Dense)               (None, 2)                 130
#
#  independent_normal (Indepen  ((None, 1),              0
#  dentNormal)                  (None, 1))
#
# =================================================================
# Total params: 4,257,938
# Trainable params: 4,257,330
# Non-trainable params: 608
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return -estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'bayesian_cnn_rockfish_example'

# checkpoint_filepath = os.path.join('/data/tuando/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

# log_dir = os.path.join('/data/tuando/logs/', model_name)

# cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

# tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

LR_callback = ReduceLROnPlateau()

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [LR_callback])
# Out:
# 2023-10-05 10:34:27.757925: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 819200000 exceeds 10% of free system memory.
# 2023-10-05 10:34:28.198109: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 819200000 exceeds 10% of free system memory.
# Epoch 1/60
# 2023-10-05 10:34:28.569689: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x2189f7a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-05 10:34:28.569717: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2023-10-05 10:34:28.586020: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-05 10:34:28.707221: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 10:34:28.767629: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2023-10-05 10:34:29.272572: I tensorflow/tsl/platform/default/subprocess.cc:304] Start cannot spawn child process: No such file or directory
# 2023-10-05 10:34:29.644788: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 313/313 [==============================] - ETA: 0s - loss: 3834.8923 - root_mean_squared_error: 1.9372
# 2023-10-05 10:34:37.804418: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 163840000 exceeds 10% of free system memory.
# 313/313 [==============================] - 11s 23ms/step - loss: 3834.8923 - root_mean_squared_error: 1.9372 - val_loss: 3223.4097 - val_root_mean_squared_error: 3.2907 - lr: 0.0010
# Epoch 2/60
# 313/313 [==============================] - 5s 17ms/step - loss: 2795.3789 - root_mean_squared_error: 1.6628 - val_loss: 2416.1011 - val_root_mean_squared_error: 1.3733 - lr: 0.0010
# Epoch 3/60
# 313/313 [==============================] - 5s 17ms/step - loss: 2123.4556 - root_mean_squared_error: 1.3332 - val_loss: 1858.9902 - val_root_mean_squared_error: 1.0908 - lr: 0.0010
# Epoch 4/60
# 313/313 [==============================] - 5s 17ms/step - loss: 1648.5812 - root_mean_squared_error: 1.0396 - val_loss: 1457.1729 - val_root_mean_squared_error: 0.8656 - lr: 0.0010
# Epoch 5/60
# 313/313 [==============================] - 6s 18ms/step - loss: 1301.3239 - root_mean_squared_error: 0.9786 - val_loss: 1157.8738 - val_root_mean_squared_error: 0.9875 - lr: 0.0010
# Epoch 6/60
# 313/313 [==============================] - 5s 17ms/step - loss: 1039.7634 - root_mean_squared_error: 0.8755 - val_loss: 930.3079 - val_root_mean_squared_error: 0.8719 - lr: 0.0010
# Epoch 7/60
# 313/313 [==============================] - 6s 18ms/step - loss: 838.5376 - root_mean_squared_error: 0.8426 - val_loss: 752.8964 - val_root_mean_squared_error: 0.9309 - lr: 0.0010
# Epoch 8/60
# 313/313 [==============================] - 5s 17ms/step - loss: 680.5306 - root_mean_squared_error: 0.7969 - val_loss: 613.0880 - val_root_mean_squared_error: 1.8486 - lr: 0.0010
# Epoch 9/60
# 313/313 [==============================] - 6s 18ms/step - loss: 555.1005 - root_mean_squared_error: 0.8782 - val_loss: 500.6400 - val_root_mean_squared_error: 1.0322 - lr: 0.0010
# Epoch 10/60
# 313/313 [==============================] - 5s 17ms/step - loss: 455.1458 - root_mean_squared_error: 0.9174 - val_loss: 410.4416 - val_root_mean_squared_error: 0.8380 - lr: 0.0010
# Epoch 11/60
# 313/313 [==============================] - 5s 17ms/step - loss: 372.5911 - root_mean_squared_error: 0.7502 - val_loss: 336.7234 - val_root_mean_squared_error: 0.6967 - lr: 0.0010
# Epoch 12/60
# 313/313 [==============================] - 5s 17ms/step - loss: 305.8593 - root_mean_squared_error: 0.7184 - val_loss: 276.3160 - val_root_mean_squared_error: 0.5595 - lr: 0.0010
# Epoch 13/60
# 313/313 [==============================] - 5s 17ms/step - loss: 250.9701 - root_mean_squared_error: 0.6462 - val_loss: 226.7538 - val_root_mean_squared_error: 0.4728 - lr: 0.0010
# Epoch 14/60
# 313/313 [==============================] - 5s 17ms/step - loss: 205.9227 - root_mean_squared_error: 0.7391 - val_loss: 185.6262 - val_root_mean_squared_error: 0.5336 - lr: 0.0010
# Epoch 15/60
# 313/313 [==============================] - 5s 17ms/step - loss: 168.4138 - root_mean_squared_error: 0.6307 - val_loss: 151.6100 - val_root_mean_squared_error: 0.7321 - lr: 0.0010
# Epoch 16/60
# 313/313 [==============================] - 5s 17ms/step - loss: 137.5038 - root_mean_squared_error: 0.5615 - val_loss: 123.6501 - val_root_mean_squared_error: 0.5132 - lr: 0.0010
# Epoch 17/60
# 313/313 [==============================] - 5s 17ms/step - loss: 111.9691 - root_mean_squared_error: 0.5219 - val_loss: 100.6181 - val_root_mean_squared_error: 0.5885 - lr: 0.0010
# Epoch 18/60
# 313/313 [==============================] - 5s 18ms/step - loss: 90.9261 - root_mean_squared_error: 0.4458 - val_loss: 81.3985 - val_root_mean_squared_error: 0.4600 - lr: 0.0010
# Epoch 19/60
# 313/313 [==============================] - 5s 17ms/step - loss: 73.6882 - root_mean_squared_error: 0.4452 - val_loss: 65.9236 - val_root_mean_squared_error: 0.4507 - lr: 0.0010
# Epoch 20/60
# 313/313 [==============================] - 5s 17ms/step - loss: 59.4257 - root_mean_squared_error: 0.4210 - val_loss: 53.0805 - val_root_mean_squared_error: 0.4314 - lr: 0.0010
# Epoch 21/60
# 313/313 [==============================] - 5s 17ms/step - loss: 47.9315 - root_mean_squared_error: 0.4132 - val_loss: 42.9013 - val_root_mean_squared_error: 0.3828 - lr: 0.0010
# Epoch 22/60
# 313/313 [==============================] - 5s 17ms/step - loss: 38.6279 - root_mean_squared_error: 0.3546 - val_loss: 34.5142 - val_root_mean_squared_error: 0.5730 - lr: 0.0010
# Epoch 23/60
# 313/313 [==============================] - 5s 17ms/step - loss: 31.1667 - root_mean_squared_error: 0.3660 - val_loss: 27.8751 - val_root_mean_squared_error: 0.3466 - lr: 0.0010
# Epoch 24/60
# 313/313 [==============================] - 5s 17ms/step - loss: 25.2774 - root_mean_squared_error: 0.3486 - val_loss: 22.7097 - val_root_mean_squared_error: 0.3378 - lr: 0.0010
# Epoch 25/60
# 313/313 [==============================] - 5s 17ms/step - loss: 20.6274 - root_mean_squared_error: 0.3234 - val_loss: 18.4478 - val_root_mean_squared_error: 0.2968 - lr: 0.0010
# Epoch 26/60
# 313/313 [==============================] - 5s 18ms/step - loss: 17.0668 - root_mean_squared_error: 0.3302 - val_loss: 15.3835 - val_root_mean_squared_error: 0.3568 - lr: 0.0010
# Epoch 27/60
# 313/313 [==============================] - 5s 17ms/step - loss: 14.3230 - root_mean_squared_error: 0.3184 - val_loss: 12.9500 - val_root_mean_squared_error: 0.2954 - lr: 0.0010
# Epoch 28/60
# 313/313 [==============================] - 5s 17ms/step - loss: 12.1599 - root_mean_squared_error: 0.3033 - val_loss: 11.1622 - val_root_mean_squared_error: 0.3055 - lr: 0.0010
# Epoch 29/60
# 313/313 [==============================] - 5s 17ms/step - loss: 10.6277 - root_mean_squared_error: 0.3089 - val_loss: 9.9273 - val_root_mean_squared_error: 0.3048 - lr: 0.0010
# Epoch 30/60
# 313/313 [==============================] - 5s 17ms/step - loss: 9.4980 - root_mean_squared_error: 0.3009 - val_loss: 8.8829 - val_root_mean_squared_error: 0.2907 - lr: 0.0010
# Epoch 31/60
# 313/313 [==============================] - 5s 17ms/step - loss: 8.6803 - root_mean_squared_error: 0.2861 - val_loss: 8.2755 - val_root_mean_squared_error: 0.2764 - lr: 0.0010
# Epoch 32/60
# 313/313 [==============================] - 5s 16ms/step - loss: 8.1116 - root_mean_squared_error: 0.2837 - val_loss: 8.1922 - val_root_mean_squared_error: 0.3461 - lr: 0.0010
# Epoch 33/60
# 313/313 [==============================] - 5s 17ms/step - loss: 7.6963 - root_mean_squared_error: 0.2863 - val_loss: 7.4164 - val_root_mean_squared_error: 0.2884 - lr: 0.0010
# Epoch 34/60
# 313/313 [==============================] - 5s 17ms/step - loss: 7.3680 - root_mean_squared_error: 0.2793 - val_loss: 7.1061 - val_root_mean_squared_error: 0.2657 - lr: 0.0010
# Epoch 35/60
# 313/313 [==============================] - 5s 17ms/step - loss: 7.2220 - root_mean_squared_error: 0.2881 - val_loss: 6.9478 - val_root_mean_squared_error: 0.2741 - lr: 0.0010
# Epoch 36/60
# 313/313 [==============================] - 5s 18ms/step - loss: 7.0479 - root_mean_squared_error: 0.2772 - val_loss: 6.9127 - val_root_mean_squared_error: 0.2676 - lr: 0.0010
# Epoch 37/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.9248 - root_mean_squared_error: 0.2794 - val_loss: 6.7769 - val_root_mean_squared_error: 0.2677 - lr: 0.0010
# Epoch 38/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.8414 - root_mean_squared_error: 0.2741 - val_loss: 6.7137 - val_root_mean_squared_error: 0.2832 - lr: 0.0010
# Epoch 39/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.8187 - root_mean_squared_error: 0.2690 - val_loss: 6.6779 - val_root_mean_squared_error: 0.2757 - lr: 0.0010
# Epoch 40/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.7545 - root_mean_squared_error: 0.2788 - val_loss: 6.6537 - val_root_mean_squared_error: 0.2602 - lr: 0.0010
# Epoch 41/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.7062 - root_mean_squared_error: 0.2732 - val_loss: 6.5740 - val_root_mean_squared_error: 0.2800 - lr: 0.0010
# Epoch 42/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.6550 - root_mean_squared_error: 0.2694 - val_loss: 6.5054 - val_root_mean_squared_error: 0.2501 - lr: 0.0010
# Epoch 43/60
# 313/313 [==============================] - 6s 18ms/step - loss: 6.6199 - root_mean_squared_error: 0.2539 - val_loss: 6.4224 - val_root_mean_squared_error: 0.2546 - lr: 0.0010
# Epoch 44/60
# 313/313 [==============================] - 6s 18ms/step - loss: 6.5941 - root_mean_squared_error: 0.2736 - val_loss: 6.4759 - val_root_mean_squared_error: 0.2494 - lr: 0.0010
# Epoch 45/60
# 313/313 [==============================] - 5s 18ms/step - loss: 6.5561 - root_mean_squared_error: 0.2599 - val_loss: 6.4147 - val_root_mean_squared_error: 0.2741 - lr: 0.0010
# Epoch 46/60
# 313/313 [==============================] - 6s 18ms/step - loss: 6.5475 - root_mean_squared_error: 0.2516 - val_loss: 6.3193 - val_root_mean_squared_error: 0.2381 - lr: 0.0010
# Epoch 47/60
# 313/313 [==============================] - 5s 18ms/step - loss: 6.4987 - root_mean_squared_error: 0.2577 - val_loss: 6.3301 - val_root_mean_squared_error: 0.2457 - lr: 0.0010
# Epoch 48/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.4705 - root_mean_squared_error: 0.2680 - val_loss: 6.3451 - val_root_mean_squared_error: 0.2471 - lr: 0.0010
# Epoch 49/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.4207 - root_mean_squared_error: 0.2487 - val_loss: 6.3252 - val_root_mean_squared_error: 0.2578 - lr: 0.0010
# Epoch 50/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.4281 - root_mean_squared_error: 0.2554 - val_loss: 6.3478 - val_root_mean_squared_error: 0.2487 - lr: 0.0010
# Epoch 51/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.3834 - root_mean_squared_error: 0.2554 - val_loss: 6.2903 - val_root_mean_squared_error: 0.2379 - lr: 0.0010
# Epoch 52/60
# 313/313 [==============================] - 5s 18ms/step - loss: 6.3609 - root_mean_squared_error: 0.2544 - val_loss: 6.2930 - val_root_mean_squared_error: 0.2747 - lr: 0.0010
# Epoch 53/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.3287 - root_mean_squared_error: 0.2566 - val_loss: 6.2235 - val_root_mean_squared_error: 0.2429 - lr: 0.0010
# Epoch 54/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.2953 - root_mean_squared_error: 0.2465 - val_loss: 6.1339 - val_root_mean_squared_error: 0.2351 - lr: 0.0010
# Epoch 55/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.2777 - root_mean_squared_error: 0.2479 - val_loss: 6.1212 - val_root_mean_squared_error: 0.2427 - lr: 0.0010
# Epoch 56/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.2554 - root_mean_squared_error: 0.2516 - val_loss: 6.1738 - val_root_mean_squared_error: 0.2367 - lr: 0.0010
# Epoch 57/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.2143 - root_mean_squared_error: 0.2484 - val_loss: 6.1150 - val_root_mean_squared_error: 0.2445 - lr: 0.0010
# Epoch 58/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.2008 - root_mean_squared_error: 0.2400 - val_loss: 6.0902 - val_root_mean_squared_error: 0.2405 - lr: 0.0010
# Epoch 59/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.1952 - root_mean_squared_error: 0.2405 - val_loss: 6.0602 - val_root_mean_squared_error: 0.2376 - lr: 0.0010
# Epoch 60/60
# 313/313 [==============================] - 5s 17ms/step - loss: 6.1346 - root_mean_squared_error: 0.2407 - val_loss: 6.0952 - val_root_mean_squared_error: 0.2528 - lr: 0.0010

# %%
model_variational.save_weights(weights_path)
# Out:
# ---------------------------------------------------------------------------
# PermissionDeniedError                     Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model_variational.save_weights(weights_path)
#
# File ~/miniconda3/envs/Diffusion/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow/python/lib/io/file_io.py:513, in recursive_create_dir_v2(path)
#     501 @tf_export("io.gfile.makedirs")
#     502 def recursive_create_dir_v2(path):
#     503   """Creates a directory and all parent/intermediate directories.
#     504
#     505   It succeeds if path already exists and is writable.
#    (...)
#     511     errors.OpError: If the operation fails.
#     512   """
# --> 513   _pywrap_file_io.RecursivelyCreateDir(compat.path_to_bytes(path))
#
# PermissionDeniedError: /models; Permission denied

# %%
model_variational.load_weights(weights_path)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 model_variational.load_weights(weights_path)
#
# File ~/miniconda3/envs/Diffusion/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~/miniconda3/envs/Diffusion/lib/python3.9/site-packages/tensorflow/python/training/py_checkpoint_reader.py:31, in error_translator(e)
#      27 error_message = str(e)
#      28 if 'not found in checkpoint' in error_message or (
#      29     'Failed to find any '
#      30     'matching files for') in error_message:
# ---> 31   raise errors_impl.NotFoundError(None, None, error_message)
#      32 elif 'Sliced checkpoints are not supported' in error_message or (
#      33     'Data type '
#      34     'not '
#      35     'supported') in error_message:
#      36   raise errors_impl.UnimplementedError(None, None, error_message)
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for /models/bayesian_cnn_rockfish_example/weights

# %%
photoz = []

for i in range(t):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[ : , 0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 2
sns.set(rc = {'figure.figsize' : (10, 10), 'lines.markersize' : 20})
plt.rcParams.update({'font.size' : 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0, t):
    if np.abs(specz[i]-photoz[i]) <= photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
sns.set(rc = {'figure.figsize' : (5, 5), 'lines.markersize' : 40})
plt.rcParams.update({'font.size' : 40})
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[ : display_size], photoz[ : display_size], c = z[ : display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[ : display_size], photoz[ : display_size], yerr = photoz_err[ : display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction With Error')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Photometric Redshift')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: " + str(overlap_variational / t))
# Out:
# Coverage: 0.5075

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x : x[0])

# %%
bins_variational = int(z_max * 5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational / len(splitted_sorted_combined_array_variational[i]) / 0.6827)
x_array = np.arange(0, z_max, z_max / bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage')
plt.xlabel('Spectroscopic Redshift')
plt.ylabel('Coverage')
plt.ylim([0, 1.5])
plt.plot([0, 2], [1, 1], color = 'black', linestyle = 'dashed')
plt.annotate("Underconfident", xy = (0, 1.06), color = 'black', size = 12)
plt.annotate("Overconfident", xy = (0, 0.9), color = 'black', size = 12)
print("Coverage: "+str(overlap_variational / t))
# Out:
# Coverage: 0.7785

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1] - splitted_sorted_combined_array_variational[i][j][0]) / (1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias / (1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total / len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max / bins_variational)

# %%
error_array = []
for i in range(0, bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total / len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc = {'figure.figsize' : (5, 5), 'lines.markersize' : 40})
plt.rcParams.update({'font.size' : 40})
plt.scatter(x_array, mean_array, marker = 'o', color = 'blue', s = 4)
# plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias: (Predicted - True) / (1 + True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key = lambda x : x[0])
bins_outlier = int(z_max * 20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array, bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0, bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count / len(specz) * bins_outlier)
x_array_outlier = np.arange(0, z_max, z_max / bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0, z_max])
plt.ylim([0, 1/2])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key = lambda x : x[0])
bins_outlier = int(z_max * 10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array, bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0, bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] / (splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count / len(specz) * bins_outlier)
x_array_outlier = np.arange(0, z_max, z_max /bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0, z_max])
plt.ylim([0, 1])
plt.show()

print("Outlier Rate: "+str(outlier_count_total / len(specz)))
# Out:
# Outlier Rate: 0.0565

# %%
# END
