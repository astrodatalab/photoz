# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import datalabutils.photoz_utils as pz


# Astropy
from astropy.coordinates import SkyCoord
from astropy import units as u

# %%
gml = pd.read_csv('/data/HSC/HSC_v6/HSC_v6.csv')
gml_PDR3_step1 = pd.read_csv('/data/HSC/HSC_v10/step0/GalaxiesML_PDR3_step1.csv')

# %%
gml_PDR3_step1.head()
# Out:
#            object_id  specz_redshift_err  specz_redshift  specz_mag_i  \
# 0  74648610368656011            0.001635         1.39888          0.0
# 1  74648610368680062            0.008295         0.85986          0.0
# 2  74648747807633155            0.010160         1.14577          0.0
# 3  74648747807615382            0.004895         1.58183          0.0
# 4  43158734788103875            0.003820         0.92803          0.0
#
#            specz_name    specz_ra  specz_dec  specz_flag_homogeneous  \
# 0   3DHST_v4.1.5_5103  214.900497  52.801971                    True
# 1  3DHST_v4.1.5_16198  214.940659  52.875404                    True
# 2  3DHST_v4.1.5_20734  214.829773  52.816357                    True
# 3  3DHST_v4.1.5_38239  214.850098  52.900436                    True
# 4   3DHST_v4.1.5_2137  150.127670   2.201092                    True
#
#            ra        dec  ... g_cmodel_mag  r_cmodel_mag  i_cmodel_mag  \
# ...

# %%
gml.specz_name.apply(lambda x: "-".join(x.split('-')[:2])).value_counts().keys().tolist()
# Out:
# ['SDSS-DR12',
#  'GAMA-DR2',
#  'VIPERS-PDR1',
#  'SDSS-DR14',
#  'WIGGLEZ-DR1',
#  'DEEP3-201701',
#  'ZCOSMOS-DR3',
#  'UDSZ-MAR2014',
#  'VVDS-J022543.65',
#  'VVDS-J022607.44',
#  'VVDS-J022719.14',
#  'VVDS-J022638.22',
#  'VVDS-J022808.51',
#  'VVDS-J022744.02',
#  'VVDS-J022602.92',
#  'VVDS-J022742.11',
#  'VVDS-J022719.91',
#  'VVDS-J022545.73',
#  'VVDS-J022551.80',
#  'VVDS-J022718.02',
#  'VVDS-J022704.91',
#  'VVDS-J022718.21',
#  'VVDS-J022555.58',
#  'VVDS-J022721.10',
#  'VVDS-J022545.82',
#  'VVDS-J022628.93',
#  'VVDS-J022556.37',
#  'VVDS-J022522.67',
#  'VVDS-J022617.41',
#  'VVDS-J022726.30',
#  'VVDS-J022556.00',
#  'VVDS-J022757.06',
#  'VVDS-J022549.99',
#  'VVDS-J022727.45',
#  'VVDS-J022512.05',
#  'VVDS-J022528.63',
#  'VVDS-J022729.48',
#  'VVDS-J022742.74',
#  'VVDS-J022650.44',
#  'VVDS-J022725.57',
#  'VVDS-J022712.72',
#  'VVDS-J221951.78',
#  'VVDS-J022543.02',
#  'VVDS-J022715.71',
#  'VVDS-J022659.27',
#  'VVDS-J022543.25',
#  'VVDS-J022659.41',
# ...
