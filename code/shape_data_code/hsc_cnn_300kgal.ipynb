# %%
# Packages that make working with data easier
import os
from astropy.io import fits
import tensorflow as tf
import pandas as pd
import numpy as np
import h5py

#Vsualization 
import matplotlib.pyplot as plt

#Data pre-processing
from DataMaker import * # Make sure DataMaker has the 300k file loaded in the fit_label_scaler method 

#Keras Models
import keras
from keras.models import Sequential ,Model
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, BatchNormalization, LeakyReLU, Dense, Input, Dropout, Flatten, GlobalAveragePooling2D, Dropout, Concatenate
from keras.utils import plot_model
from keras.layers import SpatialDropout2D
# Out:
# 2023-10-12 12:35:12.763683: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-12 12:35:13.535508: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-10-12 12:35:13.535563: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-10-12 12:35:13.535568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
# !nvidia-smi
# Out:
# Thu Oct 12 12:35:15 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 520.61.05    Driver Version: 520.61.05    CUDA Version: 11.8     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A6000    On   | 00000000:61:00.0  On |                  Off |
# | 39%   65C    P2    98W / 300W |  30304MiB / 49140MiB |     14%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1658      G   /usr/lib/xorg/Xorg                182MiB |
# |    0   N/A  N/A      3755      G   /usr/bin/gnome-shell               52MiB |
# |    0   N/A  N/A    240930      C   ...nvs/jupyterhub/bin/python     8802MiB |
# |    0   N/A  N/A    851593      C   ...envs/Diffusion/bin/python    21200MiB |
# +-----------------------------------------------------------------------------+

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
# Path to where the HSC ML Dataset images and metadata are stored and split into training, validation, and testing
start_path = '/data3/Jonathan/five_band_300kgal_127x127_with__metadata_'
TRAIN_PATH = start_path + 'training.hdf5'
TEST_PATH  = start_path + 'testing.hdf5'
VAL_PATH   = start_path + 'validation.hdf5'

# Shape of our images
IMAGE_SHAPE = (5,127,127)

# Output we are interested 
y_key = 'ishape_hsm_regauss_e1'

# %%
'''
    A dictionary of arguments used of HDF5 Image Generator from the DataMaker package 
        x_key: the input for the model; grizy-band images from the HDF5 file labeled 'image'
        y_key: the output for the model; as defined above
        scaler: scales the input
        y_scaler: scales the output; options minmax, standard, or False (for none)
        y_range: for minmax a range for values must be specified. 
        labels_encoding: not applicable for regression
        batch_size: number of images and output opened at once by the HDF5ImageGenerator
        mode: returns output and input 
'''
args_gen = {'X_key': 'image',
            'y_key': y_key,
            'scaler': False,
            'y_scaler': 'minmax',
            'y_range': (0,1),
            'labels_encoding': False,
            'batch_size': 32,
            'mode': 'train'}

# %%
#Same as above except we don't shuffle. it makes 1-1 comparison of predictions difficult later on if we do shuffle

args_gen_test = {'X_key': 'image',
            'y_key': y_key,
            'scaler': False,
            'y_scaler': 'minmax',
            'y_range': (0,1),
            'labels_encoding': False,
            'batch_size': 32,
            'shuffle': False,
            'mode': 'train'}

# %%
#Import HSC Data
train = HDF5ImageGenerator(src=TRAIN_PATH, **args_gen)
test  = HDF5ImageGenerator(src=TEST_PATH, **args_gen_test)
val   = HDF5ImageGenerator(src=VAL_PATH, **args_gen)

# %%
# Code used to plot distributions

# with h5.File(TEST_PATH, "r") as file:
#     field = np.array(file['field'])

# plt.figure(figsize=(10,6))
# plt.hist(field, density=True,alpha=0.7, color='blue')
# plt.ylabel('Field Type')
# plt.xlabel('Frequency')
# plt.title('Distribution of Galaxies Per Field: Test Set')
# plt.show()

# %%
# This code does the same as above commented code except it maekes use of HDF5 image generator methods
# __len__() returns number of batches 
#__getitem__(#) returns image and/or output with (#) signifying the element and [0] for image or [1] for output, [0][0] would signify g-band of images
e1train = []
for i in range(0, train.__len__()):
    e1train = np.append(e1train, train.__getitem__(i)[1])

    
e1test = []
for i in range(0, test.__len__()):
    e1test = np.append(e1test, test.__getitem__(i)[1])
    
e1val = []
for i in range(0, val.__len__()):
    e1val = np.append(e1val, val.__getitem__(i)[1])

# %%
plt.hist([e1train, e1test, e1val], density=True, bins = 100, histtype='step', label=['train', 'test', 'val'])
plt.xlabel('e1 scaled')
plt.ylabel('frequency')
plt.legend()
plt.show()

# %%
#VGG 19 Architecture

input_ = Input(shape=(5, 127, 127))

#First Convolution Layer
conv1  = Conv2D(64, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(input_)
bn1    = BatchNormalization()(conv1)
conv2  = Conv2D(64, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn1)
bn2    = BatchNormalization()(conv2)
pool2  = MaxPooling2D(pool_size=(2,2), data_format='channels_first')(bn2)

#Second Convolution Layer
conv3  = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(pool2)
bn3    = BatchNormalization()(conv3)
conv4  = Conv2D(128, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn3)
bn4    = BatchNormalization()(conv4)
pool4  = MaxPooling2D(pool_size=(2,2), data_format='channels_first')(bn4)

#Third Convolution Layer
conv5  = Conv2D(256, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(pool4)
bn5    = BatchNormalization()(conv5)
conv6  = Conv2D(256, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn5)
bn6    = BatchNormalization()(conv6)
conv7  = Conv2D(256, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn6)
bn7    = BatchNormalization()(conv7)
conv14 = Conv2D(256, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn7)
bn14   = BatchNormalization()(conv14)
pool7  = MaxPooling2D(pool_size=(2,2), data_format='channels_first')(bn14)

#Fourth Convolution Layer
conv8  = Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(pool7)
bn8    = BatchNormalization()(conv8) 
conv9  = Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn8)
bn9    = BatchNormalization()(conv9)
conv10 = Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn9)
bn10   = BatchNormalization()(conv10)
conv15 = Conv2D(512, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn10)
bn15   = BatchNormalization()(conv15)
pool10 = MaxPooling2D(pool_size=(2,2), data_format='channels_first')(bn15)

#Fifth Convolution Layer
conv11  = Conv2D(1024, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(pool10)
bn11    = BatchNormalization()(conv11)
conv12  = Conv2D(1024, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn11)
bn12    = BatchNormalization()(conv12)
conv13  = Conv2D(1024, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn12)
bn13    = BatchNormalization()(conv13)
conv16 = Conv2D(1024, kernel_size=(3,3), activation='relu', padding='same', data_format='channels_first')(bn13)
bn16   = BatchNormalization()(conv16)
conv17 = Conv2D(1024, kernel_size=(3, 3), activation='relu', padding='same', data_format='channels_first')(bn16)
bn17 = BatchNormalization()(conv17)
conv18 = Conv2D(1024, kernel_size=(3, 3), activation='relu', padding='same', data_format='channels_first')(bn17)
bn18 = BatchNormalization()(conv18)
conv19 = Conv2D(1024, kernel_size=(3, 3), activation='relu', padding='same', data_format='channels_first')(bn18)
bn19 = BatchNormalization()(conv19)
conv20 = Conv2D(1024, kernel_size=(3, 3), activation='relu', padding='same', data_format='channels_first')(bn19)
bn20 = BatchNormalization()(conv20)
pool14 = MaxPooling2D(pool_size=(2, 2), data_format='channels_first')(bn20)


#Fully Connected Layer
flatten = Flatten(data_format='channels_first')(pool14)
dense1  = Dense(512, activation='relu')(flatten)
drop1   = Dropout(0.5)(dense1)

#Output
output = Dense(1, activation='relu')(drop1)

model = Model(inputs=[input_], outputs=[output], name='vgg19')
model.summary()

# %%
#GoogLe Net architecture

#Code for the inception module
def Inception(input_layer, f1, f2_conv1, f2_conv3, f3_conv1, f3_conv5, f4):
    # Input: 
    # - f1: number of filters of the 1x1 convolutional layer in the first path
    # - f2_conv1, f2_conv3 are number of filters corresponding to the 1x1 and 3x3 convolutional layers in the second path
    # - f3_conv1, f3_conv5 are the number of filters corresponding to the 1x1 and 5x5  convolutional layer in the third path
    # - f4: number of filters of the 1x1 convolutional layer in the fourth path

    # 1st path:
    path1 = conv_mod(input_layer, f1, kernel_size = (1,1), padding = 'same', activation = 'relu', data_format='channels_first')

    # 2nd path
    path2 = conv_mod(input_layer, f2_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu', data_format='channels_first')
    path2 = conv_mod(path2, f2_conv3, kernel_size = (3,3), padding = 'same', activation = 'relu', data_format='channels_first')

    # 3rd path
    path3 = conv_mod(input_layer, f3_conv1, kernel_size = (1,1), padding = 'same', activation = 'relu', data_format='channels_first')
    path3 = conv_mod(path3, f3_conv5, kernel_size = (2,2), padding = 'same', activation = 'relu', data_format='channels_first')

    # 4th path
    path4 = MaxPooling2D((3,3), strides= (1,1), padding = 'same', data_format='channels_first')(input_layer)
    path4 = conv_mod(path4, f4, kernel_size = (1,1), padding = 'same', activation = 'relu', data_format='channels_first')

    output_layer = Concatenate(axis=1)([path1, path2, path3, path4])

    return output_layer

#Small block to perform convolution and batch normalization
def conv_mod(input_layer, f1, **kwargs):
    conv = Conv2D(filters=f1, **kwargs)(input_layer)
    return BatchNormalization()(conv)


# Input Layer
input_layer = Input(shape=(5, 127, 127))

#Convolution layer: filters=64, 7x7 kernel, strides=2
conv1 = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding='same', activation='relu', data_format='channels_first')(input_layer)
pool1 = MaxPooling2D(pool_size=(3,3), strides=2, padding='same', data_format='channels_first')(conv1)
bn1   = BatchNormalization()(pool1)

#Convolution layer 2: filters=64, strides=1
conv2 = conv_mod(bn1, 64, kernel_size=(1,1), strides=1, padding='same', activation='relu', data_format='channels_first')

#Convolution layer 3: filters=192, kernel_size=(3,3)
conv3 = conv_mod(conv2, 192, kernel_size=(3,3), padding='same', activation='relu', data_format='channels_first')
pool3 = MaxPooling2D(pool_size=(3,3), strides=2, padding='same', data_format='channels_first')(conv3)

#Inception BLock 1
incept1 = Inception(pool3, f1 = 64, f2_conv1 = 96, f2_conv3 = 128, f3_conv1 = 16, f3_conv5 = 32, f4 = 32)

#Incept Block 2
incept2 = Inception(incept1, f1 = 128, f2_conv1 = 128, f2_conv3 = 192, f3_conv1 = 32, f3_conv5 = 96, f4 = 64)
pool4   = MaxPooling2D(pool_size=(3,3), strides=2, padding='same', data_format='channels_first')(incept2)

#Incept Block 3 
incept3 = Inception(pool4, f1 = 192, f2_conv1 = 96, f2_conv3 = 208, f3_conv1 = 16, f3_conv5 = 48, f4 = 64)

# Extra network 1:
apool1 = AveragePooling2D(pool_size = (5,5), strides = 3, data_format='channels_first')(incept3)
conv4  = conv_mod(apool1, 512, kernel_size = (1,1), padding = 'same', activation = 'relu', data_format='channels_first')
flatten1 = Flatten(data_format='channels_first')(conv4)
dense1 = Dense(512, activation = 'relu')(flatten1)
drop1 = Dropout(0.7)(dense1)
dense1 = Dense(1, activation='relu', name='aux1')(drop1)

# 4th Inception block
incept4 = Inception(incept3, f1 = 160, f2_conv1 = 112, f2_conv3 = 224, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

# 5th Inception block
incept5 = Inception(incept4, f1 = 128, f2_conv1 = 128, f2_conv3 = 256, f3_conv1 = 24, f3_conv5 = 64, f4 = 64)

# 6th Inception block
incept6 = Inception(incept5, f1 = 112, f2_conv1 = 144, f2_conv3 = 288, f3_conv1 = 32, f3_conv5 = 64, f4 = 64)

# Extra network 2:
apool2 = AveragePooling2D(pool_size = (5,5), strides = 3, data_format='channels_first')(incept6)
conv5 = conv_mod(apool2, 512, kernel_size = (1,1), padding = 'same', activation = 'relu', data_format='channels_first')
flatten2 = Flatten(data_format='channels_first')(conv5)
dense2 = Dense(512, activation = 'relu')(flatten2)
drop2 = Dropout(0.7)(dense2)
dense2 = Dense(1, activation = 'relu', name='aux2')(drop2)


# 7th Inception block
incept7 = Inception(incept6, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

# max-pooling layer: pool_size = (3,3), strides = 2
pool5 = MaxPooling2D(pool_size = (3,3), strides = 2, padding='same', data_format='channels_first')(incept7)

# 8th Inception block
incept8 = Inception(pool5, f1 = 256, f2_conv1 = 160, f2_conv3 = 320, f3_conv1 = 32, f3_conv5 = 128, f4 = 128)

# 9th Inception block
incept9 = Inception(incept8, f1 = 384, f2_conv1 = 192, f2_conv3 = 384, f3_conv1 = 48, f3_conv5 = 128, f4 = 128)

# Global Average pooling layer 
gapool = AveragePooling2D(name = 'GAPL', data_format='channels_first')(incept9)

# FC 
flatten = Flatten(data_format='channels_first')(gapool)
dense = Dense(512, activation='relu')(flatten)
drop  = Dropout(0.7)(dense)

# output layer 
output_layer = Dense(1, activation='relu', name='main_output')(drop)

# model
model = Model(input_layer, [output_layer, dense1, dense2], name = 'GoogLeNet')
model.summary()
# Out:
# Model: "GoogLeNet"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 5, 127, 127  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 64, 64, 64)   15744       ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 32, 32)   0           ['conv2d[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 32, 32)  128         ['max_pooling2d[0][0]']
#  alization)
#
#  conv2d_1 (Conv2D)              (None, 64, 32, 32)   4160        ['batch_normalization[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 32, 32)  128         ['conv2d_1[0][0]']
#  rmalization)
#
#  conv2d_2 (Conv2D)              (None, 192, 32, 32)  110784      ['batch_normalization_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 192, 32, 32)  128        ['conv2d_2[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 192, 16, 16)  0          ['batch_normalization_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 96, 16, 16)   18528       ['max_pooling2d_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 16)   3088        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 96, 16, 16)  64          ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 16)  64          ['conv2d_6[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 192, 16, 16)  0          ['max_pooling2d_1[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 16, 16)   12352       ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 128, 16, 16)  110720      ['batch_normalization_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 32, 16, 16)   2080        ['batch_normalization_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 32, 16, 16)   6176        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 16, 16)  64          ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_5 (BatchNo  (None, 128, 16, 16)  64         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_7 (BatchNo  (None, 32, 16, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 32, 16, 16)  64          ['conv2d_8[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 256, 16, 16)  0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_5[0][0]',
#                                                                   'batch_normalization_7[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 128, 16, 16)  32896       ['concatenate[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 16, 16)   8224        ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 128, 16, 16)  64         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_12 (BatchN  (None, 32, 16, 16)  64          ['conv2d_12[0][0]']
#  ormalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 16, 16)  0          ['concatenate[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 128, 16, 16)  32896       ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 192, 16, 16)  221376      ['batch_normalization_10[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 96, 16, 16)   12384       ['batch_normalization_12[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 16, 16)   16448       ['max_pooling2d_3[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 128, 16, 16)  64         ['conv2d_9[0][0]']
#  rmalization)
#
#  batch_normalization_11 (BatchN  (None, 192, 16, 16)  64         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 96, 16, 16)  64          ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_14 (BatchN  (None, 64, 16, 16)  64          ['conv2d_14[0][0]']
#  ormalization)
#
#  concatenate_1 (Concatenate)    (None, 480, 16, 16)  0           ['batch_normalization_9[0][0]',
#                                                                   'batch_normalization_11[0][0]',
#                                                                   'batch_normalization_13[0][0]',
#                                                                   'batch_normalization_14[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 240, 8, 16)  0           ['concatenate_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 96, 8, 16)    23136       ['max_pooling2d_4[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 8, 16)    3856        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 96, 8, 16)   64          ['conv2d_16[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 16, 8, 16)   64          ['conv2d_18[0][0]']
#  ormalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 240, 8, 16)  0           ['max_pooling2d_4[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 192, 8, 16)   46272       ['max_pooling2d_4[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 208, 8, 16)   179920      ['batch_normalization_16[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 48, 8, 16)    3120        ['batch_normalization_18[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 64, 8, 16)    15424       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 192, 8, 16)  64          ['conv2d_15[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 208, 8, 16)  64          ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_19 (BatchN  (None, 48, 8, 16)   64          ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 64, 8, 16)   64          ['conv2d_20[0][0]']
#  ormalization)
#
#  concatenate_2 (Concatenate)    (None, 512, 8, 16)   0           ['batch_normalization_15[0][0]',
#                                                                   'batch_normalization_17[0][0]',
#                                                                   'batch_normalization_19[0][0]',
#                                                                   'batch_normalization_20[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 112, 8, 16)   57456       ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 24, 8, 16)    12312       ['concatenate_2[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 112, 8, 16)  64          ['conv2d_23[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 24, 8, 16)   64          ['conv2d_25[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 512, 8, 16)  0           ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 160, 8, 16)   82080       ['concatenate_2[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 224, 8, 16)   226016      ['batch_normalization_23[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 64, 8, 16)    6208        ['batch_normalization_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 8, 16)    32832       ['max_pooling2d_6[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 160, 8, 16)  64          ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_24 (BatchN  (None, 224, 8, 16)  64          ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_26 (BatchN  (None, 64, 8, 16)   64          ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 64, 8, 16)   64          ['conv2d_27[0][0]']
#  ormalization)
#
#  concatenate_3 (Concatenate)    (None, 512, 8, 16)   0           ['batch_normalization_22[0][0]',
#                                                                   'batch_normalization_24[0][0]',
#                                                                   'batch_normalization_26[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 128, 8, 16)   65664       ['concatenate_3[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 24, 8, 16)    12312       ['concatenate_3[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 128, 8, 16)  64          ['conv2d_29[0][0]']
#  ormalization)
#
#  batch_normalization_31 (BatchN  (None, 24, 8, 16)   64          ['conv2d_31[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 512, 8, 16)  0           ['concatenate_3[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 128, 8, 16)   65664       ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 256, 8, 16)   295168      ['batch_normalization_29[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 8, 16)    6208        ['batch_normalization_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 8, 16)    32832       ['max_pooling2d_7[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 128, 8, 16)  64          ['conv2d_28[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 256, 8, 16)  64          ['conv2d_30[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 64, 8, 16)   64          ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_33 (BatchN  (None, 64, 8, 16)   64          ['conv2d_33[0][0]']
#  ormalization)
#
#  concatenate_4 (Concatenate)    (None, 512, 8, 16)   0           ['batch_normalization_28[0][0]',
#                                                                   'batch_normalization_30[0][0]',
#                                                                   'batch_normalization_32[0][0]',
#                                                                   'batch_normalization_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 144, 8, 16)   73872       ['concatenate_4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 8, 16)    16416       ['concatenate_4[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 144, 8, 16)  64          ['conv2d_35[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 32, 8, 16)   64          ['conv2d_37[0][0]']
#  ormalization)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 512, 8, 16)  0           ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 112, 8, 16)   57456       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 288, 8, 16)   373536      ['batch_normalization_35[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 64, 8, 16)    8256        ['batch_normalization_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 64, 8, 16)    32832       ['max_pooling2d_8[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 112, 8, 16)  64          ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 288, 8, 16)  64          ['conv2d_36[0][0]']
#  ormalization)
#
#  batch_normalization_38 (BatchN  (None, 64, 8, 16)   64          ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_39 (BatchN  (None, 64, 8, 16)   64          ['conv2d_39[0][0]']
#  ormalization)
#
#  concatenate_5 (Concatenate)    (None, 528, 8, 16)   0           ['batch_normalization_34[0][0]',
#                                                                   'batch_normalization_36[0][0]',
#                                                                   'batch_normalization_38[0][0]',
#                                                                   'batch_normalization_39[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 160, 8, 16)   84640       ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 32, 8, 16)    16928       ['concatenate_5[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 160, 8, 16)  64          ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_44 (BatchN  (None, 32, 8, 16)   64          ['conv2d_44[0][0]']
#  ormalization)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 528, 8, 16)  0           ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 256, 8, 16)   135424      ['concatenate_5[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 320, 8, 16)   461120      ['batch_normalization_42[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 128, 8, 16)   16512       ['batch_normalization_44[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 128, 8, 16)   67712       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 256, 8, 16)  64          ['conv2d_41[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 320, 8, 16)  64          ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_45 (BatchN  (None, 128, 8, 16)  64          ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 128, 8, 16)  64          ['conv2d_46[0][0]']
#  ormalization)
#
#  concatenate_6 (Concatenate)    (None, 832, 8, 16)   0           ['batch_normalization_41[0][0]',
#                                                                   'batch_normalization_43[0][0]',
#                                                                   'batch_normalization_45[0][0]',
#                                                                   'batch_normalization_46[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 416, 4, 16)  0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_48 (Conv2D)             (None, 160, 4, 16)   66720       ['max_pooling2d_10[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 4, 16)    13344       ['max_pooling2d_10[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 160, 4, 16)  64          ['conv2d_48[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 32, 4, 16)   64          ['conv2d_50[0][0]']
#  ormalization)
#
#  max_pooling2d_11 (MaxPooling2D  (None, 416, 4, 16)  0           ['max_pooling2d_10[0][0]']
#  )
#
#  conv2d_47 (Conv2D)             (None, 256, 4, 16)   106752      ['max_pooling2d_10[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 320, 4, 16)   461120      ['batch_normalization_48[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 128, 4, 16)   16512       ['batch_normalization_50[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 128, 4, 16)   53376       ['max_pooling2d_11[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 256, 4, 16)  64          ['conv2d_47[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 320, 4, 16)  64          ['conv2d_49[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 128, 4, 16)  64          ['conv2d_51[0][0]']
#  ormalization)
#
#  batch_normalization_52 (BatchN  (None, 128, 4, 16)  64          ['conv2d_52[0][0]']
#  ormalization)
#
#  concatenate_7 (Concatenate)    (None, 832, 4, 16)   0           ['batch_normalization_47[0][0]',
#                                                                   'batch_normalization_49[0][0]',
#                                                                   'batch_normalization_51[0][0]',
#                                                                   'batch_normalization_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 192, 4, 16)   159936      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 48, 4, 16)    39984       ['concatenate_7[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 192, 4, 16)  64          ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_56 (BatchN  (None, 48, 4, 16)   64          ['conv2d_56[0][0]']
#  ormalization)
#
#  max_pooling2d_12 (MaxPooling2D  (None, 832, 4, 16)  0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 384, 4, 16)   319872      ['concatenate_7[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 384, 4, 16)   663936      ['batch_normalization_54[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 128, 4, 16)   24704       ['batch_normalization_56[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 128, 4, 16)   106624      ['max_pooling2d_12[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 384, 4, 16)  64          ['conv2d_53[0][0]']
#  ormalization)
#
#  batch_normalization_55 (BatchN  (None, 384, 4, 16)  64          ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_57 (BatchN  (None, 128, 4, 16)  64          ['conv2d_57[0][0]']
#  ormalization)
#
#  batch_normalization_58 (BatchN  (None, 128, 4, 16)  64          ['conv2d_58[0][0]']
#  ormalization)
#
#  average_pooling2d (AveragePool  (None, 170, 2, 16)  0           ['concatenate_2[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 175, 2, 16)  0           ['concatenate_5[0][0]']
#  oling2D)
#
#  concatenate_8 (Concatenate)    (None, 1024, 4, 16)  0           ['batch_normalization_53[0][0]',
#                                                                   'batch_normalization_55[0][0]',
#                                                                   'batch_normalization_57[0][0]',
#                                                                   'batch_normalization_58[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 170, 2, 512)  8704        ['average_pooling2d[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 175, 2, 512)  8704        ['average_pooling2d_1[0][0]']
#
#  GAPL (AveragePooling2D)        (None, 512, 2, 16)   0           ['concatenate_8[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 170, 2, 512)  2048       ['conv2d_21[0][0]']
#  ormalization)
#
#  batch_normalization_40 (BatchN  (None, 175, 2, 512)  2048       ['conv2d_40[0][0]']
#  ormalization)
#
#  flatten_2 (Flatten)            (None, 16384)        0           ['GAPL[0][0]']
#
#  flatten (Flatten)              (None, 174080)       0           ['batch_normalization_21[0][0]']
#
#  flatten_1 (Flatten)            (None, 179200)       0           ['batch_normalization_40[0][0]']
#
#  dense_2 (Dense)                (None, 512)          8389120     ['flatten_2[0][0]']
#
#  dense (Dense)                  (None, 512)          89129472    ['flatten[0][0]']
#
#  dense_1 (Dense)                (None, 512)          91750912    ['flatten_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 512)          0           ['dense_2[0][0]']
#
#  dropout (Dropout)              (None, 512)          0           ['dense[0][0]']
#
#  dropout_1 (Dropout)            (None, 512)          0           ['dense_1[0][0]']
#
#  main_output (Dense)            (None, 1)            513         ['dropout_2[0][0]']
#
#  aux1 (Dense)                   (None, 1)            513         ['dropout[0][0]']
#
#  aux2 (Dense)                   (None, 1)            513         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 194,448,307
# Trainable params: 194,444,339
# Non-trainable params: 3,968
# __________________________________________________________________________________________________

# %%
#Setting up learning rate/optimizer at 5e-6 and callbacks
optimizer = tf.keras.optimizers.Adam(learning_rate=0.000005)

callback = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.001, patience=10)
#callback2 = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience = 5)

#Compile model learning on MSE with MAE also being reported for reference
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=[tf.keras.metrics.MeanAbsoluteError(), tf.keras.metrics.MeanSquaredError()],)

#fit the model for 200 epochs
history = model.fit(train, epochs=200, shuffle = True, validation_data = val, verbose = 1, callbacks=callback)#, callbacks=[cp_callback])
# Out:
# Epoch 1/200
# 7500/7500 [==============================] - 518s 66ms/step - loss: 0.5722 - main_output_loss: 0.0579 - aux1_loss: 0.2577 - aux2_loss: 0.2566 - main_output_mean_absolute_error: 0.1765 - main_output_mean_squared_error: 0.0579 - aux1_mean_absolute_error: 0.4939 - aux1_mean_squared_error: 0.2577 - aux2_mean_absolute_error: 0.4938 - aux2_mean_squared_error: 0.2566 - val_loss: 0.5310 - val_main_output_loss: 0.0194 - val_aux1_loss: 0.2558 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.1031 - val_main_output_mean_squared_error: 0.0194 - val_aux1_mean_absolute_error: 0.4934 - val_aux1_mean_squared_error: 0.2558 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# Epoch 2/200
# 7500/7500 [==============================] - 2434s 325ms/step - loss: 0.5358 - main_output_loss: 0.0220 - aux1_loss: 0.2571 - aux2_loss: 0.2566 - main_output_mean_absolute_error: 0.1193 - main_output_mean_squared_error: 0.0220 - aux1_mean_absolute_error: 0.4938 - aux1_mean_squared_error: 0.2571 - aux2_mean_absolute_error: 0.4938 - aux2_mean_squared_error: 0.2566 - val_loss: 0.5286 - val_main_output_loss: 0.0171 - val_aux1_loss: 0.2558 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0984 - val_main_output_mean_squared_error: 0.0171 - val_aux1_mean_absolute_error: 0.4934 - val_aux1_mean_squared_error: 0.2558 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# 7500/7500 [==============================] - 3005s 401ms/step - loss: 0.5145 - main_output_loss: 0.0025 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0366 - main_output_mean_squared_error: 0.0025 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 12.2064 - val_main_output_loss: 0.0017 - val_aux1_loss: 11.9489 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0283 - val_main_output_mean_squared_error: 0.0017 - val_aux1_mean_absolute_error: 0.5131 - val_aux1_mean_squared_error: 11.9489 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# Epoch 27/200
# 7500/7500 [==============================] - 2534s 338ms/step - loss: 0.5144 - main_output_loss: 0.0024 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0361 - main_output_mean_squared_error: 0.0024 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 6.6389 - val_main_output_loss: 0.0018 - val_aux1_loss: 6.3814 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0289 - val_main_output_mean_squared_error: 0.0018 - val_aux1_mean_absolute_error: 0.5077 - val_aux1_mean_squared_error: 6.3814 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# Epoch 28/200
# 7500/7500 [==============================] - 2533s 338ms/step - loss: 0.5144 - main_output_loss: 0.0024 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0357 - main_output_mean_squared_error: 0.0024 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 9.7743 - val_main_output_loss: 0.0017 - val_aux1_loss: 9.5169 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0280 - val_main_output_mean_squared_error: 0.0017 - val_aux1_mean_absolute_error: 0.5110 - val_aux1_mean_squared_error: 9.5169 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# Epoch 29/200
# 7500/7500 [==============================] - 2527s 337ms/step - loss: 0.5143 - main_output_loss: 0.0023 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0353 - main_output_mean_squared_error: 0.0023 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 11.2637 - val_main_output_loss: 0.0016 - val_aux1_loss: 11.0063 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0274 - val_main_output_mean_squared_error: 0.0016 - val_aux1_mean_absolute_error: 0.5123 - val_aux1_mean_squared_error: 11.0063 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# Epoch 30/200
# 7500/7500 [==============================] - 2530s 337ms/step - loss: 0.5143 - main_output_loss: 0.0023 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0350 - main_output_mean_squared_error: 0.0023 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 7.5468 - val_main_output_loss: 0.0016 - val_aux1_loss: 7.2894 - val_aux2_loss: 0.2559 - val_main_output_mean_absolute_error: 0.0271 - val_main_output_mean_squared_error: 0.0016 - val_aux1_mean_absolute_error: 0.5087 - val_aux1_mean_squared_error: 7.2894 - val_aux2_mean_absolute_error: 0.4935 - val_aux2_mean_squared_error: 0.2559
# Epoch 31/200
# 7500/7500 [==============================] - 2533s 338ms/step - loss: 0.5143 - main_output_loss: 0.0023 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0347 - main_output_mean_squared_error: 0.0023 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 8.8201 - val_main_output_loss: 0.0016 - val_aux1_loss: 8.5628 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0270 - val_main_output_mean_squared_error: 0.0016 - val_aux1_mean_absolute_error: 0.5100 - val_aux1_mean_squared_error: 8.5628 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558
# Epoch 32/200
# 7500/7500 [==============================] - 2514s 335ms/step - loss: 0.5142 - main_output_loss: 0.0022 - aux1_loss: 0.2560 - aux2_loss: 0.2560 - main_output_mean_absolute_error: 0.0345 - main_output_mean_squared_error: 0.0022 - aux1_mean_absolute_error: 0.4937 - aux1_mean_squared_error: 0.2560 - aux2_mean_absolute_error: 0.4937 - aux2_mean_squared_error: 0.2560 - val_loss: 9.4531 - val_main_output_loss: 0.0016 - val_aux1_loss: 9.1957 - val_aux2_loss: 0.2558 - val_main_output_mean_absolute_error: 0.0281 - val_main_output_mean_squared_error: 0.0016 - val_aux1_mean_absolute_error: 0.5107 - val_aux1_mean_squared_error: 9.1957 - val_aux2_mean_absolute_error: 0.4934 - val_aux2_mean_squared_error: 0.2558

# %%
model.save('/data3/Jonathan/googlenet_10132023_run.h5')

# %%
#Plot the learning curves for the loss and validation loss

pd.DataFrame(history.history)[['main_output_loss','val_main_output_loss']].plot(figsize=(8,5))
plt.grid(True)

plt.xlabel('epoch')
plt.ylabel('Mean Squared Error')
plt.title('GoogLeNet: learning_rate=5e-6')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
#plt.ylim(0,0.1)
plt.show()

# %% [markdown]
# Evaluation and Predictions

# %%
model.evaluate(test)
# Out:
# 938/938 [==============================] - 38s 40ms/step - loss: 0.5122 - main_output_loss: 0.0016 - aux1_loss: 0.2553 - aux2_loss: 0.2553 - main_output_mean_absolute_error: 0.0281 - main_output_mean_squared_error: 0.0016 - aux1_mean_absolute_error: 0.4929 - aux1_mean_squared_error: 0.2553 - aux2_mean_absolute_error: 0.4929 - aux2_mean_squared_error: 0.2553
# [0.5122330784797668,
#  0.001589051098562777,
#  0.2553224563598633,
#  0.2553224563598633,
#  0.028092531487345695,
#  0.001589051098562777,
#  0.49292510747909546,
#  0.2553224563598633,
#  0.49292510747909546,
#  0.2553224563598633]

# %%
predictions = model.predict(test)
# Out:
# 938/938 [==============================] - 17s 17ms/step

# %%
predictions[0]
# Out:
# array([[0.41350788],
#        [0.5677644 ],
#        [0.4913022 ],
#        ...,
#        [0.5663721 ],
#        [0.41897076],
#        [0.39300877]], dtype=float32)

# %%
#Get the known outputs for the galaxies predicted above and sort them to match with predictions

hf_test = h5py.File(TEST_PATH, 'r')
y_test = hf_test[y_key][np.sort(test._indices)]
objID_test = hf_test['object_id'][np.sort(test._indices)]
hf_test.close()

# %%
objID_test[0]

# %%
#Revert back to no scale for the e1 values
predictions = train.inverse_transform_labels(predictions[0])

# %%
#Flatten the real e1 values for plotting ease
y_test = np.array(y_test).flatten()

# %%
predictions.shape
# Out:
# (30000, 1)

# %%
predDataset = pd.DataFrame({'object_id': objID_test.flatten(), 
                            'true_shear': y_test, 
                            'predicted_shear': predictions.flatten()})

# %%
predDataset.to_csv('/data3/Jonathan/predictions_googlenet_10132023.csv')

# %%
#Make a plot with the real vs predicted e1 values along with the multiplicative and additive bias. Also plot the residuals

slope, intercept = np.polyfit(y_test, predictions.flatten(), 1)

# Compute the biases
multiplicative_bias = slope - 1
additive_bias = intercept

# Plot the biases
plt.figure(figsize=(10, 5))

# Scatter plot of true vs predicted shear values
plt.subplot(1, 2, 1)
plt.scatter(y_test, predictions.flatten(), alpha=0.5)
x = np.linspace(min(y_test), max(y_test), 100)
plt.plot(x, slope*x + intercept, 'r')
x2 = np.linspace(-2, 2, 100)
plt.plot(x2, x2, 'black') 
plt.xlabel('True Shear')
plt.ylabel('Predicted Shear')

# Histogram of residuals
plt.subplot(1, 2, 2)
plt.hist(predictions.flatten() - (slope*y_test + intercept), bins=50, color='g', alpha=0.5)
plt.xlabel('Residuals')
plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

print(f"Multiplicative bias (m-1): {multiplicative_bias}")
print(f"Additive bias (c): {additive_bias}")
# Out:
# Multiplicative bias (m-1): -0.12986830720242393
# Additive bias (c): -0.022906513621474868

# %%
#Another representation of predictions and real e1 values

from scipy.stats import gaussian_kde
import numpy as np
import matplotlib.pyplot as plt

# predictions = model.predict([x_test])
# photoz = [pred[0] for pred in predictions]

# Create a 2D array of the data
data = np.vstack([y_test, predictions.flatten()])

# Calculate the Gaussian KDE
kde = gaussian_kde(data)

# Create a grid over which to evaluate the KDE
xgrid, ygrid = np.meshgrid(np.linspace(np.min(y_test), np.max(y_test), 100), 
                           np.linspace(np.min(predictions.flatten()), np.max(predictions.flatten()), 100))

# Evaluate the KDE on the grid
z = kde.evaluate(np.vstack([xgrid.ravel(), ygrid.ravel()]))

# Reshape the result back into 2D
z = z.reshape(xgrid.shape)

# Plot the result
plt.pcolormesh(xgrid, ygrid, z, shading='auto')
plt.colorbar(label='Density')
plt.ylabel('Predicted Shear_1')
plt.xlabel('Shear_1')
plt.show()
