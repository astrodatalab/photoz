# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits
import tensorflow as tf
import tensorflow_probability as tfp
import h5py
import random
from sklearn.model_selection import train_test_split
import pandas as pd
# Out:
# 2024-05-19 10:42:41.271562: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-05-19 10:42:42.000500: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
tfpl = tfp.layers
tf1 = tf.compat.v1
tfd = tfp.distributions

# %%
from tensorflow_probability.python.distributions import kl_divergence

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
  # Restrict TensorFlow to only allocate 10GB of memory on the first GPU
  try:
    tf.config.experimental.set_virtual_device_configuration(
        gpus[0],
        [tf.config.experimental.VirtualDeviceConfiguration(memory_limit = 5000)])
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Virtual devices must be set before GPUs have been initialized
    print(e)
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# 2024-05-19 10:42:43.475300: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.589958: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.590198: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.593892: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.594086: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.594256: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.670896: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.671127: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.671303: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-05-19 10:42:43.671447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5000 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:61:00.0, compute capability: 8.6

# %%
n = 10000
t = 10000
v = 2000

# %%
#hf_train = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_training_small.hdf5', 'r')
#hf_test = h5py.File('/mnt/data/HSC/HSC_v6/step3/127x127_generated.hdf5', 'r')
hf_train = h5py.File('/data/HSC/HSC_v6/step3/127x127_generated.hdf5', 'r')
hf_test = h5py.File('/data/HSC_generated/HSC_generated_v1/ddpm_extended/64x64/5x64x64_testing_1.hdf5', 'r')
hf_validation = h5py.File('/data/HSC/HSC_v6/step2A/127x127/5x127x127_validation_small.hdf5', 'r')
x_train = np.asarray(np.transpose(hf_train['image'][0:],(0,2,3,1)))
x_test = np.asarray(np.transpose(hf_test['image'][0:],(0,2,3,1)))
x_validation = np.asarray(np.transpose(hf_validation['image'][0:],(0,2,3,1)))
max_value = 4.16
x_train = np.true_divide(x_train, max_value)
x_test = np.true_divide(x_test, max_value)
x_validation = np.true_divide(x_validation, max_value)
y_train = np.asarray(hf_train['specz_redshift'][0:])[..., None]
y_test = np.asarray(hf_test['specz_redshift'][0:])[..., None]
y_validation = np.asarray(hf_validation['specz_redshift'][0:])[..., None]
hf_train.close()
hf_test.close()
hf_validation.close()

# %%
plt.imshow(x_test[0][:, :, 0])

# %%
def posterior_mean_field(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the surrogate posterior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size
    c = np.log(np.expm1(1.))

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(2 * n, dtype = dtype, initializer = lambda shape, dtype: random_gaussian_initializer(shape, dtype), trainable = True),
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t[ ..., : n],
                       scale = tf.nn.softplus(c + t[..., n:])),
            reinterpreted_batch_ndims = 1)),
    ])

def prior_trainable(kernel_size: int, bias_size: int, dtype: any) -> tf.keras.Model:
    """Specify the prior over `keras.layers.Dense` `kernel` and `bias`."""
    n = kernel_size + bias_size

    return tf.keras.Sequential([
        tfp.layers.VariableLayer(n, dtype = dtype),  # Returns a trainable variable of shape n, regardless of input
        tfp.layers.DistributionLambda(lambda t: tfd.Independent(
            tfd.Normal(loc = t, scale = 0.01),
            reinterpreted_batch_ndims = 1)),
    ])

def random_gaussian_initializer(shape, dtype):
    n = int(shape / 2)
    loc_norm = tf.random_normal_initializer(mean = 0., stddev = 0.03)
    loc = tf.Variable(
        initial_value = loc_norm(shape = (n, ), dtype = dtype)
    )
    scale_norm = tf.random_normal_initializer(mean = -3., stddev = 0.1)
    scale = tf.Variable(
        initial_value = scale_norm(shape = (n, ), dtype = dtype)
    )
    return tf.concat([loc, scale], 0)

kl_divergence_function = lambda q, p, _: kl_divergence(q, p) / n

# %%
import keras
from keras.models import Model
from tensorflow.keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, InputLayer, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D

# %%
model_variational = Sequential([
    InputLayer(input_shape = (127, 127, 5)),
    tfpl.Convolution2DFlipout(32, kernel_size=(3, 3), activation = 'tanh', kernel_divergence_fn = kl_divergence_function),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (2, 2), activation = 'tanh'),
    MaxPooling2D(2, 2),
    Conv2D(32, kernel_size = (3, 3), activation = 'relu'),
    Conv2D(32, kernel_size = (2, 2), activation = 'relu'),
    Flatten(),
    Dropout(0.2),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    tfpl.DenseVariational(64, 
                                      make_posterior_fn = posterior_mean_field,
                                      make_prior_fn = prior_trainable,
                                      kl_weight = 1 / n),
    Dense(tfpl.IndependentNormal.params_size(1)),
    tfpl.IndependentNormal(1)
])

model_variational.build((10000, 127, 127, 5))

model_variational.summary()
# Out:
# /opt/anaconda3/envs/jupyterhub/lib/python3.8/site-packages/tensorflow/python/keras/engine/base_layer.py:2191: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper (ModuleWrappe (10000, 127, 127, 5)      0
# _________________________________________________________________
# conv2d_flipout (Conv2DFlipou (10000, 125, 125, 32)     2912
# _________________________________________________________________
# module_wrapper_1 (ModuleWrap (10000, 62, 62, 32)       0
# _________________________________________________________________
# module_wrapper_2 (ModuleWrap (10000, 61, 61, 32)       4128
# _________________________________________________________________
# module_wrapper_3 (ModuleWrap (10000, 30, 30, 32)       0
# _________________________________________________________________
# module_wrapper_4 (ModuleWrap (10000, 28, 28, 32)       9248
# _________________________________________________________________
# module_wrapper_5 (ModuleWrap (10000, 27, 27, 32)       4128
# _________________________________________________________________
# module_wrapper_6 (ModuleWrap (10000, 23328)            0
# _________________________________________________________________
# module_wrapper_7 (ModuleWrap (10000, 23328)            0
# _________________________________________________________________
# dense_variational (DenseVari (10000, 64)               4479168
# _________________________________________________________________
# dense_variational_1 (DenseVa (10000, 64)               12480
# _________________________________________________________________
# module_wrapper_8 (ModuleWrap (10000, 2)                130
# _________________________________________________________________
# independent_normal (Independ multiple                  0
# =================================================================
# Total params: 4,512,194
# Trainable params: 4,512,194
# Non-trainable params: 0
# _________________________________________________________________

# %%
def loss_function(targets, estimated_distribution):
    return - estimated_distribution.log_prob(targets)

model_variational.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 0.001), loss = loss_function, metrics = [keras.metrics.RootMeanSquaredError()])

# %%
import tensorboard

model_name = 'HSC_v6_BCNN_v5'

checkpoint_filepath = os.path.join('/models/', model_name) + '/' + model_name

weights_path = os.path.join('/models/', model_name) + '/weights'

log_dir = os.path.join('/logs/', model_name)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath = checkpoint_filepath, save_weights_only = True, verbose = 1, save_freq = 150*250)

tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir = log_dir, histogram_freq = 1)

# %%
model_variational.fit(x = x_train, y = y_train, epochs = 60, shuffle = True, verbose = 1, validation_data = (x_validation, y_validation), callbacks = [tensorboard_callback, cp_callback])
# Out:
# WARNING:tensorflow:Model failed to serialize as JSON. Ignoring... Layer ModuleWrapper has arguments in `__init__` and therefore must override `get_config`.
# Epoch 1/60
# 313/313 [==============================] - 421s 16ms/step - loss: 4093.2417 - root_mean_squared_error: 3.4815 - val_loss: 3411.5034 - val_root_mean_squared_error: 2.5395
# Epoch 2/60
# 313/313 [==============================] - 4s 12ms/step - loss: 2929.3037 - root_mean_squared_error: 2.2345 - val_loss: 2512.2358 - val_root_mean_squared_error: 1.9773
# Epoch 3/60
# 313/313 [==============================] - 4s 13ms/step - loss: 2193.2473 - root_mean_squared_error: 1.8122 - val_loss: 1911.8622 - val_root_mean_squared_error: 1.6816
# Epoch 4/60
# 313/313 [==============================] - 4s 13ms/step - loss: 1682.8083 - root_mean_squared_error: 1.5825 - val_loss: 1482.5004 - val_root_mean_squared_error: 1.4946
# Epoch 5/60
# 313/313 [==============================] - 4s 13ms/step - loss: 1314.0531 - root_mean_squared_error: 1.4232 - val_loss: 1167.9337 - val_root_mean_squared_error: 1.3608
# Epoch 6/60
# 313/313 [==============================] - 4s 13ms/step - loss: 1040.0522 - root_mean_squared_error: 1.3092 - val_loss: 928.6465 - val_root_mean_squared_error: 1.2609
# Epoch 7/60
# 313/313 [==============================] - 4s 13ms/step - loss: 831.0579 - root_mean_squared_error: 1.2186 - val_loss: 749.3796 - val_root_mean_squared_error: 1.1797
# Epoch 8/60
# 313/313 [==============================] - 4s 13ms/step - loss: 668.9860 - root_mean_squared_error: 1.1487 - val_loss: 607.2599 - val_root_mean_squared_error: 1.1174
# Epoch 9/60
# 313/313 [==============================] - 4s 12ms/step - loss: 541.0962 - root_mean_squared_error: 1.0895 - val_loss: 491.3256 - val_root_mean_squared_error: 1.0635
# Epoch 10/60
# 313/313 [==============================] - 4s 13ms/step - loss: 438.9594 - root_mean_squared_error: 1.0390 - val_loss: 403.9194 - val_root_mean_squared_error: 1.0173
# Epoch 11/60
# 313/313 [==============================] - 4s 13ms/step - loss: 356.6106 - root_mean_squared_error: 0.9974 - val_loss: 330.0779 - val_root_mean_squared_error: 0.9784
# Epoch 12/60
# 313/313 [==============================] - 4s 13ms/step - loss: 289.9157 - root_mean_squared_error: 0.9610 - val_loss: 275.1848 - val_root_mean_squared_error: 0.9441
# Epoch 13/60
# 313/313 [==============================] - 4s 12ms/step - loss: 235.6056 - root_mean_squared_error: 0.9287 - val_loss: 227.7049 - val_root_mean_squared_error: 0.9138
# Epoch 14/60
# 313/313 [==============================] - 4s 13ms/step - loss: 191.1344 - root_mean_squared_error: 0.9002 - val_loss: 184.0798 - val_root_mean_squared_error: 0.8872
# Epoch 15/60
# 313/313 [==============================] - 4s 13ms/step - loss: 154.6347 - root_mean_squared_error: 0.8749 - val_loss: 156.1098 - val_root_mean_squared_error: 0.8625
# Epoch 16/60
# 313/313 [==============================] - 4s 12ms/step - loss: 124.6516 - root_mean_squared_error: 0.8507 - val_loss: 132.2672 - val_root_mean_squared_error: 0.8403
# Epoch 17/60
# 313/313 [==============================] - 4s 13ms/step - loss: 100.3513 - root_mean_squared_error: 0.8308 - val_loss: 115.4608 - val_root_mean_squared_error: 0.8214
# Epoch 18/60
# 313/313 [==============================] - 4s 13ms/step - loss: 80.2969 - root_mean_squared_error: 0.8125 - val_loss: 95.5945 - val_root_mean_squared_error: 0.8034
# Epoch 19/60
# 313/313 [==============================] - 4s 13ms/step - loss: 64.0846 - root_mean_squared_error: 0.7947 - val_loss: 73.6503 - val_root_mean_squared_error: 0.7861
# Epoch 20/60
# 313/313 [==============================] - 4s 13ms/step - loss: 50.8706 - root_mean_squared_error: 0.7779 - val_loss: 69.3898 - val_root_mean_squared_error: 0.7700
# Epoch 21/60
# 313/313 [==============================] - 4s 12ms/step - loss: 40.3418 - root_mean_squared_error: 0.7624 - val_loss: 69.8200 - val_root_mean_squared_error: 0.7549
# Epoch 22/60
# 313/313 [==============================] - 4s 12ms/step - loss: 31.9031 - root_mean_squared_error: 0.7476 - val_loss: 53.9320 - val_root_mean_squared_error: 0.7407
# Epoch 23/60
# 313/313 [==============================] - 4s 13ms/step - loss: 25.4002 - root_mean_squared_error: 0.7345 - val_loss: 54.2866 - val_root_mean_squared_error: 0.7282
# Epoch 24/60
# 313/313 [==============================] - 4s 13ms/step - loss: 20.1848 - root_mean_squared_error: 0.7219 - val_loss: 45.2544 - val_root_mean_squared_error: 0.7159
# Epoch 25/60
# 313/313 [==============================] - 4s 13ms/step - loss: 16.2887 - root_mean_squared_error: 0.7100 - val_loss: 38.3847 - val_root_mean_squared_error: 0.7044
# Epoch 26/60
# 313/313 [==============================] - 4s 12ms/step - loss: 13.2780 - root_mean_squared_error: 0.6989 - val_loss: 51.4571 - val_root_mean_squared_error: 0.6934
# Epoch 27/60
# 313/313 [==============================] - 4s 12ms/step - loss: 11.0142 - root_mean_squared_error: 0.6880 - val_loss: 57.0297 - val_root_mean_squared_error: 0.6829
# Epoch 28/60
# 313/313 [==============================] - 4s 13ms/step - loss: 9.3872 - root_mean_squared_error: 0.6779 - val_loss: 49.5130 - val_root_mean_squared_error: 0.6731
# Epoch 29/60
# 313/313 [==============================] - 4s 13ms/step - loss: 8.2402 - root_mean_squared_error: 0.6684 - val_loss: 54.3929 - val_root_mean_squared_error: 0.6637
# Epoch 30/60
# 313/313 [==============================] - 4s 13ms/step - loss: 7.5409 - root_mean_squared_error: 0.6591 - val_loss: 63.0404 - val_root_mean_squared_error: 0.6548
# Epoch 31/60
# 313/313 [==============================] - 4s 13ms/step - loss: 7.0254 - root_mean_squared_error: 0.6505 - val_loss: 40.6226 - val_root_mean_squared_error: 0.6464
# Epoch 32/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.6798 - root_mean_squared_error: 0.6423 - val_loss: 63.1157 - val_root_mean_squared_error: 0.6383
# Epoch 33/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.4393 - root_mean_squared_error: 0.6344 - val_loss: 65.5453 - val_root_mean_squared_error: 0.6305
# Epoch 34/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.2960 - root_mean_squared_error: 0.6267 - val_loss: 55.8623 - val_root_mean_squared_error: 0.6234
# Epoch 35/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.2402 - root_mean_squared_error: 0.6201 - val_loss: 71.6597 - val_root_mean_squared_error: 0.6168
# Epoch 36/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.2056 - root_mean_squared_error: 0.6135 - val_loss: 68.7852 - val_root_mean_squared_error: 0.6101
# Epoch 37/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1633 - root_mean_squared_error: 0.6067 - val_loss: 91.2404 - val_root_mean_squared_error: 0.6035
# Epoch 38/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1269 - root_mean_squared_error: 0.6003 - val_loss: 96.1634 - val_root_mean_squared_error: 0.5972
# Epoch 39/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1818 - root_mean_squared_error: 0.5941 - val_loss: 88.4095 - val_root_mean_squared_error: 0.5913
# Epoch 40/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.2028 - root_mean_squared_error: 0.5885 - val_loss: 74.5464 - val_root_mean_squared_error: 0.5857
# Epoch 41/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1634 - root_mean_squared_error: 0.5830 - val_loss: 96.2350 - val_root_mean_squared_error: 0.5802
# Epoch 42/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1759 - root_mean_squared_error: 0.5774 - val_loss: 85.1974 - val_root_mean_squared_error: 0.5748
# Epoch 43/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1480 - root_mean_squared_error: 0.5721 - val_loss: 95.8632 - val_root_mean_squared_error: 0.5695
# Epoch 44/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1661 - root_mean_squared_error: 0.5670 - val_loss: 98.8659 - val_root_mean_squared_error: 0.5645
# Epoch 45/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1837 - root_mean_squared_error: 0.5620 - val_loss: 110.8460 - val_root_mean_squared_error: 0.5596
# Epoch 46/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1891 - root_mean_squared_error: 0.5572 - val_loss: 105.0601 - val_root_mean_squared_error: 0.5549
# Epoch 47/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0825 - root_mean_squared_error: 0.5526 - val_loss: 89.4385 - val_root_mean_squared_error: 0.5504
# Epoch 48/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1898 - root_mean_squared_error: 0.5482 - val_loss: 117.9324 - val_root_mean_squared_error: 0.5461
# Epoch 49/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.1818 - root_mean_squared_error: 0.5440 - val_loss: 108.6960 - val_root_mean_squared_error: 0.5420
# Epoch 50/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0799 - root_mean_squared_error: 0.5400 - val_loss: 142.8728 - val_root_mean_squared_error: 0.5379
# Epoch 51/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0780 - root_mean_squared_error: 0.5359 - val_loss: 151.0905 - val_root_mean_squared_error: 0.5340
# Epoch 52/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0889 - root_mean_squared_error: 0.5320 - val_loss: 136.3571 - val_root_mean_squared_error: 0.5301
# Epoch 53/60
# 313/313 [==============================] - 4s 12ms/step - loss: 5.9814 - root_mean_squared_error: 0.5282 - val_loss: 138.4292 - val_root_mean_squared_error: 0.5263
# Epoch 54/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0655 - root_mean_squared_error: 0.5245 - val_loss: 159.9105 - val_root_mean_squared_error: 0.5227
# Epoch 55/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.0881 - root_mean_squared_error: 0.5209 - val_loss: 135.8223 - val_root_mean_squared_error: 0.5192
# Epoch 56/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0539 - root_mean_squared_error: 0.5175 - val_loss: 144.5683 - val_root_mean_squared_error: 0.5159
# Epoch 57/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0496 - root_mean_squared_error: 0.5142 - val_loss: 142.7195 - val_root_mean_squared_error: 0.5126
# Epoch 58/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0362 - root_mean_squared_error: 0.5110 - val_loss: 165.7105 - val_root_mean_squared_error: 0.5094
# Epoch 59/60
# 313/313 [==============================] - 4s 13ms/step - loss: 6.0226 - root_mean_squared_error: 0.5078 - val_loss: 139.8166 - val_root_mean_squared_error: 0.5062
# Epoch 60/60
# 313/313 [==============================] - 4s 12ms/step - loss: 6.0228 - root_mean_squared_error: 0.5046 - val_loss: 203.3358 - val_root_mean_squared_error: 0.5031

# %%
photoz = []

for i in range(10000):
    photoz.append(model_variational(np.array([x_test[i]])).mean()[0][0])

photoz = np.asarray(photoz).astype('float32')

# %%
specz = np.asarray(y_test)[:,0]

# %%
photoz_err = []

for i in range(t):
    photoz_err.append(model_variational(np.array([x_test[i]])).stddev()[0][0])

# %%
from scipy.stats import gaussian_kde
xy = np.asarray(np.vstack([specz, photoz])).astype('float32')
z = gaussian_kde(xy)(xy)

# %%
import seaborn as sns
z_max = 4
sns.set(rc={'figure.figsize': (10, 10), 'lines.markersize': 20})
plt.rcParams.update({'font.size': 40})
fig, ax = plt.subplots()
scatter_plot = ax.scatter(specz, photoz, c = z, s = 1, edgecolor = None)
plt.colorbar(scatter_plot, label = 'Density')
plt.title('Prediction')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max],color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
plt.show()

# %% [markdown]
# sns.set(rc={'figure.figsize':(10, 10), 'lines.markersize':20})
# plt.rcParams.update({'font.size': 100})
# sns.set(font_scale=3)
#
# data = {'BCNN':10.7, 'BNN':19.7, 'Mizuki':27.4,
#         'DEmP':25}
# models_list = list(data.keys())
# outlier_rates = list(data.values())
#
# plt.bar(models_list, outlier_rates, color=('blue', 'red', 'red', 'red'))
# plt.plot([-.5, 3.5], [15, 15], color = 'black', linestyle = 'dashed')
# plt.title("Outlier Rates")
# plt.ylabel("% Outlier Rate")
# plt.xlabel("Model Type")
# plt.show()

# %%
overlap_variational = 0
overlap_array_variational = []
for i in range(0,t):
    if np.abs(specz[i]-photoz[i])<=photoz_err[i]:
        overlap_variational += 1
        overlap_array_variational.append(1)
    else:
        overlap_array_variational.append(0)

# %%
fig, ax = plt.subplots()
display_size = 1000
scatter_plot = ax.scatter(specz[:display_size], photoz[:display_size], c = z[:display_size], s = 4, edgecolor = None, zorder = 2)
error_plot = ax.errorbar(specz[:display_size], photoz[:display_size], yerr = photoz_err[:display_size], fmt = "o", markersize = 0, color = 'blue', elinewidth = 1, zorder = 1)
plt.title('Prediction with error, Bayesian')
plt.xlabel('spectroscopic redshift')
plt.ylabel('photo z')
plt.plot([0, z_max], [0, z_max], color = 'black')
plt.xlim([0, z_max])
plt.ylim([0, z_max])
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.0546

# %%
combined_array_variational = np.transpose(np.vstack((specz, photoz, photoz_err, overlap_array_variational)))

# %%
sorted_combined_array_variational = sorted(combined_array_variational, key=lambda x: x[0])

# %%
bins_variational = int(z_max*5)
splitted_sorted_combined_array_variational = np.array_split(sorted_combined_array_variational, bins_variational)
coverage_variational = []
for i in range(0, bins_variational):
    bins_count_variational = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        if splitted_sorted_combined_array_variational[i][j][3] == 1:
            bins_count_variational += 1
    coverage_variational.append(bins_count_variational/len(splitted_sorted_combined_array_variational[i])/0.6827)
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
plt.plot(x_array, coverage_variational, c = 'red')
plt.title('Coverage, Bayesian')
plt.xlabel('spectroscopic redshift')
plt.ylabel('coverage')
plt.ylim([0, 1.5])
plt.plot([0, 4], [1, 1], color = 'black', linestyle = 'dashed')
print("Coverage: "+str(overlap_variational/t))
# Out:
# Coverage: 0.0546

# %%
mean_array = []
for i in range(0, bins_variational):
    total = 0
    for j in range(0, len(splitted_sorted_combined_array_variational[i])):
        bias = (splitted_sorted_combined_array_variational[i][j][1]-splitted_sorted_combined_array_variational[i][j][0])/(1 + splitted_sorted_combined_array_variational[i][j][0])
        total += bias/(1 + splitted_sorted_combined_array_variational[i][j][0])
    mean_array.append(total/len(splitted_sorted_combined_array_variational[i]))
x_array = np.arange(0, z_max, z_max/bins_variational)

# %%
error_array = []
for i in range(0,bins_variational):
    error_total = 0
    for j in range(0,len(splitted_sorted_combined_array_variational[i])):
        error_total += splitted_sorted_combined_array_variational[i][j][2]
    error_array.append(error_total/len(splitted_sorted_combined_array_variational[i]))

# %%
sns.set(rc={'figure.figsize':(5, 5), 'lines.markersize':40})
plt.rcParams.update({'font.size': 40})
plt.errorbar(x_array, mean_array, yerr = error_array, fmt = "o", color = 'blue', markersize = 4, elinewidth = 2)
plt.title('Bias Plot for Probabilistic Model')
plt.xlabel('True Redshift')
plt.ylabel('Bias (Predicted - True)')
plt.plot([0, z_max], [0, 0], color = 'black')
plt.plot([0, z_max], [0.003, 0.003], color = 'black', linestyle = 'dashed')
plt.plot([0, z_max], [-0.003, -0.003], color = 'black', linestyle = 'dashed')
plt.ylim([-0.1, 0.1])
plt.show()

# %%
combined_outlier_array = np.transpose(np.vstack((specz, photoz, photoz_err)))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*20)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1] - splitted_sorted_combined_outlier_array[i][j][0]) >= 3 * splitted_sorted_combined_outlier_array[i][j][2]:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

print("Outlier Rate: "+str(outlier_count_total/len(specz)))
# Out:
# Outlier Rate: 0.8364

# %%
combined_outlier_array = np.transpose(np.vstack((specz,np.subtract(photoz, specz))))
sorted_combined_outlier_array = sorted(combined_outlier_array, key=lambda x: x[0])
bins_outlier = int(z_max*10)
splitted_sorted_combined_outlier_array = np.array_split(sorted_combined_outlier_array,bins_outlier)
outlier_array = []
outlier_count_total = 0
for i in range(0,bins_outlier):
    outlier_count = 0
    for j in range(0,len(splitted_sorted_combined_outlier_array[i])):
        if np.abs(splitted_sorted_combined_outlier_array[i][j][1]/(splitted_sorted_combined_outlier_array[i][j][0] + 1)) >= .15:
            outlier_count += 1
            outlier_count_total += 1
    outlier_array.append(outlier_count/len(specz)*bins_outlier)
x_array_outlier = np.arange(0,z_max,z_max/bins_outlier)
plt.plot(x_array_outlier, outlier_array, c = 'blue')
plt.title('Outlier Rate')
plt.xlabel('spec z')
plt.ylabel('outlier rate')
plt.xlim([0,z_max])
plt.ylim([0,1/2])
plt.show()

print("Outlier Rate: "+str(outlier_count_total/len(specz)))
# Out:
# Outlier Rate: 0.6444

# %%
photoz_utils.save_with_oid_std(model_name, object_id, specz, photoz, photoz_err)
photoz_utils.save_train_with_oid_std(model_name, object_id_train, specz_train, photoz_train, photoz_err_train)
photoz_utils.save_validation_with_oid_std(model_name, object_id_validation, specz_validation, photoz_validation, photoz_err_validation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-0d3e80b2a734> in <module>
# ----> 1 photoz_utils.save_with_oid_std(model_name, object_id, specz, photoz, photoz_err)
#       2 photoz_utils.save_train_with_oid_std(model_name, object_id_train, specz_train, photoz_train, photoz_err_train)
#       3 photoz_utils.save_validation_with_oid_std(model_name, object_id_validation, specz_validation, photoz_validation, photoz_err_validation)
#
# NameError: name 'photoz_utils' is not defined

# %%
uncertains = []
for i in range(0, len(photoz_err)):
    if photoz_err[i].numpy() >= 1:
        uncertains.append(i)
        print("Object ID: " + str(object_id[i]) + ", Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check = 2
current = uncertains[check]
print("Object ID: " + str(object_id[current]) + ", Spectro_z: " + str(specz[current]) + ", Photo_z: " + str(photoz[current]) + ", Photo_z_err: " + str(photoz_err[current].numpy()))
plt.imshow(x_test[current][:,:,0])
plt.grid(False)

# %%
biases = []
for i in range(0, len(photoz)):
    if np.abs(photoz[i]-specz[i]) >= 1 and photoz_err[i].numpy() <= 0.5:
        biases.append(i)
        print("Object ID: " + str(object_id[i]) + ", Spectro_z: " + str(specz[i]) + ", Photo_z: " + str(photoz[i]) + ", Photo_z_err: " + str(photoz_err[i].numpy()))

# %%
check_bias = 3
current_bias = biases[check_bias]
print("Object ID: " + str(object_id[current_bias]) + ", Spectro_z: " + str(specz[current_bias]) + ", Photo_z: " + str(photoz[current_bias]) + ", Photo_z_err: " + str(photoz_err[current_bias].numpy()))
plt.imshow(x_test[current_bias][:,:,0])
plt.grid(False)

# %%
# END
